# %% [markdown]
# ### Installations

# %%
# !pip install holidays
# Out:
# Requirement already satisfied: holidays in c:\users\sydod\anaconda3\lib\site-packages (0.77)
# Requirement already satisfied: python-dateutil in c:\users\sydod\anaconda3\lib\site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sydod\anaconda3\lib\site-packages (from python-dateutil->holidays) (1.17.0)

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import calendar
from datetime import date, timedelta
import matplotlib.pyplot as plt
import argparse

try:
    import holidays
except ImportError:
    raise ImportError("Please install the 'holidays' library: pip install holidays")

# %% [markdown]
# ### Load Templates

# %%
dfFixtures_template = pd.read_csv('Input/fixtureTable.csv', dayfirst=True, parse_dates=['date'])  # unshifted
dfTeams_base = pd.read_csv('Input/teamTable.csv')            # no attributes
dfCompetitions = pd.read_csv('Input/competitionTable.csv')

# %% [markdown]
# ### Helper Functions for Date Shift

# %%
import pandas as pd
import calendar
from datetime import date
from typing import Optional
import holidays

# -----------------------------------------------------------------------------
# 1. Initialize UK Holiday Engine (Dynamic Year Support)
# -----------------------------------------------------------------------------
def get_uk_holiday_name(dt: date) -> Optional[str]:
    return holidays.UK(years=dt.year).get(dt)

def find_holiday_date_by_name(target_year: int, holiday_name: str) -> Optional[date]:
    """
    Look up the date of a holiday in the target year by its name.
    """
    target_holidays = holidays.UK(years=target_year)
    for dt, name in target_holidays.items():
        if name == holiday_name:
            return dt
    return None


# -----------------------------------------------------------------------------
# 2. Weekday Ordinal Preservation Logic
# -----------------------------------------------------------------------------
def get_ordinal_weekday(dt: date) -> int:
    """Return the 1-based occurrence of dt.weekday() in dt.month."""
    month_cal = calendar.monthcalendar(dt.year, dt.month)
    weekday = dt.weekday()
    occurrences = [week[weekday] for week in month_cal if week[weekday] != 0]
    for i, day in enumerate(occurrences, start=1):
        if day == dt.day:
            return i
    raise ValueError(f"Could not determine ordinal for date {dt}")


def find_nth_weekday(year: int, month: int, weekday: int, ordinal: int) -> date:
    """Find the date of the ordinal-th weekday in the given month/year."""
    month_cal = calendar.monthcalendar(year, month)
    occurrences = [week[weekday] for week in month_cal if week[weekday] != 0]
    if not occurrences:
        raise ValueError(f"No occurrences of weekday {weekday} in {month}/{year}")
    if ordinal <= len(occurrences):
        day = occurrences[ordinal - 1]
    else:
        day = occurrences[-1]
    return date(year, month, day)


# -----------------------------------------------------------------------------
# 3. Shift Logic with Holiday + Weekday Ordinal Fallback
# -----------------------------------------------------------------------------
def shift_fixture_date(original_date: date, target_year: int) -> date:
    """
    Shift a single date into target_year, preserving bank holidays and weekday ordinals.
    """
    orig_holiday = get_uk_holiday_name(original_date)
    if orig_holiday:
        holiday_match = find_holiday_date_by_name(target_year, orig_holiday)
        if holiday_match:
            return holiday_match

    ordinal = get_ordinal_weekday(original_date)
    return find_nth_weekday(
        target_year,
        original_date.month,
        original_date.weekday(),
        ordinal
    )


# -----------------------------------------------------------------------------
# 4. Rebase Fixture Dates
# -----------------------------------------------------------------------------
def rebase_fixtures(df: pd.DataFrame, target_start_year: int) -> pd.DataFrame:
    """
    Rebase fixture dates in `df` to a new season starting in `target_start_year`.
    """
    df_new = df.copy()
    if 'round' in df_new.columns:
        df_new.drop(columns=['round'], inplace=True)

    df_new['date'] = pd.to_datetime(df_new['date'], errors='coerce')
    original_start_year = int(df_new['date'].dt.year.min())

    def _shift(ts):
        if pd.isna(ts):
            return pd.NaT
        orig = ts.date()
        year_offset = orig.year - original_start_year
        new_year = target_start_year + year_offset
        return shift_fixture_date(orig, new_year)

    df_new['date'] = df_new['date'].apply(_shift)
    df_new['date'] = df_new['date'].apply(
        lambda d: d.strftime('%Y-%m-%d') if pd.notna(d) else pd.NaT
    )

    return df_new

# -----------------------------------------------------------------------------
# 5. Entry Point: Fixture Creation for a Season
# -----------------------------------------------------------------------------
def create_fixture_list(year: int) -> pd.DataFrame:
    """Create rebased fixture list for a new season."""
    return rebase_fixtures(dfFixtures_template.copy(), year)

# %% [markdown]
# ### Helper Functions for Team Attributes

# %%
import pandas as pd
import random

def position_to_attribute(pos: int, min_val: float, max_val: float, min_rank: int, max_rank: int, ascending=True) -> float:
    """
    Linearly scale attribute from min_val to max_val over [min_rank, max_rank].
    If ascending=False, scales from max_val to min_val instead.
    """
    pos = max(min_rank, min(pos, max_rank))
    scale = (pos - min_rank) / (max_rank - min_rank) if max_rank > min_rank else 0
    if not ascending:
        scale = 1.0 - scale
    return round(min_val + (max_val - min_val) * scale, 2)


def assign_team_attributes(df: pd.DataFrame, seed: int = None) -> pd.DataFrame:
    """
    Assigns 'defense', 'midfield', and 'attack' attributes based on 'lastPos'.
    """
    rng = random.Random(seed)
    df_out = df.copy()

    def compute_attributes(row):
        pos = row['lastPos']
        if 1 <= pos <= 116:
            base = position_to_attribute(pos, min_val=1.0, max_val=8.5, min_rank=1, max_rank=116, ascending=False)
            variation = 0.75
        elif 117 <= pos <= 120:
            base = position_to_attribute(pos, min_val=6.0, max_val=8.0, min_rank=117, max_rank=120, ascending=True)
            variation = 0.5
        elif 121 <= pos <= 124:
            base = position_to_attribute(pos, min_val=7.0, max_val=9.0, min_rank=121, max_rank=124, ascending=True)
            variation = 0.5
        else:
            base = 5.0
            variation = 0.5

        return {
            'defense': round(base + rng.uniform(-variation, variation), 2),
            'midfield': round(base + rng.uniform(-variation, variation), 2),
            'attack': round(base + rng.uniform(-variation, variation), 2)
        }

    attributes = df_out.apply(compute_attributes, axis=1, result_type='expand')
    df_out[['defense', 'midfield', 'attack']] = attributes
    return df_out

def generate_team_attributes() -> pd.DataFrame:
    """Generate team attributes from base lastPos table."""
    return assign_team_attributes(dfTeams_base.copy())

# %% [markdown]
# ### Match Engine

# %%
import pandas as pd
import random
from typing import Tuple

def rnd_num() -> float:
    """Return a random number between 0 and 1."""
    return random.uniform(0, 1)

def goal_chance() -> int:
    """40% chance to score a goal."""
    return 1 if rnd_num() > 0.6 else 0

def get_team_attributes(team_id: int, df: pd.DataFrame) -> list:
    """Get defense, midfield, attack as a list for given team ID."""
    row = df.loc[df['teamID'] == team_id]
    if row.empty:
        raise ValueError(f"Team ID {team_id} not found in dataframe.")
    return [row.iloc[0]['defense'], row.iloc[0]['midfield'], row.iloc[0]['attack']]

def play_match_half(team1: list, team2: list) -> list:
    """
    Simulates one half of a football match between two teams.
    Each team is a list of 3 attributes: [def, mid, att]
    """
    match_seq = list(range(1, 13))
    random.shuffle(match_seq)

    result = [0, 0]  # [home_goals, away_goals]

    for index in range(1, 11):
        if match_seq[0] == index and team1[2] > team2[0] and (random.random() * team1[2]) > (random.random() * team2[0]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[6] == index and (random.random() * team1[2]) > (random.random() * team2[0]) and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[1] == index and team2[2] > team1[0] and (random.random() * team2[2]) > (random.random() * team1[0]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[7] == index and (random.random() * team1[2]) > (random.random() * team1[0]) and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[2] == index and team1[1] > team2[1] and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[8] == index and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[3] == index and team2[1] > team1[1] and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[9] == index and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[4] == index and random.random() > 0.45:
            result[0] += 1 if random.random() > 0.6 else 0

    return result

def play_full_match(team1_id: int, team2_id: int, df: pd.DataFrame) -> list:
    """
    Play a full match between two teams and return the result [goals_team1, goals_team2].
    """
    team1 = get_team_attributes(team1_id, df)
    team2 = get_team_attributes(team2_id, df)

    first_half = play_match_half(team1, team2)
    second_half = play_match_half(team1, team2)

    final_result = [first_half[0] + second_half[0], first_half[1] + second_half[1]]
    return final_result

import random

def simulate_penalties(home_team_id: int, away_team_id: int, dfTeams) -> tuple:
    """
    Run a simple 5‐kick penalty shootout for each team, then sudden death if still tied.
    Returns: (home_pk_goals, away_pk_goals, winner_id).
    """
    # Get [defense, midfield, attack] for each side
    attrs_home = get_team_attributes(home_team_id, dfTeams)  # → list [def, mid, att]
    attrs_away = get_team_attributes(away_team_id, dfTeams)

    # Use 'attack' at index 2, and 'defense' at index 0
    home_att = attrs_home[2]
    home_def = attrs_home[0]
    away_att = attrs_away[2]
    away_def = attrs_away[0]

    # Base penalty conversion probability: blend of home_att vs away_def
    base_prob_home = 0.8 * (home_att / (home_att + away_def)) + 0.2
    base_prob_away = 0.8 * (away_att / (away_att + home_def)) + 0.2

    # Clamp between [0.5, 0.95]
    base_prob_home = min(max(base_prob_home, 0.5), 0.95)
    base_prob_away = min(max(base_prob_away, 0.5), 0.95)

    def take_five_kicks(p_success: float) -> int:
        """Simulate exactly 5 penalty kicks given success probability p_success."""
        made = 0
        for _ in range(5):
            if random.random() < p_success:
                made += 1
        return made

    # 1) First 5 kicks each
    home_score = take_five_kicks(base_prob_home)
    away_score = take_five_kicks(base_prob_away)

    # 2) Sudden death if still tied
    while home_score == away_score:
        if random.random() < base_prob_home:
            home_score += 1
        if random.random() < base_prob_away:
            away_score += 1
        # repeat until one is ahead

    winner_id = home_team_id if home_score > away_score else away_team_id
    return home_score, away_score, winner_id

def play_cup_match(home_team_id: int, away_team_id: int, dfTeams):
    """
    Simulate a single cup tie:
      1) Play 90′ via play_full_match(...)
      2) If draw, run one “extra‐time half” via play_match_half(...)
      3) If still draw, run penalties via simulate_penalties(...)
    Returns a dict with:
      - home_goals (FT + ET)
      - away_goals (FT + ET)
      - winner_id
      - extra_time_played (bool)
      - home_et_goals, away_et_goals (ints; zero if no ET)
      - home_pk, away_pk (ints; None if no shootout)
    """
    # 1) Full‐time (90′)
    home_ft, away_ft = play_full_match(home_team_id, away_team_id, dfTeams)

    # If someone wins in 90′, skip ET/PK
    if home_ft != away_ft:
        winner = home_team_id if home_ft > away_ft else away_team_id
        return {
            "home_goals": home_ft,
            "away_goals": away_ft,
            "winner_id":  winner,
            "extra_time_played": False,
            "home_et_goals": 0,
            "away_et_goals": 0,
            "home_pk":      None,
            "away_pk":      None
        }

    # 2) Extra‐time: simulate one “half” of 45′ via play_match_half(...)
    # (This effectively approximates a 30′ ET; you can adjust scaling later if needed.)
    et_home, et_away = play_match_half(
        get_team_attributes(home_team_id, dfTeams),
        get_team_attributes(away_team_id, dfTeams)
    )
    home_total = home_ft + et_home
    away_total = away_ft + et_away

    # If someone wins in ET, skip penalties
    if home_total != away_total:
        winner = home_team_id if home_total > away_total else away_team_id
        return {
            "home_goals": home_total,
            "away_goals": away_total,
            "winner_id":  winner,
            "extra_time_played": True,
            "home_et_goals":  et_home,
            "away_et_goals":  et_away,
            "home_pk":       None,
            "away_pk":       None
        }

    # 3) Penalty shootout
    home_pk, away_pk, winner = simulate_penalties(home_team_id, away_team_id, dfTeams)
    return {
        "home_goals": home_total,
        "away_goals": away_total,
        "winner_id":  winner,
        "extra_time_played": True,
        "home_et_goals":  et_home,
        "away_et_goals":  et_away,
        "home_pk":       home_pk,
        "away_pk":       away_pk
    }

# %% [markdown]
# ### Helper Function to Initialise Cup Status

# %%
import random

def initialize_cup_status(dfTeams):
    """
    Reset and set initial cup‐eligibility flags based on last season’s results:
      - inCS: Community Shield (league winner & FA Cup winner)
      - inCL: Champions League (top‐4 English, CL winner override; plus direct qualifiers lastPos ∈ {121–124})
      - inEL: Europa League (4 English slots: FA & LC winners + next best by position; 
                             plus direct qualifiers lastPos ∈ {117–120})
      - inFA: FA Cup R1 (teamID 45–92 direct; + 32 random from teamID 93–134)
      - inLC: League Cup (teamID 21–92)
    """
    # 0) Ensure lastPos is integer
    dfTeams['lastPos'] = dfTeams['lastPos'].astype(int)

    # 1) Reset all flags
    for col in ['inCS','inCL','inEL','inFA','inLC']:
        dfTeams[col] = False

    # 2) Community Shield: English league winner & FA Cup winner
    cs_mask = (
        (dfTeams['nationality']=='ENG') &
        ((dfTeams['lastPos']==1) | (dfTeams['faCupWin']==True))
    )
    dfTeams.loc[cs_mask, 'inCS'] = True

    # 3) Champions League (English slots)
    eng = dfTeams['nationality']=='ENG'
    cl_winner = dfTeams[eng & (dfTeams['clCupWin']==True)]
    if not cl_winner.empty:
        wid = cl_winner['teamID'].iat[0]
        dfTeams.loc[dfTeams['teamID']==wid, 'inCL'] = True
        others = dfTeams[eng & (dfTeams['teamID']!=wid)].nsmallest(3, 'lastPos')
        dfTeams.loc[others.index, 'inCL'] = True
    else:
        top4 = dfTeams[eng].nsmallest(4, 'lastPos')
        dfTeams.loc[top4.index, 'inCL'] = True
    # 3b) Direct CL qualifiers by lastPos codes 121–124
    dfTeams.loc[dfTeams['lastPos'].isin([121,122,123,124]), 'inCL'] = True

    # 4) Europa League (English slots)
    el_winners = dfTeams[
        eng &
        ((dfTeams['faCupWin']==True) | (dfTeams['lcCupWin']==True)) &
        (~dfTeams['inCL'])
    ]['teamID'].tolist()
    dfTeams.loc[dfTeams['teamID'].isin(el_winners), 'inEL'] = True

    # 4b) Top-up English EL slots to 4 by best lastPos among ENG not inCL/EL
    curr = dfTeams[(eng) & (dfTeams['inEL']==True)].shape[0]
    if curr < 4:
        needed = 4 - curr
        fill = dfTeams[
            eng & (~dfTeams['inCL']) & (~dfTeams['inEL'])
        ].nsmallest(needed, 'lastPos')
        dfTeams.loc[fill.index, 'inEL'] = True

    # 4c) Direct EL qualifiers by lastPos codes 117–120
    dfTeams.loc[dfTeams['lastPos'].isin([117,118,119,120]), 'inEL'] = True

    # 5) FA Cup R1: teamID 45–92 direct + random 32 from teamID 93–134
    direct_ids = dfTeams.loc[dfTeams['teamID'].between(45, 92), 'teamID'].tolist()
    pool_ids   = dfTeams.loc[dfTeams['teamID'].between(93, 134), 'teamID'].tolist()
    if len(pool_ids) < 32:
        raise ValueError(f"Not enough teams in 93–134 to pick 32; found {len(pool_ids)}")
    fa_qual = random.sample(pool_ids, 32)
    dfTeams.loc[dfTeams['teamID'].isin(direct_ids + fa_qual), 'inFA'] = True

    # 6) League Cup: teamID 21–92
    dfTeams.loc[dfTeams['teamID'].between(21, 92), 'inLC'] = True

    # 7) Summary
    print("✅ Initialized cup status:")
    print(f"  inCS: {dfTeams['inCS'].sum()} teams")
    print(f"  inCL: {dfTeams['inCL'].sum()} teams")
    print(f"  inEL: {dfTeams['inEL'].sum()} teams")
    print(f"  inFA: {dfTeams['inFA'].sum()} teams")
    print(f"  inLC: {dfTeams['inLC'].sum()} teams")

    return dfTeams

# %% [markdown]
# ### Helper Functions for League Round

# %%
'''
def play_league_round(day: int,
                      dfFixtures: pd.DataFrame,
                      dfTeams: pd.DataFrame,
                      dfCompetitions: pd.DataFrame,
                      dfGroupStage: pd.DataFrame = None) -> pd.DataFrame:
    """
    Plays all league‐style fixtures (domestic + UCL/EL group‐stage) for a given dayCounter,
    updates dfFixtures in‐place, prints results by competition, then:
      1) Recompute domestic tables (comps 1–5)
      2) If dfGroupStage is provided and EL (8) matches were played, recompute EL tables
      3) If dfGroupStage is provided and UCL (9) matches were played, recompute UCL tables
    """

    # 1) Build a “not played” mask treating NaN as False
    not_played_mask = ~dfFixtures['played'].fillna(False)

    # 2) Include domestic (1–5), EL (8), UCL (9)
    valid_comp_ids = [1, 2, 3, 4, 5, 8, 9]

    day_fixtures = dfFixtures[
        (dfFixtures['dayCounter'] == day) &
        (not_played_mask) &
        (dfFixtures['competitionID'].isin(valid_comp_ids))
    ].copy()

    if day_fixtures.empty:
        print(f"No league/group‐stage fixtures scheduled or all already played for day {day}.")
        return dfFixtures

    # 3) Build lookup maps
    team_name_map = dfTeams.set_index('teamID')['teamName'].to_dict()
    comp_name_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    results_by_comp = {}
    match_date = day_fixtures.iloc[0]['date']

    # Track which competitions had a match today
    comps_played_today = set()

    for idx, match in day_fixtures.iterrows():
        home_id = match['homeTeam']
        away_id = match['awayTeam']
        comp_id = match['competitionID']

        # Simulate 90' only
        home_goals, away_goals = play_full_match(home_id, away_id, dfTeams)

        # Update dfFixtures
        dfFixtures.at[idx, 'homeGoals'] = home_goals
        dfFixtures.at[idx, 'awayGoals'] = away_goals
        dfFixtures.at[idx, 'played'] = True

        comps_played_today.add(comp_id)

        # Format for printing
        home_name = team_name_map.get(home_id, f"Team{home_id}")
        away_name = team_name_map.get(away_id, f"Team{away_id}")
        comp_name = comp_name_map.get(comp_id, f"Competition{comp_id}")
        line = f"{home_name} {home_goals} - {away_goals} {away_name}"
        results_by_comp.setdefault(comp_id, []).append(line)

    # 4) Print results sorted by competitionID
    print(f"\nMatches played on {match_date}:")
    for comp_id in sorted(results_by_comp.keys()):
        comp_name = comp_name_map.get(comp_id, f"Competition{comp_id}")
        print(comp_name)
        for line in results_by_comp[comp_id]:
            print(line)

    # 5) Recompute domestic league tables (1–5)
    update_tables()

    # 6) If dfGroupStage is provided, update EL/UCL group tables as needed
    if dfGroupStage is not None:
        # Europa League (comp 8)
        if 8 in comps_played_today:
            global el_tables
            el_tables = generate_euro_group_tables(
                competitionID=8,
                dfFixtures=dfFixtures,
                dfTeams=dfTeams,
                dfGroupStage=dfGroupStage
            )
         
        # Champions League (comp 9)
        if 9 in comps_played_today:
            global ucl_tables
            ucl_tables = generate_euro_group_tables(
                competitionID=9,
                dfFixtures=dfFixtures,
                dfTeams=dfTeams,
                dfGroupStage=dfGroupStage
            )
          
    return dfFixtures

    '''

def play_league_round(day: int,
                      dfFixtures: pd.DataFrame,
                      dfTeams: pd.DataFrame,
                      dfCompetitions: pd.DataFrame) -> pd.DataFrame:
    """
    Plays all domestic league fixtures (comps 1–5) for a given dayCounter,
    updates dfFixtures in-place, prints results by competition, then
    recomputes domestic tables.
    """
    # 1) Build “not played” mask
    not_played = ~dfFixtures['played'].fillna(False)

    # 2) Filter for domestic comps only
    dom_ids = [1, 2, 3, 4, 5]
    day_fixtures = dfFixtures[
        (dfFixtures['dayCounter'] == day) &
        (not_played) &
        (dfFixtures['competitionID'].isin(dom_ids))
    ].copy()

    if day_fixtures.empty:
        print(f"No domestic league fixtures for day {day}.")
        return dfFixtures

    # 3) Maps for printing
    team_map = dfTeams.set_index('teamID')['teamName'].to_dict()
    comp_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    results = {}
    date = day_fixtures.iloc[0]['date']

    for idx, m in day_fixtures.iterrows():
        hid, aid = m['homeTeam'], m['awayTeam']
        gh, ga = play_full_match(hid, aid, dfTeams)
        dfFixtures.at[idx,'homeGoals'] = gh
        dfFixtures.at[idx,'awayGoals'] = ga
        dfFixtures.at[idx,'played'] = True

        cid = m['competitionID']
        results.setdefault(cid, []).append(
            f"{team_map[hid]} {gh} - {ga} {team_map[aid]}"
        )

    print(f"\nDomestic matches on {date}:")
    for cid in sorted(results):
        print(comp_map[cid])
        for line in results[cid]: print(line)

    # 4) Update domestic league tables
    update_tables()
    return dfFixtures


def play_european_league(day: int,
                         dfFixtures: pd.DataFrame,
                         dfTeams: pd.DataFrame,
                         dfCompetitions: pd.DataFrame,
                         dfGroupStage: pd.DataFrame) -> pd.DataFrame:
    """
    Plays all European group-stage fixtures (comps 8,9) for a given dayCounter,
    updates dfFixtures in-place, prints results, then regenerates the
    corresponding EL or UCL tables.
    """
    # 1) Not-played mask
    not_played = ~dfFixtures['played'].fillna(False)

    # 2) Filter for Europa (8) and Champions (9)
    euro_ids = [8, 9]
    day_fixtures = dfFixtures[
        (dfFixtures['dayCounter'] == day) &
        (not_played) &
        (dfFixtures['competitionID'].isin(euro_ids))
    ].copy()

    if day_fixtures.empty:
        print(f"No European group matches for day {day}.")
        return dfFixtures

    team_map = dfTeams.set_index('teamID')['teamName'].to_dict()
    comp_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    results = {}
    date = day_fixtures.iloc[0]['date']
    played_comps = set()

    for idx, m in day_fixtures.iterrows():
        hid, aid = m['homeTeam'], m['awayTeam']
        gh, ga = play_full_match(hid, aid, dfTeams)
        dfFixtures.at[idx,'homeGoals'] = gh
        dfFixtures.at[idx,'awayGoals'] = ga
        dfFixtures.at[idx,'played'] = True
        cid = m['competitionID']
        played_comps.add(cid)
        results.setdefault(cid, []).append(
            f"{team_map[hid]} {gh} - {ga} {team_map[aid]}"
        )

    # 3) Print
    print(f"\nEuropean matches on {date}:")
    for cid in sorted(results):
        print(comp_map[cid])
        for line in results[cid]: print(line)

    # 4) Regenerate group tables
    if 8 in played_comps:
        global el_tables
        el_tables = generate_euro_group_tables(
            competitionID=8,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfGroupStage=dfGroupStage
        )
    if 9 in played_comps:
        global ucl_tables
        ucl_tables = generate_euro_group_tables(
            competitionID=9,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfGroupStage=dfGroupStage
        )

    return dfFixtures

# %% [markdown]
# ### Helper Functions for League Tables

# %%
def generate_league_tables(dfFixtures: pd.DataFrame, dfTeams: pd.DataFrame) -> dict:
    """
    Generate league tables for CompetitionIDs 1 to 5, ensuring all teams are included even if they haven't played.
    Removes teamID and formats GF, GA, GD as integers.

    Returns:
        Dictionary {competitionID: league_table_df}
    """
    league_tables = {}

    for comp_id in range(1, 6):
        # Get all teams in this competition (home and away)
        teams_in_league = pd.unique(
            dfFixtures[dfFixtures['competitionID'] == comp_id][['homeTeam', 'awayTeam']].values.ravel()
        )

        # Initialize stats
        team_stats = {
            team_id: {'MP': 0, 'W': 0, 'D': 0, 'L': 0, 'GF': 0, 'GA': 0, 'Points': 0}
            for team_id in teams_in_league
        }

        # Played matches only
        league_matches = dfFixtures[
            (dfFixtures['competitionID'] == comp_id) & (dfFixtures['played'])
        ]

        # Accumulate stats
        for _, match in league_matches.iterrows():
            h_id, a_id = match['homeTeam'], match['awayTeam']
            hg, ag = match['homeGoals'], match['awayGoals']

            # Home update
            team_stats[h_id]['MP'] += 1
            team_stats[h_id]['GF'] += hg
            team_stats[h_id]['GA'] += ag
            # Away update
            team_stats[a_id]['MP'] += 1
            team_stats[a_id]['GF'] += ag
            team_stats[a_id]['GA'] += hg

            if hg > ag:
                team_stats[h_id]['W'] += 1
                team_stats[h_id]['Points'] += 3
                team_stats[a_id]['L'] += 1
            elif hg == ag:
                team_stats[h_id]['D'] += 1
                team_stats[a_id]['D'] += 1
                team_stats[h_id]['Points'] += 1
                team_stats[a_id]['Points'] += 1
            else:
                team_stats[a_id]['W'] += 1
                team_stats[a_id]['Points'] += 3
                team_stats[h_id]['L'] += 1

        # Build rows
        rows = []
        for team_id in teams_in_league:
            stats = team_stats[team_id]
            team_name = dfTeams.loc[dfTeams['teamID'] == team_id, 'teamName'].values[0]
            gd = stats['GF'] - stats['GA']
            rows.append({
                'teamName': team_name,
                'MP': stats['MP'],
                'W': stats['W'],
                'D': stats['D'],
                'L': stats['L'],
                'GF': int(round(stats['GF'])),
                'GA': int(round(stats['GA'])),
                'GD': int(round(gd)),
                'Points': stats['Points']
            })

        league_df = pd.DataFrame(rows)
        league_df = league_df.sort_values(by=['Points', 'GD', 'GF'], ascending=False).reset_index(drop=True)
        league_df.insert(0, 'Position', league_df.index + 1)

        league_tables[comp_id] = league_df

    return league_tables


def print_all_league_tables(league_tables: dict, dfCompetitions: pd.DataFrame):
    """
    Pretty print all league tables with their competition names as headers.

    Parameters:
        league_tables: Dict {competitionID: league DataFrame}
        dfCompetitions: DataFrame containing competitionID and competitionName
    """
    # Build a mapping from competitionID to name
    comp_name_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    for comp_id in sorted(league_tables.keys()):
        table = league_tables[comp_id]
        comp_name = comp_name_map.get(comp_id, f"Competition {comp_id}")

        print(f"\n{comp_name}")
        print(table.to_string(index=False))

# %% [markdown]
# ### Helper Functions for Cup Rounds

# %%
def play_cup_round(dayCounter, competitionID, dfFixtures, dfTeams):
    """
    Simulate every unplayed cup fixture on each day in 'dayCounter' for competitionID,
    writing the following into dfFixtures for each match:
      - homeGoals, awayGoals: total goals after 90' + ET (if any)
      - homeGoalsAET, awayGoalsAET: extra‐time goals
      - homePens, awayPens: penalty goals (None if no shootout)
      - played: True once done
    Prints a summary including “(a.e.t.)” or “[p x–y]” as needed.
    """
    # 1) Look up competition name (uses global dfCompetitions)
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == competitionID,
        'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

    # 2) Parse dayCounter into a list of ints
    if isinstance(dayCounter, str):
        days = [int(x.strip()) for x in dayCounter.split(',') if x.strip().isdigit()]
    elif isinstance(dayCounter, (list, tuple)):
        days = [int(x) for x in dayCounter]
    else:
        days = [int(dayCounter)]

    all_winners = []
    for day in days:
        # 3) Filter for unplayed cup fixtures on this day & competition
        mask = (
            (dfFixtures['dayCounter']   == day) &
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['played']        == False)
        )
        todays_matches = dfFixtures.loc[mask].copy()
        if todays_matches.empty:
            print(f"No fixtures to play on day {day} for '{comp_name}'")
            continue

        for idx, match in todays_matches.iterrows():
            # skip any blank placeholder
            if pd.isna(match['homeTeam']) or pd.isna(match['awayTeam']):
                print(f"❌ Skipping empty slot on day {day} for '{comp_name}' at index {idx}")
                continue

            home_id = int(match['homeTeam'])
            away_id = int(match['awayTeam'])

            # Simulate 90′ + ET + penalties
            result = play_cup_match(home_id, away_id, dfTeams)
            all_winners.append(result['winner_id'])

            # 4) Write results back into dfFixtures
            dfFixtures.at[idx, 'homeGoals']     = result['home_goals']
            dfFixtures.at[idx, 'awayGoals']     = result['away_goals']
            dfFixtures.at[idx, 'homeGoalsAET']  = result['home_et_goals']
            dfFixtures.at[idx, 'awayGoalsAET']  = result['away_et_goals']
            dfFixtures.at[idx, 'homePens']      = result['home_pk']
            dfFixtures.at[idx, 'awayPens']      = result['away_pk']
            dfFixtures.at[idx, 'played']        = True

            # 5) Print summary line
            home_name   = dfTeams.loc[dfTeams['teamID']==home_id, 'teamName'].iat[0]
            away_name   = dfTeams.loc[dfTeams['teamID']==away_id, 'teamName'].iat[0]
            winner_name = dfTeams.loc[dfTeams['teamID']==result['winner_id'], 'teamName'].iat[0]

            suffix = ""
            if result['extra_time_played']:
                suffix += " (a.e.t.)"
            if result['home_pk'] is not None and result['away_pk'] is not None:
                suffix += f" [p {result['home_pk']}–{result['away_pk']}]"

            print(
                f"Day {day} | {comp_name} | "
                f"{home_name} {result['home_goals']}–{result['away_goals']} {away_name}"
                f"{suffix} → Winner: {winner_name}"
            )

    return all_winners

# %% [markdown]
# ### Generic Cup Draw

# %%
import random

def draw_cup(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic cup‐draw function for:
      • Community Shield   (competitionID=10, flag 'inCS', exactly 2 teams)
      • League Cup         (competitionID=6,  flag 'inLC', even-numbered field)
      • FA Cup Round 1     (competitionID=7,  flag 'inFA', even-numbered field)
      • Europa League KO   (competitionID=8,  flag 'inEL', even-numbered field)
      • Champions League KO(competitionID=9,  flag 'inCL', even-numbered field)

    Assumes dfTeams['inXX'] flags have already been set for that competition.
    1) Read comp_id, look up its flag column.
    2) Select all dfTeams where that flag is True.
       • If comp_id == 10, require exactly 2.
       • Otherwise require an even number.
    3) Shuffle and pair off in order.
    4) Parse allowed_days from row['dayCounter'] (comma-sep ints).
    5) In dfFixtures, find blank fixtures for this comp on those days:
       competitionID == comp_id, dayCounter ∈ allowed_days,
       homeTeam/isnull & awayTeam/isnull.
    6) Fill the first N placeholders with your pairs.
    7) Print a summary.
    """
    comp_id = int(row['competitionID'])
    comp_name = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id, 'competitionName'
    ].iat[0]

    # 1) Hard-coded mapping of competition → which inXX column to use
    comp_flag_map = {
        10: 'inCS',
        6: 'inLC',
        7: 'inFA',
        8: 'inEL',
        9: 'inCL'
    }
    if comp_id not in comp_flag_map:
        print(f"❌ No cup-draw configured for competitionID {comp_id}")
        return
    flag_col = comp_flag_map[comp_id]

    # 2) Gather eligible teams
    eligible = dfTeams[dfTeams[flag_col] == True].copy()
    n = len(eligible)
    if comp_id == 10:
        if n != 2:
            print(f"❌ Error: Community Shield needs 2 teams, found {n}")
            return
    else:
        if n % 2 != 0:
            print(f"❌ Error: {comp_name} needs an even number of teams, found {n}")
            return

    # 3) Shuffle and pair
    team_ids = eligible['teamID'].tolist()
    random.shuffle(team_ids)
    pairs = [(team_ids[i], team_ids[i+1]) for i in range(0, len(team_ids), 2)]

    # 4) Parse allowed_days
    allowed_days = [
        int(d.strip()) for d in str(row['dayCounter']).split(',')
        if d.strip().isdigit()
    ]
    if not allowed_days:
        print(f"❌ Error: No valid dayCounters provided for {comp_name}")
        return

    # 5) Find blank fixtures
    mask = (
        (dfFixtures['competitionID'] == comp_id) &
        (dfFixtures['dayCounter'].isin(allowed_days)) &
        (dfFixtures['homeTeam'].isnull()) &
        (dfFixtures['awayTeam'].isnull())
    )
    open_fx = dfFixtures.loc[mask]
    if len(open_fx) < len(pairs):
        print(f"❌ Error: Not enough blank fixtures for {comp_name}: "
              f"needed {len(pairs)}, found {len(open_fx)}")
        return

    # 6) Fill placeholders
    for (home_tid, away_tid), idx in zip(pairs, open_fx.index):
        dfFixtures.at[idx, 'homeTeam'] = home_tid
        dfFixtures.at[idx, 'awayTeam'] = away_tid

    # 7) Print summary
    dates = dfFixtures.loc[open_fx.index[:len(pairs)], 'date'].unique().tolist()
    print(f"\n🏆 {comp_name} draw ({len(pairs)} matches) across: {', '.join(dates)}")
    for i, (home_tid, away_tid) in enumerate(pairs, 1):
        home_name = dfTeams.loc[dfTeams['teamID'] == home_tid, 'teamName'].iat[0]
        away_name = dfTeams.loc[dfTeams['teamID'] == away_tid, 'teamName'].iat[0]
        dayc = dfFixtures.at[open_fx.index[i-1], 'dayCounter']
        print(f"  Match {i:02d} (day {dayc}): {home_name} vs {away_name}")

    # commit back
    globals()['dfFixtures'] = dfFixtures

# %% [markdown]
# ### European Helper Functions

# %%
import random
import pandas as pd

def draw_euro_group_stage(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic draw for European group stages (UCL or EL), but now appends to a global dfGroupStage
    instead of overwriting it. This means you can call it twice (once for competitionID=9, once
    for competitionID=8) and keep both sets of group assignments.

    Expects:
      - row['competitionID'] ∈ {9 (UCL), 8 (EL)}
      - row['dayCounter']  = comma-separated string of 12 ints (for UCL) or 6 ints (for EL)
      - dfTeams, dfFixtures, dfCompetitions already in scope

    After this runs, global dfGroupStage will contain rows:
      competitionID | teamID | groupID
    for all previously‐drawn competitions (8 and/or 9), plus this new draw.
    """

    # 1) Parse dayCounters
    raw = row['dayCounter']
    if isinstance(raw, str):
        date_list = [int(x.strip()) for x in raw.split(',') if x.strip().isdigit()]
    else:
        try:
            date_list = list(raw)
        except:
            date_list = [int(raw)]

    comp_id = int(row['competitionID'])
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id, 'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"Competition{comp_id}"

    # 2) Determine flag column and expected number of dayCounters
    if comp_id == 9:    # UCL
        expected = 12
        flag_col = 'inCL'
    elif comp_id == 8:  # EL
        expected = 6
        flag_col = 'inEL'
    else:
        raise ValueError(f"CompetitionID {comp_id} is not UCL (9) or EL (8).")

    if len(date_list) != expected:
        raise ValueError(f"{comp_name} requires {expected} dayCounters, got {len(date_list)}.")

    # 3) Select exactly 32 teams still in the competition
    euro_teams = dfTeams.loc[dfTeams[flag_col] == True, ['teamID', 'nationality']].to_dict(orient='records')
    if len(euro_teams) != 32:
        raise ValueError(f"Expected 32 teams where {flag_col}==True, found {len(euro_teams)}.")

    # 4) Assign to 8 groups of 4 with unique nationality constraint
    def attempt_grouping():
        random.shuffle(euro_teams)
        groups = {gid: [] for gid in range(1, 9)}
        for team in euro_teams:
            placed = False
            order = list(groups.keys())
            random.shuffle(order)
            for gid in order:
                if len(groups[gid]) < 4:
                    existing_nats = {t['nationality'] for t in groups[gid]}
                    if team['nationality'] not in existing_nats:
                        groups[gid].append(team)
                        placed = True
                        break
            if not placed:
                return None
        return groups

    groups = None
    for _ in range(1000):
        groups = attempt_grouping()
        if groups is not None:
            break
    if groups is None:
        raise RuntimeError("Failed to assign teams into nationality‐unique groups after many tries.")

    # 5) Build a DataFrame for this draw (comp_id, teamID, groupID)
    new_group_rows = [
        {'competitionID': comp_id, 'teamID': t['teamID'], 'groupID': gid}
        for gid, members in groups.items()
        for t in members
    ]
    new_df = pd.DataFrame(new_group_rows)

    # 6) Append to global dfGroupStage (dropping any old rows for the same comp_id)
    global dfGroupStage
    try:
        # If dfGroupStage already exists, remove any rows for this comp_id, then append
        dfGroupStage = dfGroupStage[ dfGroupStage['competitionID'] != comp_id ].copy()
        dfGroupStage = pd.concat([dfGroupStage, new_df], ignore_index=True)
    except NameError:
        # dfGroupStage doesn't exist yet; just create it
        dfGroupStage = new_df.copy()

    # 7) Fill placeholders in dfFixtures for matchups (same as before)
    def single_round_robin(team_ids):
        teams = list(team_ids)
        n = len(teams)  # 4
        rounds = []
        for _ in range(n - 1):  # 3 rounds
            pairings = []
            for j in range(n // 2):
                t1 = teams[j]
                t2 = teams[n - 1 - j]
                pairings.append((t1, t2))
            rounds.append(pairings)
            teams = [teams[0]] + [teams[-1]] + teams[1:-1]
        return rounds

    group_schedules = {}
    for gid, members in groups.items():
        tids = [t['teamID'] for t in members]
        first = single_round_robin(tids)
        second = [[(away, home) for (home, away) in rnd] for rnd in first]
        full = first + second  # 6 total rounds
        group_schedules[gid] = full

    # 8) Populate existing dfFixtures placeholders:
    for rnd_idx in range(6):
        if comp_id == 9:
            # UCL: two dayCounters per round
            dc_1_4 = date_list[2 * rnd_idx]
            dc_5_8 = date_list[2 * rnd_idx + 1]
        else:
            # EL: single dayCounter per round
            dc_all = date_list[rnd_idx]

        for gid, schedule in group_schedules.items():
            match_pairs = schedule[rnd_idx]  # two (home,away) pairs
            dc = (dc_1_4 if gid <= 4 else dc_5_8) if comp_id == 9 else dc_all

            placeholder_mask = (
                (dfFixtures['competitionID'] == comp_id) &
                (dfFixtures['dayCounter']     == dc) &
                (dfFixtures['homeTeam'].isna()) &
                (dfFixtures['awayTeam'].isna())
            )
            placeholders = dfFixtures.loc[placeholder_mask]
            needed = len(match_pairs)
            if len(placeholders) < needed:
                raise RuntimeError(
                    f"Not enough placeholder rows for {comp_name} on day {dc}: "
                    f"needed {needed}, found {len(placeholders)}"
                )

            indices = placeholders.index.tolist()[:needed]
            for idx, (home_tid, away_tid) in zip(indices, match_pairs):
                dfFixtures.at[idx, 'homeTeam'] = home_tid
                dfFixtures.at[idx, 'awayTeam'] = away_tid
                dfFixtures.at[idx, 'round']    = rnd_idx + 1

    # 9) Print out group composition (for just this competition)
    print(f"\nPopulated {comp_name} Group Stage (competitionID={comp_id}):")
    for gid, members in groups.items():
        names = [
            dfTeams.loc[dfTeams['teamID'] == t['teamID'], 'teamName'].values[0]
            for t in members
        ]
        print(f"  Group {gid}: {', '.join(names)}")

    return dfGroupStage

import pandas as pd

def generate_euro_group_tables(competitionID: int,
                                dfFixtures: pd.DataFrame,
                                dfTeams: pd.DataFrame,
                                dfGroupStage: pd.DataFrame) -> dict:
    """
    Returns a dict mapping groupID → DataFrame of standings for that group,
    for the given European group-stage competition (8 = EL or 9 = UCL).

    Each DataFrame has columns:
      ['Position', 'Team', 'Played', 'Wins', 'Draws', 'Losses',
       'GoalsFor', 'GoalsAgainst', 'GoalDiff', 'Points']

    Args:
      competitionID: 8 or 9
      dfFixtures:    DataFrame with group-stage matches, including:
                      ['competitionID','homeTeam','awayTeam','homeGoals','awayGoals','played']
      dfTeams:       DataFrame with ['teamID','teamName', …]
      dfGroupStage:  DataFrame with ['competitionID','teamID','groupID']

    Returns:
      A dict { groupID: group_table_df, … } for groupID in [1..8].
    """

    # 1) Filter to played matches of this competition
    mask = (
        (dfFixtures['competitionID'] == competitionID) &
        (dfFixtures['played'] == True)
    )
    played = dfFixtures.loc[mask].copy()
    if played.empty:
        print(f"No played fixtures found for competition {competitionID}.")
        return {}

    # 2) Merge in groupID for home and away teams
    #    We assume dfGroupStage has exactly one row per (competitionID, teamID).
    gs = dfGroupStage[dfGroupStage['competitionID'] == competitionID][['teamID','groupID']]

    played = played.merge(gs.rename(columns={'teamID':'homeTeam', 'groupID':'homeGroup'}),
                          on='homeTeam', how='left')
    played = played.merge(gs.rename(columns={'teamID':'awayTeam', 'groupID':'awayGroup'}),
                          on='awayTeam', how='left')

    # 3) Build a “per‐team‐per‐match” record
    records = []
    for _, row in played.iterrows():
        h_id = int(row['homeTeam'])
        a_id = int(row['awayTeam'])
        hg   = int(row['homeGoals'])
        ag   = int(row['awayGoals'])
        hg_id = row['homeGroup']
        ag_id = row['awayGroup']
        # (They should be equal: hg_id == ag_id, otherwise data is inconsistent.)

        # Home team stats
        if hg > ag:
            h_w, h_d, h_l, h_pts = 1, 0, 0, 3
            a_w, a_d, a_l, a_pts = 0, 0, 1, 0
        elif hg < ag:
            h_w, h_d, h_l, h_pts = 0, 0, 1, 0
            a_w, a_d, a_l, a_pts = 1, 0, 0, 3
        else:
            h_w, h_d, h_l, h_pts = 0, 1, 0, 1
            a_w, a_d, a_l, a_pts = 0, 1, 0, 1

        records.append({
            'groupID':      hg_id,
            'teamID':       h_id,
            'Played':       1,
            'Wins':         h_w,
            'Draws':        h_d,
            'Losses':       h_l,
            'GoalsFor':     hg,
            'GoalsAgainst': ag,
            'Points':       h_pts
        })
        # Away team stats
        records.append({
            'groupID':      ag_id,
            'teamID':       a_id,
            'Played':       1,
            'Wins':         a_w,
            'Draws':        a_d,
            'Losses':       a_l,
            'GoalsFor':     ag,
            'GoalsAgainst': hg,
            'Points':       a_pts
        })

    df_stats = pd.DataFrame(records)

    # 4) Aggregate by groupID + teamID
    agg = df_stats.groupby(['groupID','teamID'], as_index=False).sum()
    #    Compute goal difference
    agg['GoalDiff'] = agg['GoalsFor'] - agg['GoalsAgainst']

    # 5) Merge in team names
    agg = agg.merge(dfTeams[['teamID','teamName']], on='teamID', how='left')

    # 6) For each group, create a sorted table
    group_tables = {}
    for gid in sorted(agg['groupID'].unique()):
        gdf = agg[agg['groupID'] == gid].copy()
        # Sort by Points desc, then GoalDiff desc, then GoalsFor desc
        gdf = gdf.sort_values(
            by=['Points','GoalDiff','GoalsFor'],
            ascending=[False, False, False]
        ).reset_index(drop=True)

        # Assign position 1–4
        gdf.insert(0, 'Position', range(1, len(gdf)+1))

        # Reorder columns for readability
        gdf = gdf[['Position','teamName','Played','Wins','Draws','Losses',
                   'GoalsFor','GoalsAgainst','GoalDiff','Points']]
        gdf.rename(columns={'teamName':'Team'}, inplace=True)

        group_tables[gid] = gdf

    return group_tables

import pandas as pd

import pandas as pd

def print_euro_group_tables(comp_id: int,
                            dfTeams: pd.DataFrame,
                            dfFixtures: pd.DataFrame,
                            dfGroupStage: pd.DataFrame):
    """
    Prints all 8 group standings for the given European competition (8=EL or 9=UCL).
    - If no matches have been played in a group, that group prints all zeros.
    - If some matches have been played, you'll see real stats (Played/W/D/L/GF/GA/GD/Pts).

    Args:
      comp_id       : 8 for Europa League, 9 for Champions League
      dfTeams       : DataFrame with ['teamID','teamName', …]
      dfFixtures    : DataFrame with all group fixtures, including 'played', 'homeGoals', 'awayGoals'
      dfGroupStage  : DataFrame with ['competitionID','teamID','groupID'] (32 rows for comp_id)

    Usage:
      # Right after drawing groups (so dfGroupStage has comp_id rows):
      print_euro_group_tables(9, dfTeams, dfFixtures, dfGroupStage)
      
      # After some matchdays have been simulated:
      print_euro_group_tables(9, dfTeams, dfFixtures, dfGroupStage)
    """

    # 1) Build mapping: groupID → [teamID, …] for this competition
    gs = dfGroupStage[dfGroupStage['competitionID'] == comp_id]
    if len(gs) != 32:
        raise ValueError(
            f"dfGroupStage must contain exactly 32 rows for comp {comp_id}, "
            f"found {len(gs)}"
        )

    euro_groups = gs.groupby('groupID')['teamID'].apply(list).to_dict()
    missing = [gid for gid in range(1, 9) if gid not in euro_groups]
    if missing:
        raise ValueError(f"Missing groupIDs {missing} in dfGroupStage for comp {comp_id}.")

    # 2) Generate actual group tables (this will return a dict {gid: DataFrame} for groups
    #    where at least one match has been played; empty dict if none)
    actual_tables = generate_euro_group_tables(
        competitionID=comp_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )

    # 3) For each group (1..8), either print the actual table or a zero‐stats template
    for gid in range(1, 9):
        comp_name = dfCompetitions.loc[
            dfCompetitions['competitionID'] == comp_id, 'competitionName'
        ].values[0]
        print(f"\n--- {comp_name} Group {gid} Standings ---")

        if gid in actual_tables:
            tbl = actual_tables[gid].copy()
            # Ensure there’s a Position column in front
            if 'Position' not in tbl.columns:
                tbl.insert(0, 'Position', range(1, len(tbl) + 1))
            print(tbl.to_string(index=False))
            continue

        # No matches played yet in this group: build zero‐stats
        rows = []
        for tid in euro_groups[gid]:
            team_name = dfTeams.loc[dfTeams['teamID'] == tid, 'teamName'].values[0]
            rows.append({
                'Team':         team_name,
                'Played':       0,
                'Wins':         0,
                'Draws':        0,
                'Losses':       0,
                'GoalsFor':     0,
                'GoalsAgainst': 0,
                'GoalDiff':     0,
                'Points':       0
            })
        zero_df = pd.DataFrame(rows)
        zero_df.insert(0, 'Position', range(1, 5))
        print(zero_df.to_string(index=False))

import random

import random

def end_cl_groups(row, dfTeams, dfFixtures, dfGroupStage):
    """
    After UCL group stage completes:
      1) Reset all dfTeams['inCL'] to False.
      2) Re-flag the 16 teams (8 group winners + 8 runners-up).
      3) Draw two-legged Round of 16:
         - first half of row['dayCounter'] for leg1 days,
         - second half for leg2 days,
         cycling if fewer days than matches,
         and populate existing blanks (one fixture slot per match per leg).
    """
    comp_id = 9

    # 1) Clear previous CL flags
    dfTeams['inCL'] = False

    # 2) Find winners & runners-up
    tables = generate_euro_group_tables(
        competitionID=comp_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    winners = []
    runners  = []
    for gid, tbl in tables.items():
        # map names back to IDs
        win_name, run_name = tbl.iloc[0]['Team'], tbl.iloc[1]['Team']
        win_id = dfTeams.loc[dfTeams.teamName == win_name, 'teamID'].iat[0]
        run_id = dfTeams.loc[dfTeams.teamName == run_name, 'teamID'].iat[0]
        winners.append((gid, win_id))
        runners.append((gid, run_id))

    # flag them
    dfTeams.loc[dfTeams.teamID.isin([tid for _,tid in winners] + [tid for _,tid in runners]), 'inCL'] = True

    # 3) Pair winners vs runners from different groups
    rng = list(range(len(winners)))  # should be 8
    for _ in range(1000):
        random.shuffle(runners)
        if all(winners[i][0] != runners[i][0] for i in rng):
            break
    else:
        raise RuntimeError("Cannot pair winners with runners without rematches")

    match_pairs = [(winners[i][1], runners[i][1]) for i in rng]
    n_matches = len(match_pairs)

    # 4) Parse dayCounters and split into two pools
    days = [int(x.strip()) for x in str(row['dayCounter']).split(',') if x.strip().isdigit()]
    if not days:
        raise ValueError("No valid dayCounters provided for End CL Groups")
    half = len(days) // 2 or 1
    leg1_pool = days[:half]
    leg2_pool = days[half:half*2] if len(days) > half else days

    # build full schedules, cycling
    leg1_days = [leg1_pool[i % len(leg1_pool)] for i in range(n_matches)]
    leg2_days = [leg2_pool[i % len(leg2_pool)] for i in range(n_matches)]

    # 5) Fill placeholders for leg1 then leg2
    # leg1
    for (home_tid, away_tid), dc in zip(match_pairs, leg1_days):
        mask = (
            (dfFixtures.competitionID == comp_id) &
            (dfFixtures.dayCounter    == dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank fixture for leg1 match on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = home_tid
        dfFixtures.at[idxs[0], 'awayTeam'] = away_tid

    # leg2 (reverse)
    for (home_tid, away_tid), dc in zip(match_pairs, leg2_days):
        mask = (
            (dfFixtures.competitionID == comp_id) &
            (dfFixtures.dayCounter    == dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank fixture for leg2 match on day {dc}")
        # reverse home/away
        dfFixtures.at[idxs[0], 'homeTeam'] = away_tid
        dfFixtures.at[idxs[0], 'awayTeam'] = home_tid

    # 6) Summary
    print(f"\n🏆 UCL Round of 16 (two-legged) drawn:")
    for i, ((h, a), d1, d2) in enumerate(zip(match_pairs, leg1_days, leg2_days), 1):
        h_name = dfTeams.loc[dfTeams.teamID==h, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams.teamID==a, 'teamName'].iat[0]
        print(f"  Match {i:02d}: Leg1 (day {d1}) {h_name} vs {a_name}; "
              f"Leg2 (day {d2}) {a_name} vs {h_name}")

    # commit back
    globals()['dfFixtures'] = dfFixtures

import random

def end_el_groups(row, dfTeams, dfFixtures, dfGroupStage):
    """
    After EL group stage completes:
      1) Reset dfTeams['inEL'] to False.
      2) Re-flag 24 teams: 8 EL group winners, 8 EL runners-up, and 8 CL third-place finishers.
      3) Draw and populate two-legged “Knockout play-offs” between each EL runner-up
         and one CL third-place, avoiding same-nationality clashes.
    """
    el_id = 8
    cl_id = 9
    # 1) clear inEL
    dfTeams['inEL'] = False

    # 2a) EL group winners & runners-up
    el_tables = generate_euro_group_tables(
        competitionID=el_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    winners = []
    runners  = []
    for gid, tbl in el_tables.items():
        win_name = tbl.iloc[0]['Team']
        run_name = tbl.iloc[1]['Team']
        win_id = dfTeams.loc[dfTeams.teamName==win_name,'teamID'].iat[0]
        run_id = dfTeams.loc[dfTeams.teamName==run_name,'teamID'].iat[0]
        winners.append(win_id)
        runners.append(run_id)

    # 2b) CL third-place finishers
    cl_tables = generate_euro_group_tables(
        competitionID=cl_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    thirds = []
    for gid, tbl in cl_tables.items():
        third_name = tbl.iloc[2]['Team']
        third_id   = dfTeams.loc[dfTeams.teamName==third_name,'teamID'].iat[0]
        thirds.append(third_id)

    # re-flag all 24 inEL
    dfTeams.loc[dfTeams.teamID.isin(winners + runners + thirds), 'inEL'] = True

    # 3) Pair each EL runner-up with a CL third-place, no same-nationality
    def same_nation(e, c):
        return dfTeams.loc[dfTeams.teamID==e, 'nationality'].iat[0] == \
               dfTeams.loc[dfTeams.teamID==c, 'nationality'].iat[0]

    paired = False
    for _ in range(1000):
        random.shuffle(thirds)
        if all(not same_nation(runners[i], thirds[i]) for i in range(8)):
            paired = True
            break
    if not paired:
        raise RuntimeError("Cannot pair without same-nation clash")

    match_pairs = list(zip(runners, thirds))  # 8 pairs

    # 4) Parse dayCounters
    days = [int(d) for d in str(row['dayCounter']).split(',') if d.strip().isdigit()]
    if not days:
        raise ValueError("No dayCounters provided for EL playoffs")
    half = len(days)//2 or 1
    leg1_pool = days[:half]
    leg2_pool = days[half:half*2] if len(days)>half else days

    # cycle through pools
    leg1_days = [leg1_pool[i % len(leg1_pool)] for i in range(8)]
    leg2_days = [leg2_pool[i % len(leg2_pool)] for i in range(8)]

    # 5) Fill placeholders for leg1 and leg2
    # leg1: runner-up home
    for (run_id, third_id), dc in zip(match_pairs, leg1_days):
        mask = (
            (dfFixtures.competitionID==el_id) &
            (dfFixtures.dayCounter   ==dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank EL playoff fixture for leg1 on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = run_id
        dfFixtures.at[idxs[0], 'awayTeam'] = third_id

    # leg2: third-place home
    for (run_id, third_id), dc in zip(match_pairs, leg2_days):
        mask = (
            (dfFixtures.competitionID==el_id) &
            (dfFixtures.dayCounter   ==dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank EL playoff fixture for leg2 on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = third_id
        dfFixtures.at[idxs[0], 'awayTeam'] = run_id

    # 6) Print summary
    comp_name = dfCompetitions.loc[dfCompetitions.competitionID==el_id,'competitionName'].iat[0]
    print(f"\n🏆 {comp_name} Knockout Play-offs (two-legged):")
    for i, ((r, c), d1, d2) in enumerate(zip(match_pairs, leg1_days, leg2_days), 1):
        r_name = dfTeams.loc[dfTeams.teamID==r,'teamName'].iat[0]
        c_name = dfTeams.loc[dfTeams.teamID==c,'teamName'].iat[0]
        print(f"  Match {i:02d}: Leg1 (day {d1}) {r_name} vs {c_name}; "
              f"Leg2 (day {d2}) {c_name} vs {r_name}")

    globals()['dfFixtures'] = dfFixtures

# %% [markdown]
# ### The Flow

# %%
# Load verbose flow plan
dfSeasonFlow = pd.read_csv('Input/theFlow.csv')

# Initialise flow state only once
try:
    flow_state
except NameError:
    flow_state = {'step': 0}  # this advances by 1 each time the cell is run

# %%
# 🔄 Reset simulation flow to the start
flow_state = {'step': 0}
print("✅ Flow state reset. You can now re-run the simulation from the beginning.")
# Out:
# ✅ Flow state reset. You can now re-run the simulation from the beginning.

# %% [markdown]
# ### The Flow Helper Functions

# %%
def play_league_day(day):
    """
    Wrapper around play_league_round. If dfGroupStage is not defined yet,
    we simply pass None and skip European table updates inside play_league_round.
    """
    global dfFixtures, dfGroupStage  # dfGroupStage may or may not exist

    try:
        # If dfGroupStage exists, pass it in
        dfFixtures = play_league_round(
            day=day,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfCompetitions=dfCompetitions,
            dfGroupStage=dfGroupStage
        )
    except NameError:
        # dfGroupStage doesn’t exist yet—pass None instead
        dfFixtures = play_league_round(
            day=day,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfCompetitions=dfCompetitions,
            dfGroupStage=None
        )

def update_tables():
    global league_tables
    league_tables = generate_league_tables(dfFixtures, dfTeams)

def print_tables():
    print_all_league_tables(league_tables, dfCompetitions)
    
def create_new_fixture_list():
    global dfFixtures
    dfFixtures = create_fixture_list(season_state['current_year'])
    print(f"✅ Fixture list created for {season_state['current_year']}")

def create_team_attributes():
    global dfTeams
    dfTeams = generate_team_attributes()
    print(f"✅ Team attributes created for {season_state['current_year']}")

def update_cup_status(dayCounter, competitionID, dfFixtures, dfTeams):
    """
    For each day in 'dayCounter' (which may be an int or a comma-separated string of ints),
    find all played fixtures for that competition on those days, determine the losers
    (taking into account ET and penalties), and set their corresponding 'inX' flag to False.
    
    Mapping of competitionID → dfTeams flag:
      6  → 'inLC'
      7  → 'inFA'
      8  → 'inEL'
      9  → 'inCL'
      10 → 'inCS'
    """
    # 1) Parse dayCounter into a list of ints
    if isinstance(dayCounter, str):
        day_list = [int(d.strip()) for d in dayCounter.split(',') if d.strip().isdigit()]
    else:
        # assume it's already an int (or something convertible)
        day_list = [int(dayCounter)]
    
    # 2) Map competitionID to the dfTeams boolean column
    comp_flag_map = {
        6:  'inLC',
        7:  'inFA',
        8:  'inEL',
        9:  'inCL',
        10: 'inCS'
    }
    if competitionID not in comp_flag_map:
        print(f"[Warning] No flag mapping for competitionID {competitionID}")
        return
    
    flag_col = comp_flag_map[competitionID]

    # 3) Iterate over each specified day
    for day in day_list:
        # Look up competition name (optional; for nicer printing)
        comp_row = dfCompetitions.loc[
            dfCompetitions['competitionID'] == competitionID,
            'competitionName'
        ]
        comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

        # Filter for fixtures matching this day & competition, and that have been played
        mask = (
            (dfFixtures['dayCounter']   == day) &
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['played']        == True)
        )
        played_matches = dfFixtures.loc[mask].copy()
        if played_matches.empty:
            print(f"No played fixtures found on day {day} for '{comp_name}'")
            continue

        # 4) For each match, determine loser and update dfTeams
        for idx, match in played_matches.iterrows():
            home_id    = int(match['homeTeam'])
            away_id    = int(match['awayTeam'])
            home_goals = int(match['homeGoals'])
            away_goals = int(match['awayGoals'])

            # Determine loser (accounting for ET/penalties if needed)
            if home_goals > away_goals:
                loser_id = away_id
            elif away_goals > home_goals:
                loser_id = home_id
            else:
                # tied after ET, so look at penalty columns
                home_pens = match.get('homePens')
                away_pens = match.get('awayPens')
                if home_pens is None or away_pens is None:
                    print(f"[Error] Tie on day {day}, comp '{comp_name}', but no penalty data.")
                    continue
                loser_id = home_id if home_pens < away_pens else away_id

            # Set that team’s 'inX' flag to False
            dfTeams.loc[dfTeams['teamID'] == loser_id, flag_col] = False

            # Print which team was knocked out
            loser_name = dfTeams.loc[
                dfTeams['teamID'] == loser_id, 'teamName'
            ].values[0]
            print(
                f"Day {day} | {comp_name} | Knocked out: {loser_name} → {flag_col} = False"
            )

def add_lc_teams_r2(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 2,
    except those already in Europa League or Champions League.
    Sets dfTeams['inLC'] = True for any teamID ≤ 20 where
    both inEL and inCL are False.
    """
    mask = (dfTeams['teamID'] <= 20) & (~dfTeams['inEL']) & (~dfTeams['inCL'])
    dfTeams.loc[mask, 'inLC'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to LC Round 2: {', '.join(added)}")

def add_lc_teams_r3(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 3
    if they are in Europa League (inEL) or Champions League (inCL).
    Sets dfTeams['inLC'] = True for any team meeting those criteria.
    """
    mask = (dfTeams['teamID'] <= 20) & (dfTeams['inEL'] | dfTeams['inCL'])
    dfTeams.loc[mask, 'inLC'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to LC Round 3: {', '.join(added)}")
    
def add_fa_teams_r3(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 3
    if they are in Europa League (inEL) or Champions League (inCL).
    Sets dfTeams['inLC'] = True for any team meeting those criteria.
    """
    mask = (dfTeams['teamID'] <= 44) 
    dfTeams.loc[mask, 'inFA'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to FA Cup Round 3: {', '.join(added)}")

def play_two_leg_round(dayCounter, competitionID, dfFixtures, dfTeams):
    import pandas as pd
    # Functions play_full_match, play_cup_match, and simulate_penalties are called directly

    # 1) Competition name
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == competitionID,
        'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

    # 2) Today's day
    today = int(dayCounter)

    # 3) Fetch unplayed fixtures for this competition on this day
    todays = dfFixtures[
        (dfFixtures['dayCounter'] == today) &
        (dfFixtures['competitionID'] == competitionID) &
        (~dfFixtures['played'])
    ].copy()
    if todays.empty:
        print(f"No fixtures to play on day {today} for {comp_name}")
        return

    # 4) Process each fixture
    for idx, m in todays.iterrows():
        # Skip blanks
        if pd.isna(m['homeTeam']) or pd.isna(m['awayTeam']):
            print(f"❌ Skipping empty fixture on day {today} at index {idx}")
            continue

        # IDs and names for this leg
        h_id, a_id = int(m['homeTeam']), int(m['awayTeam'])
        h_name = dfTeams.loc[dfTeams['teamID'] == h_id, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams['teamID'] == a_id, 'teamName'].iat[0]

        # 5) Look up first-leg result by finding the reverse fixture that has been played
        rev = dfFixtures[
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['homeTeam'] == a_id) &
            (dfFixtures['awayTeam'] == h_id) &
            (dfFixtures['played'] == True)
        ]

        if rev.empty:
            # --- Leg 1: simulate 90' only ---
            # For leg 1, we just play a regular 90-minute match with no extra time or penalties
            g1, g2 = play_full_match(h_id, a_id, dfTeams)
            dfFixtures.at[idx, 'homeGoals'] = int(g1)
            dfFixtures.at[idx, 'awayGoals'] = int(g2)
            dfFixtures.at[idx, 'played']    = True
            print(f"Day {today} | {comp_name} Leg 1 | {h_name} {g1}-{g2} {a_name}")
            continue

        # --- Leg 2 ---
        # For leg 2, we need to consider the aggregate score
        first_leg = rev.iloc[0]
        
        # Get goals from first leg (note: teams were reversed in first leg)
        leg1_home_goals = int(first_leg['awayGoals'])  # Goals scored by current home team when away
        leg1_away_goals = int(first_leg['homeGoals'])  # Goals scored by current away team when home
        
        # Now we'll simulate leg 2 as a cup match
        # First, play the regular 90 minutes
        result = play_cup_match(h_id, a_id, dfTeams)
        
        # Extract the 90-minute result
        g2_home = int(result['home_goals']) - int(result.get('home_et_goals', 0))
        g2_away = int(result['away_goals']) - int(result.get('away_et_goals', 0))
        
        # Calculate aggregate score
        agg_home = leg1_home_goals + g2_home
        agg_away = leg1_away_goals + g2_away
        
        # Initialize extra time and penalty variables
        et_home = et_away = None
        pk_home = pk_away = None
        suffix = f" (agg {agg_home}-{agg_away})"
        
        # Determine if we need extra time and penalties
        if agg_home > agg_away:
            # Home team wins on aggregate
            winner_id = h_id
        elif agg_away > agg_home:
            # Away team wins on aggregate
            winner_id = a_id
        else:
            # Tied on aggregate - need extra time
            # Get extra time goals from the cup match result
            et_home = int(result.get('home_et_goals', 0))
            et_away = int(result.get('away_et_goals', 0))
            suffix += f" (a.e.t. {et_home}-{et_away})"
            
            if et_home > et_away:
                # Home team wins after extra time
                winner_id = h_id
            elif et_away > et_home:
                # Away team wins after extra time
                winner_id = a_id
            else:
                # Still tied after extra time - penalties decide
                if 'home_pk' in result and 'away_pk' in result and result['home_pk'] is not None and result['away_pk'] is not None:
                    # Use penalty results from cup match
                    pk_home = int(result['home_pk'])
                    pk_away = int(result['away_pk'])
                else:
                    # If penalties aren't in the result for some reason, simulate them
                    pk_home, pk_away, penalty_winner = simulate_penalties(h_id, a_id, dfTeams)
                    
                suffix += f" [p {pk_home}-{pk_away}]"
                
                # Determine winner based on penalties
                if pk_home > pk_away:
                    winner_id = h_id
                else:
                    winner_id = a_id
        
        # Get winner name
        winner_name = dfTeams.loc[dfTeams['teamID'] == winner_id, 'teamName'].iat[0]
        
        # Write results back to fixtures
        dfFixtures.at[idx, 'homeGoals'] = g2_home
        dfFixtures.at[idx, 'awayGoals'] = g2_away
        dfFixtures.at[idx, 'homeGoalsAET'] = et_home or 0
        dfFixtures.at[idx, 'awayGoalsAET'] = et_away or 0
        dfFixtures.at[idx, 'homePens'] = pk_home
        dfFixtures.at[idx, 'awayPens'] = pk_away
        dfFixtures.at[idx, 'played'] = True
        
        # Print the result
        print(
            f"Day {today} | {comp_name} Leg 2 | {h_name} {g2_home}-{g2_away} {a_name}"
            f"{suffix} → Winner: {winner_name}"
        )
    
    # Commit back updated fixtures
    globals()['dfFixtures'] = dfFixtures
    return



def draw_two_leg_fixture(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic draw for two-legged cup ties.
    - row['competitionID']: cup ID (e.g. 6=League Cup,7=FA,8=EL,9=CL,10=CS)
    - row['dayCounter']: comma-separated days for fixtures (leg1 days then leg2 days)

    1) Determine eligible teams via dfTeams['inXX'] flag.
    2) Shuffle and pair into ties.
    3) Parse dayCounter into ordered list of days (first half = leg1, second half = leg2).
    4) Locate blank fixtures in dfFixtures for these days.
    5) Assign all first-leg fixtures to the first half of placeholders, then all second-leg fixtures to the second half.
    6) Print a summary of the draw.
    """
    comp_id = int(row['competitionID'])
    comp_flag_map = {6: 'inLC', 7: 'inFA', 8: 'inEL', 9: 'inCL', 10: 'inCS'}
    flag_col = comp_flag_map.get(comp_id)
    if not flag_col:
        print(f"❌ No draw config for competitionID={comp_id}")
        return

    comp_name = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id,
        'competitionName'
    ].iat[0]

    # 1) Eligible teams
    eligible = dfTeams[dfTeams[flag_col] == True]['teamID'].tolist()
    if len(eligible) < 2 or len(eligible) % 2 != 0:
        print(f"❌ {comp_name} draw requires an even number of teams (found {len(eligible)})")
        return

    # 2) Shuffle & pair
    random.shuffle(eligible)
    ties = [(eligible[i], eligible[i+1]) for i in range(0, len(eligible), 2)]
    n_ties = len(ties)

    # 3) Parse dayCounter into leg1_days and leg2_days
    raw = str(row['dayCounter'])
    days = [int(x.strip()) for x in raw.split(',') if x.strip().isdigit()]
    expected = n_ties * 2
    if len(days) < expected:
        raise ValueError(f"{comp_name} two-legged draw needs {expected} days, got {len(days)}")
    days = days[:expected]

    # 4) Find placeholders for all leg days
    mask = (
        (dfFixtures['competitionID'] == comp_id) &
        (dfFixtures['dayCounter'].isin(days)) &
        dfFixtures['homeTeam'].isnull() &
        dfFixtures['awayTeam'].isnull()
    )
    open_fx = dfFixtures.loc[mask]
    if len(open_fx) < expected:
        raise ValueError(f"Not enough blanks for {comp_name} two-legged draw: need {expected}, found {len(open_fx)}")

    # Sort placeholders by dayCounter then by index order
    open_fx = open_fx.sort_values('dayCounter').iloc[:expected]
    fx_idxs = open_fx.index.tolist()

    # Split placeholder indices: first n_ties for leg1, next n_ties for leg2
    first_leg_idxs = fx_idxs[:n_ties]
    second_leg_idxs = fx_idxs[n_ties:expected]

    # 5) Assign fixtures
    # Assign first legs
    for i, (home, away) in enumerate(ties):
        idx1 = first_leg_idxs[i]
        dfFixtures.at[idx1, 'homeTeam'] = home
        dfFixtures.at[idx1, 'awayTeam'] = away

    # Assign second legs
    for i, (home, away) in enumerate(ties):
        idx2 = second_leg_idxs[i]
        dfFixtures.at[idx2, 'homeTeam'] = away
        dfFixtures.at[idx2, 'awayTeam'] = home

    # 6) Print summary
    print(f"\n🏆 {comp_name} Two‑Leg Draw ({n_ties} ties) across days: {', '.join(map(str, days))}")
    for i, (home, away) in enumerate(ties, 1):
        day1 = days[i - 1]
        day2 = days[n_ties + i - 1]
        h_name = dfTeams.loc[dfTeams['teamID'] == home, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams['teamID'] == away, 'teamName'].iat[0]
        print(f"  Tie {i:02d}: Leg1 (day {day1}) {h_name} vs {a_name}; Leg2 (day {day2}) {a_name} vs {h_name}")

    globals()['dfFixtures'] = dfFixtures

# Map flow text to actual logic
flow_dispatch = {
    'Create New Fixture List': lambda row: create_new_fixture_list(),
    'Create Team Attributes': lambda row: create_team_attributes(),
    #'Play League Matches': lambda row: play_league_day(int(row['dayCounter'])),
    'Play League Matches': lambda row: play_league_round(int(row['dayCounter']),dfFixtures, dfTeams, dfCompetitions),
    'Print Tables': lambda row: print_tables(),
    'Play Cup Round': lambda row: play_cup_round(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams),
    'Update Cup Status': lambda row: update_cup_status(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams),
    'Add LC Round2 Teams': lambda row: add_lc_teams_r2(dfTeams),
    'Add LC Round3 Teams': lambda row: add_lc_teams_r3(dfTeams),
    'Draw European Group Stage': lambda row: draw_euro_group_stage(row, dfTeams, dfFixtures, dfCompetitions),
    'Draw Cup' : lambda row: draw_cup(row, dfTeams, dfFixtures, dfCompetitions),
    'Initialize Cup Status' : lambda row: initialize_cup_status(dfTeams),
    'End CL Groups' : lambda row: end_cl_groups(row, dfTeams, dfFixtures, dfGroupStage),
    'End EL Groups' : lambda row: end_el_groups(row, dfTeams, dfFixtures, dfGroupStage),
    'Add FA Round3 Teams' : lambda row: add_fa_teams_r3(dfTeams),
    'Draw Two Leg Fixture' : lambda row: draw_two_leg_fixture(row, dfTeams, dfFixtures, dfCompetitions),
    'Play Two Leg Round' : lambda row: play_two_leg_round(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams),
    'Play European League' : lambda row: play_european_league(int(row['dayCounter']), dfFixtures, dfTeams, dfCompetitions, dfGroupStage)
}

# %%
# 📅 Initialize multi-season simulation state
try:
    season_state
except NameError:
    season_state = {
        'step': 0,
        'current_year': 2024,
        'fixtures_archive': {},
        'tables_archive': {}
    }
    print("✅ Season state initialized")

# %%
# Step through the flow one step at a time
if flow_state['step'] < len(dfSeasonFlow):
    row = dfSeasonFlow.iloc[flow_state['step']]
    step_desc = row['functionToCall']
    print(f"\n=== STEP {flow_state['step']+1}: {step_desc} ===")

    # Run corresponding logic
    if step_desc in flow_dispatch:
        flow_dispatch[step_desc](row)
    else:
        print(f"[Skipped] No function mapped for: {step_desc}")

    flow_state['step'] += 1
else:
    print("=== All flow steps completed ===")
# Out:
# === STEP 1: Create New Fixture List ===
# ✅ Fixture list created for 2024

# %%
# Step through the flow in one hit to XX
def run_flow_to(target_step):
    """
    Advance the flow from its current position up to (but not including) target_step.
    target_step is 1-based: to run steps 1–80, call run_flow_to(80).
    """
    global flow_state, dfSeasonFlow, flow_dispatch

    # Convert target_step to zero-based index
    end_index = target_step

    while flow_state['step'] < len(dfSeasonFlow) and flow_state['step'] < end_index:
        row = dfSeasonFlow.iloc[flow_state['step']]
        step_desc = row['functionToCall']
        print(f"\n=== STEP {flow_state['step']+1}: {step_desc} ===")

        if step_desc in flow_dispatch:
            flow_dispatch[step_desc](row)
        else:
            print(f"[Skipped] No function mapped for: {step_desc}")

        flow_state['step'] += 1

    if flow_state['step'] >= end_index:
        print(f"\n=== Reached step {target_step}. Stopped. Current pointer: {flow_state['step']} ===")
    else:
        print("\n=== All flow steps completed before reaching the target ===")

run_flow_to(212)
# Out:
# === STEP 2: Create Team Attributes ===
# ✅ Team attributes created for 2024
#
# === STEP 3: Initialize Cup Status ===
# ✅ Initialized cup status:
#   inCS: 2 teams
#   inCL: 32 teams
#   inEL: 32 teams
#   inFA: 80 teams
#   inLC: 72 teams
#
# === STEP 4: Draw Cup ===
#
# 🏆 Community Shield draw (1 matches) across: 2024-08-04
#   Match 01 (day 3): Arsenal vs Manchester City
#
# === STEP 5: Draw Cup ===
#
# 🏆 League Cup draw (36 matches) across: 2024-08-13, 2024-08-14
#   Match 01 (day 4): Hull City vs Derby
#   Match 02 (day 4): Harrogate Town vs Blackburn
#   Match 03 (day 4): QPR vs Millwall
#   Match 04 (day 4): Peterborough vs Portsmouth
#   Match 05 (day 4): Forest Green vs Wycombe
#   Match 06 (day 4): West Brom vs Stoke City
#   Match 07 (day 4): Sunderland vs Mansfield Town
#   Match 08 (day 4): Rotherham vs Watford
#   Match 09 (day 4): Salford City vs Plymouth
#   Match 10 (day 4): Milton Keynes Dons vs Walsall
#   Match 11 (day 4): Oxford United vs Fleetwood Town
#   Match 12 (day 4): Swindon Town vs Cardiff
#   Match 13 (day 4): Crewe vs Crawley Town
#   Match 14 (day 4): Northampton vs Barrow
#   Match 15 (day 4): Burton Albion vs Wigan
#   Match 16 (day 4): Preston vs Leeds
#   Match 17 (day 4): Middlesbrough vs Leyton Orient
#   Match 18 (day 4): Charlton vs Gillingham
#   Match 19 (day 4): Birmingham vs Wrexham
#   Match 20 (day 4): AFC Wimbledon vs Shrewsbury
#   Match 21 (day 4): Tranmere vs Morecambe
#   Match 22 (day 4): Stevenage vs Leicester
#   Match 23 (day 4): Bristol Rovers vs Carlisle
#   Match 24 (day 4): Exeter City vs Bradford
#   Match 25 (day 4): Grimsby vs Stockport County
#   Match 26 (day 4): Cheltenham vs Huddersfield
#   Match 27 (day 4): Newport County vs Colchester
#   Match 28 (day 4): Port Vale vs Barnsley
#   Match 29 (day 4): Coventry vs Notts County
#   Match 30 (day 5): Norwich vs Ipswich
#   Match 31 (day 5): Cambridge United vs Sheffield Wednesday
#   Match 32 (day 5): Sutton Utd vs Reading
#   Match 33 (day 5): Swansea vs Bristol City
#   Match 34 (day 5): Accrington ST vs Southampton
#   Match 35 (day 5): Blackpool vs Lincoln
#   Match 36 (day 5): Bolton vs Doncaster
#
# === STEP 6: Play League Matches ===
#
# Domestic matches on 2024-08-02:
# Championship
# Sheffield Wednesday 1 - 3 Southampton
#
# === STEP 7: Play League Matches ===
#
# Domestic matches on 2024-08-03:
# Championship
# Watford 3 - 0 QPR
# Bristol City 0 - 0 Preston
# Blackburn 3 - 0 West Brom
# Middlesbrough 3 - 2 Millwall
# Norwich 1 - 0 Hull City
# Stoke City 1 - 2 Rotherham
# Swansea 2 - 0 Birmingham
# Plymouth 2 - 1 Huddersfield
# League One
# Carlisle 1 - 2 Fleetwood Town
# Wycombe 1 - 1 Exeter City
# Cambridge United 0 - 1 Oxford United
# Reading 4 - 0 Peterborough
# Derby 1 - 0 Wigan
# Barnsley 2 - 1 Port Vale
# Charlton 1 - 1 Leyton Orient
# Northampton 3 - 0 Stevenage
# Shrewsbury 0 - 1 Cheltenham
# Portsmouth 3 - 0 Bristol Rovers
# Blackpool 3 - 0 Burton Albion
# Bolton 2 - 1 Lincoln
# League Two
# Accrington ST 1 - 0 Newport County
# Crawley Town 0 - 2 Bradford
# Crewe 0 - 1 Mansfield Town
# Grimsby 1 - 0 AFC Wimbledon
# Morecambe 1 - 0 Walsall
# Forest Green 2 - 0 Salford City
# Tranmere 0 - 3 Barrow
# Doncaster 1 - 1 Harrogate Town
# Sutton Utd 2 - 0 Notts County
# Stockport County 3 - 0 Gillingham
# Wrexham 1 - 1 Milton Keynes Dons
# National League
# Southend 1 - 0 Oldham
# Chesterfield 2 - 0 Dorking Wanderers
# Barnet 3 - 1 Hartlepool
# Aldershot Town 2 - 1 Oxford City
# Gateshead 1 - 2 Boreham Wood
# Solihull Moors 1 - 0 Eastleigh
# FC Halifax Town 0 - 1 Bromley
# Maidenhead 3 - 0 AFC Fylde
# Altrincham 1 - 2 Dagenham & Redbridge
# Wealdstone 2 - 1 York
# Rochdale 2 - 1 Ebbsfleet United
# Kidderminster Harriers 1 - 2 Woking
#
# === STEP 8: Play League Matches ===
#
# Domestic matches on 2024-08-04:
# Championship
# Leicester 2 - 0 Coventry
# Leeds 3 - 0 Cardiff
# Sunderland 1 - 0 Ipswich
#
# === STEP 9: Play Cup Round ===
# Day 3 | Community Shield | Arsenal 2–1 Manchester City (a.e.t.) → Winner: Arsenal
#
# === STEP 10: Play Cup Round ===
# Day 4 | League Cup | Hull City 3–0 Derby → Winner: Hull City
# Day 4 | League Cup | Harrogate Town 0–3 Blackburn → Winner: Blackburn
# Day 4 | League Cup | QPR 0–1 Millwall → Winner: Millwall
# Day 4 | League Cup | Peterborough 3–4 Portsmouth (a.e.t.) → Winner: Portsmouth
# Day 4 | League Cup | Forest Green 1–1 Wycombe (a.e.t.) [p 4–3] → Winner: Forest Green
# Day 4 | League Cup | West Brom 2–0 Stoke City → Winner: West Brom
# Day 4 | League Cup | Sunderland 1–0 Mansfield Town → Winner: Sunderland
# Day 4 | League Cup | Rotherham 0–2 Watford → Winner: Watford
# Day 4 | League Cup | Salford City 2–1 Plymouth → Winner: Salford City
# Day 4 | League Cup | Milton Keynes Dons 3–1 Walsall → Winner: Milton Keynes Dons
# Day 4 | League Cup | Oxford United 0–3 Fleetwood Town → Winner: Fleetwood Town
# Day 4 | League Cup | Swindon Town 2–1 Cardiff → Winner: Swindon Town
# Day 4 | League Cup | Crewe 2–0 Crawley Town → Winner: Crewe
# Day 4 | League Cup | Northampton 1–0 Barrow → Winner: Northampton
# Day 4 | League Cup | Burton Albion 1–2 Wigan (a.e.t.) → Winner: Wigan
# Day 4 | League Cup | Preston 0–3 Leeds → Winner: Leeds
# Day 4 | League Cup | Middlesbrough 2–0 Leyton Orient → Winner: Middlesbrough
# Day 4 | League Cup | Charlton 3–0 Gillingham → Winner: Charlton
# Day 4 | League Cup | Birmingham 1–0 Wrexham → Winner: Birmingham
# Day 4 | League Cup | AFC Wimbledon 1–3 Shrewsbury → Winner: Shrewsbury
# Day 4 | League Cup | Tranmere 0–2 Morecambe → Winner: Morecambe
# Day 4 | League Cup | Stevenage 0–2 Leicester → Winner: Leicester
# Day 4 | League Cup | Bristol Rovers 2–1 Carlisle → Winner: Bristol Rovers
# Day 4 | League Cup | Exeter City 0–2 Bradford → Winner: Bradford
# Day 4 | League Cup | Grimsby 3–2 Stockport County → Winner: Grimsby
# Day 4 | League Cup | Cheltenham 0–3 Huddersfield → Winner: Huddersfield
# Day 4 | League Cup | Newport County 1–0 Colchester → Winner: Newport County
# Day 4 | League Cup | Port Vale 0–4 Barnsley → Winner: Barnsley
# Day 4 | League Cup | Coventry 2–0 Notts County → Winner: Coventry
#
# === STEP 11: Play Cup Round ===
# Day 5 | League Cup | Norwich 1–2 Ipswich (a.e.t.) → Winner: Ipswich
# Day 5 | League Cup | Cambridge United 1–2 Sheffield Wednesday → Winner: Sheffield Wednesday
# Day 5 | League Cup | Sutton Utd 2–3 Reading (a.e.t.) → Winner: Reading
# Day 5 | League Cup | Swansea 0–1 Bristol City → Winner: Bristol City
# Day 5 | League Cup | Accrington ST 1–4 Southampton → Winner: Southampton
# Day 5 | League Cup | Blackpool 1–0 Lincoln → Winner: Blackpool
# Day 5 | League Cup | Bolton 1–0 Doncaster → Winner: Bolton
#
# === STEP 12: Update Cup Status ===
# Day 4 | League Cup | Knocked out: Derby → inLC = False
# Day 4 | League Cup | Knocked out: Harrogate Town → inLC = False
# Day 4 | League Cup | Knocked out: QPR → inLC = False
# Day 4 | League Cup | Knocked out: Peterborough → inLC = False
# Day 4 | League Cup | Knocked out: Wycombe → inLC = False
# Day 4 | League Cup | Knocked out: Stoke City → inLC = False
# Day 4 | League Cup | Knocked out: Mansfield Town → inLC = False
# Day 4 | League Cup | Knocked out: Rotherham → inLC = False
# Day 4 | League Cup | Knocked out: Plymouth → inLC = False
# Day 4 | League Cup | Knocked out: Walsall → inLC = False
# Day 4 | League Cup | Knocked out: Oxford United → inLC = False
# Day 4 | League Cup | Knocked out: Cardiff → inLC = False
# Day 4 | League Cup | Knocked out: Crawley Town → inLC = False
# Day 4 | League Cup | Knocked out: Barrow → inLC = False
# Day 4 | League Cup | Knocked out: Burton Albion → inLC = False
# Day 4 | League Cup | Knocked out: Preston → inLC = False
# Day 4 | League Cup | Knocked out: Leyton Orient → inLC = False
# Day 4 | League Cup | Knocked out: Gillingham → inLC = False
# Day 4 | League Cup | Knocked out: Wrexham → inLC = False
# Day 4 | League Cup | Knocked out: AFC Wimbledon → inLC = False
# Day 4 | League Cup | Knocked out: Tranmere → inLC = False
# Day 4 | League Cup | Knocked out: Stevenage → inLC = False
# Day 4 | League Cup | Knocked out: Carlisle → inLC = False
# Day 4 | League Cup | Knocked out: Exeter City → inLC = False
# Day 4 | League Cup | Knocked out: Stockport County → inLC = False
# Day 4 | League Cup | Knocked out: Cheltenham → inLC = False
# Day 4 | League Cup | Knocked out: Colchester → inLC = False
# Day 4 | League Cup | Knocked out: Port Vale → inLC = False
# Day 4 | League Cup | Knocked out: Notts County → inLC = False
# Day 5 | League Cup | Knocked out: Norwich → inLC = False
# Day 5 | League Cup | Knocked out: Cambridge United → inLC = False
# Day 5 | League Cup | Knocked out: Sutton Utd → inLC = False
# Day 5 | League Cup | Knocked out: Swansea → inLC = False
# Day 5 | League Cup | Knocked out: Accrington ST → inLC = False
# Day 5 | League Cup | Knocked out: Lincoln → inLC = False
# Day 5 | League Cup | Knocked out: Doncaster → inLC = False
#
# === STEP 13: Add LC Round2 Teams ===
# Added to LC Round 2: Bournemouth, Brentford, Burnley, Chelsea, Crystal Palace, Everton, Fulham, Luton, Nottingham Forest, Sheffield Utd, West Ham, Wolves
#
# === STEP 14: Draw Cup ===
#
# 🏆 League Cup draw (24 matches) across: 2024-08-27, 2024-08-28
#   Match 01 (day 20): Leeds vs Grimsby
#   Match 02 (day 20): Newport County vs Morecambe
#   Match 03 (day 20): Bristol City vs Birmingham
#   Match 04 (day 20): West Ham vs Brentford
#   Match 05 (day 20): Northampton vs Salford City
#   Match 06 (day 20): Everton vs Portsmouth
#   Match 07 (day 20): Huddersfield vs Nottingham Forest
#   Match 08 (day 20): Bournemouth vs Wolves
#   Match 09 (day 20): Forest Green vs Crewe
#   Match 10 (day 20): Chelsea vs Millwall
#   Match 11 (day 20): Sheffield Wednesday vs Wigan
#   Match 12 (day 20): Ipswich vs Southampton
#   Match 13 (day 20): Fleetwood Town vs Leicester
#   Match 14 (day 20): Fulham vs Milton Keynes Dons
#   Match 15 (day 20): Watford vs Bolton
#   Match 16 (day 20): Middlesbrough vs Crystal Palace
#   Match 17 (day 20): Blackpool vs Swindon Town
#   Match 18 (day 20): Burnley vs Charlton
#   Match 19 (day 20): Reading vs Sheffield Utd
#   Match 20 (day 21): Blackburn vs West Brom
#   Match 21 (day 21): Sunderland vs Luton
#   Match 22 (day 21): Shrewsbury vs Barnsley
#   Match 23 (day 21): Hull City vs Bristol Rovers
#   Match 24 (day 21): Bradford vs Coventry
#
# === STEP 15: Play League Matches ===
#
# Domestic matches on 2024-08-09:
# Premier League
# Burnley 0 - 2 Manchester City
#
# === STEP 16: Play League Matches ===
#
# Domestic matches on 2024-08-10:
# Premier League
# Brighton 0 - 1 Luton
# Sheffield Utd 1 - 1 Crystal Palace
# Newcastle 1 - 0 Aston Villa
# Bournemouth 2 - 1 West Ham
# Everton 1 - 2 Fulham
# Arsenal 3 - 0 Nottingham Forest
# Championship
# Coventry 0 - 0 Middlesbrough
# Huddersfield 1 - 1 Leicester
# Watford 2 - 0 Plymouth
# Southampton 3 - 0 Norwich
# Cardiff 0 - 1 QPR
# Birmingham 0 - 0 Leeds
# Ipswich 0 - 3 Stoke City
# Millwall 2 - 1 Bristol City
# Preston 0 - 2 Sunderland
# West Brom 1 - 2 Swansea
# Hull City 3 - 0 Sheffield Wednesday
# Rotherham 1 - 2 Blackburn
# League One
# Wigan 1 - 1 Northampton
# Bristol Rovers 0 - 0 Barnsley
# Fleetwood Town 1 - 3 Cambridge United
# Oxford United 2 - 0 Carlisle
# Peterborough 2 - 0 Charlton
# Port Vale 0 - 0 Reading
# Exeter City 0 - 1 Blackpool
# Stevenage 1 - 2 Shrewsbury
# Cheltenham 1 - 0 Bolton
# Leyton Orient 0 - 2 Portsmouth
# Lincoln 1 - 1 Wycombe
# Burton Albion 1 - 0 Derby
# League Two
# AFC Wimbledon 3 - 1 Wrexham
# Mansfield Town 0 - 3 Morecambe
# Notts County 3 - 0 Grimsby
# Barrow 2 - 0 Sutton Utd
# Salford City 5 - 0 Crawley Town
# Harrogate Town 1 - 1 Forest Green
# Walsall 3 - 2 Stockport County
# Bradford 1 - 0 Colchester
# Gillingham 2 - 0 Accrington ST
# Milton Keynes Dons 0 - 0 Tranmere
# Swindon Town 2 - 0 Crewe
# Newport County 2 - 2 Doncaster
# National League
# Ebbsfleet United 0 - 2 Solihull Moors
# Oxford City 1 - 1 Rochdale
# Dorking Wanderers 2 - 2 Maidenhead
# Bromley 0 - 0 Barnet
# AFC Fylde 0 - 1 Chesterfield
# Oldham 2 - 0 Aldershot Town
# Hartlepool 4 - 0 Gateshead
# Dagenham & Redbridge 2 - 1 Southend
# Eastleigh 1 - 2 Wealdstone
# York 2 - 2 Kidderminster Harriers
# Boreham Wood 3 - 1 FC Halifax Town
# Woking 4 - 0 Altrincham
#
# === STEP 17: Play League Matches ===
#
# Domestic matches on 2024-08-11:
# Premier League
# Chelsea 1 - 1 Liverpool
# Brentford 0 - 4 Tottenham
#
# === STEP 18: Play League Matches ===
#
# Domestic matches on 2024-08-12:
# Premier League
# Manchester United 3 - 0 Wolves
#
# === STEP 19: Play League Matches ===
#
# Domestic matches on 2024-08-20:
# League One
# Barnsley 1 - 1 Peterborough
# Carlisle 1 - 1 Wigan
# Cambridge United 0 - 0 Stevenage
# Wycombe 1 - 0 Leyton Orient
# Blackpool 0 - 0 Port Vale
# Shrewsbury 0 - 1 Burton Albion
# Northampton 1 - 4 Lincoln
# Charlton 2 - 1 Bristol Rovers
# Reading 3 - 0 Cheltenham
# Portsmouth 1 - 1 Exeter City
# Derby 2 - 0 Oxford United
# Bolton 3 - 0 Fleetwood Town
# League Two
# Accrington ST 2 - 2 Barrow
# Sutton Utd 1 - 0 Gillingham
# Tranmere 2 - 0 Harrogate Town
# Forest Green 4 - 1 Swindon Town
# Morecambe 2 - 0 Notts County
# Grimsby 1 - 1 Salford City
# Crewe 2 - 0 Newport County
# Doncaster 0 - 1 Mansfield Town
# Crawley Town 0 - 1 Milton Keynes Dons
# Colchester 2 - 1 AFC Wimbledon
# Wrexham 0 - 3 Walsall
# Stockport County 4 - 2 Bradford
# National League
# Oldham 3 - 1 FC Halifax Town
# Hartlepool 2 - 0 Maidenhead
# Dagenham & Redbridge 0 - 0 Gateshead
# Eastleigh 2 - 0 Barnet
# Bromley 2 - 0 Wealdstone
# Woking 1 - 0 Rochdale
# AFC Fylde 0 - 2 Kidderminster Harriers
# Ebbsfleet United 1 - 0 Aldershot Town
# Oxford City 0 - 1 Chesterfield
# Dorking Wanderers 0 - 1 Southend
# York 1 - 2 Altrincham
#
# === STEP 20: Play League Matches ===
#
# Domestic matches on 2024-08-21:
# National League
# Boreham Wood 1 - 1 Solihull Moors
#
# === STEP 21: Play League Matches ===
#
# Domestic matches on 2024-08-16:
# Premier League
# Nottingham Forest 1 - 0 Sheffield Utd
# Championship
# Leeds 2 - 0 West Brom
#
# === STEP 22: Play League Matches ===
#
# Domestic matches on 2024-08-17:
# Premier League
# Fulham 2 - 0 Brentford
# Wolves 0 - 0 Brighton
# Liverpool 1 - 0 Bournemouth
# Tottenham 3 - 0 Manchester United
# Manchester City 1 - 0 Newcastle
# Championship
# Sunderland 1 - 1 Rotherham
# Swansea 2 - 0 Coventry
# Sheffield Wednesday 1 - 2 Preston
# QPR 1 - 1 Ipswich
# Stoke City 1 - 0 Watford
# Plymouth 1 - 0 Southampton
# Leicester 1 - 1 Cardiff
# Bristol City 3 - 1 Birmingham
# Blackburn 4 - 0 Hull City
# Middlesbrough 0 - 0 Huddersfield
# League One
# Derby 2 - 2 Fleetwood Town
# Reading 3 - 0 Stevenage
# Charlton 3 - 1 Port Vale
# Wycombe 1 - 0 Burton Albion
# Cambridge United 0 - 4 Bristol Rovers
# Carlisle 0 - 1 Exeter City
# Shrewsbury 1 - 2 Lincoln
# Northampton 0 - 3 Peterborough
# Bolton 1 - 2 Wigan
# Blackpool 0 - 0 Leyton Orient
# Barnsley 2 - 1 Oxford United
# Portsmouth 1 - 1 Cheltenham
# League Two
# Stockport County 1 - 2 Barrow
# Wrexham 1 - 2 Swindon Town
# Sutton Utd 0 - 1 AFC Wimbledon
# Tranmere 0 - 1 Salford City
# Forest Green 0 - 0 Newport County
# Morecambe 1 - 0 Bradford
# Crewe 1 - 1 Walsall
# Crawley Town 1 - 0 Gillingham
# Colchester 0 - 1 Milton Keynes Dons
# Accrington ST 1 - 0 Harrogate Town
# Doncaster 1 - 2 Notts County
# Grimsby 2 - 0 Mansfield Town
# National League
# Solihull Moors 1 - 1 Dorking Wanderers
# Maidenhead 1 - 1 Dagenham & Redbridge
# FC Halifax Town 2 - 0 Oxford City
# Kidderminster Harriers 0 - 3 Bromley
# Barnet 0 - 2 Woking
# Aldershot Town 1 - 0 York
# Gateshead 1 - 1 Ebbsfleet United
# Chesterfield 2 - 1 Oldham
# Rochdale 1 - 0 Eastleigh
# Southend 2 - 0 Hartlepool
# Wealdstone 3 - 0 AFC Fylde
# Altrincham 2 - 1 Boreham Wood
#
# === STEP 23: Play League Matches ===
#
# Domestic matches on 2024-08-18:
# Premier League
# Aston Villa 2 - 1 Everton
# West Ham 3 - 1 Chelsea
# Championship
# Norwich 0 - 0 Millwall
#
# === STEP 24: Play League Matches ===
#
# Domestic matches on 2024-08-19:
# Premier League
# Crystal Palace 0 - 2 Arsenal
#
# === STEP 25: Play League Matches ===
#
# Domestic matches on 2024-08-23:
# Premier League
# Chelsea 2 - 0 Luton
# Championship
# Hull City 1 - 2 Bristol City
# National League
# Solihull Moors 4 - 0 FC Halifax Town
# Southend 0 - 0 Eastleigh
# Rochdale 2 - 1 Bromley
#
# === STEP 26: Play League Matches ===
#
# Domestic matches on 2024-08-24:
# Premier League
# Arsenal 1 - 1 Fulham
# Everton 1 - 1 Wolves
# Manchester United 1 - 1 Nottingham Forest
# Bournemouth 1 - 3 Tottenham
# Brentford 1 - 2 Crystal Palace
# Brighton 0 - 1 West Ham
# Championship
# Coventry 0 - 1 Sunderland
# Rotherham 0 - 1 Leicester
# West Brom 1 - 0 Middlesbrough
# Preston 2 - 1 Swansea
# Millwall 3 - 0 Stoke City
# Ipswich 2 - 2 Leeds
# Birmingham 0 - 0 Plymouth
# Cardiff 2 - 1 Sheffield Wednesday
# Southampton 0 - 2 QPR
# Huddersfield 1 - 1 Norwich
# League One
# Oxford United 2 - 2 Charlton
# Leyton Orient 2 - 2 Cambridge United
# Lincoln 0 - 3 Blackpool
# Burton Albion 1 - 2 Bolton
# Bristol Rovers 0 - 4 Wycombe
# Fleetwood Town 0 - 0 Shrewsbury
# Peterborough 3 - 0 Derby
# Port Vale 5 - 0 Carlisle
# Exeter City 2 - 3 Reading
# Stevenage 1 - 3 Portsmouth
# Cheltenham 2 - 0 Northampton
# Wigan 0 - 2 Barnsley
# League Two
# AFC Wimbledon 0 - 3 Forest Green
# Walsall 1 - 0 Grimsby
# Bradford 1 - 1 Crewe
# Gillingham 2 - 0 Colchester
# Swindon Town 2 - 0 Crawley Town
# Newport County 1 - 0 Sutton Utd
# Mansfield Town 0 - 1 Stockport County
# Notts County 1 - 0 Tranmere
# Barrow 0 - 0 Wrexham
# Harrogate Town 2 - 0 Morecambe
# Salford City 1 - 1 Accrington ST
# Milton Keynes Dons 1 - 0 Doncaster
# National League
# Dagenham & Redbridge 1 - 2 Barnet
# Aldershot Town 1 - 3 Wealdstone
# Gateshead 2 - 1 Woking
# Boreham Wood 0 - 0 Oldham
# Maidenhead 1 - 1 Oxford City
# Ebbsfleet United 1 - 0 Kidderminster Harriers
# Altrincham 3 - 2 Chesterfield
# Dorking Wanderers 2 - 0 York
# Hartlepool 2 - 0 AFC Fylde
#
# === STEP 27: Play League Matches ===
#
# Domestic matches on 2024-08-25:
# Premier League
# Sheffield Utd 0 - 2 Manchester City
# Burnley 1 - 2 Aston Villa
# Newcastle 2 - 1 Liverpool
# Championship
# Watford 1 - 1 Blackburn
#
# === STEP 28: Play League Matches ===
#
# Domestic matches on 2024-08-26:
# National League
# AFC Fylde 0 - 0 Altrincham
# Kidderminster Harriers 0 - 1 Maidenhead
# Wealdstone 2 - 1 Dagenham & Redbridge
# FC Halifax Town 4 - 0 Gateshead
# Barnet 2 - 0 Ebbsfleet United
# Woking 3 - 0 Dorking Wanderers
# Bromley 2 - 3 Southend
# Chesterfield 1 - 2 Hartlepool
# York 1 - 3 Rochdale
# Eastleigh 1 - 1 Aldershot Town
# Oldham 1 - 0 Solihull Moors
# Oxford City 1 - 1 Boreham Wood
#
# === STEP 29: Draw European Group Stage ===
#
# Populated Champions League Group Stage (competitionID=9):
#   Group 1: Atletico Madrid, Celtic, Newcastle, SC Braga
#   Group 2: Napoli, RB Leipzig, Galatasaray, FC Copenhagen
#   Group 3: Real Madrid, PSV Eindhoven, Paris Saint Germain, Red Star Belgrade
#   Group 4: Barcelona, Lazio, Red Bull Salzburg, Union Berlin
#   Group 5: Bayern Munich, Manchester United, Benfica, Real Sociedad
#   Group 6: Ajax, Antwerp, Arsenal, BSC Young Boys
#   Group 7: AC Milan, Borussia Dortmund, Lens, Manchester City
#   Group 8: FC Porto, Feyenoord, Inter, Sevilla
#
# === STEP 30: Draw European Group Stage ===
#
# Populated Europa League Group Stage (competitionID=8):
#   Group 1: Olympiacos, Qarabag, Rangers, Servette FC
#   Group 2: Villarreal, Tottenham, Union St. Gilloise, TSC Backa Topola
#   Group 3: SC Freiburg, Panathinaikos, Aston Villa, Marseille
#   Group 4: Sporting CP, AEK Athens FC, Sheriff Tiraspol, Bayer Leverkusen
#   Group 5: Slavia Praha, Atalanta, Lask Linz, Toulouse
#   Group 6: AS Roma, Aris Limassol, Maccabi Haifa, Real Betis
#   Group 7: Liverpool, Molde, Shakhtar Donetsk, Sturm Graz
#   Group 8: BK Hacken, Brighton, Sparta Praha, Rennes
#
# === STEP 31: Play Cup Round ===
# Day 20 | League Cup | Leeds 2–0 Grimsby → Winner: Leeds
# Day 20 | League Cup | Newport County 0–2 Morecambe → Winner: Morecambe
# Day 20 | League Cup | Bristol City 2–1 Birmingham → Winner: Bristol City
# Day 20 | League Cup | West Ham 3–0 Brentford → Winner: West Ham
# Day 20 | League Cup | Northampton 0–1 Salford City (a.e.t.) → Winner: Salford City
# Day 20 | League Cup | Everton 1–0 Portsmouth (a.e.t.) → Winner: Everton
# Day 20 | League Cup | Huddersfield 0–1 Nottingham Forest → Winner: Nottingham Forest
# Day 20 | League Cup | Bournemouth 1–0 Wolves → Winner: Bournemouth
# Day 20 | League Cup | Forest Green 2–0 Crewe → Winner: Forest Green
# Day 20 | League Cup | Chelsea 4–0 Millwall → Winner: Chelsea
# Day 20 | League Cup | Sheffield Wednesday 1–2 Wigan (a.e.t.) → Winner: Wigan
# Day 20 | League Cup | Ipswich 1–1 Southampton (a.e.t.) [p 2–4] → Winner: Southampton
# Day 20 | League Cup | Fleetwood Town 0–3 Leicester → Winner: Leicester
# Day 20 | League Cup | Fulham 2–0 Milton Keynes Dons → Winner: Fulham
# Day 20 | League Cup | Watford 3–1 Bolton → Winner: Watford
# Day 20 | League Cup | Middlesbrough 1–2 Crystal Palace → Winner: Crystal Palace
# Day 20 | League Cup | Blackpool 0–1 Swindon Town → Winner: Swindon Town
# Day 20 | League Cup | Burnley 3–1 Charlton → Winner: Burnley
# Day 20 | League Cup | Reading 2–0 Sheffield Utd → Winner: Reading
#
# === STEP 32: Play Cup Round ===
# Day 21 | League Cup | Blackburn 2–0 West Brom → Winner: Blackburn
# Day 21 | League Cup | Sunderland 4–1 Luton → Winner: Sunderland
# Day 21 | League Cup | Shrewsbury 0–1 Barnsley → Winner: Barnsley
# Day 21 | League Cup | Hull City 2–0 Bristol Rovers → Winner: Hull City
# Day 21 | League Cup | Bradford 0–3 Coventry → Winner: Coventry
#
# === STEP 33: Update Cup Status ===
# Day 20 | League Cup | Knocked out: Grimsby → inLC = False
# Day 20 | League Cup | Knocked out: Newport County → inLC = False
# Day 20 | League Cup | Knocked out: Birmingham → inLC = False
# Day 20 | League Cup | Knocked out: Brentford → inLC = False
# Day 20 | League Cup | Knocked out: Northampton → inLC = False
# Day 20 | League Cup | Knocked out: Portsmouth → inLC = False
# Day 20 | League Cup | Knocked out: Huddersfield → inLC = False
# Day 20 | League Cup | Knocked out: Wolves → inLC = False
# Day 20 | League Cup | Knocked out: Crewe → inLC = False
# Day 20 | League Cup | Knocked out: Millwall → inLC = False
# Day 20 | League Cup | Knocked out: Sheffield Wednesday → inLC = False
# Day 20 | League Cup | Knocked out: Ipswich → inLC = False
# Day 20 | League Cup | Knocked out: Fleetwood Town → inLC = False
# Day 20 | League Cup | Knocked out: Milton Keynes Dons → inLC = False
# Day 20 | League Cup | Knocked out: Bolton → inLC = False
# Day 20 | League Cup | Knocked out: Middlesbrough → inLC = False
# Day 20 | League Cup | Knocked out: Blackpool → inLC = False
# Day 20 | League Cup | Knocked out: Charlton → inLC = False
# Day 20 | League Cup | Knocked out: Sheffield Utd → inLC = False
# Day 21 | League Cup | Knocked out: West Brom → inLC = False
# Day 21 | League Cup | Knocked out: Luton → inLC = False
# Day 21 | League Cup | Knocked out: Shrewsbury → inLC = False
# Day 21 | League Cup | Knocked out: Bristol Rovers → inLC = False
# Day 21 | League Cup | Knocked out: Bradford → inLC = False
#
# === STEP 34: Add LC Round3 Teams ===
# Added to LC Round 3: Arsenal, Aston Villa, Brighton, Liverpool, Manchester City, Manchester United, Newcastle, Tottenham
#
# === STEP 35: Draw Cup ===
#
# 🏆 League Cup draw (16 matches) across: 2024-09-24, 2024-09-25
#   Match 01 (day 38): Leicester vs Reading
#   Match 02 (day 38): Swindon Town vs Brighton
#   Match 03 (day 38): Salford City vs Bournemouth
#   Match 04 (day 38): Burnley vs Watford
#   Match 05 (day 38): Crystal Palace vs Blackburn
#   Match 06 (day 38): West Ham vs Morecambe
#   Match 07 (day 38): Barnsley vs Wigan
#   Match 08 (day 39): Arsenal vs Newcastle
#   Match 09 (day 39): Southampton vs Manchester City
#   Match 10 (day 39): Sunderland vs Liverpool
#   Match 11 (day 39): Nottingham Forest vs Everton
#   Match 12 (day 39): Fulham vs Chelsea
#   Match 13 (day 39): Tottenham vs Forest Green
#   Match 14 (day 39): Leeds vs Hull City
#   Match 15 (day 39): Bristol City vs Manchester United
#   Match 16 (day 39): Coventry vs Aston Villa
#
# === STEP 36: Play League Matches ===
#
# Domestic matches on 2024-09-06:
# Premier League
# Luton 1 - 1 West Ham
#
# === STEP 37: Play League Matches ===
#
# Domestic matches on 2024-09-07:
# Premier League
# Brighton 0 - 1 Newcastle
# Brentford 0 - 0 Bournemouth
# Manchester City 3 - 2 Fulham
# Chelsea 1 - 0 Nottingham Forest
# Burnley 0 - 0 Tottenham
# Sheffield Utd 2 - 1 Everton
# Championship
# Coventry 1 - 1 Watford
# Birmingham 1 - 0 Millwall
# Swansea 1 - 3 Bristol City
# Sunderland 2 - 0 Southampton
# Plymouth 0 - 1 Blackburn
# Leicester 2 - 1 Hull City
# Ipswich 0 - 0 Cardiff
# West Brom 0 - 2 Huddersfield
# Leeds 2 - 0 Sheffield Wednesday
# Middlesbrough 2 - 0 QPR
# Rotherham 2 - 1 Norwich
# Stoke City 2 - 0 Preston
# League One
# Burton Albion 1 - 0 Exeter City
# Leyton Orient 0 - 0 Stevenage
# Bristol Rovers 4 - 0 Lincoln
# Charlton 0 - 0 Fleetwood Town
# Northampton 1 - 2 Wycombe
# Oxford United 3 - 3 Port Vale
# Bolton 0 - 1 Derby
# Blackpool 0 - 0 Wigan
# Carlisle 0 - 1 Shrewsbury
# Cheltenham 2 - 2 Barnsley
# Portsmouth 2 - 2 Peterborough
# League Two
# Stockport County 2 - 1 Crawley Town
# Harrogate Town 1 - 3 Barrow
# Tranmere 0 - 0 Wrexham
# Walsall 1 - 0 Colchester
# Doncaster 0 - 0 Swindon Town
# Grimsby 0 - 1 Gillingham
# Newport County 2 - 0 AFC Wimbledon
# Mansfield Town 1 - 0 Bradford
# Morecambe 2 - 1 Salford City
# Notts County 1 - 0 Accrington ST
# Sutton Utd 0 - 1 Forest Green
# Crewe 0 - 2 Milton Keynes Dons
# National League
# Rochdale 1 - 2 FC Halifax Town
# Hartlepool 3 - 1 Wealdstone
# Aldershot Town 1 - 2 Chesterfield
# Dagenham & Redbridge 0 - 3 AFC Fylde
# Boreham Wood 0 - 3 Barnet
# Solihull Moors 2 - 0 Oxford City
# Maidenhead 1 - 2 Woking
# Ebbsfleet United 2 - 1 York
# Altrincham 0 - 1 Bromley
# Dorking Wanderers 1 - 0 Eastleigh
# Gateshead 1 - 2 Oldham
# Southend 0 - 1 Kidderminster Harriers
#
# === STEP 38: Play League Matches ===
#
# Domestic matches on 2024-09-01:
# Premier League
# Liverpool 1 - 3 Aston Villa
# Crystal Palace 2 - 2 Wolves
# Arsenal 0 - 1 Manchester United
#
# === STEP 39: Play League Matches ===
#
# Domestic matches on 2024-09-02:
# League One
# Cambridge United 0 - 1 Reading
#
# === STEP 40: Play League Matches ===
#
# Domestic matches on 2024-09-14:
# League One
# Exeter City 1 - 0 Leyton Orient
# Stevenage 0 - 0 Carlisle
# League Two
# Salford City 0 - 2 Walsall
# Wrexham 1 - 0 Doncaster
# Forest Green 1 - 0 Crewe
# Accrington ST 2 - 0 Mansfield Town
# Colchester 2 - 1 Tranmere
# Swindon Town 1 - 0 Sutton Utd
# Gillingham 2 - 0 Harrogate Town
# Bradford 4 - 0 Grimsby
# Crawley Town 0 - 0 Newport County
# AFC Wimbledon 2 - 1 Stockport County
# Milton Keynes Dons 2 - 1 Notts County
# National League
# Woking 3 - 1 Solihull Moors
# FC Halifax Town 2 - 1 Southend
# Chesterfield 2 - 0 Dagenham & Redbridge
# Oldham 1 - 1 Dorking Wanderers
# Barnet 0 - 0 Altrincham
# Eastleigh 1 - 0 Gateshead
# York 0 - 1 Boreham Wood
# Bromley 1 - 0 Maidenhead
# AFC Fylde 0 - 0 Aldershot Town
# Oxford City 0 - 1 Hartlepool
# Wealdstone 1 - 1 Ebbsfleet United
# Kidderminster Harriers 0 - 1 Rochdale
#
# === STEP 41: Play League Matches ===
#
# Domestic matches on 2024-09-20:
# Championship
# Southampton 3 - 1 Leicester
# Hull City 2 - 2 Coventry
# League Two
# Salford City 0 - 0 Notts County
#
# === STEP 42: Play League Matches ===
#
# Domestic matches on 2024-09-21:
# Premier League
# Wolves 1 - 0 Liverpool
# Manchester United 3 - 3 Brighton
# Fulham 1 - 0 Luton
# Tottenham 1 - 1 Sheffield Utd
# West Ham 1 - 1 Manchester City
# Aston Villa 2 - 2 Crystal Palace
# Newcastle 0 - 0 Brentford
# Championship
# Norwich 4 - 0 Stoke City
# Huddersfield 0 - 2 Rotherham
# Watford 3 - 2 Birmingham
# Bristol City 0 - 0 West Brom
# Preston 1 - 0 Plymouth
# Blackburn 2 - 1 Middlesbrough
# QPR 0 - 2 Sunderland
# Sheffield Wednesday 4 - 1 Ipswich
# Cardiff 2 - 0 Swansea
# League One
# Reading 1 - 1 Bolton
# Wigan 2 - 1 Cambridge United
# Derby 0 - 0 Portsmouth
# Barnsley 1 - 1 Burton Albion
# Fleetwood Town 0 - 2 Oxford United
# Peterborough 1 - 1 Leyton Orient
# Port Vale 1 - 1 Northampton
# Shrewsbury 0 - 1 Bristol Rovers
# Wycombe 3 - 1 Blackpool
# Stevenage 0 - 1 Charlton
# Lincoln 1 - 0 Carlisle
# Exeter City 0 - 1 Cheltenham
# League Two
# Bradford 4 - 0 Harrogate Town
# AFC Wimbledon 0 - 0 Crewe
# Gillingham 0 - 2 Morecambe
# Milton Keynes Dons 2 - 1 Stockport County
# Swindon Town 2 - 0 Walsall
# Accrington ST 4 - 0 Sutton Utd
# Forest Green 1 - 0 Doncaster
# Newport County 0 - 1 Barrow
# Crawley Town 1 - 3 Tranmere
# Colchester 1 - 0 Mansfield Town
# Wrexham 0 - 1 Grimsby
# National League
# Maidenhead 3 - 1 Boreham Wood
# Bromley 1 - 1 Oldham
# Kidderminster Harriers 0 - 1 Solihull Moors
# Aldershot Town 4 - 0 Gateshead
# Hartlepool 0 - 0 Woking
# Rochdale 2 - 1 Barnet
# York 0 - 1 Southend
# Oxford City 2 - 1 Dagenham & Redbridge
# Wealdstone 1 - 2 Altrincham
# FC Halifax Town 3 - 0 Dorking Wanderers
# AFC Fylde 2 - 3 Eastleigh
# Ebbsfleet United 0 - 1 Chesterfield
#
# === STEP 43: Play League Matches ===
#
# Domestic matches on 2024-09-15:
# Premier League
# Bournemouth 2 - 0 Chelsea
# Everton 1 - 1 Arsenal
# Championship
# Millwall 3 - 1 Leeds
#
# === STEP 44: Play League Matches ===
#
# Domestic matches on 2024-09-16:
# Premier League
# Nottingham Forest 2 - 1 Burnley
#
# === STEP 45: Play League Matches ===
#
# Domestic matches on 2024-09-17:
# Championship
# QPR 1 - 3 Swansea
# Sheffield Wednesday 2 - 2 Middlesbrough
# Bristol City 2 - 0 Plymouth
# Preston 1 - 0 Birmingham
# Cardiff 1 - 1 Coventry
# Southampton 1 - 0 Ipswich
# League One
# Port Vale 0 - 1 Burton Albion
# Barnsley 4 - 0 Portsmouth
# Peterborough 2 - 1 Cheltenham
# National League
# Southend 3 - 0 Maidenhead
# Chesterfield 0 - 3 FC Halifax Town
# Oldham 1 - 0 York
# Barnet 0 - 0 Aldershot Town
# Dagenham & Redbridge 3 - 0 Bromley
# Eastleigh 1 - 0 Oxford City
# Gateshead 3 - 1 Kidderminster Harriers
# Boreham Wood 2 - 2 Rochdale
# Altrincham 1 - 3 Hartlepool
# Dorking Wanderers 3 - 3 Wealdstone
# Woking 2 - 0 Ebbsfleet United
# Solihull Moors 0 - 0 AFC Fylde
#
# === STEP 46: Play European League ===
#
# European matches on 2024-09-17:
# Champions League
# Atletico Madrid 4 - 0 SC Braga
# Celtic 0 - 1 Newcastle
# Napoli 3 - 1 FC Copenhagen
# RB Leipzig 2 - 0 Galatasaray
# Real Madrid 4 - 2 Red Star Belgrade
# PSV Eindhoven 1 - 2 Paris Saint Germain
# Barcelona 1 - 1 Union Berlin
# Lazio 3 - 1 Red Bull Salzburg
#
# === STEP 47: Play League Matches ===
#
# Domestic matches on 2024-09-18:
# Championship
# Hull City 2 - 1 Leeds
# Norwich 2 - 0 Leicester
# Blackburn 0 - 2 Sunderland
# Huddersfield 2 - 1 Stoke City
# Watford 2 - 1 West Brom
# Millwall 1 - 0 Rotherham
#
# === STEP 48: Play European League ===
#
# European matches on 2024-09-18:
# Champions League
# Bayern Munich 1 - 2 Real Sociedad
# Manchester United 1 - 3 Benfica
# Ajax 0 - 1 BSC Young Boys
# Antwerp 0 - 3 Arsenal
# AC Milan 0 - 2 Manchester City
# Borussia Dortmund 1 - 1 Lens
# FC Porto 2 - 0 Sevilla
# Feyenoord 1 - 1 Inter
#
# === STEP 49: Play European League ===
#
# European matches on 2024-09-19:
# Europa League
# Olympiacos 2 - 2 Servette FC
# Qarabag 1 - 0 Rangers
# Villarreal 3 - 0 TSC Backa Topola
# Tottenham 0 - 0 Union St. Gilloise
# SC Freiburg 2 - 0 Marseille
# Panathinaikos 0 - 3 Aston Villa
# Sporting CP 0 - 1 Bayer Leverkusen
# AEK Athens FC 1 - 0 Sheriff Tiraspol
# Slavia Praha 1 - 0 Toulouse
# Atalanta 3 - 0 Lask Linz
# AS Roma 1 - 1 Real Betis
# Aris Limassol 1 - 3 Maccabi Haifa
# Liverpool 2 - 0 Sturm Graz
# Molde 2 - 0 Shakhtar Donetsk
# BK Hacken 0 - 3 Rennes
# Brighton 3 - 1 Sparta Praha
#
# === STEP 50: Play League Matches ===
#
# Domestic matches on 2024-09-27:
# Championship
# Birmingham 2 - 1 QPR
#
# === STEP 51: Play League Matches ===
#
# Domestic matches on 2024-09-28:
# Premier League
# Manchester City 1 - 1 Nottingham Forest
# Crystal Palace 1 - 2 Fulham
# Luton 0 - 1 Wolves
# Brentford 1 - 0 Everton
# Burnley 1 - 2 Manchester United
# Championship
# Leicester 2 - 1 Bristol City
# West Brom 2 - 0 Millwall
# Leeds 2 - 0 Watford
# Middlesbrough 2 - 0 Southampton
# Rotherham 0 - 0 Preston
# Swansea 0 - 0 Sheffield Wednesday
# Plymouth 1 - 0 Norwich
# Ipswich 0 - 1 Blackburn
# League One
# Bolton 2 - 1 Peterborough
# Cambridge United 3 - 0 Port Vale
# Leyton Orient 0 - 1 Shrewsbury
# Burton Albion 1 - 0 Fleetwood Town
# Carlisle 0 - 2 Derby
# Bristol Rovers 0 - 1 Wigan
# Charlton 0 - 2 Wycombe
# Northampton 1 - 1 Barnsley
# Oxford United 0 - 1 Exeter City
# Portsmouth 2 - 0 Lincoln
# Blackpool 0 - 0 Reading
# Cheltenham 2 - 0 Stevenage
# League Two
# Morecambe 1 - 1 Swindon Town
# Mansfield Town 3 - 1 Barrow
# Newport County 0 - 0 Bradford
# Grimsby 1 - 0 Crawley Town
# Crewe 2 - 2 Colchester
# Doncaster 0 - 2 Gillingham
# Walsall 3 - 0 AFC Wimbledon
# Stockport County 2 - 1 Wrexham
# Harrogate Town 1 - 1 Salford City
# Sutton Utd 0 - 1 Milton Keynes Dons
# Tranmere 0 - 0 Accrington ST
# Notts County 0 - 0 Forest Green
# National League
# Altrincham 1 - 0 Ebbsfleet United
# Dorking Wanderers 0 - 1 Rochdale
# Solihull Moors 0 - 0 Bromley
# Boreham Wood 0 - 1 Aldershot Town
# Eastleigh 2 - 0 Kidderminster Harriers
# Woking 0 - 0 York
# Southend 2 - 1 AFC Fylde
# Chesterfield 0 - 1 Wealdstone
# Barnet 1 - 2 FC Halifax Town
# Dagenham & Redbridge 1 - 0 Hartlepool
# Gateshead 1 - 1 Maidenhead
# Oldham 3 - 1 Oxford City
#
# === STEP 52: Play League Matches ===
#
# Domestic matches on 2024-09-22:
# Premier League
# Liverpool 2 - 1 West Ham
# Arsenal 2 - 1 Tottenham
# Brighton 2 - 0 Bournemouth
# Sheffield Utd 1 - 1 Newcastle
# Chelsea 2 - 1 Aston Villa
# Championship
# Sunderland 2 - 0 Cardiff
# Stoke City 1 - 1 Hull City
#
# === STEP 53: Play League Matches ===
#
# Domestic matches on 2024-09-23:
# Championship
# Coventry 1 - 0 Huddersfield
#
# === STEP 54: Play League Matches ===
#
# Domestic matches on 2024-09-24:
# National League
# Hartlepool 1 - 0 Solihull Moors
# Aldershot Town 0 - 0 Southend
# York 0 - 0 Barnet
# Bromley 1 - 2 Eastleigh
# Wealdstone 1 - 1 Woking
# Maidenhead 1 - 1 Altrincham
# AFC Fylde 0 - 2 Boreham Wood
# Ebbsfleet United 2 - 1 Dorking Wanderers
# FC Halifax Town 3 - 1 Dagenham & Redbridge
# Oxford City 1 - 2 Gateshead
# Kidderminster Harriers 0 - 2 Oldham
# Rochdale 0 - 1 Chesterfield
#
# === STEP 55: Play Cup Round ===
# Day 38 | League Cup | Leicester 2–1 Reading → Winner: Leicester
# Day 38 | League Cup | Swindon Town 1–0 Brighton (a.e.t.) → Winner: Swindon Town
# Day 38 | League Cup | Salford City 0–1 Bournemouth → Winner: Bournemouth
# Day 38 | League Cup | Burnley 2–0 Watford → Winner: Burnley
# Day 38 | League Cup | Crystal Palace 1–0 Blackburn → Winner: Crystal Palace
# Day 38 | League Cup | West Ham 1–0 Morecambe (a.e.t.) → Winner: West Ham
# Day 38 | League Cup | Barnsley 4–3 Wigan → Winner: Barnsley
#
# === STEP 56: Play Cup Round ===
# Day 39 | League Cup | Arsenal 2–0 Newcastle → Winner: Arsenal
# Day 39 | League Cup | Southampton 1–0 Manchester City → Winner: Southampton
# Day 39 | League Cup | Sunderland 1–0 Liverpool → Winner: Sunderland
# Day 39 | League Cup | Nottingham Forest 3–2 Everton → Winner: Nottingham Forest
# Day 39 | League Cup | Fulham 3–1 Chelsea → Winner: Fulham
# Day 39 | League Cup | Tottenham 1–0 Forest Green → Winner: Tottenham
# Day 39 | League Cup | Leeds 1–0 Hull City → Winner: Leeds
# Day 39 | League Cup | Bristol City 1–0 Manchester United → Winner: Bristol City
# Day 39 | League Cup | Coventry 1–2 Aston Villa (a.e.t.) → Winner: Aston Villa
#
# === STEP 57: Update Cup Status ===
# Day 38 | League Cup | Knocked out: Reading → inLC = False
# Day 38 | League Cup | Knocked out: Brighton → inLC = False
# Day 38 | League Cup | Knocked out: Salford City → inLC = False
# Day 38 | League Cup | Knocked out: Watford → inLC = False
# Day 38 | League Cup | Knocked out: Blackburn → inLC = False
# Day 38 | League Cup | Knocked out: Morecambe → inLC = False
# Day 38 | League Cup | Knocked out: Wigan → inLC = False
# Day 39 | League Cup | Knocked out: Newcastle → inLC = False
# Day 39 | League Cup | Knocked out: Manchester City → inLC = False
# Day 39 | League Cup | Knocked out: Liverpool → inLC = False
# Day 39 | League Cup | Knocked out: Everton → inLC = False
# Day 39 | League Cup | Knocked out: Chelsea → inLC = False
# Day 39 | League Cup | Knocked out: Forest Green → inLC = False
# Day 39 | League Cup | Knocked out: Hull City → inLC = False
# Day 39 | League Cup | Knocked out: Manchester United → inLC = False
# Day 39 | League Cup | Knocked out: Coventry → inLC = False
#
# === STEP 58: Draw Cup ===
#
# 🏆 League Cup draw (8 matches) across: 2024-10-29, 2024-11-06
#   Match 01 (day 63): West Ham vs Nottingham Forest
#   Match 02 (day 63): Southampton vs Burnley
#   Match 03 (day 64): Barnsley vs Fulham
#   Match 04 (day 64): Arsenal vs Crystal Palace
#   Match 05 (day 64): Bournemouth vs Leicester
#   Match 06 (day 64): Leeds vs Tottenham
#   Match 07 (day 64): Aston Villa vs Sunderland
#   Match 08 (day 64): Bristol City vs Swindon Town
#
# === STEP 59: Play League Matches ===
#
# Domestic matches on 2024-09-27:
# Championship
# Sheffield Wednesday 0 - 1 Sunderland
#
# === STEP 60: Play League Matches ===
#
# Domestic matches on 2024-09-28:
# Premier League
# Aston Villa 0 - 0 Brighton
# Manchester United 2 - 1 Crystal Palace
# Newcastle 0 - 2 Burnley
# Wolves 1 - 1 Manchester City
# Everton 2 - 0 Luton
# West Ham 1 - 0 Sheffield Utd
# Bournemouth 1 - 1 Arsenal
# Tottenham 1 - 2 Liverpool
# Championship
# Norwich 2 - 1 Birmingham
# QPR 1 - 1 Coventry
# Hull City 2 - 1 Plymouth
# Watford 4 - 0 Middlesbrough
# Huddersfield 4 - 0 Ipswich
# Southampton 3 - 1 Leeds
# Millwall 0 - 0 Swansea
# Preston 0 - 3 West Brom
# Cardiff 0 - 2 Rotherham
# Bristol City 1 - 0 Stoke City
# League One
# Reading 1 - 0 Burton Albion
# Port Vale 0 - 1 Bolton
# Derby 1 - 0 Cambridge United
# Barnsley 0 - 1 Blackpool
# Fleetwood Town 2 - 1 Leyton Orient
# Peterborough 3 - 0 Bristol Rovers
# Shrewsbury 2 - 2 Charlton
# Wycombe 2 - 1 Carlisle
# Exeter City 2 - 0 Northampton
# Stevenage 2 - 0 Oxford United
# Lincoln 0 - 1 Cheltenham
# Wigan 3 - 1 Portsmouth
# League Two
# Gillingham 0 - 2 Mansfield Town
# Salford City 4 - 1 Newport County
# Colchester 1 - 0 Notts County
# Accrington ST 0 - 1 Stockport County
# Swindon Town 1 - 1 Grimsby
# Milton Keynes Dons 3 - 0 Harrogate Town
# AFC Wimbledon 3 - 2 Tranmere
# Crawley Town 1 - 1 Sutton Utd
# Forest Green 0 - 0 Morecambe
# Barrow 0 - 0 Doncaster
# Wrexham 0 - 4 Crewe
# Bradford 2 - 1 Walsall
# National League
# Hartlepool 1 - 0 Dorking Wanderers
# Rochdale 0 - 1 Southend
# Aldershot Town 2 - 0 Dagenham & Redbridge
# York 1 - 0 Solihull Moors
# Oxford City 2 - 0 Altrincham
# Wealdstone 1 - 0 Oldham
# Kidderminster Harriers 1 - 1 Barnet
# FC Halifax Town 0 - 2 Eastleigh
# Ebbsfleet United 0 - 0 Boreham Wood
# Bromley 2 - 2 Gateshead
# AFC Fylde 0 - 1 Woking
# Maidenhead 1 - 1 Chesterfield
#
# === STEP 61: Play League Matches ===
#
# Domestic matches on 2024-10-06:
# Premier League
# Nottingham Forest 2 - 0 Brentford
# Championship
# Blackburn 1 - 3 Leicester
#
# === STEP 62: Play League Matches ===
#
# Domestic matches on 2024-10-07:
# Premier League
# Fulham 1 - 0 Chelsea
# Luton 2 - 1 Burnley
#
# === STEP 63: Play League Matches ===
#
# Domestic matches on 2024-10-01:
# Championship
# Stoke City 0 - 0 Southampton
# West Brom 1 - 1 Sheffield Wednesday
# Plymouth 0 - 0 Millwall
# Middlesbrough 2 - 0 Cardiff
# Ipswich 1 - 2 Hull City
# Birmingham 1 - 2 Huddersfield
# League One
# Northampton 0 - 1 Reading
# Blackpool 1 - 0 Derby
# Cambridge United 0 - 0 Barnsley
# Carlisle 0 - 0 Peterborough
# Cheltenham 1 - 1 Fleetwood Town
# Charlton 2 - 1 Exeter City
# Portsmouth 2 - 1 Wycombe
# Oxford United 0 - 1 Shrewsbury
# Bristol Rovers 1 - 0 Port Vale
# Bolton 5 - 0 Stevenage
# Burton Albion 0 - 0 Wigan
# League Two
# Grimsby 0 - 2 Barrow
# Harrogate Town 2 - 0 AFC Wimbledon
# Sutton Utd 0 - 3 Salford City
# Tranmere 2 - 2 Bradford
# Morecambe 2 - 2 Accrington ST
# Mansfield Town 1 - 0 Wrexham
# Newport County 0 - 0 Colchester
# Crewe 0 - 0 Gillingham
# Doncaster 2 - 0 Crawley Town
# Walsall 0 - 0 Milton Keynes Dons
# Stockport County 1 - 1 Forest Green
# Notts County 1 - 2 Swindon Town
# National League
# Chesterfield 0 - 2 Bromley
# Southend 3 - 0 Oxford City
# Oldham 1 - 1 Maidenhead
# Barnet 1 - 1 AFC Fylde
# Dagenham & Redbridge 2 - 0 York
# Eastleigh 0 - 1 Ebbsfleet United
# Gateshead 0 - 2 Wealdstone
# Solihull Moors 0 - 1 Rochdale
# Woking 0 - 1 FC Halifax Town
# Altrincham 2 - 1 Aldershot Town
# Dorking Wanderers 1 - 1 Kidderminster Harriers
#
# === STEP 64: Play European League ===
#
# European matches on 2024-10-01:
# Champions League
# Atletico Madrid 1 - 0 Newcastle
# SC Braga 2 - 1 Celtic
# Napoli 2 - 1 Galatasaray
# FC Copenhagen 2 - 0 RB Leipzig
# Real Madrid 0 - 1 Paris Saint Germain
# Red Star Belgrade 1 - 0 PSV Eindhoven
# Barcelona 1 - 1 Red Bull Salzburg
# Union Berlin 0 - 1 Lazio
#
# === STEP 65: Play League Matches ===
#
# Domestic matches on 2024-10-02:
# Championship
# Rotherham 2 - 1 Bristol City
# Coventry 1 - 2 Blackburn
# Sunderland 4 - 0 Watford
# Swansea 1 - 0 Norwich
# Leeds 3 - 1 QPR
# Leicester 3 - 0 Preston
# National League
# Boreham Wood 4 - 2 Hartlepool
#
# === STEP 66: Play European League ===
#
# European matches on 2024-10-02:
# Champions League
# Bayern Munich 1 - 1 Benfica
# Real Sociedad 1 - 1 Manchester United
# Ajax 1 - 2 Arsenal
# BSC Young Boys 0 - 1 Antwerp
# AC Milan 3 - 2 Lens
# Manchester City 1 - 3 Borussia Dortmund
# FC Porto 0 - 1 Inter
# Sevilla 2 - 1 Feyenoord
#
# === STEP 67: Play European League ===
#
# European matches on 2024-10-03:
# Europa League
# Olympiacos 2 - 2 Rangers
# Servette FC 3 - 0 Qarabag
# Villarreal 3 - 0 Union St. Gilloise
# TSC Backa Topola 0 - 1 Tottenham
# SC Freiburg 1 - 1 Aston Villa
# Marseille 3 - 0 Panathinaikos
# Sporting CP 2 - 0 Sheriff Tiraspol
# Bayer Leverkusen 3 - 0 AEK Athens FC
# Slavia Praha 3 - 1 Lask Linz
# Toulouse 1 - 2 Atalanta
# AS Roma 1 - 0 Maccabi Haifa
# Real Betis 1 - 0 Aris Limassol
# Liverpool 3 - 1 Shakhtar Donetsk
# Sturm Graz 2 - 1 Molde
# BK Hacken 0 - 3 Sparta Praha
# Rennes 1 - 1 Brighton
#
# === STEP 68: Play League Matches ===
#
# Domestic matches on 2024-10-04:
# Championship
# Birmingham 2 - 0 West Brom
#
# === STEP 69: Play League Matches ===
#
# Domestic matches on 2024-10-05:
# Premier League
# Manchester United 1 - 0 Brentford
# Fulham 2 - 0 Sheffield Utd
# Burnley 0 - 2 Chelsea
# Everton 0 - 2 Bournemouth
# Crystal Palace 2 - 2 Nottingham Forest
# Luton 0 - 2 Tottenham
# Championship
# Plymouth 2 - 1 Swansea
# Sunderland 2 - 1 Middlesbrough
# Southampton 3 - 0 Rotherham
# Cardiff 0 - 2 Watford
# Leicester 2 - 0 Stoke City
# Ipswich 0 - 1 Preston
# Millwall 1 - 0 Hull City
# Leeds 3 - 0 Bristol City
# QPR 1 - 2 Blackburn
# Sheffield Wednesday 1 - 2 Huddersfield
# Coventry 0 - 0 Norwich
# League One
# Oxford United 0 - 0 Bristol Rovers
# Bolton 3 - 0 Carlisle
# Charlton 2 - 2 Blackpool
# Fleetwood Town 2 - 1 Wycombe
# Peterborough 2 - 0 Lincoln
# Shrewsbury 4 - 0 Northampton
# Portsmouth 4 - 0 Port Vale
# Exeter City 2 - 1 Barnsley
# Cheltenham 1 - 2 Derby
# Stevenage 0 - 5 Wigan
# Leyton Orient 0 - 1 Reading
# League Two
# Stockport County 3 - 0 Doncaster
# Barrow 2 - 0 Notts County
# Tranmere 0 - 1 Grimsby
# Mansfield Town 2 - 2 AFC Wimbledon
# Newport County 2 - 0 Harrogate Town
# Crawley Town 1 - 1 Wrexham
# Colchester 0 - 1 Morecambe
# Accrington ST 2 - 1 Forest Green
# Gillingham 1 - 1 Milton Keynes Dons
# Bradford 1 - 1 Swindon Town
# Salford City 3 - 0 Crewe
# Sutton Utd 1 - 2 Walsall
# National League
# Hartlepool 4 - 0 Eastleigh
# Dorking Wanderers 2 - 1 Barnet
# Kidderminster Harriers 1 - 1 Wealdstone
# Oxford City 1 - 0 AFC Fylde
# Ebbsfleet United 1 - 3 FC Halifax Town
# Maidenhead 0 - 2 Rochdale
# Woking 1 - 0 Southend
# Solihull Moors 1 - 0 Aldershot Town
# Boreham Wood 1 - 0 Chesterfield
# York 0 - 1 Bromley
# Gateshead 2 - 1 Altrincham
# Oldham 1 - 0 Dagenham & Redbridge
#
# === STEP 70: Play League Matches ===
#
# Domestic matches on 2024-10-13:
# Premier League
# Arsenal 1 - 1 Manchester City
# Brighton 0 - 2 Liverpool
# West Ham 2 - 1 Newcastle
# Wolves 0 - 0 Aston Villa
#
# === STEP 71: Play League Matches ===
#
# Domestic matches on 2024-10-14:
# League One
# Burton Albion 1 - 1 Cambridge United
#
# === STEP 72: Play League Matches ===
#
# Domestic matches on 2024-10-12:
# League One
# Lincoln 0 - 0 Burton Albion
# Carlisle 2 - 1 Leyton Orient
# Cambridge United 1 - 1 Shrewsbury
# Blackpool 5 - 1 Stevenage
# League Two
# Crewe 2 - 0 Tranmere
# Grimsby 0 - 0 Accrington ST
# Doncaster 2 - 0 Sutton Utd
# Swindon Town 2 - 0 Newport County
# Walsall 3 - 0 Gillingham
# Forest Green 1 - 0 Colchester
# AFC Wimbledon 2 - 1 Bradford
# Notts County 0 - 4 Mansfield Town
# Milton Keynes Dons 2 - 0 Barrow
# Wrexham 1 - 1 Salford City
# Harrogate Town 1 - 3 Stockport County
#
# === STEP 73: Draw Cup ===
#
# 🏆 FA Cup draw (40 matches) across: 2024-11-01, 2024-11-02, 2024-11-03
#   Match 01 (day 65): Forest Green vs Boreham Wood
#   Match 02 (day 65): Oldham vs Salford City
#   Match 03 (day 65): Sheppey United vs Dorking Wanderers
#   Match 04 (day 66): Derby vs Bolton
#   Match 05 (day 66): Worthing vs Port Vale
#   Match 06 (day 66): Accrington ST vs Southend
#   Match 07 (day 66): Worksop Town vs Crawley Town
#   Match 08 (day 66): Curzon Ashton vs Blackpool
#   Match 09 (day 66): Stevenage vs Wigan
#   Match 10 (day 66): Peterborough vs Newport County
#   Match 11 (day 66): Oxford City vs Mansfield Town
#   Match 12 (day 66): Crewe vs Sutton Utd
#   Match 13 (day 66): Eastleigh vs Fleetwood Town
#   Match 14 (day 66): Northampton vs Cheltenham
#   Match 15 (day 66): Ramsgate vs Barrow
#   Match 16 (day 66): Rochdale vs Chesham United
#   Match 17 (day 66): Gateshead vs Dagenham & Redbridge
#   Match 18 (day 66): Burton Albion vs Shrewsbury
#   Match 19 (day 66): Reading vs Bromley
#   Match 20 (day 66): Harrogate Town vs Slough Town
#   Match 21 (day 66): Milton Keynes Dons vs Exeter City
#   Match 22 (day 66): Solihull Moors vs Barnsley
#   Match 23 (day 66): Bradford vs Doncaster
#   Match 24 (day 66): Tranmere vs Kidderminster Harriers
#   Match 25 (day 66): Maidstone Utd vs Notts County
#   Match 26 (day 66): AFC Fylde vs Oxford United
#   Match 27 (day 66): Hereford vs Bristol Rovers
#   Match 28 (day 66): Gillingham vs Wealdstone
#   Match 29 (day 66): Colchester vs Ebbsfleet United
#   Match 30 (day 66): Leyton Orient vs York
#   Match 31 (day 66): Portsmouth vs Woking
#   Match 32 (day 66): Cambridge United vs FC Halifax Town
#   Match 33 (day 66): Chesterfield vs Scarborough Athletic
#   Match 34 (day 66): Aldershot Town vs Carlisle
#   Match 35 (day 66): Wrexham vs Wycombe
#   Match 36 (day 67): Grimsby vs Chester
#   Match 37 (day 67): Charlton vs Lincoln
#   Match 38 (day 67): Swindon Town vs Yeovil Town
#   Match 39 (day 67): Morecambe vs AFC Wimbledon
#   Match 40 (day 67): Walsall vs Stockport County
#
# === STEP 74: Play League Matches ===
#
# Domestic matches on 2024-10-18:
# League Two
# Newport County 1 - 2 Walsall
# Tranmere 1 - 0 Doncaster
#
# === STEP 75: Play League Matches ===
#
# Domestic matches on 2024-10-19:
# Premier League
# Sheffield Utd 0 - 0 Manchester United
# Chelsea 1 - 1 Arsenal
# Nottingham Forest 0 - 1 Luton
# Bournemouth 0 - 1 Wolves
# Newcastle 1 - 1 Crystal Palace
# Liverpool 2 - 0 Everton
# Manchester City 1 - 0 Brighton
# Brentford 0 - 1 Burnley
# Championship
# Swansea 0 - 1 Leicester
# Norwich 1 - 2 Leeds
# Middlesbrough 2 - 1 Birmingham
# Blackburn 2 - 0 Cardiff
# Hull City 0 - 1 Southampton
# West Brom 2 - 0 Plymouth
# Bristol City 1 - 1 Coventry
# Watford 0 - 2 Sheffield Wednesday
# Huddersfield 1 - 0 QPR
# Preston 0 - 1 Millwall
# Stoke City 2 - 3 Sunderland
# League One
# Bolton 1 - 2 Northampton
# Leyton Orient 2 - 2 Barnsley
# Cheltenham 3 - 0 Cambridge United
# Stevenage 1 - 3 Port Vale
# Exeter City 1 - 3 Wigan
# Charlton 0 - 1 Reading
# Shrewsbury 0 - 1 Derby
# Peterborough 1 - 3 Wycombe
# Oxford United 2 - 1 Blackpool
# Fleetwood Town 3 - 2 Lincoln
# Burton Albion 0 - 2 Bristol Rovers
# Portsmouth 3 - 2 Carlisle
# League Two
# Barrow 3 - 0 AFC Wimbledon
# Crawley Town 1 - 1 Crewe
# Colchester 1 - 1 Harrogate Town
# Accrington ST 0 - 2 Milton Keynes Dons
# Sutton Utd 0 - 1 Morecambe
# Salford City 0 - 2 Swindon Town
# Bradford 3 - 0 Wrexham
# Stockport County 3 - 1 Grimsby
# Gillingham 2 - 0 Notts County
# National League
# Southend 1 - 0 Solihull Moors
# Barnet 1 - 3 Maidenhead
# Aldershot Town 2 - 4 Hartlepool
# Dagenham & Redbridge 1 - 1 Woking
# Eastleigh 0 - 1 York
# Bromley 2 - 0 Oxford City
# AFC Fylde 2 - 0 Ebbsfleet United
# FC Halifax Town 4 - 0 Kidderminster Harriers
# Wealdstone 0 - 2 Boreham Wood
# Rochdale 0 - 1 Oldham
#
# === STEP 76: Play League Matches ===
#
# Domestic matches on 2024-10-27:
# Premier League
# Aston Villa 0 - 1 West Ham
#
# === STEP 77: Play League Matches ===
#
# Domestic matches on 2024-10-28:
# Premier League
# Tottenham 2 - 1 Fulham
#
# === STEP 78: Play League Matches ===
#
# Domestic matches on 2024-10-22:
# Championship
# West Brom 1 - 0 QPR
# Huddersfield 1 - 2 Cardiff
# Swansea 3 - 0 Watford
# Norwich 1 - 1 Middlesbrough
# Millwall 0 - 1 Blackburn
# Leicester 2 - 1 Sunderland
# League One
# Wigan 2 - 0 Oxford United
# Derby 1 - 1 Exeter City
# Barnsley 3 - 0 Shrewsbury
# Cambridge United 0 - 0 Portsmouth
# Northampton 0 - 0 Leyton Orient
# Blackpool 2 - 1 Cheltenham
# Wycombe 0 - 2 Bolton
# Carlisle 0 - 3 Burton Albion
# Bristol Rovers 0 - 0 Stevenage
# Lincoln 2 - 2 Charlton
# Reading 2 - 0 Fleetwood Town
# Port Vale 0 - 2 Peterborough
# League Two
# AFC Wimbledon 0 - 1 Accrington ST
# Milton Keynes Dons 2 - 1 Bradford
# Swindon Town 4 - 1 Gillingham
# Doncaster 1 - 0 Salford City
# Crewe 0 - 0 Stockport County
# Grimsby 0 - 0 Colchester
# Morecambe 1 - 2 Tranmere
# Notts County 2 - 4 Newport County
# Forest Green 0 - 1 Barrow
# Wrexham 1 - 1 Sutton Utd
# Harrogate Town 1 - 1 Mansfield Town
# Walsall 1 - 0 Crawley Town
# National League
# Wealdstone 2 - 3 Oxford City
# Altrincham 3 - 1 Kidderminster Harriers
# FC Halifax Town 1 - 2 Hartlepool
# AFC Fylde 0 - 3 Oldham
# Bromley 1 - 4 Dorking Wanderers
# Eastleigh 1 - 1 Woking
# Dagenham & Redbridge 0 - 2 Boreham Wood
# Aldershot Town 3 - 1 Maidenhead
# Barnet 3 - 1 Solihull Moors
# Chesterfield 3 - 0 York
# Southend 0 - 0 Ebbsfleet United
# Rochdale 2 - 0 Gateshead
#
# === STEP 79: Play European League ===
#
# European matches on 2024-10-22:
# Champions League
# Atletico Madrid 2 - 1 Celtic
# Newcastle 0 - 0 SC Braga
# Napoli 0 - 4 RB Leipzig
# ...
#   Match 05 (day 136): Derby vs Arsenal
#   Match 06 (day 137): Rotherham vs Bristol City
#   Match 07 (day 137): Bristol Rovers vs Aston Villa
#   Match 08 (day 137): Nottingham Forest vs Middlesbrough
#   Match 09 (day 137): Fulham vs Plymouth
#   Match 10 (day 137): Peterborough vs Brighton
#   Match 11 (day 137): Manchester United vs Coventry
#   Match 12 (day 138): Huddersfield vs Luton
#   Match 13 (day 138): Preston vs Leeds
#   Match 14 (day 138): Millwall vs Crystal Palace
#   Match 15 (day 138): Hull City vs Burnley
#   Match 16 (day 139): Sheffield Utd vs Stoke City
#
# === STEP 172: Play League Matches ===
#
# Domestic matches on 2025-01-14:
# League One
# Fleetwood Town 0 - 1 Derby
# Burton Albion 0 - 1 Wycombe
# Exeter City 0 - 0 Carlisle
# Port Vale 2 - 1 Charlton
# Cheltenham 0 - 3 Portsmouth
# League Two
# Swindon Town 3 - 0 Colchester
# Salford City 1 - 2 Forest Green
# Barrow 2 - 1 Tranmere
# Mansfield Town 4 - 1 Crewe
# Bradford 2 - 0 Crawley Town
# Harrogate Town 2 - 1 Doncaster
# National League
# Dorking Wanderers 1 - 1 Oldham
# Altrincham 2 - 2 Barnet
# Ebbsfleet United 1 - 1 Wealdstone
# Maidenhead 1 - 1 Bromley
# Solihull Moors 2 - 3 Woking
# Hartlepool 4 - 0 Oxford City
# Southend 2 - 1 FC Halifax Town
# Rochdale 2 - 0 Kidderminster Harriers
# Boreham Wood 2 - 0 York
# AFC Fylde 0 - 1 Hartlepool
# Barnet 1 - 0 Dagenham & Redbridge
#
# === STEP 173: Draw Two Leg Fixture ===
#
# 🏆 League Cup Two‑Leg Draw (2 ties) across days: 122, 123, 133, 134
#   Tie 01: Leg1 (day 122) Burnley vs Tottenham; Leg2 (day 133) Tottenham vs Burnley
#   Tie 02: Leg1 (day 123) West Ham vs Aston Villa; Leg2 (day 134) Aston Villa vs West Ham
#
# === STEP 174: Play Two Leg Round ===
# Day 122 | League Cup Leg 1 | Burnley 0-1 Tottenham
#
# === STEP 175: Play League Matches ===
#
# Domestic matches on 2025-01-08:
# National League
# Chesterfield 4 - 0 Gateshead
#
# === STEP 176: Play Two Leg Round ===
# Day 123 | League Cup Leg 1 | West Ham 0-4 Aston Villa
#
# === STEP 177: Play League Matches ===
#
# Domestic matches on 2025-01-10:
# Premier League
# Burnley 4 - 1 Luton
# Championship
# Hull City 0 - 0 Norwich
#
# === STEP 178: Play League Matches ===
#
# Domestic matches on 2025-01-11:
# Premier League
# Newcastle 2 - 1 Manchester City
# Chelsea 1 - 2 Fulham
# Championship
# Coventry 2 - 3 Leicester
# Huddersfield 2 - 0 Plymouth
# Southampton 3 - 1 Sheffield Wednesday
# Birmingham 1 - 0 Swansea
# Ipswich 1 - 2 Sunderland
# Rotherham 3 - 0 Stoke City
# Cardiff 0 - 1 Leeds
# Preston 1 - 1 Bristol City
# Millwall 3 - 0 Middlesbrough
# West Brom 1 - 0 Blackburn
# League One
# Cambridge United 1 - 3 Fleetwood Town
# Wycombe 1 - 0 Lincoln
# Blackpool 2 - 1 Exeter City
# Charlton 0 - 1 Peterborough
# Portsmouth 1 - 0 Leyton Orient
# Shrewsbury 0 - 0 Stevenage
# Northampton 3 - 0 Wigan
# Barnsley 3 - 1 Bristol Rovers
# Carlisle 0 - 2 Oxford United
# League Two
# Sutton Utd 2 - 1 Barrow
# Tranmere 1 - 2 Milton Keynes Dons
# Wrexham 2 - 1 AFC Wimbledon
# Stockport County 0 - 1 Walsall
# Forest Green 2 - 0 Harrogate Town
# Morecambe 1 - 1 Mansfield Town
# Grimsby 1 - 0 Notts County
# Crewe 1 - 0 Swindon Town
# Colchester 2 - 0 Bradford
# Accrington ST 4 - 0 Gillingham
# Doncaster 2 - 0 Newport County
# Crawley Town 0 - 4 Salford City
# National League
# Eastleigh 0 - 2 Southend
#
# === STEP 179: Play League Matches ===
#
# Domestic matches on 2025-01-12:
# Premier League
# Manchester United 1 - 1 Tottenham
# Everton 0 - 0 Aston Villa
# Championship
# QPR 1 - 1 Watford
#
# === STEP 180: Play League Matches ===
#
# Domestic matches on 2025-01-20:
# League One
# Derby 0 - 1 Burton Albion
#
# === STEP 181: Play League Matches ===
#
# Domestic matches on 2025-01-21:
# League One
# Barnsley 3 - 0 Carlisle
# National League
# Chesterfield 1 - 0 Altrincham
#
# === STEP 182: Play League Matches ===
#
# Domestic matches on 2025-01-17:
# Championship
# Sunderland 1 - 2 Hull City
#
# === STEP 183: Play League Matches ===
#
# Domestic matches on 2025-01-18:
# Premier League
# Brentford 1 - 1 Nottingham Forest
# Arsenal 0 - 0 Crystal Palace
# Championship
# Sheffield Wednesday 1 - 2 Coventry
# Stoke City 1 - 3 Birmingham
# QPR 1 - 0 Millwall
# Plymouth 0 - 2 Cardiff
# Middlesbrough 1 - 0 Rotherham
# Bristol City 2 - 0 Watford
# Swansea 0 - 0 Southampton
# Norwich 2 - 1 West Brom
# Blackburn 2 - 1 Huddersfield
# League One
# Wigan 2 - 0 Reading
# Bristol Rovers 0 - 1 Blackpool
# Burton Albion 0 - 2 Charlton
# Lincoln 0 - 2 Derby
# Leyton Orient 0 - 0 Bolton
# Exeter City 3 - 0 Cambridge United
# Peterborough 4 - 1 Shrewsbury
# Fleetwood Town 1 - 2 Portsmouth
# League Two
# Gillingham 0 - 1 Forest Green
# Milton Keynes Dons 1 - 0 Morecambe
# Newport County 3 - 1 Wrexham
# Barrow 1 - 0 Crewe
# National League
# Dorking Wanderers 3 - 1 Gateshead
# Kidderminster Harriers 2 - 2 Aldershot Town
# Ebbsfleet United 0 - 1 Hartlepool
# Bromley 2 - 2 Boreham Wood
#
# === STEP 184: Play League Matches ===
#
# Domestic matches on 2025-01-19:
# Premier League
# Sheffield Utd 2 - 1 West Ham
# Bournemouth 2 - 1 Liverpool
# Championship
# Leeds 3 - 0 Preston
#
# === STEP 185: Play League Matches ===
#
# Domestic matches on 2025-01-27:
# Premier League
# Brighton 0 - 1 Wolves
# Championship
# Leicester 4 - 0 Ipswich
#
# === STEP 186: Play League Matches ===
#
# Domestic matches on 2025-01-28:
# League One
# Wigan 0 - 0 Wycombe
# Reading 1 - 0 Derby
# Oxford United 1 - 1 Barnsley
# Charlton 3 - 0 Northampton
# Bristol Rovers 2 - 2 Exeter City
# Bolton 2 - 0 Cheltenham
# League Two
# Milton Keynes Dons 5 - 0 AFC Wimbledon
# Bradford 0 - 0 Salford City
# Mansfield Town 5 - 0 Sutton Utd
# National League
# Oldham 2 - 0 Barnet
# Chesterfield 0 - 1 Woking
# Oxford City 2 - 0 York
# AFC Fylde 0 - 2 FC Halifax Town
# Maidenhead 1 - 0 Ebbsfleet United
# Dagenham & Redbridge 2 - 2 Dorking Wanderers
# Aldershot Town 1 - 1 Bromley
# Hartlepool 1 - 0 Kidderminster Harriers
#
# === STEP 187: Play Two Leg Round ===
# Day 133 | League Cup Leg 2 | Tottenham 0-1 Burnley (agg 1-1) (a.e.t. 0-0) [p 9-8] → Winner: Tottenham
#
# === STEP 188: Play League Matches ===
#
# Domestic matches on 2025-01-22:
# Championship
# Leeds 4 - 0 Norwich
# National League
# Boreham Wood 1 - 0 Eastleigh
#
# === STEP 189: Play Two Leg Round ===
# Day 134 | League Cup Leg 2 | Aston Villa 3-1 West Ham (agg 7-1) → Winner: Aston Villa
#
# === STEP 190: Update Cup Status ===
# Day 133 | League Cup | Knocked out: Tottenham → inLC = False
# Day 134 | League Cup | Knocked out: West Ham → inLC = False
#
# === STEP 191: Draw Cup ===
#
# 🏆 League Cup draw (1 matches) across: 2025-02-23
#   Match 01 (day 164): Burnley vs Aston Villa
#
# === STEP 192: Play Cup Round ===
# Day 135 | FA Cup | Southampton 0–3 Brentford → Winner: Brentford
#
# === STEP 193: Play Cup Round ===
# Day 136 | FA Cup | West Ham 0–1 Liverpool → Winner: Liverpool
# Day 136 | FA Cup | Everton 0–1 Ipswich → Winner: Ipswich
# Day 136 | FA Cup | Gillingham 0–1 Watford (a.e.t.) → Winner: Watford
# Day 136 | FA Cup | Derby 1–0 Arsenal → Winner: Derby
#
# === STEP 194: Play League Matches ===
#
# Domestic matches on 2025-01-25:
# Championship
# Sunderland 1 - 1 Stoke City
# Millwall 2 - 2 Preston
# League One
# Carlisle 1 - 2 Bolton
# Lincoln 3 - 1 Peterborough
# Cambridge United 1 - 1 Burton Albion
# Wycombe 1 - 1 Fleetwood Town
# Port Vale 1 - 1 Portsmouth
# Reading 2 - 0 Leyton Orient
# Wigan 1 - 1 Stevenage
# Blackpool 0 - 0 Charlton
# Derby 2 - 1 Cheltenham
# Bristol Rovers 1 - 1 Oxford United
# Northampton 1 - 1 Shrewsbury
# Barnsley 2 - 0 Exeter City
# League Two
# Forest Green 1 - 1 Accrington ST
# Notts County 1 - 3 Barrow
# Morecambe 0 - 0 Colchester
# Grimsby 2 - 2 Tranmere
# Crewe 0 - 1 Salford City
# Milton Keynes Dons 5 - 1 Gillingham
# Walsall 3 - 2 Sutton Utd
# AFC Wimbledon 0 - 3 Mansfield Town
# Doncaster 1 - 2 Stockport County
# Swindon Town 2 - 1 Bradford
# National League
# Chesterfield 2 - 0 Southend
# Hartlepool 3 - 0 York
# Oldham 1 - 1 Woking
# Wealdstone 0 - 0 FC Halifax Town
# Boreham Wood 1 - 1 Dorking Wanderers
# Maidenhead 3 - 0 Solihull Moors
# AFC Fylde 0 - 2 Bromley
# Oxford City 0 - 0 Ebbsfleet United
# Altrincham 0 - 0 Eastleigh
# Gateshead 4 - 1 Barnet
# Dagenham & Redbridge 1 - 3 Kidderminster Harriers
# Aldershot Town 0 - 0 Rochdale
#
# === STEP 195: Play Cup Round ===
# Day 137 | FA Cup | Rotherham 3–2 Bristol City (a.e.t.) → Winner: Rotherham
# Day 137 | FA Cup | Bristol Rovers 2–1 Aston Villa → Winner: Bristol Rovers
# Day 137 | FA Cup | Nottingham Forest 2–1 Middlesbrough (a.e.t.) → Winner: Nottingham Forest
# Day 137 | FA Cup | Fulham 3–0 Plymouth → Winner: Fulham
# Day 137 | FA Cup | Peterborough 0–2 Brighton → Winner: Brighton
# Day 137 | FA Cup | Manchester United 2–0 Coventry → Winner: Manchester United
#
# === STEP 196: Play Cup Round ===
# Day 138 | FA Cup | Huddersfield 2–2 Luton (a.e.t.) [p 2–3] → Winner: Luton
# Day 138 | FA Cup | Preston 0–3 Leeds → Winner: Leeds
# Day 138 | FA Cup | Millwall 1–4 Crystal Palace → Winner: Crystal Palace
# Day 138 | FA Cup | Hull City 1–4 Burnley (a.e.t.) → Winner: Burnley
#
# === STEP 197: Play Cup Round ===
# Day 139 | FA Cup | Sheffield Utd 0–1 Stoke City → Winner: Stoke City
#
# === STEP 198: Update Cup Status ===
# Day 135 | FA Cup | Knocked out: Southampton → inFA = False
# Day 136 | FA Cup | Knocked out: West Ham → inFA = False
# Day 136 | FA Cup | Knocked out: Everton → inFA = False
# Day 136 | FA Cup | Knocked out: Gillingham → inFA = False
# Day 136 | FA Cup | Knocked out: Arsenal → inFA = False
# Day 137 | FA Cup | Knocked out: Bristol City → inFA = False
# Day 137 | FA Cup | Knocked out: Aston Villa → inFA = False
# Day 137 | FA Cup | Knocked out: Middlesbrough → inFA = False
# Day 137 | FA Cup | Knocked out: Plymouth → inFA = False
# Day 137 | FA Cup | Knocked out: Peterborough → inFA = False
# Day 137 | FA Cup | Knocked out: Coventry → inFA = False
# Day 138 | FA Cup | Knocked out: Huddersfield → inFA = False
# Day 138 | FA Cup | Knocked out: Preston → inFA = False
# Day 138 | FA Cup | Knocked out: Millwall → inFA = False
# Day 138 | FA Cup | Knocked out: Hull City → inFA = False
# Day 139 | FA Cup | Knocked out: Sheffield Utd → inFA = False
#
# === STEP 199: Draw Cup ===
# ❌ Error: Not enough blank fixtures for FA Cup: needed 8, found 0
#
# === STEP 200: Play League Matches ===
#
# Domestic matches on 2025-01-28:
# Premier League
# Fulham 1 - 1 Everton
# Nottingham Forest 1 - 1 Arsenal
# Luton 1 - 1 Brighton
# Aston Villa 3 - 1 Newcastle
# Crystal Palace 1 - 0 Sheffield Utd
# Championship
# QPR 1 - 2 Huddersfield
# Coventry 1 - 1 Bristol City
# Leicester 2 - 0 Swansea
# League One
# Oxford United 0 - 0 Portsmouth
# League Two
# Sutton Utd 1 - 0 Harrogate Town
# National League
# Wealdstone 2 - 1 Aldershot Town
# Solihull Moors 1 - 1 Dagenham & Redbridge
#
# === STEP 201: Play League Matches ===
#
# Domestic matches on 2025-01-29:
# Premier League
# Liverpool 1 - 0 Chelsea
# Manchester City 1 - 1 Burnley
# Tottenham 0 - 0 Brentford
# Championship
# Sheffield Wednesday 2 - 2 Watford
#
# === STEP 202: Play League Matches ===
#
# Domestic matches on 2025-02-06:
# Premier League
# Wolves 1 - 1 Manchester United
# West Ham 2 - 0 Bournemouth
#
# === STEP 203: Play League Matches ===
#
# Domestic matches on 2025-02-07:
# Championship
# Bristol City 0 - 2 Leeds
#
# === STEP 204: Play League Matches ===
#
# Domestic matches on 2025-02-01:
# Premier League
# Everton 1 - 0 Tottenham
# Brighton 0 - 0 Crystal Palace
# Burnley 1 - 0 Fulham
# Newcastle 1 - 0 Luton
# Sheffield Utd 0 - 1 Aston Villa
# Championship
# Hull City 2 - 0 Millwall
# Blackburn 0 - 1 QPR
# Norwich 2 - 2 Coventry
# Rotherham 3 - 0 Southampton
# Stoke City 0 - 2 Leicester
# Swansea 3 - 0 Plymouth
# Preston 2 - 1 Ipswich
# West Brom 2 - 0 Birmingham
# Watford 3 - 0 Cardiff
# Huddersfield 2 - 0 Sheffield Wednesday
# League One
# Charlton 2 - 1 Derby
# Leyton Orient 2 - 1 Carlisle
# Cheltenham 3 - 1 Wycombe
# Stevenage 1 - 2 Blackpool
# Burton Albion 2 - 1 Lincoln
# Exeter City 3 - 1 Bristol Rovers
# Shrewsbury 1 - 0 Cambridge United
# Bolton 1 - 0 Barnsley
# Peterborough 2 - 3 Wigan
# Oxford United 0 - 0 Reading
# Fleetwood Town 2 - 1 Port Vale
# Portsmouth 0 - 1 Northampton
# League Two
# Sutton Utd 0 - 1 Doncaster
# Barrow 1 - 1 Milton Keynes Dons
# Tranmere 0 - 0 Crewe
# Mansfield Town 0 - 1 Notts County
# Crawley Town 0 - 3 Morecambe
# Colchester 1 - 1 Forest Green
# Accrington ST 0 - 0 Grimsby
# Gillingham 0 - 0 Walsall
# Bradford 2 - 0 AFC Wimbledon
# Salford City 1 - 0 Wrexham
# Stockport County 1 - 0 Harrogate Town
# Newport County 0 - 1 Swindon Town
# National League
# Solihull Moors 0 - 0 Altrincham
# Rochdale 2 - 1 Dagenham & Redbridge
# Southend 1 - 0 Gateshead
# Barnet 2 - 3 Wealdstone
# Eastleigh 0 - 2 Chesterfield
# York 2 - 2 Maidenhead
# Bromley 2 - 3 Hartlepool
# Woking 0 - 1 Boreham Wood
# FC Halifax Town 2 - 0 Aldershot Town
# Kidderminster Harriers 4 - 0 Oxford City
# Dorking Wanderers 1 - 1 AFC Fylde
# Ebbsfleet United 2 - 1 Oldham
#
# === STEP 205: Play League Matches ===
#
# Domestic matches on 2025-02-02:
# Premier League
# Arsenal 2 - 1 Liverpool
# Chelsea 1 - 0 Wolves
# Bournemouth 5 - 0 Nottingham Forest
# Manchester United 2 - 1 West Ham
# Championship
# Middlesbrough 0 - 1 Sunderland
#
# === STEP 206: Play League Matches ===
#
# Domestic matches on 2025-02-03:
# Premier League
# Brentford 1 - 0 Manchester City
#
# === STEP 207: Play League Matches ===
#
# Domestic matches on 2025-02-04:
# League One
# Stevenage 1 - 1 Reading
# Exeter City 1 - 0 Peterborough
# Port Vale 2 - 0 Leyton Orient
# Bristol Rovers 2 - 4 Fleetwood Town
# National League
# Gateshead 0 - 2 Eastleigh
# Woking 2 - 0 Oxford City
# FC Halifax Town 0 - 0 Solihull Moors
# Dagenham & Redbridge 0 - 2 Chesterfield
# Wealdstone 0 - 1 Maidenhead
#
# === STEP 208: Play League Matches ===
#
# Domestic matches on 2025-02-14:
# Championship
# Sheffield Wednesday 1 - 0 Birmingham
# League Two
# Notts County 1 - 1 Gillingham
#
# === STEP 209: Play League Matches ===
#
# Domestic matches on 2025-02-08:
# Premier League
# Manchester City 3 - 0 Everton
# Fulham 5 - 1 Bournemouth
# Liverpool 2 - 0 Burnley
# Wolves 1 - 1 Brentford
# Tottenham 1 - 1 Brighton
# Luton 1 - 2 Sheffield Utd
# Nottingham Forest 2 - 2 Newcastle
# Championship
# Middlesbrough 3 - 0 Bristol City
# QPR 1 - 0 Norwich
# Sunderland 4 - 0 Plymouth
# Leeds 2 - 0 Rotherham
# Southampton 1 - 0 Huddersfield
# Cardiff 0 - 0 Preston
# Blackburn 1 - 1 Stoke City
# Ipswich 0 - 0 West Brom
# Watford 2 - 0 Leicester
# Hull City 1 - 0 Swansea
# League One
# Northampton 0 - 1 Bolton
# Bristol Rovers 1 - 2 Burton Albion
# Barnsley 2 - 0 Leyton Orient
# Derby 2 - 0 Shrewsbury
# Wigan 2 - 0 Exeter City
# Reading 4 - 0 Charlton
# Lincoln 1 - 1 Fleetwood Town
# Port Vale 2 - 0 Stevenage
# Blackpool 2 - 1 Oxford United
# Wycombe 0 - 1 Peterborough
# Carlisle 1 - 0 Portsmouth
# Cambridge United 3 - 1 Cheltenham
# League Two
# Harrogate Town 1 - 0 Colchester
# Wrexham 1 - 1 Bradford
# Forest Green 3 - 0 Mansfield Town
# Morecambe 3 - 0 Sutton Utd
# Grimsby 1 - 1 Stockport County
# Crewe 3 - 0 Crawley Town
# Doncaster 1 - 0 Tranmere
# Milton Keynes Dons 3 - 0 Accrington ST
# Walsall 2 - 0 Newport County
# AFC Wimbledon 4 - 0 Barrow
# Swindon Town 2 - 1 Salford City
# National League
# Southend 1 - 1 York
# Altrincham 1 - 3 Rochdale
# Boreham Wood 2 - 1 Maidenhead
# Woking 1 - 2 Hartlepool
# Eastleigh 4 - 2 AFC Fylde
# Dorking Wanderers 0 - 1 FC Halifax Town
# Dagenham & Redbridge 1 - 0 Oxford City
# Chesterfield 2 - 0 Ebbsfleet United
#
# === STEP 210: Play League Matches ===
#
# Domestic matches on 2025-02-09:
# Premier League
# Aston Villa 2 - 1 Manchester United
# West Ham 2 - 0 Arsenal
# Championship
# Coventry 3 - 1 Millwall
#
# === STEP 211: Play League Matches ===
#
# Domestic matches on 2025-02-10:
# Premier League
# Crystal Palace 0 - 0 Chelsea
#
# === STEP 212: Play League Matches ===
#
# Domestic matches on 2025-02-11:
# Championship
# Birmingham 1 - 1 Blackburn
# Leicester 1 - 0 Sheffield Wednesday
# Bristol City 0 - 1 Southampton
# Swansea 0 - 1 Leeds
# West Brom 1 - 0 Cardiff
# Norwich 4 - 1 Watford
# Rotherham 1 - 0 Hull City
# League One
# Leyton Orient 3 - 0 Northampton
# Cheltenham 0 - 3 Blackpool
# Stevenage 2 - 0 Bristol Rovers
# Portsmouth 4 - 0 Cambridge United
# Shrewsbury 0 - 0 Barnsley
# Oxford United 1 - 0 Wigan
# Fleetwood Town 1 - 0 Reading
# Bolton 0 - 2 Wycombe
# Exeter City 1 - 0 Derby
# Charlton 1 - 0 Lincoln
# League Two
# Sutton Utd 0 - 1 Wrexham
# Barrow 1 - 1 Forest Green
# Tranmere 0 - 1 Morecambe
# Mansfield Town 0 - 1 Harrogate Town
# Newport County 1 - 1 Notts County
# Crawley Town 0 - 3 Walsall
# Accrington ST 2 - 0 AFC Wimbledon
# Gillingham 1 - 2 Swindon Town
# Bradford 1 - 0 Milton Keynes Dons
# Salford City 1 - 0 Doncaster
# Stockport County 0 - 0 Crewe
# National League
# York 2 - 0 Dorking Wanderers
# Aldershot Town 5 - 0 AFC Fylde
# Oldham 1 - 0 Boreham Wood
# FC Halifax Town 2 - 0 Maidenhead
#
# === Reached step 212. Stopped. Current pointer: 212 ===

# %% [markdown]
# ### Still in Cup

# %%
eligible_teams = dfTeams[dfTeams['inFA'] == True].copy()
print(len(eligible_teams))
pd.set_option('display.max_rows', None)
eligible_teams

# %% [markdown]
# ### Print League Tables

# %%
print_all_league_tables(league_tables, dfCompetitions)

# %%
print_euro_group_tables(8, dfTeams, dfFixtures, dfGroupStage)
# Out:
# --- Europa League Group 1 Standings ---
#  Position     Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1 Brighton       6     4      2       0        11             3         8      14
#         2 Atalanta       6     2      2       2         8             9        -1       8
#         3 Toulouse       6     1      3       2         7            10        -3       6
#         4    Molde       6     0      3       3         5             9        -4       3
#
# --- Europa League Group 2 Standings ---
#  Position             Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1      Sporting CP       6     5      0       1         9             2         7      15
#         2 TSC Backa Topola       6     2      2       2         5             5         0       8
#         3       Olympiacos       6     2      1       3         6             3         3       7
#         4        Lask Linz       6     1      1       4         2            12       -10       4
#
# --- Europa League Group 3 Standings ---
#  Position             Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1     Slavia Praha       6     5      1       0        12             4         8      16
#         2 Bayer Leverkusen       6     3      0       3         7             5         2       9
#         3        Tottenham       6     1      2       3         5             8        -3       5
#         4    Maccabi Haifa       6     1      1       4         5            12        -7       4
#
# --- Europa League Group 4 Standings ---
#  Position          Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1       Rangers       6     5      1       0        12             1        11      16
#         2     Marseille       6     4      0       2        11             3         8      12
#         3 Panathinaikos       6     0      3       3         1             7        -6       3
#         4 Aris Limassol       6     0      2       4         0            13       -13       2
#
# --- Europa League Group 5 Standings ---
#  Position         Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1 Sparta Praha       6     5      1       0        10             2         8      16
#         2   Real Betis       6     2      2       2         5             5         0       8
#         3    Liverpool       6     1      2       3         5             5         0       5
#         4  Servette FC       6     1      1       4         3            11        -8       4
#
# --- Europa League Group 6 Standings ---
#  Position          Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1       Qarabag       6     3      3       0        13             6         7      12
#         2 AEK Athens FC       6     3      1       2         9            10        -1      10
#         3    Sturm Graz       6     1      4       1         7             8        -1       7
#         4     BK Hacken       6     0      2       4         5            10        -5       2
#
# --- Europa League Group 7 Standings ---
#  Position               Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1        Aston Villa       6     4      1       1        11             3         8      13
#         2            AS Roma       6     2      3       1         8             4         4       9
#         3        SC Freiburg       6     2      1       3         7             8        -1       7
#         4 Union St. Gilloise       6     1      1       4         2            13       -11       4
#
# --- Europa League Group 8 Standings ---
#  Position             Team  Played  Wins  Draws  Losses  GoalsFor  GoalsAgainst  GoalDiff  Points
#         1       Villarreal       6     5      1       0        15             1        14      16
#         2           Rennes       6     3      1       2         7            14        -7      10
#         3 Shakhtar Donetsk       6     1      1       4         4             7        -3       4
#         4 Sheriff Tiraspol       6     1      1       4         4             8        -4       4

# %%
clgames = dfFixtures[dfFixtures['competitionID'] == 6].copy()

# %%
pd.set_option('display.max_rows', None)
print(len(clgames))
clgames
