# %% [markdown]
# ### Installations

# %%
# !pip install holidays
# Out:
# Requirement already satisfied: holidays in c:\users\sdodman-local\anaconda3\lib\site-packages (0.77)
# Requirement already satisfied: python-dateutil in c:\users\sdodman-local\anaconda3\lib\site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sdodman-local\anaconda3\lib\site-packages (from python-dateutil->holidays) (1.17.0)

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import calendar
from datetime import date, timedelta
import matplotlib.pyplot as plt
import argparse

try:
    import holidays
except ImportError:
    raise ImportError("Please install the 'holidays' library: pip install holidays")

# %% [markdown]
# ### Load Templates

# %%
dfFixtures_template = pd.read_csv('Input/fixtureTable.csv', dayfirst=True, parse_dates=['date'])  # unshifted
dfTeams_base = pd.read_csv('Input/teamTable.csv')            # no attributes
dfCompetitions = pd.read_csv('Input/competitionTable.csv')

# %% [markdown]
# ### Helper Functions for Date Shift

# %%
import pandas as pd
import calendar
from datetime import date
from typing import Optional
import holidays

# -----------------------------------------------------------------------------
# 1. Initialize UK Holiday Engine (Dynamic Year Support)
# -----------------------------------------------------------------------------
def get_uk_holiday_name(dt: date) -> Optional[str]:
    return holidays.UK(years=dt.year).get(dt)

def find_holiday_date_by_name(target_year: int, holiday_name: str) -> Optional[date]:
    """
    Look up the date of a holiday in the target year by its name.
    """
    target_holidays = holidays.UK(years=target_year)
    for dt, name in target_holidays.items():
        if name == holiday_name:
            return dt
    return None


# -----------------------------------------------------------------------------
# 2. Weekday Ordinal Preservation Logic
# -----------------------------------------------------------------------------
def get_ordinal_weekday(dt: date) -> int:
    """Return the 1-based occurrence of dt.weekday() in dt.month."""
    month_cal = calendar.monthcalendar(dt.year, dt.month)
    weekday = dt.weekday()
    occurrences = [week[weekday] for week in month_cal if week[weekday] != 0]
    for i, day in enumerate(occurrences, start=1):
        if day == dt.day:
            return i
    raise ValueError(f"Could not determine ordinal for date {dt}")


def find_nth_weekday(year: int, month: int, weekday: int, ordinal: int) -> date:
    """Find the date of the ordinal-th weekday in the given month/year."""
    month_cal = calendar.monthcalendar(year, month)
    occurrences = [week[weekday] for week in month_cal if week[weekday] != 0]
    if not occurrences:
        raise ValueError(f"No occurrences of weekday {weekday} in {month}/{year}")
    if ordinal <= len(occurrences):
        day = occurrences[ordinal - 1]
    else:
        day = occurrences[-1]
    return date(year, month, day)


# -----------------------------------------------------------------------------
# 3. Shift Logic with Holiday + Weekday Ordinal Fallback
# -----------------------------------------------------------------------------
def shift_fixture_date(original_date: date, target_year: int) -> date:
    """
    Shift a single date into target_year, preserving bank holidays and weekday ordinals.
    """
    orig_holiday = get_uk_holiday_name(original_date)
    if orig_holiday:
        holiday_match = find_holiday_date_by_name(target_year, orig_holiday)
        if holiday_match:
            return holiday_match

    ordinal = get_ordinal_weekday(original_date)
    return find_nth_weekday(
        target_year,
        original_date.month,
        original_date.weekday(),
        ordinal
    )


# -----------------------------------------------------------------------------
# 4. Rebase Fixture Dates
# -----------------------------------------------------------------------------
def rebase_fixtures(df: pd.DataFrame, target_start_year: int) -> pd.DataFrame:
    """
    Rebase fixture dates in `df` to a new season starting in `target_start_year`.
    """
    df_new = df.copy()
    if 'round' in df_new.columns:
        df_new.drop(columns=['round'], inplace=True)

    df_new['date'] = pd.to_datetime(df_new['date'], errors='coerce')
    original_start_year = int(df_new['date'].dt.year.min())

    def _shift(ts):
        if pd.isna(ts):
            return pd.NaT
        orig = ts.date()
        year_offset = orig.year - original_start_year
        new_year = target_start_year + year_offset
        return shift_fixture_date(orig, new_year)

    df_new['date'] = df_new['date'].apply(_shift)
    df_new['date'] = df_new['date'].apply(
        lambda d: d.strftime('%Y-%m-%d') if pd.notna(d) else pd.NaT
    )

    return df_new

# -----------------------------------------------------------------------------
# 5. Entry Point: Fixture Creation for a Season
# -----------------------------------------------------------------------------
def create_fixture_list(year: int) -> pd.DataFrame:
    """Create rebased fixture list for a new season."""
    return rebase_fixtures(dfFixtures_template.copy(), year)

# %% [markdown]
# ### Helper Functions for Team Attributes

# %%
import pandas as pd
import random

def position_to_attribute(pos: int, min_val: float, max_val: float, min_rank: int, max_rank: int, ascending=True) -> float:
    """
    Linearly scale attribute from min_val to max_val over [min_rank, max_rank].
    If ascending=False, scales from max_val to min_val instead.
    """
    pos = max(min_rank, min(pos, max_rank))
    scale = (pos - min_rank) / (max_rank - min_rank) if max_rank > min_rank else 0
    if not ascending:
        scale = 1.0 - scale
    return round(min_val + (max_val - min_val) * scale, 2)


def assign_team_attributes(df: pd.DataFrame, seed: int = None) -> pd.DataFrame:
    """
    Assigns 'defense', 'midfield', and 'attack' attributes based on 'lastPos'.
    """
    rng = random.Random(seed)
    df_out = df.copy()

    def compute_attributes(row):
        pos = row['lastPos']
        if 1 <= pos <= 116:
            base = position_to_attribute(pos, min_val=1.0, max_val=8.5, min_rank=1, max_rank=116, ascending=False)
            variation = 0.75
        elif 117 <= pos <= 120:
            base = position_to_attribute(pos, min_val=6.0, max_val=8.0, min_rank=117, max_rank=120, ascending=True)
            variation = 0.5
        elif 121 <= pos <= 124:
            base = position_to_attribute(pos, min_val=7.0, max_val=9.0, min_rank=121, max_rank=124, ascending=True)
            variation = 0.5
        else:
            base = 5.0
            variation = 0.5

        return {
            'defense': round(base + rng.uniform(-variation, variation), 2),
            'midfield': round(base + rng.uniform(-variation, variation), 2),
            'attack': round(base + rng.uniform(-variation, variation), 2)
        }

    attributes = df_out.apply(compute_attributes, axis=1, result_type='expand')
    df_out[['defense', 'midfield', 'attack']] = attributes
    return df_out

def generate_team_attributes() -> pd.DataFrame:
    """Generate team attributes from base lastPos table."""
    return assign_team_attributes(dfTeams_base.copy())

# %% [markdown]
# ### Match Engine

# %%
import pandas as pd
import random
from typing import Tuple

def rnd_num() -> float:
    """Return a random number between 0 and 1."""
    return random.uniform(0, 1)

def goal_chance() -> int:
    """40% chance to score a goal."""
    return 1 if rnd_num() > 0.6 else 0

def get_team_attributes(team_id: int, df: pd.DataFrame) -> list:
    """Get defense, midfield, attack as a list for given team ID."""
    row = df.loc[df['teamID'] == team_id]
    if row.empty:
        raise ValueError(f"Team ID {team_id} not found in dataframe.")
    return [row.iloc[0]['defense'], row.iloc[0]['midfield'], row.iloc[0]['attack']]

def play_match_half(team1: list, team2: list) -> list:
    """
    Simulates one half of a football match between two teams.
    Each team is a list of 3 attributes: [def, mid, att]
    """
    match_seq = list(range(1, 13))
    random.shuffle(match_seq)

    result = [0, 0]  # [home_goals, away_goals]

    for index in range(1, 11):
        if match_seq[0] == index and team1[2] > team2[0] and (random.random() * team1[2]) > (random.random() * team2[0]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[6] == index and (random.random() * team1[2]) > (random.random() * team2[0]) and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[1] == index and team2[2] > team1[0] and (random.random() * team2[2]) > (random.random() * team1[0]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[7] == index and (random.random() * team1[2]) > (random.random() * team1[0]) and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[2] == index and team1[1] > team2[1] and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[8] == index and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[3] == index and team2[1] > team1[1] and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[9] == index and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[4] == index and random.random() > 0.45:
            result[0] += 1 if random.random() > 0.6 else 0

    return result

def play_full_match(team1_id: int, team2_id: int, df: pd.DataFrame) -> list:
    """
    Play a full match between two teams and return the result [goals_team1, goals_team2].
    """
    team1 = get_team_attributes(team1_id, df)
    team2 = get_team_attributes(team2_id, df)

    first_half = play_match_half(team1, team2)
    second_half = play_match_half(team1, team2)

    final_result = [first_half[0] + second_half[0], first_half[1] + second_half[1]]
    return final_result

import random

def simulate_penalties(home_team_id: int, away_team_id: int, dfTeams) -> tuple:
    """
    Run a simple 5‐kick penalty shootout for each team, then sudden death if still tied.
    Returns: (home_pk_goals, away_pk_goals, winner_id).
    """
    # Get [defense, midfield, attack] for each side
    attrs_home = get_team_attributes(home_team_id, dfTeams)  # → list [def, mid, att]
    attrs_away = get_team_attributes(away_team_id, dfTeams)

    # Use 'attack' at index 2, and 'defense' at index 0
    home_att = attrs_home[2]
    home_def = attrs_home[0]
    away_att = attrs_away[2]
    away_def = attrs_away[0]

    # Base penalty conversion probability: blend of home_att vs away_def
    base_prob_home = 0.8 * (home_att / (home_att + away_def)) + 0.2
    base_prob_away = 0.8 * (away_att / (away_att + home_def)) + 0.2

    # Clamp between [0.5, 0.95]
    base_prob_home = min(max(base_prob_home, 0.5), 0.95)
    base_prob_away = min(max(base_prob_away, 0.5), 0.95)

    def take_five_kicks(p_success: float) -> int:
        """Simulate exactly 5 penalty kicks given success probability p_success."""
        made = 0
        for _ in range(5):
            if random.random() < p_success:
                made += 1
        return made

    # 1) First 5 kicks each
    home_score = take_five_kicks(base_prob_home)
    away_score = take_five_kicks(base_prob_away)

    # 2) Sudden death if still tied
    while home_score == away_score:
        if random.random() < base_prob_home:
            home_score += 1
        if random.random() < base_prob_away:
            away_score += 1
        # repeat until one is ahead

    winner_id = home_team_id if home_score > away_score else away_team_id
    return home_score, away_score, winner_id

def play_cup_match(home_team_id: int, away_team_id: int, dfTeams):
    """
    Simulate a single cup tie:
      1) Play 90′ via play_full_match(...)
      2) If draw, run one “extra‐time half” via play_match_half(...)
      3) If still draw, run penalties via simulate_penalties(...)
    Returns a dict with:
      - home_goals (FT + ET)
      - away_goals (FT + ET)
      - winner_id
      - extra_time_played (bool)
      - home_et_goals, away_et_goals (ints; zero if no ET)
      - home_pk, away_pk (ints; None if no shootout)
    """
    # 1) Full‐time (90′)
    home_ft, away_ft = play_full_match(home_team_id, away_team_id, dfTeams)

    # If someone wins in 90′, skip ET/PK
    if home_ft != away_ft:
        winner = home_team_id if home_ft > away_ft else away_team_id
        return {
            "home_goals": home_ft,
            "away_goals": away_ft,
            "winner_id":  winner,
            "extra_time_played": False,
            "home_et_goals": 0,
            "away_et_goals": 0,
            "home_pk":      None,
            "away_pk":      None
        }

    # 2) Extra‐time: simulate one “half” of 45′ via play_match_half(...)
    # (This effectively approximates a 30′ ET; you can adjust scaling later if needed.)
    et_home, et_away = play_match_half(
        get_team_attributes(home_team_id, dfTeams),
        get_team_attributes(away_team_id, dfTeams)
    )
    home_total = home_ft + et_home
    away_total = away_ft + et_away

    # If someone wins in ET, skip penalties
    if home_total != away_total:
        winner = home_team_id if home_total > away_total else away_team_id
        return {
            "home_goals": home_total,
            "away_goals": away_total,
            "winner_id":  winner,
            "extra_time_played": True,
            "home_et_goals":  et_home,
            "away_et_goals":  et_away,
            "home_pk":       None,
            "away_pk":       None
        }

    # 3) Penalty shootout
    home_pk, away_pk, winner = simulate_penalties(home_team_id, away_team_id, dfTeams)
    return {
        "home_goals": home_total,
        "away_goals": away_total,
        "winner_id":  winner,
        "extra_time_played": True,
        "home_et_goals":  et_home,
        "away_et_goals":  et_away,
        "home_pk":       home_pk,
        "away_pk":       away_pk
    }

# %% [markdown]
# ### Helper Function to Initialise Cup Status

# %%
import random

def initialize_cup_status(dfTeams):
    """
    Reset and set initial cup‐eligibility flags based on last season’s results:
      - inCS: Community Shield (league winner & FA Cup winner)
      - inCL: Champions League (top‐4 English, CL winner override; plus direct qualifiers lastPos ∈ {121–124})
      - inEL: Europa League (4 English slots: FA & LC winners + next best by position; 
                             plus direct qualifiers lastPos ∈ {117–120})
      - inFA: FA Cup R1 (teamID 45–92 direct; + 32 random from teamID 93–134)
      - inLC: League Cup (teamID 21–92)
    """
    # 0) Ensure lastPos is integer
    dfTeams['lastPos'] = dfTeams['lastPos'].astype(int)

    # 1) Reset all flags
    for col in ['inCS','inCL','inEL','inFA','inLC']:
        dfTeams[col] = False

    # 2) Community Shield: English league winner & FA Cup winner
    cs_mask = (
        (dfTeams['nationality']=='ENG') &
        ((dfTeams['lastPos']==1) | (dfTeams['faCupWin']==True))
    )
    dfTeams.loc[cs_mask, 'inCS'] = True

    # 3) Champions League (English slots)
    eng = dfTeams['nationality']=='ENG'
    cl_winner = dfTeams[eng & (dfTeams['clCupWin']==True)]
    if not cl_winner.empty:
        wid = cl_winner['teamID'].iat[0]
        dfTeams.loc[dfTeams['teamID']==wid, 'inCL'] = True
        others = dfTeams[eng & (dfTeams['teamID']!=wid)].nsmallest(3, 'lastPos')
        dfTeams.loc[others.index, 'inCL'] = True
    else:
        top4 = dfTeams[eng].nsmallest(4, 'lastPos')
        dfTeams.loc[top4.index, 'inCL'] = True
    # 3b) Direct CL qualifiers by lastPos codes 121–124
    dfTeams.loc[dfTeams['lastPos'].isin([121,122,123,124]), 'inCL'] = True

    # 4) Europa League (English slots)
    el_winners = dfTeams[
        eng &
        ((dfTeams['faCupWin']==True) | (dfTeams['lcCupWin']==True)) &
        (~dfTeams['inCL'])
    ]['teamID'].tolist()
    dfTeams.loc[dfTeams['teamID'].isin(el_winners), 'inEL'] = True

    # 4b) Top-up English EL slots to 4 by best lastPos among ENG not inCL/EL
    curr = dfTeams[(eng) & (dfTeams['inEL']==True)].shape[0]
    if curr < 4:
        needed = 4 - curr
        fill = dfTeams[
            eng & (~dfTeams['inCL']) & (~dfTeams['inEL'])
        ].nsmallest(needed, 'lastPos')
        dfTeams.loc[fill.index, 'inEL'] = True

    # 4c) Direct EL qualifiers by lastPos codes 117–120
    dfTeams.loc[dfTeams['lastPos'].isin([117,118,119,120]), 'inEL'] = True

    # 5) FA Cup R1: teamID 45–92 direct + random 32 from teamID 93–134
    direct_ids = dfTeams.loc[dfTeams['teamID'].between(45, 92), 'teamID'].tolist()
    pool_ids   = dfTeams.loc[dfTeams['teamID'].between(93, 134), 'teamID'].tolist()
    if len(pool_ids) < 32:
        raise ValueError(f"Not enough teams in 93–134 to pick 32; found {len(pool_ids)}")
    fa_qual = random.sample(pool_ids, 32)
    dfTeams.loc[dfTeams['teamID'].isin(direct_ids + fa_qual), 'inFA'] = True

    # 6) League Cup: teamID 21–92
    dfTeams.loc[dfTeams['teamID'].between(21, 92), 'inLC'] = True

    # 7) Summary
    print("✅ Initialized cup status:")
    print(f"  inCS: {dfTeams['inCS'].sum()} teams")
    print(f"  inCL: {dfTeams['inCL'].sum()} teams")
    print(f"  inEL: {dfTeams['inEL'].sum()} teams")
    print(f"  inFA: {dfTeams['inFA'].sum()} teams")
    print(f"  inLC: {dfTeams['inLC'].sum()} teams")

    return dfTeams

# %% [markdown]
# ### Helper Functions for League Round

# %%
def play_league_round(day: int,
                      dfFixtures: pd.DataFrame,
                      dfTeams: pd.DataFrame,
                      dfCompetitions: pd.DataFrame,
                      dfGroupStage: pd.DataFrame = None) -> pd.DataFrame:
    """
    Plays all league‐style fixtures (domestic + UCL/EL group‐stage) for a given dayCounter,
    updates dfFixtures in‐place, prints results by competition, then:
      1) Recompute domestic tables (comps 1–5)
      2) If dfGroupStage is provided and EL (8) matches were played, recompute EL tables
      3) If dfGroupStage is provided and UCL (9) matches were played, recompute UCL tables
    """

    # 1) Build a “not played” mask treating NaN as False
    not_played_mask = ~dfFixtures['played'].fillna(False)

    # 2) Include domestic (1–5), EL (8), UCL (9)
    valid_comp_ids = [1, 2, 3, 4, 5, 8, 9]

    day_fixtures = dfFixtures[
        (dfFixtures['dayCounter'] == day) &
        (not_played_mask) &
        (dfFixtures['competitionID'].isin(valid_comp_ids))
    ].copy()

    if day_fixtures.empty:
        print(f"No league/group‐stage fixtures scheduled or all already played for day {day}.")
        return dfFixtures

    # 3) Build lookup maps
    team_name_map = dfTeams.set_index('teamID')['teamName'].to_dict()
    comp_name_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    results_by_comp = {}
    match_date = day_fixtures.iloc[0]['date']

    # Track which competitions had a match today
    comps_played_today = set()

    for idx, match in day_fixtures.iterrows():
        home_id = match['homeTeam']
        away_id = match['awayTeam']
        comp_id = match['competitionID']

        # Simulate 90' only
        home_goals, away_goals = play_full_match(home_id, away_id, dfTeams)

        # Update dfFixtures
        dfFixtures.at[idx, 'homeGoals'] = home_goals
        dfFixtures.at[idx, 'awayGoals'] = away_goals
        dfFixtures.at[idx, 'played'] = True

        comps_played_today.add(comp_id)

        # Format for printing
        home_name = team_name_map.get(home_id, f"Team{home_id}")
        away_name = team_name_map.get(away_id, f"Team{away_id}")
        comp_name = comp_name_map.get(comp_id, f"Competition{comp_id}")
        line = f"{home_name} {home_goals} - {away_goals} {away_name}"
        results_by_comp.setdefault(comp_id, []).append(line)

    # 4) Print results sorted by competitionID
    print(f"\nMatches played on {match_date}:")
    for comp_id in sorted(results_by_comp.keys()):
        comp_name = comp_name_map.get(comp_id, f"Competition{comp_id}")
        print(comp_name)
        for line in results_by_comp[comp_id]:
            print(line)

    # 5) Recompute domestic league tables (1–5)
    update_tables()

    # 6) If dfGroupStage is provided, update EL/UCL group tables as needed
    if dfGroupStage is not None:
        # Europa League (comp 8)
        if 8 in comps_played_today:
            global el_tables
            el_tables = generate_euro_group_tables(
                competitionID=8,
                dfFixtures=dfFixtures,
                dfTeams=dfTeams,
                dfGroupStage=dfGroupStage
            )
         
        # Champions League (comp 9)
        if 9 in comps_played_today:
            global ucl_tables
            ucl_tables = generate_euro_group_tables(
                competitionID=9,
                dfFixtures=dfFixtures,
                dfTeams=dfTeams,
                dfGroupStage=dfGroupStage
            )
          
    return dfFixtures

# %% [markdown]
# ### Helper Functions for League Tables

# %%
def generate_league_tables(dfFixtures: pd.DataFrame, dfTeams: pd.DataFrame) -> dict:
    """
    Generate league tables for CompetitionIDs 1 to 5, ensuring all teams are included even if they haven't played.
    Removes teamID and formats GF, GA, GD as integers.

    Returns:
        Dictionary {competitionID: league_table_df}
    """
    league_tables = {}

    for comp_id in range(1, 6):
        # Get all teams in this competition (home and away)
        teams_in_league = pd.unique(
            dfFixtures[dfFixtures['competitionID'] == comp_id][['homeTeam', 'awayTeam']].values.ravel()
        )

        # Initialize stats
        team_stats = {
            team_id: {'MP': 0, 'W': 0, 'D': 0, 'L': 0, 'GF': 0, 'GA': 0, 'Points': 0}
            for team_id in teams_in_league
        }

        # Played matches only
        league_matches = dfFixtures[
            (dfFixtures['competitionID'] == comp_id) & (dfFixtures['played'])
        ]

        # Accumulate stats
        for _, match in league_matches.iterrows():
            h_id, a_id = match['homeTeam'], match['awayTeam']
            hg, ag = match['homeGoals'], match['awayGoals']

            # Home update
            team_stats[h_id]['MP'] += 1
            team_stats[h_id]['GF'] += hg
            team_stats[h_id]['GA'] += ag
            # Away update
            team_stats[a_id]['MP'] += 1
            team_stats[a_id]['GF'] += ag
            team_stats[a_id]['GA'] += hg

            if hg > ag:
                team_stats[h_id]['W'] += 1
                team_stats[h_id]['Points'] += 3
                team_stats[a_id]['L'] += 1
            elif hg == ag:
                team_stats[h_id]['D'] += 1
                team_stats[a_id]['D'] += 1
                team_stats[h_id]['Points'] += 1
                team_stats[a_id]['Points'] += 1
            else:
                team_stats[a_id]['W'] += 1
                team_stats[a_id]['Points'] += 3
                team_stats[h_id]['L'] += 1

        # Build rows
        rows = []
        for team_id in teams_in_league:
            stats = team_stats[team_id]
            team_name = dfTeams.loc[dfTeams['teamID'] == team_id, 'teamName'].values[0]
            gd = stats['GF'] - stats['GA']
            rows.append({
                'teamName': team_name,
                'MP': stats['MP'],
                'W': stats['W'],
                'D': stats['D'],
                'L': stats['L'],
                'GF': int(round(stats['GF'])),
                'GA': int(round(stats['GA'])),
                'GD': int(round(gd)),
                'Points': stats['Points']
            })

        league_df = pd.DataFrame(rows)
        league_df = league_df.sort_values(by=['Points', 'GD', 'GF'], ascending=False).reset_index(drop=True)
        league_df.insert(0, 'Position', league_df.index + 1)

        league_tables[comp_id] = league_df

    return league_tables


def print_all_league_tables(league_tables: dict, dfCompetitions: pd.DataFrame):
    """
    Pretty print all league tables with their competition names as headers.

    Parameters:
        league_tables: Dict {competitionID: league DataFrame}
        dfCompetitions: DataFrame containing competitionID and competitionName
    """
    # Build a mapping from competitionID to name
    comp_name_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    for comp_id in sorted(league_tables.keys()):
        table = league_tables[comp_id]
        comp_name = comp_name_map.get(comp_id, f"Competition {comp_id}")

        print(f"\n{comp_name}")
        print(table.to_string(index=False))

# %% [markdown]
# ### Helper Functions for Cup Rounds

# %%
def play_cup_round(dayCounter, competitionID, dfFixtures, dfTeams):
    """
    Simulate every unplayed cup fixture on each day in 'dayCounter' for competitionID,
    writing the following into dfFixtures for each match:
      - homeGoals, awayGoals: total goals after 90' + ET (if any)
      - homeGoalsAET, awayGoalsAET: extra‐time goals
      - homePens, awayPens: penalty goals (None if no shootout)
      - played: True once done
    Prints a summary including “(a.e.t.)” or “[p x–y]” as needed.
    """
    # 1) Look up competition name (uses global dfCompetitions)
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == competitionID,
        'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

    # 2) Parse dayCounter into a list of ints
    if isinstance(dayCounter, str):
        days = [int(x.strip()) for x in dayCounter.split(',') if x.strip().isdigit()]
    elif isinstance(dayCounter, (list, tuple)):
        days = [int(x) for x in dayCounter]
    else:
        days = [int(dayCounter)]

    all_winners = []
    for day in days:
        # 3) Filter for unplayed cup fixtures on this day & competition
        mask = (
            (dfFixtures['dayCounter']   == day) &
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['played']        == False)
        )
        todays_matches = dfFixtures.loc[mask].copy()
        if todays_matches.empty:
            print(f"No fixtures to play on day {day} for '{comp_name}'")
            continue

        for idx, match in todays_matches.iterrows():
            # skip any blank placeholder
            if pd.isna(match['homeTeam']) or pd.isna(match['awayTeam']):
                print(f"❌ Skipping empty slot on day {day} for '{comp_name}' at index {idx}")
                continue

            home_id = int(match['homeTeam'])
            away_id = int(match['awayTeam'])

            # Simulate 90′ + ET + penalties
            result = play_cup_match(home_id, away_id, dfTeams)
            all_winners.append(result['winner_id'])

            # 4) Write results back into dfFixtures
            dfFixtures.at[idx, 'homeGoals']     = result['home_goals']
            dfFixtures.at[idx, 'awayGoals']     = result['away_goals']
            dfFixtures.at[idx, 'homeGoalsAET']  = result['home_et_goals']
            dfFixtures.at[idx, 'awayGoalsAET']  = result['away_et_goals']
            dfFixtures.at[idx, 'homePens']      = result['home_pk']
            dfFixtures.at[idx, 'awayPens']      = result['away_pk']
            dfFixtures.at[idx, 'played']        = True

            # 5) Print summary line
            home_name   = dfTeams.loc[dfTeams['teamID']==home_id, 'teamName'].iat[0]
            away_name   = dfTeams.loc[dfTeams['teamID']==away_id, 'teamName'].iat[0]
            winner_name = dfTeams.loc[dfTeams['teamID']==result['winner_id'], 'teamName'].iat[0]

            suffix = ""
            if result['extra_time_played']:
                suffix += " (a.e.t.)"
            if result['home_pk'] is not None and result['away_pk'] is not None:
                suffix += f" [p {result['home_pk']}–{result['away_pk']}]"

            print(
                f"Day {day} | {comp_name} | "
                f"{home_name} {result['home_goals']}–{result['away_goals']} {away_name}"
                f"{suffix} → Winner: {winner_name}"
            )

    return all_winners

# %% [markdown]
# ### Generic Cup Draw

# %%
import random

def draw_cup(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic cup‐draw function for:
      • Community Shield   (competitionID=10, flag 'inCS', exactly 2 teams)
      • League Cup         (competitionID=6,  flag 'inLC', even-numbered field)
      • FA Cup Round 1     (competitionID=7,  flag 'inFA', even-numbered field)
      • Europa League KO   (competitionID=8,  flag 'inEL', even-numbered field)
      • Champions League KO(competitionID=9,  flag 'inCL', even-numbered field)

    Assumes dfTeams['inXX'] flags have already been set for that competition.
    1) Read comp_id, look up its flag column.
    2) Select all dfTeams where that flag is True.
       • If comp_id == 10, require exactly 2.
       • Otherwise require an even number.
    3) Shuffle and pair off in order.
    4) Parse allowed_days from row['dayCounter'] (comma-sep ints).
    5) In dfFixtures, find blank fixtures for this comp on those days:
       competitionID == comp_id, dayCounter ∈ allowed_days,
       homeTeam/isnull & awayTeam/isnull.
    6) Fill the first N placeholders with your pairs.
    7) Print a summary.
    """
    comp_id = int(row['competitionID'])
    comp_name = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id, 'competitionName'
    ].iat[0]

    # 1) Hard-coded mapping of competition → which inXX column to use
    comp_flag_map = {
        10: 'inCS',
        6: 'inLC',
        7: 'inFA',
        8: 'inEL',
        9: 'inCL'
    }
    if comp_id not in comp_flag_map:
        print(f"❌ No cup-draw configured for competitionID {comp_id}")
        return
    flag_col = comp_flag_map[comp_id]

    # 2) Gather eligible teams
    eligible = dfTeams[dfTeams[flag_col] == True].copy()
    n = len(eligible)
    if comp_id == 10:
        if n != 2:
            print(f"❌ Error: Community Shield needs 2 teams, found {n}")
            return
    else:
        if n % 2 != 0:
            print(f"❌ Error: {comp_name} needs an even number of teams, found {n}")
            return

    # 3) Shuffle and pair
    team_ids = eligible['teamID'].tolist()
    random.shuffle(team_ids)
    pairs = [(team_ids[i], team_ids[i+1]) for i in range(0, len(team_ids), 2)]

    # 4) Parse allowed_days
    allowed_days = [
        int(d.strip()) for d in str(row['dayCounter']).split(',')
        if d.strip().isdigit()
    ]
    if not allowed_days:
        print(f"❌ Error: No valid dayCounters provided for {comp_name}")
        return

    # 5) Find blank fixtures
    mask = (
        (dfFixtures['competitionID'] == comp_id) &
        (dfFixtures['dayCounter'].isin(allowed_days)) &
        (dfFixtures['homeTeam'].isnull()) &
        (dfFixtures['awayTeam'].isnull())
    )
    open_fx = dfFixtures.loc[mask]
    if len(open_fx) < len(pairs):
        print(f"❌ Error: Not enough blank fixtures for {comp_name}: "
              f"needed {len(pairs)}, found {len(open_fx)}")
        return

    # 6) Fill placeholders
    for (home_tid, away_tid), idx in zip(pairs, open_fx.index):
        dfFixtures.at[idx, 'homeTeam'] = home_tid
        dfFixtures.at[idx, 'awayTeam'] = away_tid

    # 7) Print summary
    dates = dfFixtures.loc[open_fx.index[:len(pairs)], 'date'].unique().tolist()
    print(f"\n🏆 {comp_name} draw ({len(pairs)} matches) across: {', '.join(dates)}")
    for i, (home_tid, away_tid) in enumerate(pairs, 1):
        home_name = dfTeams.loc[dfTeams['teamID'] == home_tid, 'teamName'].iat[0]
        away_name = dfTeams.loc[dfTeams['teamID'] == away_tid, 'teamName'].iat[0]
        dayc = dfFixtures.at[open_fx.index[i-1], 'dayCounter']
        print(f"  Match {i:02d} (day {dayc}): {home_name} vs {away_name}")

    # commit back
    globals()['dfFixtures'] = dfFixtures

# %% [markdown]
# ### European Helper Functions

# %%
import random
import pandas as pd

def draw_euro_group_stage(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic draw for European group stages (UCL or EL), but now appends to a global dfGroupStage
    instead of overwriting it. This means you can call it twice (once for competitionID=9, once
    for competitionID=8) and keep both sets of group assignments.

    Expects:
      - row['competitionID'] ∈ {9 (UCL), 8 (EL)}
      - row['dayCounter']  = comma-separated string of 12 ints (for UCL) or 6 ints (for EL)
      - dfTeams, dfFixtures, dfCompetitions already in scope

    After this runs, global dfGroupStage will contain rows:
      competitionID | teamID | groupID
    for all previously‐drawn competitions (8 and/or 9), plus this new draw.
    """

    # 1) Parse dayCounters
    raw = row['dayCounter']
    if isinstance(raw, str):
        date_list = [int(x.strip()) for x in raw.split(',') if x.strip().isdigit()]
    else:
        try:
            date_list = list(raw)
        except:
            date_list = [int(raw)]

    comp_id = int(row['competitionID'])
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id, 'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"Competition{comp_id}"

    # 2) Determine flag column and expected number of dayCounters
    if comp_id == 9:    # UCL
        expected = 12
        flag_col = 'inCL'
    elif comp_id == 8:  # EL
        expected = 6
        flag_col = 'inEL'
    else:
        raise ValueError(f"CompetitionID {comp_id} is not UCL (9) or EL (8).")

    if len(date_list) != expected:
        raise ValueError(f"{comp_name} requires {expected} dayCounters, got {len(date_list)}.")

    # 3) Select exactly 32 teams still in the competition
    euro_teams = dfTeams.loc[dfTeams[flag_col] == True, ['teamID', 'nationality']].to_dict(orient='records')
    if len(euro_teams) != 32:
        raise ValueError(f"Expected 32 teams where {flag_col}==True, found {len(euro_teams)}.")

    # 4) Assign to 8 groups of 4 with unique nationality constraint
    def attempt_grouping():
        random.shuffle(euro_teams)
        groups = {gid: [] for gid in range(1, 9)}
        for team in euro_teams:
            placed = False
            order = list(groups.keys())
            random.shuffle(order)
            for gid in order:
                if len(groups[gid]) < 4:
                    existing_nats = {t['nationality'] for t in groups[gid]}
                    if team['nationality'] not in existing_nats:
                        groups[gid].append(team)
                        placed = True
                        break
            if not placed:
                return None
        return groups

    groups = None
    for _ in range(1000):
        groups = attempt_grouping()
        if groups is not None:
            break
    if groups is None:
        raise RuntimeError("Failed to assign teams into nationality‐unique groups after many tries.")

    # 5) Build a DataFrame for this draw (comp_id, teamID, groupID)
    new_group_rows = [
        {'competitionID': comp_id, 'teamID': t['teamID'], 'groupID': gid}
        for gid, members in groups.items()
        for t in members
    ]
    new_df = pd.DataFrame(new_group_rows)

    # 6) Append to global dfGroupStage (dropping any old rows for the same comp_id)
    global dfGroupStage
    try:
        # If dfGroupStage already exists, remove any rows for this comp_id, then append
        dfGroupStage = dfGroupStage[ dfGroupStage['competitionID'] != comp_id ].copy()
        dfGroupStage = pd.concat([dfGroupStage, new_df], ignore_index=True)
    except NameError:
        # dfGroupStage doesn't exist yet; just create it
        dfGroupStage = new_df.copy()

    # 7) Fill placeholders in dfFixtures for matchups (same as before)
    def single_round_robin(team_ids):
        teams = list(team_ids)
        n = len(teams)  # 4
        rounds = []
        for _ in range(n - 1):  # 3 rounds
            pairings = []
            for j in range(n // 2):
                t1 = teams[j]
                t2 = teams[n - 1 - j]
                pairings.append((t1, t2))
            rounds.append(pairings)
            teams = [teams[0]] + [teams[-1]] + teams[1:-1]
        return rounds

    group_schedules = {}
    for gid, members in groups.items():
        tids = [t['teamID'] for t in members]
        first = single_round_robin(tids)
        second = [[(away, home) for (home, away) in rnd] for rnd in first]
        full = first + second  # 6 total rounds
        group_schedules[gid] = full

    # 8) Populate existing dfFixtures placeholders:
    for rnd_idx in range(6):
        if comp_id == 9:
            # UCL: two dayCounters per round
            dc_1_4 = date_list[2 * rnd_idx]
            dc_5_8 = date_list[2 * rnd_idx + 1]
        else:
            # EL: single dayCounter per round
            dc_all = date_list[rnd_idx]

        for gid, schedule in group_schedules.items():
            match_pairs = schedule[rnd_idx]  # two (home,away) pairs
            dc = (dc_1_4 if gid <= 4 else dc_5_8) if comp_id == 9 else dc_all

            placeholder_mask = (
                (dfFixtures['competitionID'] == comp_id) &
                (dfFixtures['dayCounter']     == dc) &
                (dfFixtures['homeTeam'].isna()) &
                (dfFixtures['awayTeam'].isna())
            )
            placeholders = dfFixtures.loc[placeholder_mask]
            needed = len(match_pairs)
            if len(placeholders) < needed:
                raise RuntimeError(
                    f"Not enough placeholder rows for {comp_name} on day {dc}: "
                    f"needed {needed}, found {len(placeholders)}"
                )

            indices = placeholders.index.tolist()[:needed]
            for idx, (home_tid, away_tid) in zip(indices, match_pairs):
                dfFixtures.at[idx, 'homeTeam'] = home_tid
                dfFixtures.at[idx, 'awayTeam'] = away_tid
                dfFixtures.at[idx, 'round']    = rnd_idx + 1

    # 9) Print out group composition (for just this competition)
    print(f"\nPopulated {comp_name} Group Stage (competitionID={comp_id}):")
    for gid, members in groups.items():
        names = [
            dfTeams.loc[dfTeams['teamID'] == t['teamID'], 'teamName'].values[0]
            for t in members
        ]
        print(f"  Group {gid}: {', '.join(names)}")

    return dfGroupStage

import pandas as pd

def generate_euro_group_tables(competitionID: int,
                                dfFixtures: pd.DataFrame,
                                dfTeams: pd.DataFrame,
                                dfGroupStage: pd.DataFrame) -> dict:
    """
    Returns a dict mapping groupID → DataFrame of standings for that group,
    for the given European group-stage competition (8 = EL or 9 = UCL).

    Each DataFrame has columns:
      ['Position', 'Team', 'Played', 'Wins', 'Draws', 'Losses',
       'GoalsFor', 'GoalsAgainst', 'GoalDiff', 'Points']

    Args:
      competitionID: 8 or 9
      dfFixtures:    DataFrame with group-stage matches, including:
                      ['competitionID','homeTeam','awayTeam','homeGoals','awayGoals','played']
      dfTeams:       DataFrame with ['teamID','teamName', …]
      dfGroupStage:  DataFrame with ['competitionID','teamID','groupID']

    Returns:
      A dict { groupID: group_table_df, … } for groupID in [1..8].
    """

    # 1) Filter to played matches of this competition
    mask = (
        (dfFixtures['competitionID'] == competitionID) &
        (dfFixtures['played'] == True)
    )
    played = dfFixtures.loc[mask].copy()
    if played.empty:
        print(f"No played fixtures found for competition {competitionID}.")
        return {}

    # 2) Merge in groupID for home and away teams
    #    We assume dfGroupStage has exactly one row per (competitionID, teamID).
    gs = dfGroupStage[dfGroupStage['competitionID'] == competitionID][['teamID','groupID']]

    played = played.merge(gs.rename(columns={'teamID':'homeTeam', 'groupID':'homeGroup'}),
                          on='homeTeam', how='left')
    played = played.merge(gs.rename(columns={'teamID':'awayTeam', 'groupID':'awayGroup'}),
                          on='awayTeam', how='left')

    # 3) Build a “per‐team‐per‐match” record
    records = []
    for _, row in played.iterrows():
        h_id = int(row['homeTeam'])
        a_id = int(row['awayTeam'])
        hg   = int(row['homeGoals'])
        ag   = int(row['awayGoals'])
        hg_id = row['homeGroup']
        ag_id = row['awayGroup']
        # (They should be equal: hg_id == ag_id, otherwise data is inconsistent.)

        # Home team stats
        if hg > ag:
            h_w, h_d, h_l, h_pts = 1, 0, 0, 3
            a_w, a_d, a_l, a_pts = 0, 0, 1, 0
        elif hg < ag:
            h_w, h_d, h_l, h_pts = 0, 0, 1, 0
            a_w, a_d, a_l, a_pts = 1, 0, 0, 3
        else:
            h_w, h_d, h_l, h_pts = 0, 1, 0, 1
            a_w, a_d, a_l, a_pts = 0, 1, 0, 1

        records.append({
            'groupID':      hg_id,
            'teamID':       h_id,
            'Played':       1,
            'Wins':         h_w,
            'Draws':        h_d,
            'Losses':       h_l,
            'GoalsFor':     hg,
            'GoalsAgainst': ag,
            'Points':       h_pts
        })
        # Away team stats
        records.append({
            'groupID':      ag_id,
            'teamID':       a_id,
            'Played':       1,
            'Wins':         a_w,
            'Draws':        a_d,
            'Losses':       a_l,
            'GoalsFor':     ag,
            'GoalsAgainst': hg,
            'Points':       a_pts
        })

    df_stats = pd.DataFrame(records)

    # 4) Aggregate by groupID + teamID
    agg = df_stats.groupby(['groupID','teamID'], as_index=False).sum()
    #    Compute goal difference
    agg['GoalDiff'] = agg['GoalsFor'] - agg['GoalsAgainst']

    # 5) Merge in team names
    agg = agg.merge(dfTeams[['teamID','teamName']], on='teamID', how='left')

    # 6) For each group, create a sorted table
    group_tables = {}
    for gid in sorted(agg['groupID'].unique()):
        gdf = agg[agg['groupID'] == gid].copy()
        # Sort by Points desc, then GoalDiff desc, then GoalsFor desc
        gdf = gdf.sort_values(
            by=['Points','GoalDiff','GoalsFor'],
            ascending=[False, False, False]
        ).reset_index(drop=True)

        # Assign position 1–4
        gdf.insert(0, 'Position', range(1, len(gdf)+1))

        # Reorder columns for readability
        gdf = gdf[['Position','teamName','Played','Wins','Draws','Losses',
                   'GoalsFor','GoalsAgainst','GoalDiff','Points']]
        gdf.rename(columns={'teamName':'Team'}, inplace=True)

        group_tables[gid] = gdf

    return group_tables

import pandas as pd

import pandas as pd

def print_euro_group_tables(comp_id: int,
                            dfTeams: pd.DataFrame,
                            dfFixtures: pd.DataFrame,
                            dfGroupStage: pd.DataFrame):
    """
    Prints all 8 group standings for the given European competition (8=EL or 9=UCL).
    - If no matches have been played in a group, that group prints all zeros.
    - If some matches have been played, you'll see real stats (Played/W/D/L/GF/GA/GD/Pts).

    Args:
      comp_id       : 8 for Europa League, 9 for Champions League
      dfTeams       : DataFrame with ['teamID','teamName', …]
      dfFixtures    : DataFrame with all group fixtures, including 'played', 'homeGoals', 'awayGoals'
      dfGroupStage  : DataFrame with ['competitionID','teamID','groupID'] (32 rows for comp_id)

    Usage:
      # Right after drawing groups (so dfGroupStage has comp_id rows):
      print_euro_group_tables(9, dfTeams, dfFixtures, dfGroupStage)
      
      # After some matchdays have been simulated:
      print_euro_group_tables(9, dfTeams, dfFixtures, dfGroupStage)
    """

    # 1) Build mapping: groupID → [teamID, …] for this competition
    gs = dfGroupStage[dfGroupStage['competitionID'] == comp_id]
    if len(gs) != 32:
        raise ValueError(
            f"dfGroupStage must contain exactly 32 rows for comp {comp_id}, "
            f"found {len(gs)}"
        )

    euro_groups = gs.groupby('groupID')['teamID'].apply(list).to_dict()
    missing = [gid for gid in range(1, 9) if gid not in euro_groups]
    if missing:
        raise ValueError(f"Missing groupIDs {missing} in dfGroupStage for comp {comp_id}.")

    # 2) Generate actual group tables (this will return a dict {gid: DataFrame} for groups
    #    where at least one match has been played; empty dict if none)
    actual_tables = generate_euro_group_tables(
        competitionID=comp_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )

    # 3) For each group (1..8), either print the actual table or a zero‐stats template
    for gid in range(1, 9):
        comp_name = dfCompetitions.loc[
            dfCompetitions['competitionID'] == comp_id, 'competitionName'
        ].values[0]
        print(f"\n--- {comp_name} Group {gid} Standings ---")

        if gid in actual_tables:
            tbl = actual_tables[gid].copy()
            # Ensure there’s a Position column in front
            if 'Position' not in tbl.columns:
                tbl.insert(0, 'Position', range(1, len(tbl) + 1))
            print(tbl.to_string(index=False))
            continue

        # No matches played yet in this group: build zero‐stats
        rows = []
        for tid in euro_groups[gid]:
            team_name = dfTeams.loc[dfTeams['teamID'] == tid, 'teamName'].values[0]
            rows.append({
                'Team':         team_name,
                'Played':       0,
                'Wins':         0,
                'Draws':        0,
                'Losses':       0,
                'GoalsFor':     0,
                'GoalsAgainst': 0,
                'GoalDiff':     0,
                'Points':       0
            })
        zero_df = pd.DataFrame(rows)
        zero_df.insert(0, 'Position', range(1, 5))
        print(zero_df.to_string(index=False))

import random

import random

def end_cl_groups(row, dfTeams, dfFixtures, dfGroupStage):
    """
    After UCL group stage completes:
      1) Reset all dfTeams['inCL'] to False.
      2) Re-flag the 16 teams (8 group winners + 8 runners-up).
      3) Draw two-legged Round of 16:
         - first half of row['dayCounter'] for leg1 days,
         - second half for leg2 days,
         cycling if fewer days than matches,
         and populate existing blanks (one fixture slot per match per leg).
    """
    comp_id = 9

    # 1) Clear previous CL flags
    dfTeams['inCL'] = False

    # 2) Find winners & runners-up
    tables = generate_euro_group_tables(
        competitionID=comp_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    winners = []
    runners  = []
    for gid, tbl in tables.items():
        # map names back to IDs
        win_name, run_name = tbl.iloc[0]['Team'], tbl.iloc[1]['Team']
        win_id = dfTeams.loc[dfTeams.teamName == win_name, 'teamID'].iat[0]
        run_id = dfTeams.loc[dfTeams.teamName == run_name, 'teamID'].iat[0]
        winners.append((gid, win_id))
        runners.append((gid, run_id))

    # flag them
    dfTeams.loc[dfTeams.teamID.isin([tid for _,tid in winners] + [tid for _,tid in runners]), 'inCL'] = True

    # 3) Pair winners vs runners from different groups
    rng = list(range(len(winners)))  # should be 8
    for _ in range(1000):
        random.shuffle(runners)
        if all(winners[i][0] != runners[i][0] for i in rng):
            break
    else:
        raise RuntimeError("Cannot pair winners with runners without rematches")

    match_pairs = [(winners[i][1], runners[i][1]) for i in rng]
    n_matches = len(match_pairs)

    # 4) Parse dayCounters and split into two pools
    days = [int(x.strip()) for x in str(row['dayCounter']).split(',') if x.strip().isdigit()]
    if not days:
        raise ValueError("No valid dayCounters provided for End CL Groups")
    half = len(days) // 2 or 1
    leg1_pool = days[:half]
    leg2_pool = days[half:half*2] if len(days) > half else days

    # build full schedules, cycling
    leg1_days = [leg1_pool[i % len(leg1_pool)] for i in range(n_matches)]
    leg2_days = [leg2_pool[i % len(leg2_pool)] for i in range(n_matches)]

    # 5) Fill placeholders for leg1 then leg2
    # leg1
    for (home_tid, away_tid), dc in zip(match_pairs, leg1_days):
        mask = (
            (dfFixtures.competitionID == comp_id) &
            (dfFixtures.dayCounter    == dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank fixture for leg1 match on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = home_tid
        dfFixtures.at[idxs[0], 'awayTeam'] = away_tid

    # leg2 (reverse)
    for (home_tid, away_tid), dc in zip(match_pairs, leg2_days):
        mask = (
            (dfFixtures.competitionID == comp_id) &
            (dfFixtures.dayCounter    == dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank fixture for leg2 match on day {dc}")
        # reverse home/away
        dfFixtures.at[idxs[0], 'homeTeam'] = away_tid
        dfFixtures.at[idxs[0], 'awayTeam'] = home_tid

    # 6) Summary
    print(f"\n🏆 UCL Round of 16 (two-legged) drawn:")
    for i, ((h, a), d1, d2) in enumerate(zip(match_pairs, leg1_days, leg2_days), 1):
        h_name = dfTeams.loc[dfTeams.teamID==h, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams.teamID==a, 'teamName'].iat[0]
        print(f"  Match {i:02d}: Leg1 (day {d1}) {h_name} vs {a_name}; "
              f"Leg2 (day {d2}) {a_name} vs {h_name}")

    # commit back
    globals()['dfFixtures'] = dfFixtures

import random

def end_el_groups(row, dfTeams, dfFixtures, dfGroupStage):
    """
    After EL group stage completes:
      1) Reset dfTeams['inEL'] to False.
      2) Re-flag 24 teams: 8 EL group winners, 8 EL runners-up, and 8 CL third-place finishers.
      3) Draw and populate two-legged “Knockout play-offs” between each EL runner-up
         and one CL third-place, avoiding same-nationality clashes.
    """
    el_id = 8
    cl_id = 9
    # 1) clear inEL
    dfTeams['inEL'] = False

    # 2a) EL group winners & runners-up
    el_tables = generate_euro_group_tables(
        competitionID=el_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    winners = []
    runners  = []
    for gid, tbl in el_tables.items():
        win_name = tbl.iloc[0]['Team']
        run_name = tbl.iloc[1]['Team']
        win_id = dfTeams.loc[dfTeams.teamName==win_name,'teamID'].iat[0]
        run_id = dfTeams.loc[dfTeams.teamName==run_name,'teamID'].iat[0]
        winners.append(win_id)
        runners.append(run_id)

    # 2b) CL third-place finishers
    cl_tables = generate_euro_group_tables(
        competitionID=cl_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    thirds = []
    for gid, tbl in cl_tables.items():
        third_name = tbl.iloc[2]['Team']
        third_id   = dfTeams.loc[dfTeams.teamName==third_name,'teamID'].iat[0]
        thirds.append(third_id)

    # re-flag all 24 inEL
    dfTeams.loc[dfTeams.teamID.isin(winners + runners + thirds), 'inEL'] = True

    # 3) Pair each EL runner-up with a CL third-place, no same-nationality
    def same_nation(e, c):
        return dfTeams.loc[dfTeams.teamID==e, 'nationality'].iat[0] == \
               dfTeams.loc[dfTeams.teamID==c, 'nationality'].iat[0]

    paired = False
    for _ in range(1000):
        random.shuffle(thirds)
        if all(not same_nation(runners[i], thirds[i]) for i in range(8)):
            paired = True
            break
    if not paired:
        raise RuntimeError("Cannot pair without same-nation clash")

    match_pairs = list(zip(runners, thirds))  # 8 pairs

    # 4) Parse dayCounters
    days = [int(d) for d in str(row['dayCounter']).split(',') if d.strip().isdigit()]
    if not days:
        raise ValueError("No dayCounters provided for EL playoffs")
    half = len(days)//2 or 1
    leg1_pool = days[:half]
    leg2_pool = days[half:half*2] if len(days)>half else days

    # cycle through pools
    leg1_days = [leg1_pool[i % len(leg1_pool)] for i in range(8)]
    leg2_days = [leg2_pool[i % len(leg2_pool)] for i in range(8)]

    # 5) Fill placeholders for leg1 and leg2
    # leg1: runner-up home
    for (run_id, third_id), dc in zip(match_pairs, leg1_days):
        mask = (
            (dfFixtures.competitionID==el_id) &
            (dfFixtures.dayCounter   ==dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank EL playoff fixture for leg1 on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = run_id
        dfFixtures.at[idxs[0], 'awayTeam'] = third_id

    # leg2: third-place home
    for (run_id, third_id), dc in zip(match_pairs, leg2_days):
        mask = (
            (dfFixtures.competitionID==el_id) &
            (dfFixtures.dayCounter   ==dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank EL playoff fixture for leg2 on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = third_id
        dfFixtures.at[idxs[0], 'awayTeam'] = run_id

    # 6) Print summary
    comp_name = dfCompetitions.loc[dfCompetitions.competitionID==el_id,'competitionName'].iat[0]
    print(f"\n🏆 {comp_name} Knockout Play-offs (two-legged):")
    for i, ((r, c), d1, d2) in enumerate(zip(match_pairs, leg1_days, leg2_days), 1):
        r_name = dfTeams.loc[dfTeams.teamID==r,'teamName'].iat[0]
        c_name = dfTeams.loc[dfTeams.teamID==c,'teamName'].iat[0]
        print(f"  Match {i:02d}: Leg1 (day {d1}) {r_name} vs {c_name}; "
              f"Leg2 (day {d2}) {c_name} vs {r_name}")

    globals()['dfFixtures'] = dfFixtures

# %% [markdown]
# ### The Flow

# %%
# Load verbose flow plan
dfSeasonFlow = pd.read_csv('Input/theFlow.csv')

# Initialise flow state only once
try:
    flow_state
except NameError:
    flow_state = {'step': 0}  # this advances by 1 each time the cell is run

# %%
# 🔄 Reset simulation flow to the start
flow_state = {'step': 0}
print("✅ Flow state reset. You can now re-run the simulation from the beginning.")
# Out:
# ✅ Flow state reset. You can now re-run the simulation from the beginning.

# %% [markdown]
# ### The Flow Helper Functions

# %%
def play_league_day(day):
    """
    Wrapper around play_league_round. If dfGroupStage is not defined yet,
    we simply pass None and skip European table updates inside play_league_round.
    """
    global dfFixtures, dfGroupStage  # dfGroupStage may or may not exist

    try:
        # If dfGroupStage exists, pass it in
        dfFixtures = play_league_round(
            day=day,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfCompetitions=dfCompetitions,
            dfGroupStage=dfGroupStage
        )
    except NameError:
        # dfGroupStage doesn’t exist yet—pass None instead
        dfFixtures = play_league_round(
            day=day,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfCompetitions=dfCompetitions,
            dfGroupStage=None
        )

def update_tables():
    global league_tables
    league_tables = generate_league_tables(dfFixtures, dfTeams)

def print_tables():
    print_all_league_tables(league_tables, dfCompetitions)
    
def create_new_fixture_list():
    global dfFixtures
    dfFixtures = create_fixture_list(season_state['current_year'])
    print(f"✅ Fixture list created for {season_state['current_year']}")

def create_team_attributes():
    global dfTeams
    dfTeams = generate_team_attributes()
    print(f"✅ Team attributes created for {season_state['current_year']}")

def update_cup_status(dayCounter, competitionID, dfFixtures, dfTeams):
    """
    For each day in 'dayCounter' (which may be an int or a comma-separated string of ints),
    find all played fixtures for that competition on those days, determine the losers
    (taking into account ET and penalties), and set their corresponding 'inX' flag to False.
    
    Mapping of competitionID → dfTeams flag:
      6  → 'inLC'
      7  → 'inFA'
      8  → 'inEL'
      9  → 'inCL'
      10 → 'inCS'
    """
    # 1) Parse dayCounter into a list of ints
    if isinstance(dayCounter, str):
        day_list = [int(d.strip()) for d in dayCounter.split(',') if d.strip().isdigit()]
    else:
        # assume it's already an int (or something convertible)
        day_list = [int(dayCounter)]
    
    # 2) Map competitionID to the dfTeams boolean column
    comp_flag_map = {
        6:  'inLC',
        7:  'inFA',
        8:  'inEL',
        9:  'inCL',
        10: 'inCS'
    }
    if competitionID not in comp_flag_map:
        print(f"[Warning] No flag mapping for competitionID {competitionID}")
        return
    
    flag_col = comp_flag_map[competitionID]

    # 3) Iterate over each specified day
    for day in day_list:
        # Look up competition name (optional; for nicer printing)
        comp_row = dfCompetitions.loc[
            dfCompetitions['competitionID'] == competitionID,
            'competitionName'
        ]
        comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

        # Filter for fixtures matching this day & competition, and that have been played
        mask = (
            (dfFixtures['dayCounter']   == day) &
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['played']        == True)
        )
        played_matches = dfFixtures.loc[mask].copy()
        if played_matches.empty:
            print(f"No played fixtures found on day {day} for '{comp_name}'")
            continue

        # 4) For each match, determine loser and update dfTeams
        for idx, match in played_matches.iterrows():
            home_id    = int(match['homeTeam'])
            away_id    = int(match['awayTeam'])
            home_goals = int(match['homeGoals'])
            away_goals = int(match['awayGoals'])

            # Determine loser (accounting for ET/penalties if needed)
            if home_goals > away_goals:
                loser_id = away_id
            elif away_goals > home_goals:
                loser_id = home_id
            else:
                # tied after ET, so look at penalty columns
                home_pens = match.get('homePens')
                away_pens = match.get('awayPens')
                if home_pens is None or away_pens is None:
                    print(f"[Error] Tie on day {day}, comp '{comp_name}', but no penalty data.")
                    continue
                loser_id = home_id if home_pens < away_pens else away_id

            # Set that team’s 'inX' flag to False
            dfTeams.loc[dfTeams['teamID'] == loser_id, flag_col] = False

            # Print which team was knocked out
            loser_name = dfTeams.loc[
                dfTeams['teamID'] == loser_id, 'teamName'
            ].values[0]
            print(
                f"Day {day} | {comp_name} | Knocked out: {loser_name} → {flag_col} = False"
            )

def add_lc_teams_r2(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 2,
    except those already in Europa League or Champions League.
    Sets dfTeams['inLC'] = True for any teamID ≤ 20 where
    both inEL and inCL are False.
    """
    mask = (dfTeams['teamID'] <= 20) & (~dfTeams['inEL']) & (~dfTeams['inCL'])
    dfTeams.loc[mask, 'inLC'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to LC Round 2: {', '.join(added)}")

def add_lc_teams_r3(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 3
    if they are in Europa League (inEL) or Champions League (inCL).
    Sets dfTeams['inLC'] = True for any team meeting those criteria.
    """
    mask = (dfTeams['teamID'] <= 20) & (dfTeams['inEL'] | dfTeams['inCL'])
    dfTeams.loc[mask, 'inLC'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to LC Round 3: {', '.join(added)}")
    
def add_fa_teams_r3(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 3
    if they are in Europa League (inEL) or Champions League (inCL).
    Sets dfTeams['inLC'] = True for any team meeting those criteria.
    """
    mask = (dfTeams['teamID'] <= 44) 
    dfTeams.loc[mask, 'inFA'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to FA Cup Round 3: {', '.join(added)}")

def play_two_leg_round(dayCounter, competitionID, dfFixtures, dfTeams):
    import pandas as pd

    # 1) Competition name
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == competitionID,
        'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

    # 2) Today's day
    today = int(dayCounter)

    # 3) Unplayed fixtures for today & comp
    todays = dfFixtures[
        (dfFixtures['dayCounter']   == today) &
        (dfFixtures['competitionID'] == competitionID) &
        (~dfFixtures['played'])
    ].copy()
    if todays.empty:
        print(f"No fixtures to play on day {today} for {comp_name}")
        return

    # 4) Process each
    for idx, m in todays.iterrows():
        if pd.isna(m['homeTeam']) or pd.isna(m['awayTeam']):
            print(f"❌ Skipping empty fixture on day {today} at index {idx}")
            continue

        # IDs and names
        h_id = int(m['homeTeam']);    a_id = int(m['awayTeam'])
        h_name = dfTeams.loc[dfTeams['teamID']==h_id, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams['teamID']==a_id, 'teamName'].iat[0]

        # 5) Detect leg 2: has leg 1 already been played? (original mapping)
        first_leg = dfFixtures[
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['homeTeam']      == h_id) &
            (dfFixtures['awayTeam']      == a_id) &
            (dfFixtures['played']        == True)
        ]
        is_leg2 = not first_leg.empty

        if not is_leg2:
            # --- Leg 1: 90' only ---
            g_h, g_a = play_full_match(h_id, a_id, dfTeams)
            dfFixtures.at[idx, 'homeGoals'] = int(g_h)
            dfFixtures.at[idx, 'awayGoals'] = int(g_a)
            dfFixtures.at[idx, 'played']    = True

            print(f"Day {today} | {comp_name} L1 | {h_name} {g_h}-{g_a} {a_name}")
        else:
            # --- Leg 2: aggregate + ET/PK ---
            # pull leg1 scores
            rev = first_leg.iloc[0]
            leg1_h = int(rev['homeGoals']);    leg1_a = int(rev['awayGoals'])

            # play 90'
            g_h, g_a = play_full_match(h_id, a_id, dfTeams)
            g_h, g_a = int(g_h), int(g_a)

            # aggregate
            agg_h = leg1_h + g_h
            agg_a = leg1_a + g_a

            # ET/PK if tied
            et_h = et_a = None; pk_h = pk_a = None
            if agg_h == agg_a:
                res = play_cup_match(h_id, a_id, dfTeams)
                et_h = int(res['home_et_goals']);    et_a = int(res['away_et_goals'])
                pk_h = int(res['home_pk']) if res['home_pk'] is not None else None
                pk_a = int(res['away_pk']) if res['away_pk'] is not None else None
                winner_id = res['winner_id']
            else:
                winner_id = h_id if agg_h > agg_a else a_id

            winner_name = dfTeams.loc[dfTeams['teamID']==winner_id,'teamName'].iat[0]

            # write back
            dfFixtures.at[idx,'homeGoals']    = g_h
            dfFixtures.at[idx,'awayGoals']    = g_a
            dfFixtures.at[idx,'homeGoalsAET'] = et_h or 0
            dfFixtures.at[idx,'awayGoalsAET'] = et_a or 0
            dfFixtures.at[idx,'homePens']     = pk_h
            dfFixtures.at[idx,'awayPens']     = pk_a
            dfFixtures.at[idx,'played']       = True

            # suffix
            suffix = f" (agg {agg_h}-{agg_a})"
            if et_h is not None and et_a is not None:
                suffix += f" + ET {et_h}-{et_a}"
            if pk_h is not None and pk_a is not None:
                suffix += f" [p {pk_h}-{pk_a}]"

            print(
                f"Day {today} | {comp_name} L2 | {h_name} {g_h}-{g_a} {a_name}"
                f"{suffix} → Winner: {winner_name}"
            )
    globals()['dfFixtures'] = dfFixtures
    return


def play_two_leg_round(dayCounter, competitionID, dfFixtures, dfTeams):
    import pandas as pd

    # 1) Competition name
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == competitionID,
        'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

    # 2) Today's day
    today = int(dayCounter)

    # 3) Unplayed fixtures for today & comp
    todays = dfFixtures[
        (dfFixtures['dayCounter'] == today) &
        (dfFixtures['competitionID'] == competitionID) &
        (~dfFixtures['played'])
    ].copy()
    if todays.empty:
        print(f"No fixtures to play on day {today} for {comp_name}")
        return

    # 4) Process each match
    for idx, m in todays.iterrows():
        if pd.isna(m['homeTeam']) or pd.isna(m['awayTeam']):
            print(f"❌ Skipping empty fixture on day {today} at index {idx}")
            continue

        h_id, a_id = int(m['homeTeam']), int(m['awayTeam'])
        h_name = dfTeams.loc[dfTeams['teamID'] == h_id, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams['teamID'] == a_id, 'teamName'].iat[0]

        # detect leg2 by checking for reverse fixture
        reverse = dfFixtures[
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['homeTeam'] == a_id) &
            (dfFixtures['awayTeam'] == h_id) &
            (dfFixtures['played'] == True)
        ]
        is_leg2 = not reverse.empty

        if not is_leg2:
            # --- Leg 1: 90' only ---
            g_h, g_a = play_full_match(h_id, a_id, dfTeams)
            dfFixtures.at[idx, 'homeGoals'] = int(g_h)
            dfFixtures.at[idx, 'awayGoals'] = int(g_a)
            dfFixtures.at[idx, 'played'] = True
            print(f"Day {today} | {comp_name} Leg 1 | {h_name} {g_h}-{g_a} {a_name}")
        else:
            # --- Leg 2: aggregate, ET, then penalties if needed ---
            leg1 = reverse.iloc[0]
            # Goals for this fixture perspective
            leg1_h = int(leg1['awayGoals'])
            leg1_a = int(leg1['homeGoals'])

            # 90' second leg
            g_h, g_a = play_full_match(h_id, a_id, dfTeams)
            g_h, g_a = int(g_h), int(g_a)

            # aggregate
            agg_h = leg1_h + g_h
            agg_a = leg1_a + g_a
            suffix = f" (agg {agg_h}-{agg_a})"

            # ET and/or penalties data
            et_h = et_a = None
            pk_h = pk_a = None

            if agg_h != agg_a:
                # decided on aggregate
                winner_id = h_id if agg_h > agg_a else a_id
            else:
                # tie on aggregate: simulate ET + PK together
                res = play_cup_match(h_id, a_id, dfTeams)
                et_h = int(res['home_et_goals'])
                et_a = int(res['away_et_goals'])
                suffix += f" (a.e.t. {et_h}-{et_a})"
                if et_h != et_a:
                    # decided in ET
                    winner_id = h_id if et_h > et_a else a_id
                else:
                    # tied after ET: penalties decide
                    if res['home_pk'] is not None and res['away_pk'] is not None:
                        pk_h = int(res['home_pk'])
                        pk_a = int(res['away_pk'])
                        suffix += f" [p {pk_h}-{pk_a}]"
                    winner_id = res['winner_id']

            winner_name = dfTeams.loc[dfTeams['teamID'] == winner_id, 'teamName'].iat[0]

            # write back second-leg
            dfFixtures.at[idx, 'homeGoals'] = g_h
            dfFixtures.at[idx, 'awayGoals'] = g_a
            dfFixtures.at[idx, 'homeGoalsAET'] = et_h or 0
            dfFixtures.at[idx, 'awayGoalsAET'] = et_a or 0
            dfFixtures.at[idx, 'homePens'] = pk_h
            dfFixtures.at[idx, 'awayPens'] = pk_a
            dfFixtures.at[idx, 'played'] = True

            print(
                f"Day {today} | {comp_name} Leg 2 | {h_name} {g_h}-{g_a} {a_name}"
                f"{suffix} → Winner: {winner_name}"
            )

    globals()['dfFixtures'] = dfFixtures
    return








    
def draw_two_leg_fixture(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic draw for two-legged cup ties.
    - row['competitionID']: cup ID (e.g. 6=League Cup,7=FA,8=EL,9=CL,10=CS)
    - row['dayCounter']: comma-separated days for fixtures (leg1 days then leg2 days)

    1) Determine eligible teams via dfTeams['inXX'] flag.
    2) Shuffle and pair into ties.
    3) Parse dayCounter into ordered list of days (first half = leg1, second half = leg2).
    4) Locate blank fixtures in dfFixtures for these days.
    5) Assign all first-leg fixtures to the first half of placeholders, then all second-leg fixtures to the second half.
    6) Print a summary of the draw.
    """
    comp_id = int(row['competitionID'])
    comp_flag_map = {6: 'inLC', 7: 'inFA', 8: 'inEL', 9: 'inCL', 10: 'inCS'}
    flag_col = comp_flag_map.get(comp_id)
    if not flag_col:
        print(f"❌ No draw config for competitionID={comp_id}")
        return

    comp_name = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id,
        'competitionName'
    ].iat[0]

    # 1) Eligible teams
    eligible = dfTeams[dfTeams[flag_col] == True]['teamID'].tolist()
    if len(eligible) < 2 or len(eligible) % 2 != 0:
        print(f"❌ {comp_name} draw requires an even number of teams (found {len(eligible)})")
        return

    # 2) Shuffle & pair
    random.shuffle(eligible)
    ties = [(eligible[i], eligible[i+1]) for i in range(0, len(eligible), 2)]
    n_ties = len(ties)

    # 3) Parse dayCounter into leg1_days and leg2_days
    raw = str(row['dayCounter'])
    days = [int(x.strip()) for x in raw.split(',') if x.strip().isdigit()]
    expected = n_ties * 2
    if len(days) < expected:
        raise ValueError(f"{comp_name} two-legged draw needs {expected} days, got {len(days)}")
    days = days[:expected]

    # 4) Find placeholders for all leg days
    mask = (
        (dfFixtures['competitionID'] == comp_id) &
        (dfFixtures['dayCounter'].isin(days)) &
        dfFixtures['homeTeam'].isnull() &
        dfFixtures['awayTeam'].isnull()
    )
    open_fx = dfFixtures.loc[mask]
    if len(open_fx) < expected:
        raise ValueError(f"Not enough blanks for {comp_name} two-legged draw: need {expected}, found {len(open_fx)}")

    # Sort placeholders by dayCounter then by index order
    open_fx = open_fx.sort_values('dayCounter').iloc[:expected]
    fx_idxs = open_fx.index.tolist()

    # Split placeholder indices: first n_ties for leg1, next n_ties for leg2
    first_leg_idxs = fx_idxs[:n_ties]
    second_leg_idxs = fx_idxs[n_ties:expected]

    # 5) Assign fixtures
    # Assign first legs
    for i, (home, away) in enumerate(ties):
        idx1 = first_leg_idxs[i]
        dfFixtures.at[idx1, 'homeTeam'] = home
        dfFixtures.at[idx1, 'awayTeam'] = away

    # Assign second legs
    for i, (home, away) in enumerate(ties):
        idx2 = second_leg_idxs[i]
        dfFixtures.at[idx2, 'homeTeam'] = away
        dfFixtures.at[idx2, 'awayTeam'] = home

    # 6) Print summary
    print(f"\n🏆 {comp_name} Two‑Leg Draw ({n_ties} ties) across days: {', '.join(map(str, days))}")
    for i, (home, away) in enumerate(ties, 1):
        day1 = days[i - 1]
        day2 = days[n_ties + i - 1]
        h_name = dfTeams.loc[dfTeams['teamID'] == home, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams['teamID'] == away, 'teamName'].iat[0]
        print(f"  Tie {i:02d}: Leg1 (day {day1}) {h_name} vs {a_name}; Leg2 (day {day2}) {a_name} vs {h_name}")

    globals()['dfFixtures'] = dfFixtures

# Map flow text to actual logic
flow_dispatch = {
    'Create New Fixture List': lambda row: create_new_fixture_list(),
    'Create Team Attributes': lambda row: create_team_attributes(),
    'Play League Matches': lambda row: play_league_day(int(row['dayCounter'])),
    'Print Tables': lambda row: print_tables(),
    'Play Cup Round': lambda row: play_cup_round(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams),
    'Update Cup Status': lambda row: update_cup_status(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams),
    'Add LC Round2 Teams': lambda row: add_lc_teams_r2(dfTeams),
    'Add LC Round3 Teams': lambda row: add_lc_teams_r3(dfTeams),
    'Draw European Group Stage': lambda row: draw_euro_group_stage(row, dfTeams, dfFixtures, dfCompetitions),
    'Draw Cup' : lambda row: draw_cup(row, dfTeams, dfFixtures, dfCompetitions),
    'Initialize Cup Status' : lambda row: initialize_cup_status(dfTeams),
    'End CL Groups' : lambda row: end_cl_groups(row, dfTeams, dfFixtures, dfGroupStage),
    'End EL Groups' : lambda row: end_el_groups(row, dfTeams, dfFixtures, dfGroupStage),
    'Add FA Round3 Teams' : lambda row: add_fa_teams_r3(dfTeams),
    'Draw Two Leg Fixture' : lambda row: draw_two_leg_fixture(row, dfTeams, dfFixtures, dfCompetitions),
    'Play Two Leg Round' : lambda row: play_two_leg_round(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams)
}

# %%
# 📅 Initialize multi-season simulation state
try:
    season_state
except NameError:
    season_state = {
        'step': 0,
        'current_year': 2024,
        'fixtures_archive': {},
        'tables_archive': {}
    }
    print("✅ Season state initialized")

# %%
# Step through the flow one step at a time
if flow_state['step'] < len(dfSeasonFlow):
    row = dfSeasonFlow.iloc[flow_state['step']]
    step_desc = row['functionToCall']
    print(f"\n=== STEP {flow_state['step']+1}: {step_desc} ===")

    # Run corresponding logic
    if step_desc in flow_dispatch:
        flow_dispatch[step_desc](row)
    else:
        print(f"[Skipped] No function mapped for: {step_desc}")

    flow_state['step'] += 1
else:
    print("=== All flow steps completed ===")
# Out:
# === STEP 1: Create New Fixture List ===
# ✅ Fixture list created for 2024

# %%
# Step through the flow in one hit to XX
def run_flow_to(target_step):
    """
    Advance the flow from its current position up to (but not including) target_step.
    target_step is 1-based: to run steps 1–80, call run_flow_to(80).
    """
    global flow_state, dfSeasonFlow, flow_dispatch

    # Convert target_step to zero-based index
    end_index = target_step

    while flow_state['step'] < len(dfSeasonFlow) and flow_state['step'] < end_index:
        row = dfSeasonFlow.iloc[flow_state['step']]
        step_desc = row['functionToCall']
        print(f"\n=== STEP {flow_state['step']+1}: {step_desc} ===")

        if step_desc in flow_dispatch:
            flow_dispatch[step_desc](row)
        else:
            print(f"[Skipped] No function mapped for: {step_desc}")

        flow_state['step'] += 1

    if flow_state['step'] >= end_index:
        print(f"\n=== Reached step {target_step}. Stopped. Current pointer: {flow_state['step']} ===")
    else:
        print("\n=== All flow steps completed before reaching the target ===")

run_flow_to(180)
# Out:
# === STEP 2: Create Team Attributes ===
# ✅ Team attributes created for 2024
#
# === STEP 3: Initialize Cup Status ===
# ✅ Initialized cup status:
#   inCS: 2 teams
#   inCL: 32 teams
#   inEL: 32 teams
#   inFA: 80 teams
#   inLC: 72 teams
#
# === STEP 4: Draw Cup ===
#
# 🏆 Community Shield draw (1 matches) across: 2024-08-04
#   Match 01 (day 3): Manchester City vs Arsenal
#
# === STEP 5: Draw Cup ===
#
# 🏆 League Cup draw (36 matches) across: 2024-08-13, 2024-08-14
#   Match 01 (day 4): Swansea vs Blackpool
#   Match 02 (day 4): Reading vs Hull City
#   Match 03 (day 4): Gillingham vs Wycombe
#   Match 04 (day 4): Exeter City vs Sheffield Wednesday
#   Match 05 (day 4): Bolton vs Derby
#   Match 06 (day 4): Charlton vs Fleetwood Town
#   Match 07 (day 4): Tranmere vs Watford
#   Match 08 (day 4): Bristol Rovers vs Colchester
#   Match 09 (day 4): Wrexham vs Blackburn
#   Match 10 (day 4): Birmingham vs Southampton
#   Match 11 (day 4): Barrow vs Middlesbrough
#   Match 12 (day 4): Walsall vs Coventry
#   Match 13 (day 4): Norwich vs Newport County
#   Match 14 (day 4): Shrewsbury vs Huddersfield
#   Match 15 (day 4): Sutton Utd vs Grimsby
#   Match 16 (day 4): Preston vs QPR
#   Match 17 (day 4): West Brom vs Swindon Town
#   Match 18 (day 4): Milton Keynes Dons vs Bristol City
#   Match 19 (day 4): Sunderland vs Cardiff
#   Match 20 (day 4): Crawley Town vs Stockport County
#   Match 21 (day 4): Millwall vs Wigan
#   Match 22 (day 4): Barnsley vs Crewe
#   Match 23 (day 4): Stevenage vs Cambridge United
#   Match 24 (day 4): Oxford United vs Rotherham
#   Match 25 (day 4): Bradford vs AFC Wimbledon
#   Match 26 (day 4): Doncaster vs Lincoln
#   Match 27 (day 4): Ipswich vs Portsmouth
#   Match 28 (day 4): Carlisle vs Stoke City
#   Match 29 (day 4): Peterborough vs Notts County
#   Match 30 (day 5): Cheltenham vs Forest Green
#   Match 31 (day 5): Leicester vs Mansfield Town
#   Match 32 (day 5): Harrogate Town vs Burton Albion
#   Match 33 (day 5): Leeds vs Accrington ST
#   Match 34 (day 5): Salford City vs Morecambe
#   Match 35 (day 5): Northampton vs Plymouth
#   Match 36 (day 5): Leyton Orient vs Port Vale
#
# === STEP 6: Play League Matches ===
#
# Matches played on 2024-08-02:
# Championship
# Sheffield Wednesday 3 - 0 Southampton
#
# === STEP 7: Play League Matches ===
#
# Matches played on 2024-08-03:
# Championship
# Watford 3 - 0 QPR
# Bristol City 1 - 2 Preston
# Blackburn 1 - 1 West Brom
# Middlesbrough 2 - 0 Millwall
# Norwich 1 - 0 Hull City
# Stoke City 2 - 0 Rotherham
# Swansea 0 - 0 Birmingham
# Plymouth 1 - 2 Huddersfield
# League One
# Carlisle 2 - 1 Fleetwood Town
# Wycombe 1 - 0 Exeter City
# Cambridge United 2 - 0 Oxford United
# Reading 1 - 3 Peterborough
# Derby 1 - 0 Wigan
# Barnsley 2 - 1 Port Vale
# Charlton 1 - 0 Leyton Orient
# Northampton 0 - 0 Stevenage
# Shrewsbury 0 - 0 Cheltenham
# Portsmouth 3 - 0 Bristol Rovers
# Blackpool 4 - 0 Burton Albion
# Bolton 2 - 0 Lincoln
# League Two
# Accrington ST 3 - 1 Newport County
# Crawley Town 1 - 2 Bradford
# Crewe 1 - 0 Mansfield Town
# Grimsby 2 - 0 AFC Wimbledon
# Morecambe 5 - 1 Walsall
# Forest Green 1 - 0 Salford City
# Tranmere 1 - 2 Barrow
# Doncaster 2 - 1 Harrogate Town
# Sutton Utd 4 - 0 Notts County
# Stockport County 0 - 1 Gillingham
# Wrexham 0 - 2 Milton Keynes Dons
# National League
# Southend 2 - 1 Oldham
# Chesterfield 3 - 0 Dorking Wanderers
# Barnet 2 - 0 Hartlepool
# Aldershot Town 1 - 0 Oxford City
# Gateshead 0 - 3 Boreham Wood
# Solihull Moors 1 - 3 Eastleigh
# FC Halifax Town 0 - 1 Bromley
# Maidenhead 1 - 1 AFC Fylde
# Altrincham 2 - 2 Dagenham & Redbridge
# Wealdstone 3 - 1 York
# Rochdale 6 - 1 Ebbsfleet United
# Kidderminster Harriers 2 - 2 Woking
#
# === STEP 8: Play League Matches ===
#
# Matches played on 2024-08-04:
# Championship
# Leicester 1 - 0 Coventry
# Leeds 4 - 0 Cardiff
# Sunderland 0 - 0 Ipswich
#
# === STEP 9: Play Cup Round ===
# Day 3 | Community Shield | Manchester City 1–2 Arsenal (a.e.t.) → Winner: Arsenal
#
# === STEP 10: Play Cup Round ===
# Day 4 | League Cup | Swansea 2–0 Blackpool → Winner: Swansea
# Day 4 | League Cup | Reading 1–1 Hull City (a.e.t.) [p 5–4] → Winner: Reading
# Day 4 | League Cup | Gillingham 0–2 Wycombe → Winner: Wycombe
# Day 4 | League Cup | Exeter City 1–2 Sheffield Wednesday → Winner: Sheffield Wednesday
# Day 4 | League Cup | Bolton 0–1 Derby → Winner: Derby
# Day 4 | League Cup | Charlton 1–0 Fleetwood Town → Winner: Charlton
# Day 4 | League Cup | Tranmere 0–3 Watford → Winner: Watford
# Day 4 | League Cup | Bristol Rovers 2–0 Colchester → Winner: Bristol Rovers
# Day 4 | League Cup | Wrexham 0–3 Blackburn → Winner: Blackburn
# Day 4 | League Cup | Birmingham 1–0 Southampton → Winner: Birmingham
# Day 4 | League Cup | Barrow 0–2 Middlesbrough → Winner: Middlesbrough
# Day 4 | League Cup | Walsall 1–3 Coventry → Winner: Coventry
# Day 4 | League Cup | Norwich 4–1 Newport County → Winner: Norwich
# Day 4 | League Cup | Shrewsbury 0–1 Huddersfield → Winner: Huddersfield
# Day 4 | League Cup | Sutton Utd 1–1 Grimsby (a.e.t.) [p 3–2] → Winner: Sutton Utd
# Day 4 | League Cup | Preston 1–0 QPR (a.e.t.) → Winner: Preston
# Day 4 | League Cup | West Brom 2–0 Swindon Town → Winner: West Brom
# Day 4 | League Cup | Milton Keynes Dons 0–2 Bristol City → Winner: Bristol City
# Day 4 | League Cup | Sunderland 2–1 Cardiff (a.e.t.) → Winner: Sunderland
# Day 4 | League Cup | Crawley Town 3–0 Stockport County → Winner: Crawley Town
# Day 4 | League Cup | Millwall 1–0 Wigan → Winner: Millwall
# Day 4 | League Cup | Barnsley 1–0 Crewe (a.e.t.) → Winner: Barnsley
# Day 4 | League Cup | Stevenage 1–0 Cambridge United → Winner: Stevenage
# Day 4 | League Cup | Oxford United 1–2 Rotherham → Winner: Rotherham
# Day 4 | League Cup | Bradford 3–2 AFC Wimbledon → Winner: Bradford
# Day 4 | League Cup | Doncaster 0–1 Lincoln → Winner: Lincoln
# Day 4 | League Cup | Ipswich 5–0 Portsmouth → Winner: Ipswich
# Day 4 | League Cup | Carlisle 1–0 Stoke City (a.e.t.) → Winner: Carlisle
# Day 4 | League Cup | Peterborough 1–0 Notts County → Winner: Peterborough
#
# === STEP 11: Play Cup Round ===
# Day 5 | League Cup | Cheltenham 3–0 Forest Green → Winner: Cheltenham
# Day 5 | League Cup | Leicester 2–0 Mansfield Town (a.e.t.) → Winner: Leicester
# Day 5 | League Cup | Harrogate Town 1–2 Burton Albion → Winner: Burton Albion
# Day 5 | League Cup | Leeds 3–1 Accrington ST → Winner: Leeds
# Day 5 | League Cup | Salford City 2–3 Morecambe → Winner: Morecambe
# Day 5 | League Cup | Northampton 3–2 Plymouth (a.e.t.) → Winner: Northampton
# Day 5 | League Cup | Leyton Orient 2–0 Port Vale → Winner: Leyton Orient
#
# === STEP 12: Update Cup Status ===
# Day 4 | League Cup | Knocked out: Blackpool → inLC = False
# Day 4 | League Cup | Knocked out: Hull City → inLC = False
# Day 4 | League Cup | Knocked out: Gillingham → inLC = False
# Day 4 | League Cup | Knocked out: Exeter City → inLC = False
# Day 4 | League Cup | Knocked out: Bolton → inLC = False
# Day 4 | League Cup | Knocked out: Fleetwood Town → inLC = False
# Day 4 | League Cup | Knocked out: Tranmere → inLC = False
# Day 4 | League Cup | Knocked out: Colchester → inLC = False
# Day 4 | League Cup | Knocked out: Wrexham → inLC = False
# Day 4 | League Cup | Knocked out: Southampton → inLC = False
# Day 4 | League Cup | Knocked out: Barrow → inLC = False
# Day 4 | League Cup | Knocked out: Walsall → inLC = False
# Day 4 | League Cup | Knocked out: Newport County → inLC = False
# Day 4 | League Cup | Knocked out: Shrewsbury → inLC = False
# Day 4 | League Cup | Knocked out: Grimsby → inLC = False
# Day 4 | League Cup | Knocked out: QPR → inLC = False
# Day 4 | League Cup | Knocked out: Swindon Town → inLC = False
# Day 4 | League Cup | Knocked out: Milton Keynes Dons → inLC = False
# Day 4 | League Cup | Knocked out: Cardiff → inLC = False
# Day 4 | League Cup | Knocked out: Stockport County → inLC = False
# Day 4 | League Cup | Knocked out: Wigan → inLC = False
# Day 4 | League Cup | Knocked out: Crewe → inLC = False
# Day 4 | League Cup | Knocked out: Cambridge United → inLC = False
# Day 4 | League Cup | Knocked out: Oxford United → inLC = False
# Day 4 | League Cup | Knocked out: AFC Wimbledon → inLC = False
# Day 4 | League Cup | Knocked out: Doncaster → inLC = False
# Day 4 | League Cup | Knocked out: Portsmouth → inLC = False
# Day 4 | League Cup | Knocked out: Stoke City → inLC = False
# Day 4 | League Cup | Knocked out: Notts County → inLC = False
# Day 5 | League Cup | Knocked out: Forest Green → inLC = False
# Day 5 | League Cup | Knocked out: Mansfield Town → inLC = False
# Day 5 | League Cup | Knocked out: Harrogate Town → inLC = False
# Day 5 | League Cup | Knocked out: Accrington ST → inLC = False
# Day 5 | League Cup | Knocked out: Salford City → inLC = False
# Day 5 | League Cup | Knocked out: Plymouth → inLC = False
# Day 5 | League Cup | Knocked out: Port Vale → inLC = False
#
# === STEP 13: Add LC Round2 Teams ===
# Added to LC Round 2: Bournemouth, Brentford, Burnley, Chelsea, Crystal Palace, Everton, Fulham, Luton, Nottingham Forest, Sheffield Utd, West Ham, Wolves
#
# === STEP 14: Draw Cup ===
#
# 🏆 League Cup draw (24 matches) across: 2024-08-27, 2024-08-28
#   Match 01 (day 20): Morecambe vs Northampton
#   Match 02 (day 20): Birmingham vs Millwall
#   Match 03 (day 20): Blackburn vs Chelsea
#   Match 04 (day 20): Sheffield Utd vs Burton Albion
#   Match 05 (day 20): West Ham vs Barnsley
#   Match 06 (day 20): Bradford vs Stevenage
#   Match 07 (day 20): Charlton vs Derby
#   Match 08 (day 20): Sutton Utd vs Peterborough
#   Match 09 (day 20): Middlesbrough vs Everton
#   Match 10 (day 20): Ipswich vs Fulham
#   Match 11 (day 20): Bristol Rovers vs Watford
#   Match 12 (day 20): Sheffield Wednesday vs Lincoln
#   Match 13 (day 20): Sunderland vs Norwich
#   Match 14 (day 20): Leeds vs Cheltenham
#   Match 15 (day 20): Carlisle vs West Brom
#   Match 16 (day 20): Leyton Orient vs Crawley Town
#   Match 17 (day 20): Burnley vs Brentford
#   Match 18 (day 20): Wycombe vs Luton
#   Match 19 (day 20): Leicester vs Bristol City
#   Match 20 (day 21): Bournemouth vs Swansea
#   Match 21 (day 21): Coventry vs Reading
#   Match 22 (day 21): Nottingham Forest vs Rotherham
#   Match 23 (day 21): Preston vs Huddersfield
#   Match 24 (day 21): Crystal Palace vs Wolves
#
# === STEP 15: Play League Matches ===
#
# Matches played on 2024-08-09:
# Premier League
# Burnley 2 - 0 Manchester City
#
# === STEP 16: Play League Matches ===
#
# Matches played on 2024-08-10:
# Premier League
# Brighton 3 - 0 Luton
# Sheffield Utd 0 - 0 Crystal Palace
# Newcastle 3 - 1 Aston Villa
# Bournemouth 1 - 0 West Ham
# Everton 0 - 2 Fulham
# Arsenal 2 - 1 Nottingham Forest
# Championship
# Coventry 1 - 1 Middlesbrough
# Huddersfield 0 - 1 Leicester
# Watford 1 - 1 Plymouth
# Southampton 0 - 0 Norwich
# Cardiff 1 - 0 QPR
# Birmingham 2 - 1 Leeds
# Ipswich 1 - 0 Stoke City
# Millwall 2 - 0 Bristol City
# Preston 2 - 0 Sunderland
# West Brom 1 - 0 Swansea
# Hull City 1 - 1 Sheffield Wednesday
# Rotherham 0 - 1 Blackburn
# League One
# Wigan 1 - 0 Northampton
# Bristol Rovers 1 - 2 Barnsley
# Fleetwood Town 3 - 0 Cambridge United
# Oxford United 2 - 1 Carlisle
# Peterborough 0 - 0 Charlton
# Port Vale 2 - 2 Reading
# Exeter City 0 - 4 Blackpool
# Stevenage 0 - 3 Shrewsbury
# Cheltenham 0 - 0 Bolton
# Leyton Orient 1 - 0 Portsmouth
# Lincoln 1 - 1 Wycombe
# Burton Albion 1 - 1 Derby
# League Two
# AFC Wimbledon 1 - 0 Wrexham
# Mansfield Town 0 - 2 Morecambe
# Notts County 1 - 2 Grimsby
# Barrow 2 - 0 Sutton Utd
# Salford City 3 - 1 Crawley Town
# Harrogate Town 0 - 3 Forest Green
# Walsall 2 - 2 Stockport County
# Bradford 1 - 0 Colchester
# Gillingham 1 - 3 Accrington ST
# Milton Keynes Dons 0 - 0 Tranmere
# Swindon Town 1 - 0 Crewe
# Newport County 1 - 1 Doncaster
# National League
# Ebbsfleet United 1 - 1 Solihull Moors
# Oxford City 0 - 1 Rochdale
# Dorking Wanderers 0 - 1 Maidenhead
# Bromley 3 - 0 Barnet
# AFC Fylde 0 - 2 Chesterfield
# Oldham 1 - 1 Aldershot Town
# Hartlepool 1 - 1 Gateshead
# Dagenham & Redbridge 4 - 1 Southend
# Eastleigh 0 - 0 Wealdstone
# York 3 - 0 Kidderminster Harriers
# Boreham Wood 1 - 0 FC Halifax Town
# Woking 3 - 0 Altrincham
#
# === STEP 17: Play League Matches ===
#
# Matches played on 2024-08-11:
# Premier League
# Chelsea 2 - 2 Liverpool
# Brentford 3 - 1 Tottenham
#
# === STEP 18: Play League Matches ===
#
# Matches played on 2024-08-12:
# Premier League
# Manchester United 1 - 1 Wolves
#
# === STEP 19: Play League Matches ===
#
# Matches played on 2024-08-20:
# League One
# Barnsley 2 - 0 Peterborough
# Carlisle 1 - 0 Wigan
# Cambridge United 3 - 0 Stevenage
# Wycombe 4 - 0 Leyton Orient
# Blackpool 1 - 1 Port Vale
# Shrewsbury 1 - 1 Burton Albion
# Northampton 3 - 1 Lincoln
# Charlton 3 - 1 Bristol Rovers
# Reading 0 - 0 Cheltenham
# Portsmouth 3 - 1 Exeter City
# Derby 2 - 0 Oxford United
# Bolton 0 - 0 Fleetwood Town
# League Two
# Accrington ST 0 - 1 Barrow
# Sutton Utd 3 - 0 Gillingham
# Tranmere 2 - 1 Harrogate Town
# Forest Green 1 - 1 Swindon Town
# Morecambe 2 - 1 Notts County
# Grimsby 1 - 2 Salford City
# Crewe 2 - 2 Newport County
# Doncaster 3 - 0 Mansfield Town
# Crawley Town 0 - 1 Milton Keynes Dons
# Colchester 2 - 0 AFC Wimbledon
# Wrexham 2 - 1 Walsall
# Stockport County 1 - 0 Bradford
# National League
# Oldham 0 - 0 FC Halifax Town
# Hartlepool 3 - 1 Maidenhead
# Dagenham & Redbridge 1 - 0 Gateshead
# Eastleigh 1 - 2 Barnet
# Bromley 0 - 1 Wealdstone
# Woking 2 - 4 Rochdale
# AFC Fylde 0 - 0 Kidderminster Harriers
# Ebbsfleet United 0 - 2 Aldershot Town
# Oxford City 1 - 3 Chesterfield
# Dorking Wanderers 0 - 1 Southend
# York 0 - 3 Altrincham
#
# === STEP 20: Play League Matches ===
#
# Matches played on 2024-08-21:
# National League
# Boreham Wood 1 - 0 Solihull Moors
#
# === STEP 21: Play League Matches ===
#
# Matches played on 2024-08-16:
# Premier League
# Nottingham Forest 0 - 2 Sheffield Utd
# Championship
# Leeds 4 - 0 West Brom
#
# === STEP 22: Play League Matches ===
#
# Matches played on 2024-08-17:
# Premier League
# Fulham 0 - 0 Brentford
# Wolves 2 - 0 Brighton
# Liverpool 3 - 1 Bournemouth
# Tottenham 3 - 0 Manchester United
# Manchester City 0 - 1 Newcastle
# Championship
# Sunderland 2 - 0 Rotherham
# Swansea 1 - 0 Coventry
# Sheffield Wednesday 1 - 0 Preston
# QPR 1 - 2 Ipswich
# Stoke City 1 - 1 Watford
# Plymouth 0 - 3 Southampton
# Leicester 2 - 0 Cardiff
# Bristol City 1 - 1 Birmingham
# Blackburn 1 - 1 Hull City
# Middlesbrough 2 - 2 Huddersfield
# League One
# Derby 1 - 1 Fleetwood Town
# Reading 1 - 1 Stevenage
# Charlton 1 - 0 Port Vale
# Wycombe 2 - 0 Burton Albion
# Cambridge United 1 - 2 Bristol Rovers
# Carlisle 0 - 1 Exeter City
# Shrewsbury 3 - 0 Lincoln
# Northampton 1 - 3 Peterborough
# Bolton 2 - 0 Wigan
# Blackpool 1 - 0 Leyton Orient
# Barnsley 1 - 1 Oxford United
# Portsmouth 4 - 1 Cheltenham
# League Two
# Stockport County 2 - 1 Barrow
# Wrexham 0 - 1 Swindon Town
# Sutton Utd 0 - 1 AFC Wimbledon
# Tranmere 1 - 1 Salford City
# Forest Green 2 - 0 Newport County
# Morecambe 1 - 0 Bradford
# Crewe 1 - 1 Walsall
# Crawley Town 0 - 1 Gillingham
# Colchester 0 - 0 Milton Keynes Dons
# Accrington ST 0 - 0 Harrogate Town
# Doncaster 1 - 0 Notts County
# Grimsby 0 - 3 Mansfield Town
# National League
# Solihull Moors 0 - 4 Dorking Wanderers
# Maidenhead 0 - 2 Dagenham & Redbridge
# FC Halifax Town 0 - 0 Oxford City
# Kidderminster Harriers 0 - 2 Bromley
# Barnet 1 - 4 Woking
# Aldershot Town 0 - 1 York
# Gateshead 0 - 0 Ebbsfleet United
# Chesterfield 1 - 0 Oldham
# Rochdale 1 - 0 Eastleigh
# Southend 1 - 0 Hartlepool
# Wealdstone 1 - 0 AFC Fylde
# Altrincham 0 - 1 Boreham Wood
#
# === STEP 23: Play League Matches ===
#
# Matches played on 2024-08-18:
# Premier League
# Aston Villa 2 - 2 Everton
# West Ham 1 - 0 Chelsea
# Championship
# Norwich 0 - 0 Millwall
#
# === STEP 24: Play League Matches ===
#
# Matches played on 2024-08-19:
# Premier League
# Crystal Palace 2 - 2 Arsenal
#
# === STEP 25: Play League Matches ===
#
# Matches played on 2024-08-23:
# Premier League
# Chelsea 2 - 1 Luton
# Championship
# Hull City 1 - 1 Bristol City
# National League
# Solihull Moors 0 - 2 FC Halifax Town
# Southend 3 - 1 Eastleigh
# Rochdale 2 - 0 Bromley
#
# === STEP 26: Play League Matches ===
#
# Matches played on 2024-08-24:
# Premier League
# Arsenal 1 - 0 Fulham
# Everton 3 - 0 Wolves
# Manchester United 4 - 1 Nottingham Forest
# Bournemouth 1 - 3 Tottenham
# Brentford 0 - 0 Crystal Palace
# Brighton 2 - 0 West Ham
# Championship
# Coventry 2 - 2 Sunderland
# Rotherham 1 - 2 Leicester
# West Brom 2 - 0 Middlesbrough
# Preston 1 - 1 Swansea
# Millwall 0 - 0 Stoke City
# Ipswich 0 - 1 Leeds
# Birmingham 2 - 0 Plymouth
# Cardiff 3 - 0 Sheffield Wednesday
# Southampton 1 - 0 QPR
# Huddersfield 3 - 0 Norwich
# League One
# Oxford United 0 - 2 Charlton
# Leyton Orient 2 - 1 Cambridge United
# Lincoln 0 - 2 Blackpool
# Burton Albion 0 - 1 Bolton
# Bristol Rovers 3 - 2 Wycombe
# Fleetwood Town 3 - 2 Shrewsbury
# Peterborough 0 - 0 Derby
# Port Vale 4 - 0 Carlisle
# Exeter City 1 - 2 Reading
# Stevenage 1 - 2 Portsmouth
# Cheltenham 3 - 0 Northampton
# Wigan 3 - 0 Barnsley
# League Two
# AFC Wimbledon 2 - 3 Forest Green
# Walsall 0 - 1 Grimsby
# Bradford 2 - 0 Crewe
# Gillingham 1 - 3 Colchester
# Swindon Town 2 - 0 Crawley Town
# Newport County 0 - 0 Sutton Utd
# Mansfield Town 2 - 0 Stockport County
# Notts County 0 - 3 Tranmere
# Barrow 2 - 0 Wrexham
# Harrogate Town 0 - 1 Morecambe
# Salford City 0 - 1 Accrington ST
# Milton Keynes Dons 2 - 1 Doncaster
# National League
# Dagenham & Redbridge 3 - 0 Barnet
# Aldershot Town 0 - 0 Wealdstone
# Gateshead 0 - 2 Woking
# Boreham Wood 2 - 0 Oldham
# Maidenhead 1 - 1 Oxford City
# Ebbsfleet United 0 - 0 Kidderminster Harriers
# Altrincham 1 - 1 Chesterfield
# Dorking Wanderers 2 - 1 York
# Hartlepool 1 - 0 AFC Fylde
#
# === STEP 27: Play League Matches ===
#
# Matches played on 2024-08-25:
# Premier League
# Sheffield Utd 2 - 1 Manchester City
# Burnley 0 - 0 Aston Villa
# Newcastle 0 - 2 Liverpool
# Championship
# Watford 1 - 0 Blackburn
#
# === STEP 28: Play League Matches ===
#
# Matches played on 2024-08-26:
# National League
# AFC Fylde 1 - 0 Altrincham
# Kidderminster Harriers 1 - 2 Maidenhead
# Wealdstone 1 - 0 Dagenham & Redbridge
# FC Halifax Town 1 - 1 Gateshead
# Barnet 1 - 1 Ebbsfleet United
# Woking 0 - 1 Dorking Wanderers
# Bromley 0 - 0 Southend
# Chesterfield 1 - 0 Hartlepool
# York 1 - 0 Rochdale
# Eastleigh 3 - 0 Aldershot Town
# Oldham 2 - 1 Solihull Moors
# Oxford City 0 - 1 Boreham Wood
#
# === STEP 29: Draw European Group Stage ===
#
# Populated Champions League Group Stage (competitionID=9):
#   Group 1: Sevilla, Lens, Galatasaray, Benfica
#   Group 2: Newcastle, Bayern Munich, Real Madrid, Red Star Belgrade
#   Group 3: Celtic, AC Milan, Feyenoord, RB Leipzig
#   Group 4: Inter, SC Braga, Borussia Dortmund, Barcelona
#   Group 5: FC Copenhagen, FC Porto, Arsenal, Antwerp
#   Group 6: BSC Young Boys, Napoli, Manchester United, Paris Saint Germain
#   Group 7: Atletico Madrid, Manchester City, Union Berlin, Ajax
#   Group 8: Red Bull Salzburg, PSV Eindhoven, Real Sociedad, Lazio
#
# === STEP 30: Draw European Group Stage ===
#
# Populated Europa League Group Stage (competitionID=8):
#   Group 1: Bayer Leverkusen, Sheriff Tiraspol, Tottenham, Olympiacos
#   Group 2: BK Hacken, Toulouse, Panathinaikos, Aston Villa
#   Group 3: Maccabi Haifa, Rennes, Real Betis, AS Roma
#   Group 4: Union St. Gilloise, Sturm Graz, AEK Athens FC, Liverpool
#   Group 5: SC Freiburg, Lask Linz, Qarabag, Sporting CP
#   Group 6: Atalanta, Aris Limassol, Sparta Praha, Molde
#   Group 7: Marseille, Villarreal, Slavia Praha, Rangers
#   Group 8: Brighton, Shakhtar Donetsk, TSC Backa Topola, Servette FC
#
# === STEP 31: Play Cup Round ===
# Day 20 | League Cup | Morecambe 2–0 Northampton → Winner: Morecambe
# Day 20 | League Cup | Birmingham 2–1 Millwall → Winner: Birmingham
# Day 20 | League Cup | Blackburn 1–3 Chelsea → Winner: Chelsea
# Day 20 | League Cup | Sheffield Utd 1–0 Burton Albion (a.e.t.) → Winner: Sheffield Utd
# Day 20 | League Cup | West Ham 1–0 Barnsley (a.e.t.) → Winner: West Ham
# Day 20 | League Cup | Bradford 2–1 Stevenage → Winner: Bradford
# Day 20 | League Cup | Charlton 1–1 Derby (a.e.t.) [p 3–2] → Winner: Charlton
# Day 20 | League Cup | Sutton Utd 2–1 Peterborough → Winner: Sutton Utd
# Day 20 | League Cup | Middlesbrough 2–1 Everton (a.e.t.) → Winner: Middlesbrough
# Day 20 | League Cup | Ipswich 0–2 Fulham (a.e.t.) → Winner: Fulham
# Day 20 | League Cup | Bristol Rovers 0–1 Watford → Winner: Watford
# Day 20 | League Cup | Sheffield Wednesday 2–1 Lincoln → Winner: Sheffield Wednesday
# Day 20 | League Cup | Sunderland 2–0 Norwich → Winner: Sunderland
# Day 20 | League Cup | Leeds 2–0 Cheltenham → Winner: Leeds
# Day 20 | League Cup | Carlisle 0–5 West Brom → Winner: West Brom
# Day 20 | League Cup | Leyton Orient 1–1 Crawley Town (a.e.t.) [p 3–2] → Winner: Leyton Orient
# Day 20 | League Cup | Burnley 3–2 Brentford → Winner: Burnley
# Day 20 | League Cup | Wycombe 0–2 Luton → Winner: Luton
# Day 20 | League Cup | Leicester 1–0 Bristol City → Winner: Leicester
#
# === STEP 32: Play Cup Round ===
# Day 21 | League Cup | Bournemouth 0–2 Swansea → Winner: Swansea
# Day 21 | League Cup | Coventry 1–0 Reading → Winner: Coventry
# Day 21 | League Cup | Nottingham Forest 3–1 Rotherham → Winner: Nottingham Forest
# Day 21 | League Cup | Preston 3–2 Huddersfield (a.e.t.) → Winner: Preston
# Day 21 | League Cup | Crystal Palace 1–0 Wolves → Winner: Crystal Palace
#
# === STEP 33: Update Cup Status ===
# Day 20 | League Cup | Knocked out: Northampton → inLC = False
# Day 20 | League Cup | Knocked out: Millwall → inLC = False
# Day 20 | League Cup | Knocked out: Blackburn → inLC = False
# Day 20 | League Cup | Knocked out: Burton Albion → inLC = False
# Day 20 | League Cup | Knocked out: Barnsley → inLC = False
# Day 20 | League Cup | Knocked out: Stevenage → inLC = False
# Day 20 | League Cup | Knocked out: Derby → inLC = False
# Day 20 | League Cup | Knocked out: Peterborough → inLC = False
# Day 20 | League Cup | Knocked out: Everton → inLC = False
# Day 20 | League Cup | Knocked out: Ipswich → inLC = False
# Day 20 | League Cup | Knocked out: Bristol Rovers → inLC = False
# Day 20 | League Cup | Knocked out: Lincoln → inLC = False
# Day 20 | League Cup | Knocked out: Norwich → inLC = False
# Day 20 | League Cup | Knocked out: Cheltenham → inLC = False
# Day 20 | League Cup | Knocked out: Carlisle → inLC = False
# Day 20 | League Cup | Knocked out: Crawley Town → inLC = False
# Day 20 | League Cup | Knocked out: Brentford → inLC = False
# Day 20 | League Cup | Knocked out: Wycombe → inLC = False
# Day 20 | League Cup | Knocked out: Bristol City → inLC = False
# Day 21 | League Cup | Knocked out: Bournemouth → inLC = False
# Day 21 | League Cup | Knocked out: Reading → inLC = False
# Day 21 | League Cup | Knocked out: Rotherham → inLC = False
# Day 21 | League Cup | Knocked out: Huddersfield → inLC = False
# Day 21 | League Cup | Knocked out: Wolves → inLC = False
#
# === STEP 34: Add LC Round3 Teams ===
# Added to LC Round 3: Arsenal, Aston Villa, Brighton, Liverpool, Manchester City, Manchester United, Newcastle, Tottenham
#
# === STEP 35: Draw Cup ===
#
# 🏆 League Cup draw (16 matches) across: 2024-09-24, 2024-09-25
#   Match 01 (day 38): Middlesbrough vs Aston Villa
#   Match 02 (day 38): Crystal Palace vs Nottingham Forest
#   Match 03 (day 38): Preston vs West Ham
#   Match 04 (day 38): Chelsea vs Liverpool
#   Match 05 (day 38): Newcastle vs Coventry
#   Match 06 (day 38): Fulham vs Manchester United
#   Match 07 (day 38): Luton vs Manchester City
#   Match 08 (day 39): Charlton vs Burnley
#   Match 09 (day 39): Swansea vs Sutton Utd
#   Match 10 (day 39): Bradford vs Morecambe
#   Match 11 (day 39): Leyton Orient vs Leicester
#   Match 12 (day 39): Brighton vs Arsenal
#   Match 13 (day 39): Birmingham vs Sheffield Utd
#   Match 14 (day 39): Watford vs Leeds
#   Match 15 (day 39): Tottenham vs West Brom
#   Match 16 (day 39): Sunderland vs Sheffield Wednesday
#
# === STEP 36: Play League Matches ===
#
# Matches played on 2024-09-06:
# Premier League
# Luton 1 - 0 West Ham
#
# === STEP 37: Play League Matches ===
#
# Matches played on 2024-09-07:
# Premier League
# Brighton 2 - 1 Newcastle
# Brentford 2 - 0 Bournemouth
# Manchester City 2 - 0 Fulham
# Chelsea 1 - 2 Nottingham Forest
# Burnley 2 - 2 Tottenham
# Sheffield Utd 1 - 3 Everton
# Championship
# Coventry 2 - 1 Watford
# Birmingham 1 - 3 Millwall
# Swansea 2 - 1 Bristol City
# Sunderland 2 - 0 Southampton
# Plymouth 1 - 0 Blackburn
# Leicester 0 - 0 Hull City
# Ipswich 3 - 0 Cardiff
# West Brom 1 - 1 Huddersfield
# Leeds 1 - 1 Sheffield Wednesday
# Middlesbrough 2 - 0 QPR
# Rotherham 0 - 0 Norwich
# Stoke City 0 - 2 Preston
# League One
# Burton Albion 1 - 1 Exeter City
# Leyton Orient 0 - 3 Stevenage
# Bristol Rovers 2 - 0 Lincoln
# Charlton 2 - 1 Fleetwood Town
# Northampton 1 - 0 Wycombe
# Oxford United 1 - 1 Port Vale
# Bolton 0 - 1 Derby
# Blackpool 1 - 2 Wigan
# Carlisle 1 - 2 Shrewsbury
# Cheltenham 2 - 1 Barnsley
# Portsmouth 1 - 0 Peterborough
# League Two
# Stockport County 3 - 0 Crawley Town
# Harrogate Town 1 - 0 Barrow
# Tranmere 3 - 3 Wrexham
# Walsall 1 - 2 Colchester
# Doncaster 1 - 2 Swindon Town
# Grimsby 0 - 1 Gillingham
# Newport County 1 - 1 AFC Wimbledon
# Mansfield Town 1 - 1 Bradford
# Morecambe 3 - 1 Salford City
# Notts County 1 - 1 Accrington ST
# Sutton Utd 0 - 2 Forest Green
# Crewe 0 - 1 Milton Keynes Dons
# National League
# Rochdale 3 - 1 FC Halifax Town
# Hartlepool 0 - 2 Wealdstone
# Aldershot Town 1 - 2 Chesterfield
# Dagenham & Redbridge 3 - 1 AFC Fylde
# Boreham Wood 1 - 0 Barnet
# Solihull Moors 0 - 0 Oxford City
# Maidenhead 0 - 4 Woking
# Ebbsfleet United 0 - 0 York
# Altrincham 1 - 1 Bromley
# Dorking Wanderers 0 - 1 Eastleigh
# Gateshead 2 - 2 Oldham
# Southend 1 - 0 Kidderminster Harriers
#
# === STEP 38: Play League Matches ===
#
# Matches played on 2024-09-01:
# Premier League
# Liverpool 2 - 2 Aston Villa
# Crystal Palace 4 - 3 Wolves
# Arsenal 1 - 0 Manchester United
#
# === STEP 39: Play League Matches ===
#
# Matches played on 2024-09-02:
# League One
# Cambridge United 1 - 1 Reading
#
# === STEP 40: Play League Matches ===
#
# Matches played on 2024-09-14:
# League One
# Exeter City 1 - 0 Leyton Orient
# Stevenage 1 - 2 Carlisle
# League Two
# Salford City 2 - 0 Walsall
# Wrexham 0 - 2 Doncaster
# Forest Green 3 - 0 Crewe
# Accrington ST 1 - 1 Mansfield Town
# Colchester 1 - 1 Tranmere
# Swindon Town 1 - 0 Sutton Utd
# Gillingham 1 - 1 Harrogate Town
# Bradford 2 - 0 Grimsby
# Crawley Town 0 - 1 Newport County
# AFC Wimbledon 1 - 1 Stockport County
# Milton Keynes Dons 2 - 0 Notts County
# National League
# Woking 2 - 0 Solihull Moors
# FC Halifax Town 2 - 2 Southend
# Chesterfield 0 - 0 Dagenham & Redbridge
# Oldham 1 - 0 Dorking Wanderers
# Barnet 2 - 1 Altrincham
# Eastleigh 1 - 0 Gateshead
# York 0 - 5 Boreham Wood
# Bromley 3 - 0 Maidenhead
# AFC Fylde 4 - 1 Aldershot Town
# Oxford City 1 - 2 Hartlepool
# Wealdstone 1 - 1 Ebbsfleet United
# Kidderminster Harriers 0 - 1 Rochdale
#
# === STEP 41: Play League Matches ===
#
# Matches played on 2024-09-20:
# Championship
# Southampton 0 - 0 Leicester
# Hull City 2 - 2 Coventry
# League Two
# Salford City 1 - 0 Notts County
#
# === STEP 42: Play League Matches ===
#
# Matches played on 2024-09-21:
# Premier League
# Wolves 0 - 0 Liverpool
# Manchester United 2 - 1 Brighton
# Fulham 1 - 1 Luton
# Tottenham 2 - 1 Sheffield Utd
# West Ham 0 - 0 Manchester City
# Aston Villa 3 - 1 Crystal Palace
# Newcastle 1 - 3 Brentford
# Championship
# Norwich 1 - 2 Stoke City
# Huddersfield 2 - 0 Rotherham
# Watford 2 - 1 Birmingham
# Bristol City 0 - 1 West Brom
# Preston 1 - 0 Plymouth
# Blackburn 1 - 1 Middlesbrough
# QPR 0 - 2 Sunderland
# Sheffield Wednesday 1 - 2 Ipswich
# Cardiff 1 - 1 Swansea
# League One
# Reading 0 - 0 Bolton
# Wigan 2 - 0 Cambridge United
# Derby 1 - 2 Portsmouth
# Barnsley 2 - 1 Burton Albion
# Fleetwood Town 3 - 2 Oxford United
# Peterborough 1 - 1 Leyton Orient
# Port Vale 2 - 1 Northampton
# Shrewsbury 2 - 1 Bristol Rovers
# Wycombe 0 - 1 Blackpool
# Stevenage 1 - 3 Charlton
# Lincoln 2 - 0 Carlisle
# Exeter City 0 - 1 Cheltenham
# League Two
# Bradford 2 - 0 Harrogate Town
# AFC Wimbledon 0 - 2 Crewe
# Gillingham 0 - 2 Morecambe
# Milton Keynes Dons 0 - 0 Stockport County
# Swindon Town 1 - 0 Walsall
# Accrington ST 3 - 0 Sutton Utd
# Forest Green 2 - 0 Doncaster
# Newport County 1 - 2 Barrow
# Crawley Town 1 - 0 Tranmere
# Colchester 2 - 0 Mansfield Town
# Wrexham 1 - 1 Grimsby
# National League
# Maidenhead 1 - 3 Boreham Wood
# Bromley 1 - 0 Oldham
# Kidderminster Harriers 2 - 1 Solihull Moors
# Aldershot Town 0 - 3 Gateshead
# Hartlepool 1 - 1 Woking
# Rochdale 3 - 0 Barnet
# York 1 - 2 Southend
# Oxford City 0 - 2 Dagenham & Redbridge
# Wealdstone 0 - 0 Altrincham
# FC Halifax Town 0 - 0 Dorking Wanderers
# AFC Fylde 1 - 1 Eastleigh
# Ebbsfleet United 1 - 2 Chesterfield
#
# === STEP 43: Play League Matches ===
#
# Matches played on 2024-09-15:
# Premier League
# Bournemouth 0 - 1 Chelsea
# Everton 1 - 2 Arsenal
# Championship
# Millwall 2 - 2 Leeds
#
# === STEP 44: Play League Matches ===
#
# Matches played on 2024-09-16:
# Premier League
# Nottingham Forest 2 - 1 Burnley
#
# === STEP 45: Play League Matches ===
#
# Matches played on 2024-09-17:
# Championship
# QPR 0 - 0 Swansea
# Sheffield Wednesday 0 - 0 Middlesbrough
# Bristol City 2 - 1 Plymouth
# Preston 1 - 1 Birmingham
# Cardiff 1 - 1 Coventry
# Southampton 1 - 2 Ipswich
# League One
# Port Vale 1 - 0 Burton Albion
# Barnsley 2 - 1 Portsmouth
# Peterborough 0 - 0 Cheltenham
# National League
# Southend 3 - 0 Maidenhead
# Chesterfield 2 - 1 FC Halifax Town
# Oldham 1 - 0 York
# Barnet 2 - 1 Aldershot Town
# Dagenham & Redbridge 1 - 0 Bromley
# Eastleigh 3 - 0 Oxford City
# Gateshead 2 - 0 Kidderminster Harriers
# Boreham Wood 0 - 3 Rochdale
# Altrincham 1 - 0 Hartlepool
# Dorking Wanderers 0 - 1 Wealdstone
# Woking 1 - 0 Ebbsfleet United
# Solihull Moors 2 - 2 AFC Fylde
# Champions League
# Sevilla 2 - 2 Benfica
# Lens 2 - 0 Galatasaray
# Newcastle 4 - 1 Red Star Belgrade
# Bayern Munich 2 - 1 Real Madrid
# Celtic 0 - 1 RB Leipzig
# AC Milan 0 - 0 Feyenoord
# Inter 1 - 1 Barcelona
# SC Braga 0 - 0 Borussia Dortmund
#
# === STEP 46: Play League Matches ===
#
# Matches played on 2024-09-18:
# Championship
# Hull City 0 - 1 Leeds
# Norwich 2 - 1 Leicester
# Blackburn 1 - 1 Sunderland
# Huddersfield 2 - 2 Stoke City
# Watford 2 - 2 West Brom
# Millwall 1 - 1 Rotherham
# Champions League
# FC Copenhagen 2 - 0 Antwerp
# FC Porto 1 - 3 Arsenal
# BSC Young Boys 1 - 3 Paris Saint Germain
# Napoli 1 - 0 Manchester United
# Atletico Madrid 2 - 1 Ajax
# Manchester City 3 - 0 Union Berlin
# Red Bull Salzburg 2 - 0 Lazio
# PSV Eindhoven 1 - 0 Real Sociedad
#
# === STEP 47: Play League Matches ===
#
# Matches played on 2024-09-19:
# Europa League
# Bayer Leverkusen 0 - 0 Olympiacos
# Sheriff Tiraspol 0 - 2 Tottenham
# BK Hacken 1 - 1 Aston Villa
# Toulouse 2 - 0 Panathinaikos
# Maccabi Haifa 1 - 0 AS Roma
# Rennes 0 - 2 Real Betis
# Union St. Gilloise 1 - 1 Liverpool
# Sturm Graz 2 - 0 AEK Athens FC
# SC Freiburg 1 - 0 Sporting CP
# Lask Linz 1 - 2 Qarabag
# Atalanta 1 - 1 Molde
# Aris Limassol 1 - 2 Sparta Praha
# Marseille 1 - 0 Rangers
# Villarreal 1 - 0 Slavia Praha
# Brighton 0 - 1 Servette FC
# Shakhtar Donetsk 2 - 1 TSC Backa Topola
#
# === STEP 48: Play League Matches ===
#
# Matches played on 2024-09-27:
# Championship
# Birmingham 1 - 0 QPR
#
# === STEP 49: Play League Matches ===
#
# Matches played on 2024-09-28:
# Premier League
# Manchester City 0 - 0 Nottingham Forest
# Crystal Palace 0 - 0 Fulham
# Luton 0 - 0 Wolves
# Brentford 3 - 0 Everton
# Burnley 0 - 2 Manchester United
# Championship
# Leicester 1 - 2 Bristol City
# West Brom 1 - 2 Millwall
# Leeds 2 - 0 Watford
# Middlesbrough 0 - 1 Southampton
# Rotherham 1 - 1 Preston
# Swansea 2 - 0 Sheffield Wednesday
# Plymouth 1 - 1 Norwich
# Ipswich 1 - 0 Blackburn
# League One
# Bolton 1 - 4 Peterborough
# Cambridge United 0 - 3 Port Vale
# Leyton Orient 0 - 2 Shrewsbury
# Burton Albion 3 - 3 Fleetwood Town
# Carlisle 1 - 0 Derby
# Bristol Rovers 0 - 1 Wigan
# Charlton 0 - 0 Wycombe
# Northampton 0 - 2 Barnsley
# Oxford United 1 - 1 Exeter City
# Portsmouth 3 - 2 Lincoln
# Blackpool 1 - 2 Reading
# Cheltenham 2 - 1 Stevenage
# League Two
# Morecambe 0 - 1 Swindon Town
# Mansfield Town 2 - 1 Barrow
# Newport County 0 - 2 Bradford
# Grimsby 1 - 0 Crawley Town
# Crewe 2 - 1 Colchester
# Doncaster 1 - 0 Gillingham
# Walsall 2 - 0 AFC Wimbledon
# Stockport County 4 - 0 Wrexham
# Harrogate Town 1 - 3 Salford City
# Sutton Utd 0 - 3 Milton Keynes Dons
# Tranmere 0 - 0 Accrington ST
# Notts County 1 - 0 Forest Green
# National League
# Altrincham 1 - 0 Ebbsfleet United
# Dorking Wanderers 4 - 3 Rochdale
# Solihull Moors 2 - 2 Bromley
# Boreham Wood 3 - 0 Aldershot Town
# Eastleigh 2 - 1 Kidderminster Harriers
# Woking 2 - 0 York
# Southend 4 - 0 AFC Fylde
# Chesterfield 1 - 0 Wealdstone
# Barnet 3 - 1 FC Halifax Town
# Dagenham & Redbridge 1 - 0 Hartlepool
# Gateshead 2 - 0 Maidenhead
# Oldham 3 - 1 Oxford City
#
# === STEP 50: Play League Matches ===
#
# Matches played on 2024-09-22:
# Premier League
# Liverpool 3 - 1 West Ham
# Arsenal 1 - 2 Tottenham
# Brighton 1 - 0 Bournemouth
# Sheffield Utd 1 - 1 Newcastle
# Chelsea 1 - 0 Aston Villa
# Championship
# Sunderland 3 - 0 Cardiff
# Stoke City 1 - 0 Hull City
#
# === STEP 51: Play League Matches ===
#
# Matches played on 2024-09-23:
# Championship
# Coventry 2 - 2 Huddersfield
#
# === STEP 52: Play League Matches ===
#
# Matches played on 2024-09-24:
# National League
# Hartlepool 4 - 0 Solihull Moors
# Aldershot Town 2 - 3 Southend
# York 0 - 0 Barnet
# Bromley 0 - 0 Eastleigh
# Wealdstone 1 - 2 Woking
# Maidenhead 1 - 3 Altrincham
# AFC Fylde 1 - 1 Boreham Wood
# Ebbsfleet United 2 - 1 Dorking Wanderers
# FC Halifax Town 0 - 3 Dagenham & Redbridge
# Oxford City 0 - 4 Gateshead
# Kidderminster Harriers 1 - 0 Oldham
# Rochdale 1 - 1 Chesterfield
#
# === STEP 53: Play Cup Round ===
# Day 38 | League Cup | Middlesbrough 2–2 Aston Villa (a.e.t.) [p 2–3] → Winner: Aston Villa
# Day 38 | League Cup | Crystal Palace 2–0 Nottingham Forest → Winner: Crystal Palace
# Day 38 | League Cup | Preston 1–2 West Ham → Winner: West Ham
# Day 38 | League Cup | Chelsea 0–1 Liverpool → Winner: Liverpool
# Day 38 | League Cup | Newcastle 1–0 Coventry → Winner: Newcastle
# Day 38 | League Cup | Fulham 4–2 Manchester United → Winner: Fulham
# Day 38 | League Cup | Luton 0–1 Manchester City → Winner: Manchester City
#
# === STEP 54: Play Cup Round ===
# Day 39 | League Cup | Charlton 0–1 Burnley → Winner: Burnley
# Day 39 | League Cup | Swansea 3–0 Sutton Utd → Winner: Swansea
# Day 39 | League Cup | Bradford 1–2 Morecambe → Winner: Morecambe
# Day 39 | League Cup | Leyton Orient 0–1 Leicester → Winner: Leicester
# Day 39 | League Cup | Brighton 2–1 Arsenal → Winner: Brighton
# Day 39 | League Cup | Birmingham 0–1 Sheffield Utd → Winner: Sheffield Utd
# Day 39 | League Cup | Watford 0–2 Leeds → Winner: Leeds
# Day 39 | League Cup | Tottenham 1–0 West Brom → Winner: Tottenham
# Day 39 | League Cup | Sunderland 1–1 Sheffield Wednesday (a.e.t.) [p 4–3] → Winner: Sunderland
#
# === STEP 55: Update Cup Status ===
# Day 38 | League Cup | Knocked out: Middlesbrough → inLC = False
# Day 38 | League Cup | Knocked out: Nottingham Forest → inLC = False
# Day 38 | League Cup | Knocked out: Preston → inLC = False
# Day 38 | League Cup | Knocked out: Chelsea → inLC = False
# Day 38 | League Cup | Knocked out: Coventry → inLC = False
# Day 38 | League Cup | Knocked out: Manchester United → inLC = False
# Day 38 | League Cup | Knocked out: Luton → inLC = False
# Day 39 | League Cup | Knocked out: Charlton → inLC = False
# Day 39 | League Cup | Knocked out: Sutton Utd → inLC = False
# Day 39 | League Cup | Knocked out: Bradford → inLC = False
# Day 39 | League Cup | Knocked out: Leyton Orient → inLC = False
# Day 39 | League Cup | Knocked out: Arsenal → inLC = False
# Day 39 | League Cup | Knocked out: Birmingham → inLC = False
# Day 39 | League Cup | Knocked out: Watford → inLC = False
# Day 39 | League Cup | Knocked out: West Brom → inLC = False
# Day 39 | League Cup | Knocked out: Sheffield Wednesday → inLC = False
#
# === STEP 56: Draw Cup ===
#
# 🏆 League Cup draw (8 matches) across: 2024-10-29, 2024-11-06
#   Match 01 (day 63): Burnley vs Leicester
#   Match 02 (day 63): Newcastle vs Sheffield Utd
#   Match 03 (day 64): Crystal Palace vs West Ham
#   Match 04 (day 64): Brighton vs Liverpool
#   Match 05 (day 64): Swansea vs Aston Villa
#   Match 06 (day 64): Sunderland vs Tottenham
#   Match 07 (day 64): Leeds vs Manchester City
#   Match 08 (day 64): Morecambe vs Fulham
#
# === STEP 57: Play League Matches ===
#
# Matches played on 2024-09-27:
# Championship
# Sheffield Wednesday 0 - 1 Sunderland
#
# === STEP 58: Play League Matches ===
#
# Matches played on 2024-09-28:
# Premier League
# Aston Villa 1 - 1 Brighton
# Manchester United 3 - 1 Crystal Palace
# Newcastle 1 - 1 Burnley
# Wolves 2 - 0 Manchester City
# Everton 4 - 2 Luton
# West Ham 1 - 0 Sheffield Utd
# Bournemouth 0 - 1 Arsenal
# Tottenham 2 - 1 Liverpool
# Championship
# Norwich 3 - 1 Birmingham
# QPR 1 - 2 Coventry
# Hull City 1 - 0 Plymouth
# Watford 2 - 2 Middlesbrough
# Huddersfield 1 - 1 Ipswich
# Southampton 1 - 0 Leeds
# Millwall 1 - 0 Swansea
# Preston 2 - 0 West Brom
# Cardiff 0 - 1 Rotherham
# Bristol City 1 - 0 Stoke City
# League One
# Reading 1 - 0 Burton Albion
# Port Vale 3 - 1 Bolton
# Derby 2 - 1 Cambridge United
# Barnsley 2 - 0 Blackpool
# Fleetwood Town 2 - 0 Leyton Orient
# Peterborough 1 - 0 Bristol Rovers
# Shrewsbury 1 - 1 Charlton
# Wycombe 2 - 0 Carlisle
# Exeter City 1 - 0 Northampton
# Stevenage 2 - 0 Oxford United
# Lincoln 1 - 2 Cheltenham
# Wigan 2 - 0 Portsmouth
# League Two
# Gillingham 2 - 0 Mansfield Town
# Salford City 2 - 1 Newport County
# Colchester 1 - 0 Notts County
# Accrington ST 1 - 0 Stockport County
# Swindon Town 2 - 0 Grimsby
# Milton Keynes Dons 1 - 0 Harrogate Town
# AFC Wimbledon 0 - 2 Tranmere
# Crawley Town 0 - 2 Sutton Utd
# Forest Green 0 - 1 Morecambe
# Barrow 0 - 0 Doncaster
# Wrexham 1 - 1 Crewe
# Bradford 1 - 0 Walsall
# National League
# Hartlepool 3 - 0 Dorking Wanderers
# Rochdale 0 - 1 Southend
# Aldershot Town 1 - 1 Dagenham & Redbridge
# York 3 - 0 Solihull Moors
# Oxford City 0 - 0 Altrincham
# Wealdstone 1 - 2 Oldham
# Kidderminster Harriers 0 - 3 Barnet
# FC Halifax Town 0 - 0 Eastleigh
# Ebbsfleet United 0 - 3 Boreham Wood
# Bromley 2 - 1 Gateshead
# AFC Fylde 1 - 4 Woking
# Maidenhead 0 - 1 Chesterfield
#
# === STEP 59: Play League Matches ===
#
# Matches played on 2024-10-06:
# Premier League
# Nottingham Forest 1 - 0 Brentford
# Championship
# Blackburn 2 - 1 Leicester
#
# === STEP 60: Play League Matches ===
#
# Matches played on 2024-10-07:
# Premier League
# Fulham 1 - 0 Chelsea
# Luton 1 - 2 Burnley
#
# === STEP 61: Play League Matches ===
#
# Matches played on 2024-10-01:
# Championship
# Stoke City 1 - 0 Southampton
# West Brom 1 - 1 Sheffield Wednesday
# Plymouth 0 - 0 Millwall
# Middlesbrough 1 - 0 Cardiff
# Ipswich 2 - 0 Hull City
# Birmingham 2 - 0 Huddersfield
# League One
# Northampton 0 - 3 Reading
# Blackpool 2 - 2 Derby
# Cambridge United 1 - 1 Barnsley
# Carlisle 0 - 2 Peterborough
# Cheltenham 0 - 2 Fleetwood Town
# Charlton 2 - 0 Exeter City
# Portsmouth 0 - 1 Wycombe
# Oxford United 0 - 2 Shrewsbury
# Bristol Rovers 2 - 2 Port Vale
# Bolton 1 - 0 Stevenage
# Burton Albion 0 - 1 Wigan
# League Two
# Grimsby 1 - 1 Barrow
# Harrogate Town 4 - 1 AFC Wimbledon
# Sutton Utd 1 - 1 Salford City
# Tranmere 0 - 2 Bradford
# Morecambe 1 - 4 Accrington ST
# Mansfield Town 2 - 1 Wrexham
# Newport County 2 - 1 Colchester
# Crewe 2 - 0 Gillingham
# Doncaster 3 - 0 Crawley Town
# Walsall 0 - 1 Milton Keynes Dons
# Stockport County 1 - 1 Forest Green
# Notts County 0 - 1 Swindon Town
# National League
# Chesterfield 0 - 2 Bromley
# Southend 2 - 0 Oxford City
# Oldham 5 - 0 Maidenhead
# Barnet 1 - 0 AFC Fylde
# Dagenham & Redbridge 3 - 0 York
# Eastleigh 1 - 0 Ebbsfleet United
# Gateshead 1 - 1 Wealdstone
# Solihull Moors 1 - 3 Rochdale
# Woking 2 - 1 FC Halifax Town
# Altrincham 2 - 0 Aldershot Town
# Dorking Wanderers 2 - 0 Kidderminster Harriers
# Champions League
# Sevilla 0 - 1 Galatasaray
# Benfica 0 - 0 Lens
# Newcastle 1 - 0 Real Madrid
# Red Star Belgrade 0 - 1 Bayern Munich
# Celtic 1 - 2 Feyenoord
# RB Leipzig 3 - 0 AC Milan
# Inter 1 - 1 Borussia Dortmund
# Barcelona 3 - 2 SC Braga
#
# === STEP 62: Play League Matches ===
#
# Matches played on 2024-10-02:
# Championship
# Rotherham 0 - 1 Bristol City
# Coventry 1 - 1 Blackburn
# Sunderland 3 - 1 Watford
# Swansea 1 - 1 Norwich
# Leeds 2 - 1 QPR
# Leicester 2 - 1 Preston
# National League
# Boreham Wood 0 - 0 Hartlepool
# Champions League
# FC Copenhagen 1 - 0 Arsenal
# Antwerp 2 - 1 FC Porto
# BSC Young Boys 1 - 1 Manchester United
# Paris Saint Germain 0 - 0 Napoli
# Atletico Madrid 2 - 1 Union Berlin
# Ajax 0 - 2 Manchester City
# Red Bull Salzburg 1 - 0 Real Sociedad
# Lazio 0 - 1 PSV Eindhoven
#
# === STEP 63: Play League Matches ===
#
# Matches played on 2024-10-03:
# Europa League
# Bayer Leverkusen 0 - 0 Tottenham
# Olympiacos 2 - 0 Sheriff Tiraspol
# BK Hacken 4 - 1 Panathinaikos
# Aston Villa 2 - 0 Toulouse
# Maccabi Haifa 2 - 1 Real Betis
# AS Roma 2 - 0 Rennes
# Union St. Gilloise 1 - 0 AEK Athens FC
# Liverpool 1 - 0 Sturm Graz
# SC Freiburg 0 - 0 Qarabag
# Sporting CP 2 - 1 Lask Linz
# Atalanta 0 - 0 Sparta Praha
# Molde 2 - 0 Aris Limassol
# Marseille 2 - 3 Slavia Praha
# Rangers 1 - 1 Villarreal
# Brighton 1 - 1 TSC Backa Topola
# Servette FC 2 - 1 Shakhtar Donetsk
#
# === STEP 64: Play League Matches ===
#
# Matches played on 2024-10-04:
# Championship
# Birmingham 0 - 2 West Brom
#
# === STEP 65: Play League Matches ===
#
# Matches played on 2024-10-05:
# Premier League
# Manchester United 0 - 0 Brentford
# Fulham 3 - 0 Sheffield Utd
# Burnley 0 - 1 Chelsea
# Everton 2 - 0 Bournemouth
# Crystal Palace 1 - 0 Nottingham Forest
# Luton 1 - 0 Tottenham
# Championship
# Plymouth 0 - 2 Swansea
# Sunderland 2 - 2 Middlesbrough
# Southampton 3 - 0 Rotherham
# Cardiff 1 - 1 Watford
# Leicester 1 - 1 Stoke City
# Ipswich 2 - 2 Preston
# Millwall 2 - 1 Hull City
# Leeds 1 - 0 Bristol City
# QPR 1 - 1 Blackburn
# Sheffield Wednesday 0 - 1 Huddersfield
# Coventry 2 - 1 Norwich
# League One
# Oxford United 0 - 0 Bristol Rovers
# Bolton 2 - 0 Carlisle
# Charlton 1 - 1 Blackpool
# Fleetwood Town 1 - 0 Wycombe
# Peterborough 1 - 1 Lincoln
# Shrewsbury 0 - 1 Northampton
# Portsmouth 0 - 1 Port Vale
# Exeter City 0 - 0 Barnsley
# Cheltenham 0 - 2 Derby
# Stevenage 0 - 2 Wigan
# Leyton Orient 1 - 3 Reading
# League Two
# Stockport County 2 - 0 Doncaster
# Barrow 1 - 0 Notts County
# Tranmere 2 - 0 Grimsby
# Mansfield Town 2 - 0 AFC Wimbledon
# Newport County 1 - 3 Harrogate Town
# Crawley Town 0 - 1 Wrexham
# Colchester 1 - 2 Morecambe
# Accrington ST 2 - 3 Forest Green
# Gillingham 0 - 2 Milton Keynes Dons
# Bradford 1 - 0 Swindon Town
# Salford City 1 - 0 Crewe
# Sutton Utd 2 - 1 Walsall
# National League
# Hartlepool 1 - 1 Eastleigh
# Dorking Wanderers 0 - 2 Barnet
# Kidderminster Harriers 2 - 1 Wealdstone
# Oxford City 1 - 0 AFC Fylde
# Ebbsfleet United 0 - 2 FC Halifax Town
# Maidenhead 0 - 2 Rochdale
# Woking 2 - 2 Southend
# Solihull Moors 1 - 3 Aldershot Town
# Boreham Wood 0 - 1 Chesterfield
# York 1 - 1 Bromley
# Gateshead 1 - 1 Altrincham
# Oldham 0 - 1 Dagenham & Redbridge
#
# === STEP 66: Play League Matches ===
#
# Matches played on 2024-10-13:
# Premier League
# Arsenal 0 - 0 Manchester City
# Brighton 0 - 2 Liverpool
# West Ham 1 - 0 Newcastle
# Wolves 1 - 0 Aston Villa
#
# === STEP 67: Play League Matches ===
#
# Matches played on 2024-10-14:
# League One
# Burton Albion 1 - 0 Cambridge United
#
# === STEP 68: Play League Matches ===
#
# Matches played on 2024-10-12:
# League One
# Lincoln 0 - 1 Burton Albion
# Carlisle 0 - 3 Leyton Orient
# Cambridge United 1 - 2 Shrewsbury
# Blackpool 0 - 0 Stevenage
# League Two
# Crewe 1 - 0 Tranmere
# Grimsby 1 - 3 Accrington ST
# Doncaster 2 - 0 Sutton Utd
# Swindon Town 0 - 0 Newport County
# Walsall 3 - 2 Gillingham
# Forest Green 3 - 1 Colchester
# AFC Wimbledon 0 - 2 Bradford
# Notts County 0 - 0 Mansfield Town
# Milton Keynes Dons 3 - 0 Barrow
# Wrexham 2 - 0 Salford City
# Harrogate Town 0 - 0 Stockport County
#
# === STEP 69: Draw Cup ===
#
# 🏆 FA Cup draw (40 matches) across: 2024-11-01, 2024-11-02, 2024-11-03
#   Match 01 (day 65): Forest Green vs Stockport County
#   Match 02 (day 65): Gillingham vs Cray Valley PM
#   Match 03 (day 65): Morecambe vs Doncaster
#   Match 04 (day 66): Eastleigh vs Scarborough Athletic
#   Match 05 (day 66): Barnet vs Derby
#   Match 06 (day 66): Hereford vs Colchester
#   Match 07 (day 66): Chester vs Crewe
#   Match 08 (day 66): Port Vale vs Fleetwood Town
#   Match 09 (day 66): Wrexham vs Worthing
#   Match 10 (day 66): Marine vs Maidstone Utd
#   Match 11 (day 66): Horsham vs Newport County
#   Match 12 (day 66): Barrow vs Hartlepool
#   Match 13 (day 66): Chesham United vs Crawley Town
#   Match 14 (day 66): Chesterfield vs Sutton Utd
#   Match 15 (day 66): Solihull Moors vs Curzon Ashton
#   Match 16 (day 66): Wycombe vs Burton Albion
#   Match 17 (day 66): Reading vs AFC Wimbledon
#   Match 18 (day 66): Accrington ST vs Sheppey United
#   Match 19 (day 66): Oxford City vs Blackpool
#   Match 20 (day 66): Peterborough vs York
#   Match 21 (day 66): Bracknell Town vs Bolton
#   Match 22 (day 66): AFC Fylde vs Oxford United
#   Match 23 (day 66): Bradford vs Notts County
#   Match 24 (day 66): Cambridge United vs Bromley
#   Match 25 (day 66): Boreham Wood vs Mansfield Town
#   Match 26 (day 66): Tranmere vs Charlton
#   Match 27 (day 66): Milton Keynes Dons vs Leyton Orient
#   Match 28 (day 66): Yeovil Town vs Shrewsbury
#   Match 29 (day 66): Portsmouth vs Ebbsfleet United
#   Match 30 (day 66): Woking vs Cheltenham
#   Match 31 (day 66): Salford City vs Alfreton Town
#   Match 32 (day 66): Walsall vs Dorking Wanderers
#   Match 33 (day 66): Bristol Rovers vs Stevenage
#   Match 34 (day 66): Whitby Town vs Carlisle
#   Match 35 (day 66): Swindon Town vs Slough Town
#   Match 36 (day 67): Wigan vs Lincoln
#   Match 37 (day 67): Grimsby vs Harrogate Town
#   Match 38 (day 67): Maidenhead vs Northampton
#   Match 39 (day 67): Barnsley vs Exeter City
#   Match 40 (day 67): Wealdstone vs Ramsgate
#
# === STEP 70: Play League Matches ===
#
# Matches played on 2024-10-18:
# League Two
# Newport County 2 - 2 Walsall
# Tranmere 2 - 0 Doncaster
#
# === STEP 71: Play League Matches ===
#
# Matches played on 2024-10-19:
# Premier League
# Sheffield Utd 1 - 1 Manchester United
# Chelsea 2 - 1 Arsenal
# Nottingham Forest 0 - 1 Luton
# Bournemouth 0 - 1 Wolves
# Newcastle 1 - 0 Crystal Palace
# Liverpool 2 - 0 Everton
# Manchester City 2 - 0 Brighton
# Brentford 1 - 0 Burnley
# Championship
# Swansea 0 - 1 Leicester
# Norwich 0 - 2 Leeds
# Middlesbrough 2 - 1 Birmingham
# Blackburn 1 - 2 Cardiff
# Hull City 2 - 3 Southampton
# West Brom 1 - 0 Plymouth
# Bristol City 1 - 0 Coventry
# Watford 3 - 1 Sheffield Wednesday
# Huddersfield 1 - 1 QPR
# Preston 0 - 0 Millwall
# Stoke City 2 - 1 Sunderland
# League One
# Bolton 0 - 2 Northampton
# Leyton Orient 1 - 1 Barnsley
# Cheltenham 2 - 0 Cambridge United
# Stevenage 0 - 1 Port Vale
# Exeter City 0 - 1 Wigan
# Charlton 1 - 0 Reading
# Shrewsbury 1 - 1 Derby
# Peterborough 0 - 1 Wycombe
# Oxford United 0 - 3 Blackpool
# Fleetwood Town 1 - 1 Lincoln
# Burton Albion 0 - 1 Bristol Rovers
# Portsmouth 3 - 0 Carlisle
# League Two
# Barrow 2 - 1 AFC Wimbledon
# Crawley Town 3 - 1 Crewe
# Colchester 0 - 0 Harrogate Town
# Accrington ST 2 - 0 Milton Keynes Dons
# Sutton Utd 1 - 2 Morecambe
# Salford City 1 - 2 Swindon Town
# Bradford 2 - 0 Wrexham
# Stockport County 0 - 0 Grimsby
# Gillingham 1 - 2 Notts County
# National League
# Southend 2 - 1 Solihull Moors
# Barnet 2 - 0 Maidenhead
# Aldershot Town 0 - 2 Hartlepool
# Dagenham & Redbridge 1 - 1 Woking
# Eastleigh 4 - 0 York
# Bromley 1 - 0 Oxford City
# AFC Fylde 1 - 1 Ebbsfleet United
# FC Halifax Town 1 - 1 Kidderminster Harriers
# Wealdstone 1 - 3 Boreham Wood
# Rochdale 0 - 0 Oldham
#
# === STEP 72: Play League Matches ===
#
# Matches played on 2024-10-27:
# Premier League
# Aston Villa 3 - 1 West Ham
#
# === STEP 73: Play League Matches ===
#
# Matches played on 2024-10-28:
# Premier League
# Tottenham 1 - 1 Fulham
#
# === STEP 74: Play League Matches ===
#
# Matches played on 2024-10-22:
# Championship
# West Brom 0 - 2 QPR
# Huddersfield 0 - 0 Cardiff
# Swansea 0 - 1 Watford
# Norwich 2 - 1 Middlesbrough
# Millwall 0 - 1 Blackburn
# Leicester 0 - 1 Sunderland
# League One
# Wigan 3 - 1 Oxford United
# Derby 2 - 2 Exeter City
# Barnsley 2 - 1 Shrewsbury
# Cambridge United 0 - 0 Portsmouth
# Northampton 0 - 1 Leyton Orient
# Blackpool 1 - 0 Cheltenham
# Wycombe 3 - 0 Bolton
# Carlisle 2 - 1 Burton Albion
# Bristol Rovers 1 - 0 Stevenage
# Lincoln 1 - 0 Charlton
# Reading 0 - 1 Fleetwood Town
# Port Vale 1 - 2 Peterborough
# League Two
# AFC Wimbledon 3 - 2 Accrington ST
# Milton Keynes Dons 3 - 0 Bradford
# Swindon Town 1 - 1 Gillingham
# Doncaster 0 - 1 Salford City
# Crewe 2 - 1 Stockport County
# Grimsby 1 - 1 Colchester
# Morecambe 4 - 0 Tranmere
# Notts County 2 - 3 Newport County
# Forest Green 0 - 3 Barrow
# Wrexham 2 - 1 Sutton Utd
# Harrogate Town 1 - 2 Mansfield Town
# Walsall 1 - 0 Crawley Town
# National League
# Wealdstone 1 - 0 Oxford City
# Altrincham 0 - 2 Kidderminster Harriers
# FC Halifax Town 2 - 3 Hartlepool
# AFC Fylde 0 - 1 Oldham
# Bromley 2 - 0 Dorking Wanderers
# Eastleigh 2 - 1 Woking
# Dagenham & Redbridge 3 - 2 Boreham Wood
# Aldershot Town 4 - 0 Maidenhead
# Barnet 2 - 0 Solihull Moors
# Chesterfield 1 - 0 York
# Southend 2 - 0 Ebbsfleet United
# Rochdale 1 - 0 Gateshead
# Champions League
# Sevilla 1 - 0 Lens
# Galatasaray 1 - 1 Benfica
# Newcastle 1 - 1 Bayern Munich
# Real Madrid 2 - 1 Red Star Belgrade
# Celtic 0 - 1 AC Milan
# Feyenoord 0 - 3 RB Leipzig
# Inter 2 - 1 SC Braga
# Borussia Dortmund 1 - 2 Barcelona
#
# === STEP 75: Play League Matches ===
#
# Matches played on 2024-10-23:
# Championship
# Stoke City 1 - 0 Leeds
# Plymouth 1 - 0 Sheffield Wednesday
# Rotherham 1 - 2 Coventry
# Preston 2 - 1 Southampton
# Bristol City 1 - 2 Ipswich
# Birmingham 0 - 1 Hull City
# Champions League
# FC Copenhagen 3 - 3 FC Porto
# Arsenal 2 - 1 Antwerp
# BSC Young Boys 0 - 0 Napoli
# ...
# Kidderminster Harriers 0 - 0 Southend
# Wealdstone 0 - 3 Hartlepool
# Bromley 0 - 1 Altrincham
#
# === STEP 145: Play League Matches ===
#
# Matches played on 2024-12-22:
# Premier League
# Wolves 1 - 2 Chelsea
#
# === STEP 146: Play League Matches ===
#
# Matches played on 2024-12-26:
# Premier League
# Manchester United 0 - 2 Aston Villa
# Burnley 1 - 2 Liverpool
# Sheffield Utd 0 - 0 Luton
# Bournemouth 0 - 1 Fulham
# Newcastle 1 - 1 Nottingham Forest
# Championship
# Birmingham 2 - 1 Stoke City
# Preston 1 - 1 Leeds
# Millwall 3 - 0 QPR
# Huddersfield 0 - 1 Blackburn
# Ipswich 0 - 4 Leicester
# Watford 5 - 0 Bristol City
# Cardiff 2 - 0 Plymouth
# West Brom 0 - 2 Norwich
# Hull City 1 - 0 Sunderland
# Rotherham 2 - 2 Middlesbrough
# Coventry 0 - 2 Sheffield Wednesday
# Southampton 1 - 0 Swansea
# League One
# Port Vale 2 - 1 Barnsley
# Stevenage 0 - 4 Northampton
# Exeter City 2 - 0 Wycombe
# Peterborough 1 - 0 Reading
# Oxford United 1 - 0 Cambridge United
# Fleetwood Town 1 - 0 Carlisle
# Bristol Rovers 1 - 0 Portsmouth
# Burton Albion 1 - 0 Blackpool
# Wigan 1 - 3 Derby
# Leyton Orient 0 - 1 Charlton
# Cheltenham 0 - 1 Shrewsbury
# Lincoln 1 - 0 Bolton
# League Two
# Barrow 3 - 2 Stockport County
# Notts County 0 - 0 Doncaster
# AFC Wimbledon 2 - 0 Sutton Utd
# Swindon Town 3 - 1 Wrexham
# Milton Keynes Dons 0 - 1 Colchester
# Walsall 0 - 2 Crewe
# Harrogate Town 0 - 2 Accrington ST
# Gillingham 0 - 0 Crawley Town
# Mansfield Town 3 - 1 Grimsby
# Newport County 1 - 2 Forest Green
# Salford City 3 - 1 Tranmere
# Bradford 0 - 2 Morecambe
# National League
# Rochdale 2 - 0 AFC Fylde
# Maidenhead 1 - 3 Wealdstone
# Hartlepool 1 - 0 Oldham
# Aldershot Town 0 - 2 Woking
# Southend 1 - 0 Barnet
# Ebbsfleet United 2 - 2 Bromley
# Solihull Moors 0 - 0 Chesterfield
# Boreham Wood 1 - 1 Kidderminster Harriers
# Gateshead 2 - 0 York
# Altrincham 2 - 0 FC Halifax Town
# Dorking Wanderers 2 - 0 Oxford City
# Dagenham & Redbridge 2 - 2 Eastleigh
#
# === STEP 147: Play League Matches ===
#
# Matches played on 2024-12-25:
# Premier League
# Brentford 0 - 1 Wolves
# Chelsea 0 - 1 Crystal Palace
# Everton 1 - 1 Manchester City
#
# === STEP 148: Play League Matches ===
#
# Matches played on 2024-12-26:
# Premier League
# Arsenal 1 - 1 West Ham
# Brighton 3 - 3 Tottenham
#
# === STEP 149: Play League Matches ===
#
# Matches played on 2024-12-27:
# Championship
# Hull City 2 - 0 Blackburn
# Preston 0 - 0 Sheffield Wednesday
# Millwall 1 - 1 Norwich
# Ipswich 1 - 0 QPR
# Birmingham 1 - 0 Bristol City
# Cardiff 3 - 0 Leicester
# Watford 1 - 0 Stoke City
# West Brom 0 - 2 Leeds
# Coventry 1 - 2 Swansea
# Rotherham 1 - 1 Sunderland
# Southampton 2 - 1 Plymouth
# Huddersfield 1 - 2 Middlesbrough
# League One
# Bristol Rovers 1 - 1 Charlton
# Fleetwood Town 2 - 1 Bolton
# Oxford United 1 - 1 Derby
# Peterborough 1 - 0 Barnsley
# Port Vale 1 - 2 Blackpool
# Exeter City 2 - 1 Portsmouth
# Cheltenham 1 - 2 Reading
# Leyton Orient 1 - 1 Wycombe
# Burton Albion 0 - 3 Shrewsbury
# Lincoln 1 - 2 Northampton
# Wigan 2 - 1 Carlisle
# League Two
# Walsall 2 - 0 Wrexham
# Salford City 2 - 1 Grimsby
# Harrogate Town 3 - 0 Tranmere
# Barrow 0 - 1 Accrington ST
# Notts County 1 - 2 Morecambe
# Mansfield Town 0 - 0 Doncaster
# Newport County 1 - 1 Crewe
# Swindon Town 1 - 1 Forest Green
# Milton Keynes Dons 3 - 0 Crawley Town
# Gillingham 2 - 1 Sutton Utd
# Bradford 1 - 0 Stockport County
# AFC Wimbledon 0 - 1 Colchester
#
# === STEP 150: Play League Matches ===
#
# Matches played on 2024-12-28:
# Premier League
# Crystal Palace 0 - 1 Brentford
# Aston Villa 1 - 0 Burnley
# Nottingham Forest 1 - 3 Manchester United
# Wolves 0 - 0 Everton
# Manchester City 1 - 2 Sheffield Utd
# Luton 1 - 1 Chelsea
# National League
# Oldham 3 - 0 Hartlepool
# Barnet 1 - 1 Southend
# Bromley 2 - 0 Ebbsfleet United
# Kidderminster Harriers 0 - 1 Boreham Wood
#
# === STEP 151: Play League Matches ===
#
# Matches played on 2024-12-29:
# Premier League
# Tottenham 0 - 0 Bournemouth
# Fulham 0 - 1 Arsenal
#
# === STEP 152: Play League Matches ===
#
# Matches played on 2025-01-01:
# Premier League
# Liverpool 3 - 0 Newcastle
# Championship
# QPR 1 - 1 Cardiff
# Norwich 1 - 1 Southampton
# Leeds 3 - 0 Birmingham
# Sheffield Wednesday 0 - 0 Hull City
# Plymouth 0 - 2 Watford
# Swansea 0 - 0 West Brom
# Stoke City 0 - 0 Ipswich
# Sunderland 1 - 0 Preston
# Leicester 0 - 1 Huddersfield
# Bristol City 1 - 0 Millwall
# Blackburn 1 - 1 Rotherham
# Middlesbrough 1 - 1 Coventry
# League One
# Reading 1 - 0 Exeter City
# Shrewsbury 2 - 1 Fleetwood Town
# Portsmouth 1 - 0 Stevenage
# Blackpool 1 - 0 Lincoln
# Wycombe 1 - 2 Bristol Rovers
# Cambridge United 2 - 1 Leyton Orient
# Carlisle 0 - 1 Port Vale
# Charlton 4 - 1 Oxford United
# Barnsley 0 - 1 Wigan
# Derby 1 - 1 Peterborough
# Bolton 1 - 1 Burton Albion
# Northampton 1 - 2 Cheltenham
# League Two
# Doncaster 2 - 3 Milton Keynes Dons
# Accrington ST 2 - 1 Salford City
# Colchester 3 - 0 Gillingham
# Crawley Town 1 - 1 Swindon Town
# Crewe 1 - 1 Bradford
# Morecambe 2 - 0 Harrogate Town
# Forest Green 1 - 1 AFC Wimbledon
# Tranmere 1 - 1 Notts County
# Sutton Utd 1 - 2 Newport County
# Wrexham 0 - 2 Barrow
# Stockport County 0 - 1 Mansfield Town
# Grimsby 3 - 0 Walsall
# National League
# Oxford City 2 - 2 Dorking Wanderers
# FC Halifax Town 0 - 1 Altrincham
# AFC Fylde 1 - 2 Rochdale
# Woking 2 - 0 Aldershot Town
# York 2 - 0 Gateshead
# Eastleigh 2 - 0 Dagenham & Redbridge
# Chesterfield 2 - 0 Solihull Moors
#
# === STEP 153: Play League Matches ===
#
# Matches played on 2025-01-07:
# Premier League
# West Ham 1 - 1 Brighton
#
# === STEP 154: Play Cup Round ===
# Day 117 | FA Cup | Sheffield Utd 0–1 Swansea → Winner: Swansea
#
# === STEP 155: Play Cup Round ===
# Day 118 | FA Cup | Charlton 2–0 Walsall → Winner: Charlton
# Day 118 | FA Cup | Hartlepool 0–3 Southampton → Winner: Southampton
# Day 118 | FA Cup | Tottenham 3–2 Norwich (a.e.t.) → Winner: Tottenham
#
# === STEP 156: Play Cup Round ===
# Day 119 | FA Cup | Mansfield Town 1–2 Everton → Winner: Everton
# Day 119 | FA Cup | Lincoln 1–3 Reading → Winner: Reading
# Day 119 | FA Cup | Preston 1–0 Barnsley → Winner: Preston
# Day 119 | FA Cup | Wealdstone 0–2 Bournemouth → Winner: Bournemouth
# Day 119 | FA Cup | QPR 3–0 Bradford → Winner: QPR
# Day 119 | FA Cup | Brighton 0–1 Newcastle → Winner: Newcastle
# Day 119 | FA Cup | West Ham 2–0 Bristol City → Winner: West Ham
# Day 119 | FA Cup | Ipswich 3–0 Accrington ST → Winner: Ipswich
# Day 119 | FA Cup | Peterborough 0–3 Huddersfield → Winner: Huddersfield
# Day 119 | FA Cup | Plymouth 4–0 Bolton → Winner: Plymouth
# Day 119 | FA Cup | Aston Villa 1–0 Luton → Winner: Aston Villa
# Day 119 | FA Cup | Cardiff 1–2 Arsenal → Winner: Arsenal
# Day 119 | FA Cup | Liverpool 0–0 Sheffield Wednesday (a.e.t.) [p 4–1] → Winner: Liverpool
# Day 119 | FA Cup | Cambridge United 1–1 Wolves (a.e.t.) [p 2–5] → Winner: Wolves
# Day 119 | FA Cup | Fulham 1–1 Sunderland (a.e.t.) [p 3–4] → Winner: Sunderland
# Day 119 | FA Cup | Millwall 3–0 Morecambe → Winner: Millwall
# Day 119 | FA Cup | Watford 4–0 Bristol Rovers → Winner: Watford
# Day 119 | FA Cup | Crystal Palace 1–0 Coventry → Winner: Crystal Palace
# Day 119 | FA Cup | Middlesbrough 1–2 West Brom → Winner: West Brom
#
# === STEP 157: Play Cup Round ===
# Day 120 | FA Cup | Shrewsbury 0–1 Chelsea → Winner: Chelsea
# Day 120 | FA Cup | Port Vale 3–1 Leeds → Winner: Port Vale
# Day 120 | FA Cup | Stoke City 2–1 Cheltenham → Winner: Stoke City
# Day 120 | FA Cup | Leicester 1–2 Manchester United → Winner: Manchester United
# Day 120 | FA Cup | Birmingham 1–2 Blackburn → Winner: Blackburn
# Day 120 | FA Cup | Manchester City 0–2 Brentford → Winner: Brentford
# Day 120 | FA Cup | Swindon Town 0–1 Rotherham → Winner: Rotherham
# Day 120 | FA Cup | Burnley 3–0 Hull City → Winner: Burnley
#
# === STEP 158: Play Cup Round ===
# Day 121 | FA Cup | Milton Keynes Dons 0–2 Nottingham Forest → Winner: Nottingham Forest
#
# === STEP 159: Update Cup Status ===
# Day 117 | FA Cup | Knocked out: Sheffield Utd → inFA = False
# Day 118 | FA Cup | Knocked out: Walsall → inFA = False
# Day 118 | FA Cup | Knocked out: Hartlepool → inFA = False
# Day 118 | FA Cup | Knocked out: Norwich → inFA = False
# Day 119 | FA Cup | Knocked out: Mansfield Town → inFA = False
# Day 119 | FA Cup | Knocked out: Lincoln → inFA = False
# Day 119 | FA Cup | Knocked out: Barnsley → inFA = False
# Day 119 | FA Cup | Knocked out: Wealdstone → inFA = False
# Day 119 | FA Cup | Knocked out: Bradford → inFA = False
# Day 119 | FA Cup | Knocked out: Brighton → inFA = False
# Day 119 | FA Cup | Knocked out: Bristol City → inFA = False
# Day 119 | FA Cup | Knocked out: Accrington ST → inFA = False
# Day 119 | FA Cup | Knocked out: Peterborough → inFA = False
# Day 119 | FA Cup | Knocked out: Bolton → inFA = False
# Day 119 | FA Cup | Knocked out: Luton → inFA = False
# Day 119 | FA Cup | Knocked out: Cardiff → inFA = False
# Day 119 | FA Cup | Knocked out: Sheffield Wednesday → inFA = False
# Day 119 | FA Cup | Knocked out: Cambridge United → inFA = False
# Day 119 | FA Cup | Knocked out: Fulham → inFA = False
# Day 119 | FA Cup | Knocked out: Morecambe → inFA = False
# Day 119 | FA Cup | Knocked out: Bristol Rovers → inFA = False
# Day 119 | FA Cup | Knocked out: Coventry → inFA = False
# Day 119 | FA Cup | Knocked out: Middlesbrough → inFA = False
# Day 120 | FA Cup | Knocked out: Shrewsbury → inFA = False
# Day 120 | FA Cup | Knocked out: Leeds → inFA = False
# Day 120 | FA Cup | Knocked out: Cheltenham → inFA = False
# Day 120 | FA Cup | Knocked out: Leicester → inFA = False
# Day 120 | FA Cup | Knocked out: Birmingham → inFA = False
# Day 120 | FA Cup | Knocked out: Manchester City → inFA = False
# Day 120 | FA Cup | Knocked out: Swindon Town → inFA = False
# Day 120 | FA Cup | Knocked out: Hull City → inFA = False
# Day 121 | FA Cup | Knocked out: Milton Keynes Dons → inFA = False
#
# === STEP 160: Draw Cup ===
#
# 🏆 FA Cup draw (16 matches) across: 2025-01-23, 2025-01-24, 2025-01-25, 2025-01-26, 2025-01-27
#   Match 01 (day 135): Arsenal vs Watford
#   Match 02 (day 136): West Brom vs Wolves
#   Match 03 (day 136): Aston Villa vs Preston
#   Match 04 (day 136): QPR vs Tottenham
#   Match 05 (day 136): Nottingham Forest vs Brentford
#   Match 06 (day 137): Ipswich vs Bournemouth
#   Match 07 (day 137): Stoke City vs Chelsea
#   Match 08 (day 137): Southampton vs Crystal Palace
#   Match 09 (day 137): Huddersfield vs Port Vale
#   Match 10 (day 137): Millwall vs Liverpool
#   Match 11 (day 137): Sunderland vs West Ham
#   Match 12 (day 138): Charlton vs Burnley
#   Match 13 (day 138): Everton vs Swansea
#   Match 14 (day 138): Rotherham vs Newcastle
#   Match 15 (day 138): Blackburn vs Manchester United
#   Match 16 (day 139): Reading vs Plymouth
#
# === STEP 161: Play League Matches ===
#
# Matches played on 2025-01-14:
# League One
# Fleetwood Town 0 - 1 Derby
# Burton Albion 3 - 0 Wycombe
# Exeter City 1 - 2 Carlisle
# Port Vale 0 - 2 Charlton
# Cheltenham 2 - 0 Portsmouth
# League Two
# Swindon Town 3 - 1 Colchester
# Salford City 2 - 1 Forest Green
# Barrow 1 - 0 Tranmere
# Mansfield Town 1 - 1 Crewe
# Bradford 2 - 0 Crawley Town
# Harrogate Town 1 - 2 Doncaster
# National League
# Dorking Wanderers 1 - 1 Oldham
# Altrincham 0 - 2 Barnet
# Ebbsfleet United 0 - 2 Wealdstone
# Maidenhead 1 - 4 Bromley
# Solihull Moors 0 - 1 Woking
# Hartlepool 2 - 0 Oxford City
# Southend 0 - 0 FC Halifax Town
# Rochdale 6 - 0 Kidderminster Harriers
# Boreham Wood 1 - 1 York
# AFC Fylde 2 - 2 Hartlepool
# Barnet 0 - 0 Dagenham & Redbridge
#
# === STEP 162: Draw Two Leg Fixture ===
#
# 🏆 League Cup Two‑Leg Draw (2 ties) across days: 122, 123, 133, 134
#   Tie 01: Leg1 (day 122) Manchester City vs Fulham; Leg2 (day 133) Fulham vs Manchester City
#   Tie 02: Leg1 (day 123) Crystal Palace vs Burnley; Leg2 (day 134) Burnley vs Crystal Palace
#
# === STEP 163: Play Two Leg Round ===
# Day 122 | League Cup Leg 1 | Manchester City 2-1 Fulham
#
# === STEP 164: Play League Matches ===
#
# Matches played on 2025-01-08:
# National League
# Chesterfield 0 - 1 Gateshead
#
# === STEP 165: Play Two Leg Round ===
# Day 123 | League Cup Leg 1 | Crystal Palace 1-1 Burnley
#
# === STEP 166: Play League Matches ===
#
# Matches played on 2025-01-10:
# Premier League
# Burnley 2 - 0 Luton
# Championship
# Hull City 1 - 3 Norwich
#
# === STEP 167: Play League Matches ===
#
# Matches played on 2025-01-11:
# Premier League
# Newcastle 0 - 2 Manchester City
# Chelsea 1 - 2 Fulham
# Championship
# Coventry 2 - 2 Leicester
# Huddersfield 2 - 0 Plymouth
# Southampton 1 - 1 Sheffield Wednesday
# Birmingham 1 - 0 Swansea
# Ipswich 1 - 1 Sunderland
# Rotherham 1 - 2 Stoke City
# Cardiff 1 - 2 Leeds
# Preston 1 - 1 Bristol City
# Millwall 1 - 1 Middlesbrough
# West Brom 0 - 1 Blackburn
# League One
# Cambridge United 1 - 0 Fleetwood Town
# Wycombe 1 - 1 Lincoln
# Blackpool 3 - 1 Exeter City
# Charlton 2 - 0 Peterborough
# Portsmouth 3 - 0 Leyton Orient
# Shrewsbury 0 - 0 Stevenage
# Northampton 0 - 2 Wigan
# Barnsley 1 - 0 Bristol Rovers
# Carlisle 4 - 3 Oxford United
# League Two
# Sutton Utd 1 - 1 Barrow
# Tranmere 0 - 1 Milton Keynes Dons
# Wrexham 3 - 1 AFC Wimbledon
# Stockport County 2 - 2 Walsall
# Forest Green 2 - 1 Harrogate Town
# Morecambe 3 - 0 Mansfield Town
# Grimsby 2 - 0 Notts County
# Crewe 0 - 1 Swindon Town
# Colchester 1 - 2 Bradford
# Accrington ST 2 - 0 Gillingham
# Doncaster 2 - 1 Newport County
# Crawley Town 1 - 1 Salford City
# National League
# Eastleigh 1 - 1 Southend
#
# === STEP 168: Play League Matches ===
#
# Matches played on 2025-01-12:
# Premier League
# Manchester United 5 - 1 Tottenham
# Everton 2 - 2 Aston Villa
# Championship
# QPR 0 - 0 Watford
#
# === STEP 169: Play League Matches ===
#
# Matches played on 2025-01-20:
# League One
# Derby 2 - 1 Burton Albion
#
# === STEP 170: Play League Matches ===
#
# Matches played on 2025-01-21:
# League One
# Barnsley 1 - 1 Carlisle
# National League
# Chesterfield 4 - 0 Altrincham
#
# === STEP 171: Play League Matches ===
#
# Matches played on 2025-01-17:
# Championship
# Sunderland 0 - 0 Hull City
#
# === STEP 172: Play League Matches ===
#
# Matches played on 2025-01-18:
# Premier League
# Brentford 2 - 0 Nottingham Forest
# Arsenal 3 - 0 Crystal Palace
# Championship
# Sheffield Wednesday 0 - 1 Coventry
# Stoke City 0 - 0 Birmingham
# QPR 2 - 4 Millwall
# Plymouth 1 - 0 Cardiff
# Middlesbrough 4 - 0 Rotherham
# Bristol City 1 - 1 Watford
# Swansea 3 - 0 Southampton
# Norwich 2 - 0 West Brom
# Blackburn 1 - 1 Huddersfield
# League One
# Wigan 1 - 1 Reading
# Bristol Rovers 2 - 1 Blackpool
# Burton Albion 0 - 0 Charlton
# Lincoln 0 - 0 Derby
# Leyton Orient 0 - 0 Bolton
# Exeter City 1 - 0 Cambridge United
# Peterborough 2 - 0 Shrewsbury
# Fleetwood Town 2 - 1 Portsmouth
# League Two
# Gillingham 1 - 4 Forest Green
# Milton Keynes Dons 2 - 1 Morecambe
# Newport County 2 - 0 Wrexham
# Barrow 3 - 1 Crewe
# National League
# Dorking Wanderers 0 - 2 Gateshead
# Kidderminster Harriers 1 - 1 Aldershot Town
# Ebbsfleet United 0 - 2 Hartlepool
# Bromley 0 - 0 Boreham Wood
#
# === STEP 173: Play League Matches ===
#
# Matches played on 2025-01-19:
# Premier League
# Sheffield Utd 0 - 1 West Ham
# Bournemouth 0 - 2 Liverpool
# Championship
# Leeds 2 - 0 Preston
#
# === STEP 174: Play League Matches ===
#
# Matches played on 2025-01-27:
# Premier League
# Brighton 1 - 2 Wolves
# Championship
# Leicester 1 - 0 Ipswich
#
# === STEP 175: Play League Matches ===
#
# Matches played on 2025-01-28:
# League One
# Wigan 3 - 0 Wycombe
# Reading 1 - 0 Derby
# Oxford United 0 - 2 Barnsley
# Charlton 2 - 0 Northampton
# Bristol Rovers 2 - 0 Exeter City
# Bolton 2 - 0 Cheltenham
# League Two
# Milton Keynes Dons 2 - 0 AFC Wimbledon
# Bradford 0 - 0 Salford City
# Mansfield Town 0 - 1 Sutton Utd
# National League
# Oldham 1 - 1 Barnet
# Chesterfield 1 - 0 Woking
# Oxford City 0 - 2 York
# AFC Fylde 3 - 1 FC Halifax Town
# Maidenhead 4 - 0 Ebbsfleet United
# Dagenham & Redbridge 4 - 0 Dorking Wanderers
# Aldershot Town 1 - 2 Bromley
# Hartlepool 4 - 0 Kidderminster Harriers
#
# === STEP 176: Play Two Leg Round ===
# Day 133 | League Cup Leg 2 | Fulham 1-1 Manchester City (agg 2-3) → Winner: Manchester City
#
# === STEP 177: Play League Matches ===
#
# Matches played on 2025-01-22:
# Championship
# Leeds 2 - 0 Norwich
# National League
# Boreham Wood 1 - 1 Eastleigh
#
# === STEP 178: Play Two Leg Round ===
# Day 134 | League Cup Leg 2 | Burnley 2-2 Crystal Palace (agg 3-3) (a.e.t. 0-0) → Winner: Burnley
#
# === STEP 179: Update Cup Status ===
# Day 133 | League Cup | Knocked out: Manchester City → inLC = False
# Day 134 | League Cup | Knocked out: Crystal Palace → inLC = False
#
# === STEP 180: Draw Cup ===
#
# 🏆 League Cup draw (1 matches) across: 2025-02-23
#   Match 01 (day 164): Fulham vs Burnley
#
# === Reached step 180. Stopped. Current pointer: 180 ===

# %% [markdown]
# ### Still in Cup

# %%
eligible_teams = dfTeams[dfTeams['inLC'] == True].copy()
print(len(eligible_teams))
pd.set_option('display.max_rows', None)
eligible_teams

# %% [markdown]
# ### Print League Tables

# %%
print_all_league_tables(league_tables, dfCompetitions)

# %%
print_euro_group_tables(8, dfTeams, dfFixtures, dfGroupStage)

# %%
clgames = dfFixtures[dfFixtures['competitionID'] == 6].copy()

# %%
pd.set_option('display.max_rows', None)
print(len(clgames))
clgames
