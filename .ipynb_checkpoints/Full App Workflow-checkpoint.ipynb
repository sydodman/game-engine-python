# %% [markdown]
# ### Installations

# %%
# !pip install holidays
# Out:
# Requirement already satisfied: holidays in c:\users\sdodman-local\anaconda3\lib\site-packages (0.73)
# Requirement already satisfied: python-dateutil in c:\users\sdodman-local\anaconda3\lib\site-packages (from holidays) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sdodman-local\appdata\roaming\python\python39\site-packages (from python-dateutil->holidays) (1.12.0)

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import calendar
from datetime import date, timedelta
import matplotlib.pyplot as plt
import argparse

try:
    import holidays
except ImportError:
    raise ImportError("Please install the 'holidays' library: pip install holidays")

# %% [markdown]
# ### Load Templates

# %%
dfFixtures_template = pd.read_csv('Input/fixtureTable.csv', dayfirst=True, parse_dates=['date'])  # unshifted
dfTeams_base = pd.read_csv('Input/teamTable.csv')            # no attributes
dfCompetitions = pd.read_csv('Input/competitionTable.csv')

# %% [markdown]
# ### Helper Functions for Date Shift

# %%
import pandas as pd
import calendar
from datetime import date
from typing import Optional
import holidays

# -----------------------------------------------------------------------------
# 1. Initialize UK Holiday Engine (Dynamic Year Support)
# -----------------------------------------------------------------------------
def get_uk_holiday_name(dt: date) -> Optional[str]:
    return holidays.UK(years=dt.year).get(dt)

def find_holiday_date_by_name(target_year: int, holiday_name: str) -> Optional[date]:
    """
    Look up the date of a holiday in the target year by its name.
    """
    target_holidays = holidays.UK(years=target_year)
    for dt, name in target_holidays.items():
        if name == holiday_name:
            return dt
    return None


# -----------------------------------------------------------------------------
# 2. Weekday Ordinal Preservation Logic
# -----------------------------------------------------------------------------
def get_ordinal_weekday(dt: date) -> int:
    """Return the 1-based occurrence of dt.weekday() in dt.month."""
    month_cal = calendar.monthcalendar(dt.year, dt.month)
    weekday = dt.weekday()
    occurrences = [week[weekday] for week in month_cal if week[weekday] != 0]
    for i, day in enumerate(occurrences, start=1):
        if day == dt.day:
            return i
    raise ValueError(f"Could not determine ordinal for date {dt}")


def find_nth_weekday(year: int, month: int, weekday: int, ordinal: int) -> date:
    """Find the date of the ordinal-th weekday in the given month/year."""
    month_cal = calendar.monthcalendar(year, month)
    occurrences = [week[weekday] for week in month_cal if week[weekday] != 0]
    if not occurrences:
        raise ValueError(f"No occurrences of weekday {weekday} in {month}/{year}")
    if ordinal <= len(occurrences):
        day = occurrences[ordinal - 1]
    else:
        day = occurrences[-1]
    return date(year, month, day)


# -----------------------------------------------------------------------------
# 3. Shift Logic with Holiday + Weekday Ordinal Fallback
# -----------------------------------------------------------------------------
def shift_fixture_date(original_date: date, target_year: int) -> date:
    """
    Shift a single date into target_year, preserving bank holidays and weekday ordinals.
    """
    orig_holiday = get_uk_holiday_name(original_date)
    if orig_holiday:
        holiday_match = find_holiday_date_by_name(target_year, orig_holiday)
        if holiday_match:
            return holiday_match

    ordinal = get_ordinal_weekday(original_date)
    return find_nth_weekday(
        target_year,
        original_date.month,
        original_date.weekday(),
        ordinal
    )


# -----------------------------------------------------------------------------
# 4. Rebase Fixture Dates
# -----------------------------------------------------------------------------
def rebase_fixtures(df: pd.DataFrame, target_start_year: int) -> pd.DataFrame:
    """
    Rebase fixture dates in `df` to a new season starting in `target_start_year`.
    """
    df_new = df.copy()
    if 'round' in df_new.columns:
        df_new.drop(columns=['round'], inplace=True)

    df_new['date'] = pd.to_datetime(df_new['date'], errors='coerce')
    original_start_year = int(df_new['date'].dt.year.min())

    def _shift(ts):
        if pd.isna(ts):
            return pd.NaT
        orig = ts.date()
        year_offset = orig.year - original_start_year
        new_year = target_start_year + year_offset
        return shift_fixture_date(orig, new_year)

    df_new['date'] = df_new['date'].apply(_shift)
    df_new['date'] = df_new['date'].apply(
        lambda d: d.strftime('%Y-%m-%d') if pd.notna(d) else pd.NaT
    )

    return df_new

# -----------------------------------------------------------------------------
# 5. Entry Point: Fixture Creation for a Season
# -----------------------------------------------------------------------------
def create_fixture_list(year: int) -> pd.DataFrame:
    """Create rebased fixture list for a new season."""
    return rebase_fixtures(dfFixtures_template.copy(), year)

# %% [markdown]
# ### Helper Functions for Team Attributes

# %%
import pandas as pd
import random

def position_to_attribute(pos: int, min_val: float, max_val: float, min_rank: int, max_rank: int, ascending=True) -> float:
    """
    Linearly scale attribute from min_val to max_val over [min_rank, max_rank].
    If ascending=False, scales from max_val to min_val instead.
    """
    pos = max(min_rank, min(pos, max_rank))
    scale = (pos - min_rank) / (max_rank - min_rank) if max_rank > min_rank else 0
    if not ascending:
        scale = 1.0 - scale
    return round(min_val + (max_val - min_val) * scale, 2)


def assign_team_attributes(df: pd.DataFrame, seed: int = None) -> pd.DataFrame:
    """
    Assigns 'defense', 'midfield', and 'attack' attributes based on 'lastPos'.
    """
    rng = random.Random(seed)
    df_out = df.copy()

    def compute_attributes(row):
        pos = row['lastPos']
        if 1 <= pos <= 116:
            base = position_to_attribute(pos, min_val=1.0, max_val=8.5, min_rank=1, max_rank=116, ascending=False)
            variation = 0.75
        elif 117 <= pos <= 120:
            base = position_to_attribute(pos, min_val=6.0, max_val=8.0, min_rank=117, max_rank=120, ascending=True)
            variation = 0.5
        elif 121 <= pos <= 124:
            base = position_to_attribute(pos, min_val=7.0, max_val=9.0, min_rank=121, max_rank=124, ascending=True)
            variation = 0.5
        else:
            base = 5.0
            variation = 0.5

        return {
            'defense': round(base + rng.uniform(-variation, variation), 2),
            'midfield': round(base + rng.uniform(-variation, variation), 2),
            'attack': round(base + rng.uniform(-variation, variation), 2)
        }

    attributes = df_out.apply(compute_attributes, axis=1, result_type='expand')
    df_out[['defense', 'midfield', 'attack']] = attributes
    return df_out

def generate_team_attributes() -> pd.DataFrame:
    """Generate team attributes from base lastPos table."""
    return assign_team_attributes(dfTeams_base.copy())

# %% [markdown]
# ### Match Engine

# %%
import pandas as pd
import random
from typing import Tuple

def rnd_num() -> float:
    """Return a random number between 0 and 1."""
    return random.uniform(0, 1)

def goal_chance() -> int:
    """40% chance to score a goal."""
    return 1 if rnd_num() > 0.6 else 0

def get_team_attributes(team_id: int, df: pd.DataFrame) -> list:
    """Get defense, midfield, attack as a list for given team ID."""
    row = df.loc[df['teamID'] == team_id]
    if row.empty:
        raise ValueError(f"Team ID {team_id} not found in dataframe.")
    return [row.iloc[0]['defense'], row.iloc[0]['midfield'], row.iloc[0]['attack']]

def play_match_half(team1: list, team2: list) -> list:
    """
    Simulates one half of a football match between two teams.
    Each team is a list of 3 attributes: [def, mid, att]
    """
    match_seq = list(range(1, 13))
    random.shuffle(match_seq)

    result = [0, 0]  # [home_goals, away_goals]

    for index in range(1, 11):
        if match_seq[0] == index and team1[2] > team2[0] and (random.random() * team1[2]) > (random.random() * team2[0]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[6] == index and (random.random() * team1[2]) > (random.random() * team2[0]) and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[1] == index and team2[2] > team1[0] and (random.random() * team2[2]) > (random.random() * team1[0]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[7] == index and (random.random() * team1[2]) > (random.random() * team1[0]) and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[2] == index and team1[1] > team2[1] and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[8] == index and (random.random() * team1[1]) > (random.random() * team2[1]):
            result[0] += 1 if random.random() > 0.6 else 0
        elif match_seq[3] == index and team2[1] > team1[1] and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[9] == index and (random.random() * team2[1]) > (random.random() * team1[1]):
            result[1] += 1 if random.random() > 0.6 else 0
        elif match_seq[4] == index and random.random() > 0.45:
            result[0] += 1 if random.random() > 0.6 else 0

    return result

def play_full_match(team1_id: int, team2_id: int, df: pd.DataFrame) -> list:
    """
    Play a full match between two teams and return the result [goals_team1, goals_team2].
    """
    team1 = get_team_attributes(team1_id, df)
    team2 = get_team_attributes(team2_id, df)

    first_half = play_match_half(team1, team2)
    second_half = play_match_half(team1, team2)

    final_result = [first_half[0] + second_half[0], first_half[1] + second_half[1]]
    return final_result

import random

def simulate_penalties(home_team_id: int, away_team_id: int, dfTeams) -> tuple:
    """
    Run a simple 5‐kick penalty shootout for each team, then sudden death if still tied.
    Returns: (home_pk_goals, away_pk_goals, winner_id).
    """
    # Get [defense, midfield, attack] for each side
    attrs_home = get_team_attributes(home_team_id, dfTeams)  # → list [def, mid, att]
    attrs_away = get_team_attributes(away_team_id, dfTeams)

    # Use 'attack' at index 2, and 'defense' at index 0
    home_att = attrs_home[2]
    home_def = attrs_home[0]
    away_att = attrs_away[2]
    away_def = attrs_away[0]

    # Base penalty conversion probability: blend of home_att vs away_def
    base_prob_home = 0.8 * (home_att / (home_att + away_def)) + 0.2
    base_prob_away = 0.8 * (away_att / (away_att + home_def)) + 0.2

    # Clamp between [0.5, 0.95]
    base_prob_home = min(max(base_prob_home, 0.5), 0.95)
    base_prob_away = min(max(base_prob_away, 0.5), 0.95)

    def take_five_kicks(p_success: float) -> int:
        """Simulate exactly 5 penalty kicks given success probability p_success."""
        made = 0
        for _ in range(5):
            if random.random() < p_success:
                made += 1
        return made

    # 1) First 5 kicks each
    home_score = take_five_kicks(base_prob_home)
    away_score = take_five_kicks(base_prob_away)

    # 2) Sudden death if still tied
    while home_score == away_score:
        if random.random() < base_prob_home:
            home_score += 1
        if random.random() < base_prob_away:
            away_score += 1
        # repeat until one is ahead

    winner_id = home_team_id if home_score > away_score else away_team_id
    return home_score, away_score, winner_id

def play_cup_match(home_team_id: int, away_team_id: int, dfTeams):
    """
    Simulate a single cup tie:
      1) Play 90′ via play_full_match(...)
      2) If draw, run one “extra‐time half” via play_match_half(...)
      3) If still draw, run penalties via simulate_penalties(...)
    Returns a dict with:
      - home_goals (FT + ET)
      - away_goals (FT + ET)
      - winner_id
      - extra_time_played (bool)
      - home_et_goals, away_et_goals (ints; zero if no ET)
      - home_pk, away_pk (ints; None if no shootout)
    """
    # 1) Full‐time (90′)
    home_ft, away_ft = play_full_match(home_team_id, away_team_id, dfTeams)

    # If someone wins in 90′, skip ET/PK
    if home_ft != away_ft:
        winner = home_team_id if home_ft > away_ft else away_team_id
        return {
            "home_goals": home_ft,
            "away_goals": away_ft,
            "winner_id":  winner,
            "extra_time_played": False,
            "home_et_goals": 0,
            "away_et_goals": 0,
            "home_pk":      None,
            "away_pk":      None
        }

    # 2) Extra‐time: simulate one “half” of 45′ via play_match_half(...)
    # (This effectively approximates a 30′ ET; you can adjust scaling later if needed.)
    et_home, et_away = play_match_half(
        get_team_attributes(home_team_id, dfTeams),
        get_team_attributes(away_team_id, dfTeams)
    )
    home_total = home_ft + et_home
    away_total = away_ft + et_away

    # If someone wins in ET, skip penalties
    if home_total != away_total:
        winner = home_team_id if home_total > away_total else away_team_id
        return {
            "home_goals": home_total,
            "away_goals": away_total,
            "winner_id":  winner,
            "extra_time_played": True,
            "home_et_goals":  et_home,
            "away_et_goals":  et_away,
            "home_pk":       None,
            "away_pk":       None
        }

    # 3) Penalty shootout
    home_pk, away_pk, winner = simulate_penalties(home_team_id, away_team_id, dfTeams)
    return {
        "home_goals": home_total,
        "away_goals": away_total,
        "winner_id":  winner,
        "extra_time_played": True,
        "home_et_goals":  et_home,
        "away_et_goals":  et_away,
        "home_pk":       home_pk,
        "away_pk":       away_pk
    }

# %% [markdown]
# ### Helper Function to Initialise Cup Status

# %%
import random

def initialize_cup_status(dfTeams):
    """
    Reset and set initial cup‐eligibility flags based on last season’s results:
      - inCS: Community Shield (league winner & FA Cup winner)
      - inCL: Champions League (top‐4 English, CL winner override; plus direct qualifiers lastPos ∈ {121–124})
      - inEL: Europa League (4 English slots: FA & LC winners + next best by position; 
                             plus direct qualifiers lastPos ∈ {117–120})
      - inFA: FA Cup R1 (teamID 45–92 direct; + 32 random from teamID 93–134)
      - inLC: League Cup (teamID 21–92)
    """
    # 0) Ensure lastPos is integer
    dfTeams['lastPos'] = dfTeams['lastPos'].astype(int)

    # 1) Reset all flags
    for col in ['inCS','inCL','inEL','inFA','inLC']:
        dfTeams[col] = False

    # 2) Community Shield: English league winner & FA Cup winner
    cs_mask = (
        (dfTeams['nationality']=='ENG') &
        ((dfTeams['lastPos']==1) | (dfTeams['faCupWin']==True))
    )
    dfTeams.loc[cs_mask, 'inCS'] = True

    # 3) Champions League (English slots)
    eng = dfTeams['nationality']=='ENG'
    cl_winner = dfTeams[eng & (dfTeams['clCupWin']==True)]
    if not cl_winner.empty:
        wid = cl_winner['teamID'].iat[0]
        dfTeams.loc[dfTeams['teamID']==wid, 'inCL'] = True
        others = dfTeams[eng & (dfTeams['teamID']!=wid)].nsmallest(3, 'lastPos')
        dfTeams.loc[others.index, 'inCL'] = True
    else:
        top4 = dfTeams[eng].nsmallest(4, 'lastPos')
        dfTeams.loc[top4.index, 'inCL'] = True
    # 3b) Direct CL qualifiers by lastPos codes 121–124
    dfTeams.loc[dfTeams['lastPos'].isin([121,122,123,124]), 'inCL'] = True

    # 4) Europa League (English slots)
    el_winners = dfTeams[
        eng &
        ((dfTeams['faCupWin']==True) | (dfTeams['lcCupWin']==True)) &
        (~dfTeams['inCL'])
    ]['teamID'].tolist()
    dfTeams.loc[dfTeams['teamID'].isin(el_winners), 'inEL'] = True

    # 4b) Top-up English EL slots to 4 by best lastPos among ENG not inCL/EL
    curr = dfTeams[(eng) & (dfTeams['inEL']==True)].shape[0]
    if curr < 4:
        needed = 4 - curr
        fill = dfTeams[
            eng & (~dfTeams['inCL']) & (~dfTeams['inEL'])
        ].nsmallest(needed, 'lastPos')
        dfTeams.loc[fill.index, 'inEL'] = True

    # 4c) Direct EL qualifiers by lastPos codes 117–120
    dfTeams.loc[dfTeams['lastPos'].isin([117,118,119,120]), 'inEL'] = True

    # 5) FA Cup R1: teamID 45–92 direct + random 32 from teamID 93–134
    direct_ids = dfTeams.loc[dfTeams['teamID'].between(45, 92), 'teamID'].tolist()
    pool_ids   = dfTeams.loc[dfTeams['teamID'].between(93, 134), 'teamID'].tolist()
    if len(pool_ids) < 32:
        raise ValueError(f"Not enough teams in 93–134 to pick 32; found {len(pool_ids)}")
    fa_qual = random.sample(pool_ids, 32)
    dfTeams.loc[dfTeams['teamID'].isin(direct_ids + fa_qual), 'inFA'] = True

    # 6) League Cup: teamID 21–92
    dfTeams.loc[dfTeams['teamID'].between(21, 92), 'inLC'] = True

    # 7) Summary
    print("✅ Initialized cup status:")
    print(f"  inCS: {dfTeams['inCS'].sum()} teams")
    print(f"  inCL: {dfTeams['inCL'].sum()} teams")
    print(f"  inEL: {dfTeams['inEL'].sum()} teams")
    print(f"  inFA: {dfTeams['inFA'].sum()} teams")
    print(f"  inLC: {dfTeams['inLC'].sum()} teams")

    return dfTeams

# %% [markdown]
# ### Helper Functions for League Round

# %%
def play_league_round(day: int,
                      dfFixtures: pd.DataFrame,
                      dfTeams: pd.DataFrame,
                      dfCompetitions: pd.DataFrame,
                      dfGroupStage: pd.DataFrame = None) -> pd.DataFrame:
    """
    Plays all league‐style fixtures (domestic + UCL/EL group‐stage) for a given dayCounter,
    updates dfFixtures in‐place, prints results by competition, then:
      1) Recompute domestic tables (comps 1–5)
      2) If dfGroupStage is provided and EL (8) matches were played, recompute EL tables
      3) If dfGroupStage is provided and UCL (9) matches were played, recompute UCL tables
    """

    # 1) Build a “not played” mask treating NaN as False
    not_played_mask = ~dfFixtures['played'].fillna(False)

    # 2) Include domestic (1–5), EL (8), UCL (9)
    valid_comp_ids = [1, 2, 3, 4, 5, 8, 9]

    day_fixtures = dfFixtures[
        (dfFixtures['dayCounter'] == day) &
        (not_played_mask) &
        (dfFixtures['competitionID'].isin(valid_comp_ids))
    ].copy()

    if day_fixtures.empty:
        print(f"No league/group‐stage fixtures scheduled or all already played for day {day}.")
        return dfFixtures

    # 3) Build lookup maps
    team_name_map = dfTeams.set_index('teamID')['teamName'].to_dict()
    comp_name_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    results_by_comp = {}
    match_date = day_fixtures.iloc[0]['date']

    # Track which competitions had a match today
    comps_played_today = set()

    for idx, match in day_fixtures.iterrows():
        home_id = match['homeTeam']
        away_id = match['awayTeam']
        comp_id = match['competitionID']

        # Simulate 90' only
        home_goals, away_goals = play_full_match(home_id, away_id, dfTeams)

        # Update dfFixtures
        dfFixtures.at[idx, 'homeGoals'] = home_goals
        dfFixtures.at[idx, 'awayGoals'] = away_goals
        dfFixtures.at[idx, 'played'] = True

        comps_played_today.add(comp_id)

        # Format for printing
        home_name = team_name_map.get(home_id, f"Team{home_id}")
        away_name = team_name_map.get(away_id, f"Team{away_id}")
        comp_name = comp_name_map.get(comp_id, f"Competition{comp_id}")
        line = f"{home_name} {home_goals} - {away_goals} {away_name}"
        results_by_comp.setdefault(comp_id, []).append(line)

    # 4) Print results sorted by competitionID
    print(f"\nMatches played on {match_date}:")
    for comp_id in sorted(results_by_comp.keys()):
        comp_name = comp_name_map.get(comp_id, f"Competition{comp_id}")
        print(comp_name)
        for line in results_by_comp[comp_id]:
            print(line)

    # 5) Recompute domestic league tables (1–5)
    update_tables()

    # 6) If dfGroupStage is provided, update EL/UCL group tables as needed
    if dfGroupStage is not None:
        # Europa League (comp 8)
        if 8 in comps_played_today:
            global el_tables
            el_tables = generate_euro_group_tables(
                competitionID=8,
                dfFixtures=dfFixtures,
                dfTeams=dfTeams,
                dfGroupStage=dfGroupStage
            )
         
        # Champions League (comp 9)
        if 9 in comps_played_today:
            global ucl_tables
            ucl_tables = generate_euro_group_tables(
                competitionID=9,
                dfFixtures=dfFixtures,
                dfTeams=dfTeams,
                dfGroupStage=dfGroupStage
            )
          
    return dfFixtures

# %% [markdown]
# ### Helper Functions for League Tables

# %%
def generate_league_tables(dfFixtures: pd.DataFrame, dfTeams: pd.DataFrame) -> dict:
    """
    Generate league tables for CompetitionIDs 1 to 5, ensuring all teams are included even if they haven't played.
    Removes teamID and formats GF, GA, GD as integers.

    Returns:
        Dictionary {competitionID: league_table_df}
    """
    league_tables = {}

    for comp_id in range(1, 6):
        # Get all teams in this competition (home and away)
        teams_in_league = pd.unique(
            dfFixtures[dfFixtures['competitionID'] == comp_id][['homeTeam', 'awayTeam']].values.ravel()
        )

        # Initialize stats
        team_stats = {
            team_id: {'MP': 0, 'W': 0, 'D': 0, 'L': 0, 'GF': 0, 'GA': 0, 'Points': 0}
            for team_id in teams_in_league
        }

        # Played matches only
        league_matches = dfFixtures[
            (dfFixtures['competitionID'] == comp_id) & (dfFixtures['played'])
        ]

        # Accumulate stats
        for _, match in league_matches.iterrows():
            h_id, a_id = match['homeTeam'], match['awayTeam']
            hg, ag = match['homeGoals'], match['awayGoals']

            # Home update
            team_stats[h_id]['MP'] += 1
            team_stats[h_id]['GF'] += hg
            team_stats[h_id]['GA'] += ag
            # Away update
            team_stats[a_id]['MP'] += 1
            team_stats[a_id]['GF'] += ag
            team_stats[a_id]['GA'] += hg

            if hg > ag:
                team_stats[h_id]['W'] += 1
                team_stats[h_id]['Points'] += 3
                team_stats[a_id]['L'] += 1
            elif hg == ag:
                team_stats[h_id]['D'] += 1
                team_stats[a_id]['D'] += 1
                team_stats[h_id]['Points'] += 1
                team_stats[a_id]['Points'] += 1
            else:
                team_stats[a_id]['W'] += 1
                team_stats[a_id]['Points'] += 3
                team_stats[h_id]['L'] += 1

        # Build rows
        rows = []
        for team_id in teams_in_league:
            stats = team_stats[team_id]
            team_name = dfTeams.loc[dfTeams['teamID'] == team_id, 'teamName'].values[0]
            gd = stats['GF'] - stats['GA']
            rows.append({
                'teamName': team_name,
                'MP': stats['MP'],
                'W': stats['W'],
                'D': stats['D'],
                'L': stats['L'],
                'GF': int(round(stats['GF'])),
                'GA': int(round(stats['GA'])),
                'GD': int(round(gd)),
                'Points': stats['Points']
            })

        league_df = pd.DataFrame(rows)
        league_df = league_df.sort_values(by=['Points', 'GD', 'GF'], ascending=False).reset_index(drop=True)
        league_df.insert(0, 'Position', league_df.index + 1)

        league_tables[comp_id] = league_df

    return league_tables


def print_all_league_tables(league_tables: dict, dfCompetitions: pd.DataFrame):
    """
    Pretty print all league tables with their competition names as headers.

    Parameters:
        league_tables: Dict {competitionID: league DataFrame}
        dfCompetitions: DataFrame containing competitionID and competitionName
    """
    # Build a mapping from competitionID to name
    comp_name_map = dfCompetitions.set_index('competitionID')['competitionName'].to_dict()

    for comp_id in sorted(league_tables.keys()):
        table = league_tables[comp_id]
        comp_name = comp_name_map.get(comp_id, f"Competition {comp_id}")

        print(f"\n{comp_name}")
        print(table.to_string(index=False))

# %% [markdown]
# ### Helper Functions for Cup Rounds

# %%
def play_cup_round(dayCounter, competitionID, dfFixtures, dfTeams):
    """
    Simulate every unplayed cup fixture on each day in 'dayCounter' for competitionID,
    writing the following into dfFixtures for each match:
      - homeGoals, awayGoals: total goals after 90' + ET (if any)
      - homeGoalsAET, awayGoalsAET: extra‐time goals
      - homePens, awayPens: penalty goals (None if no shootout)
      - played: True once done
    Prints a summary including “(a.e.t.)” or “[p x–y]” as needed.
    """
    # 1) Look up competition name (uses global dfCompetitions)
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == competitionID,
        'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

    # 2) Parse dayCounter into a list of ints
    if isinstance(dayCounter, str):
        days = [int(x.strip()) for x in dayCounter.split(',') if x.strip().isdigit()]
    elif isinstance(dayCounter, (list, tuple)):
        days = [int(x) for x in dayCounter]
    else:
        days = [int(dayCounter)]

    all_winners = []
    for day in days:
        # 3) Filter for unplayed cup fixtures on this day & competition
        mask = (
            (dfFixtures['dayCounter']   == day) &
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['played']        == False)
        )
        todays_matches = dfFixtures.loc[mask].copy()
        if todays_matches.empty:
            print(f"No fixtures to play on day {day} for '{comp_name}'")
            continue

        for idx, match in todays_matches.iterrows():
            # skip any blank placeholder
            if pd.isna(match['homeTeam']) or pd.isna(match['awayTeam']):
                print(f"❌ Skipping empty slot on day {day} for '{comp_name}' at index {idx}")
                continue

            home_id = int(match['homeTeam'])
            away_id = int(match['awayTeam'])

            # Simulate 90′ + ET + penalties
            result = play_cup_match(home_id, away_id, dfTeams)
            all_winners.append(result['winner_id'])

            # 4) Write results back into dfFixtures
            dfFixtures.at[idx, 'homeGoals']     = result['home_goals']
            dfFixtures.at[idx, 'awayGoals']     = result['away_goals']
            dfFixtures.at[idx, 'homeGoalsAET']  = result['home_et_goals']
            dfFixtures.at[idx, 'awayGoalsAET']  = result['away_et_goals']
            dfFixtures.at[idx, 'homePens']      = result['home_pk']
            dfFixtures.at[idx, 'awayPens']      = result['away_pk']
            dfFixtures.at[idx, 'played']        = True

            # 5) Print summary line
            home_name   = dfTeams.loc[dfTeams['teamID']==home_id, 'teamName'].iat[0]
            away_name   = dfTeams.loc[dfTeams['teamID']==away_id, 'teamName'].iat[0]
            winner_name = dfTeams.loc[dfTeams['teamID']==result['winner_id'], 'teamName'].iat[0]

            suffix = ""
            if result['extra_time_played']:
                suffix += " (a.e.t.)"
            if result['home_pk'] is not None and result['away_pk'] is not None:
                suffix += f" [p {result['home_pk']}–{result['away_pk']}]"

            print(
                f"Day {day} | {comp_name} | "
                f"{home_name} {result['home_goals']}–{result['away_goals']} {away_name}"
                f"{suffix} → Winner: {winner_name}"
            )

    return all_winners

# %% [markdown]
# ### Generic Cup Draw

# %%
import random

def draw_cup(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic cup‐draw function for:
      • Community Shield   (competitionID=10, flag 'inCS', exactly 2 teams)
      • League Cup         (competitionID=6,  flag 'inLC', even-numbered field)
      • FA Cup Round 1     (competitionID=7,  flag 'inFA', even-numbered field)
      • Europa League KO   (competitionID=8,  flag 'inEL', even-numbered field)
      • Champions League KO(competitionID=9,  flag 'inCL', even-numbered field)

    Assumes dfTeams['inXX'] flags have already been set for that competition.
    1) Read comp_id, look up its flag column.
    2) Select all dfTeams where that flag is True.
       • If comp_id == 10, require exactly 2.
       • Otherwise require an even number.
    3) Shuffle and pair off in order.
    4) Parse allowed_days from row['dayCounter'] (comma-sep ints).
    5) In dfFixtures, find blank fixtures for this comp on those days:
       competitionID == comp_id, dayCounter ∈ allowed_days,
       homeTeam/isnull & awayTeam/isnull.
    6) Fill the first N placeholders with your pairs.
    7) Print a summary.
    """
    comp_id = int(row['competitionID'])
    comp_name = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id, 'competitionName'
    ].iat[0]

    # 1) Hard-coded mapping of competition → which inXX column to use
    comp_flag_map = {
        10: 'inCS',
        6: 'inLC',
        7: 'inFA',
        8: 'inEL',
        9: 'inCL'
    }
    if comp_id not in comp_flag_map:
        print(f"❌ No cup-draw configured for competitionID {comp_id}")
        return
    flag_col = comp_flag_map[comp_id]

    # 2) Gather eligible teams
    eligible = dfTeams[dfTeams[flag_col] == True].copy()
    n = len(eligible)
    if comp_id == 10:
        if n != 2:
            print(f"❌ Error: Community Shield needs 2 teams, found {n}")
            return
    else:
        if n % 2 != 0:
            print(f"❌ Error: {comp_name} needs an even number of teams, found {n}")
            return

    # 3) Shuffle and pair
    team_ids = eligible['teamID'].tolist()
    random.shuffle(team_ids)
    pairs = [(team_ids[i], team_ids[i+1]) for i in range(0, len(team_ids), 2)]

    # 4) Parse allowed_days
    allowed_days = [
        int(d.strip()) for d in str(row['dayCounter']).split(',')
        if d.strip().isdigit()
    ]
    if not allowed_days:
        print(f"❌ Error: No valid dayCounters provided for {comp_name}")
        return

    # 5) Find blank fixtures
    mask = (
        (dfFixtures['competitionID'] == comp_id) &
        (dfFixtures['dayCounter'].isin(allowed_days)) &
        (dfFixtures['homeTeam'].isnull()) &
        (dfFixtures['awayTeam'].isnull())
    )
    open_fx = dfFixtures.loc[mask]
    if len(open_fx) < len(pairs):
        print(f"❌ Error: Not enough blank fixtures for {comp_name}: "
              f"needed {len(pairs)}, found {len(open_fx)}")
        return

    # 6) Fill placeholders
    for (home_tid, away_tid), idx in zip(pairs, open_fx.index):
        dfFixtures.at[idx, 'homeTeam'] = home_tid
        dfFixtures.at[idx, 'awayTeam'] = away_tid

    # 7) Print summary
    dates = dfFixtures.loc[open_fx.index[:len(pairs)], 'date'].unique().tolist()
    print(f"\n🏆 {comp_name} draw ({len(pairs)} matches) across: {', '.join(dates)}")
    for i, (home_tid, away_tid) in enumerate(pairs, 1):
        home_name = dfTeams.loc[dfTeams['teamID'] == home_tid, 'teamName'].iat[0]
        away_name = dfTeams.loc[dfTeams['teamID'] == away_tid, 'teamName'].iat[0]
        dayc = dfFixtures.at[open_fx.index[i-1], 'dayCounter']
        print(f"  Match {i:02d} (day {dayc}): {home_name} vs {away_name}")

    # commit back
    globals()['dfFixtures'] = dfFixtures

# %% [markdown]
# ### European Helper Functions

# %%
import random
import pandas as pd

def draw_euro_group_stage(row, dfTeams, dfFixtures, dfCompetitions):
    """
    Generic draw for European group stages (UCL or EL), but now appends to a global dfGroupStage
    instead of overwriting it. This means you can call it twice (once for competitionID=9, once
    for competitionID=8) and keep both sets of group assignments.

    Expects:
      - row['competitionID'] ∈ {9 (UCL), 8 (EL)}
      - row['dayCounter']  = comma-separated string of 12 ints (for UCL) or 6 ints (for EL)
      - dfTeams, dfFixtures, dfCompetitions already in scope

    After this runs, global dfGroupStage will contain rows:
      competitionID | teamID | groupID
    for all previously‐drawn competitions (8 and/or 9), plus this new draw.
    """

    # 1) Parse dayCounters
    raw = row['dayCounter']
    if isinstance(raw, str):
        date_list = [int(x.strip()) for x in raw.split(',') if x.strip().isdigit()]
    else:
        try:
            date_list = list(raw)
        except:
            date_list = [int(raw)]

    comp_id = int(row['competitionID'])
    comp_row = dfCompetitions.loc[
        dfCompetitions['competitionID'] == comp_id, 'competitionName'
    ]
    comp_name = comp_row.values[0] if not comp_row.empty else f"Competition{comp_id}"

    # 2) Determine flag column and expected number of dayCounters
    if comp_id == 9:    # UCL
        expected = 12
        flag_col = 'inCL'
    elif comp_id == 8:  # EL
        expected = 6
        flag_col = 'inEL'
    else:
        raise ValueError(f"CompetitionID {comp_id} is not UCL (9) or EL (8).")

    if len(date_list) != expected:
        raise ValueError(f"{comp_name} requires {expected} dayCounters, got {len(date_list)}.")

    # 3) Select exactly 32 teams still in the competition
    euro_teams = dfTeams.loc[dfTeams[flag_col] == True, ['teamID', 'nationality']].to_dict(orient='records')
    if len(euro_teams) != 32:
        raise ValueError(f"Expected 32 teams where {flag_col}==True, found {len(euro_teams)}.")

    # 4) Assign to 8 groups of 4 with unique nationality constraint
    def attempt_grouping():
        random.shuffle(euro_teams)
        groups = {gid: [] for gid in range(1, 9)}
        for team in euro_teams:
            placed = False
            order = list(groups.keys())
            random.shuffle(order)
            for gid in order:
                if len(groups[gid]) < 4:
                    existing_nats = {t['nationality'] for t in groups[gid]}
                    if team['nationality'] not in existing_nats:
                        groups[gid].append(team)
                        placed = True
                        break
            if not placed:
                return None
        return groups

    groups = None
    for _ in range(1000):
        groups = attempt_grouping()
        if groups is not None:
            break
    if groups is None:
        raise RuntimeError("Failed to assign teams into nationality‐unique groups after many tries.")

    # 5) Build a DataFrame for this draw (comp_id, teamID, groupID)
    new_group_rows = [
        {'competitionID': comp_id, 'teamID': t['teamID'], 'groupID': gid}
        for gid, members in groups.items()
        for t in members
    ]
    new_df = pd.DataFrame(new_group_rows)

    # 6) Append to global dfGroupStage (dropping any old rows for the same comp_id)
    global dfGroupStage
    try:
        # If dfGroupStage already exists, remove any rows for this comp_id, then append
        dfGroupStage = dfGroupStage[ dfGroupStage['competitionID'] != comp_id ].copy()
        dfGroupStage = pd.concat([dfGroupStage, new_df], ignore_index=True)
    except NameError:
        # dfGroupStage doesn't exist yet; just create it
        dfGroupStage = new_df.copy()

    # 7) Fill placeholders in dfFixtures for matchups (same as before)
    def single_round_robin(team_ids):
        teams = list(team_ids)
        n = len(teams)  # 4
        rounds = []
        for _ in range(n - 1):  # 3 rounds
            pairings = []
            for j in range(n // 2):
                t1 = teams[j]
                t2 = teams[n - 1 - j]
                pairings.append((t1, t2))
            rounds.append(pairings)
            teams = [teams[0]] + [teams[-1]] + teams[1:-1]
        return rounds

    group_schedules = {}
    for gid, members in groups.items():
        tids = [t['teamID'] for t in members]
        first = single_round_robin(tids)
        second = [[(away, home) for (home, away) in rnd] for rnd in first]
        full = first + second  # 6 total rounds
        group_schedules[gid] = full

    # 8) Populate existing dfFixtures placeholders:
    for rnd_idx in range(6):
        if comp_id == 9:
            # UCL: two dayCounters per round
            dc_1_4 = date_list[2 * rnd_idx]
            dc_5_8 = date_list[2 * rnd_idx + 1]
        else:
            # EL: single dayCounter per round
            dc_all = date_list[rnd_idx]

        for gid, schedule in group_schedules.items():
            match_pairs = schedule[rnd_idx]  # two (home,away) pairs
            dc = (dc_1_4 if gid <= 4 else dc_5_8) if comp_id == 9 else dc_all

            placeholder_mask = (
                (dfFixtures['competitionID'] == comp_id) &
                (dfFixtures['dayCounter']     == dc) &
                (dfFixtures['homeTeam'].isna()) &
                (dfFixtures['awayTeam'].isna())
            )
            placeholders = dfFixtures.loc[placeholder_mask]
            needed = len(match_pairs)
            if len(placeholders) < needed:
                raise RuntimeError(
                    f"Not enough placeholder rows for {comp_name} on day {dc}: "
                    f"needed {needed}, found {len(placeholders)}"
                )

            indices = placeholders.index.tolist()[:needed]
            for idx, (home_tid, away_tid) in zip(indices, match_pairs):
                dfFixtures.at[idx, 'homeTeam'] = home_tid
                dfFixtures.at[idx, 'awayTeam'] = away_tid
                dfFixtures.at[idx, 'round']    = rnd_idx + 1

    # 9) Print out group composition (for just this competition)
    print(f"\nPopulated {comp_name} Group Stage (competitionID={comp_id}):")
    for gid, members in groups.items():
        names = [
            dfTeams.loc[dfTeams['teamID'] == t['teamID'], 'teamName'].values[0]
            for t in members
        ]
        print(f"  Group {gid}: {', '.join(names)}")

    return dfGroupStage

import pandas as pd

def generate_euro_group_tables(competitionID: int,
                                dfFixtures: pd.DataFrame,
                                dfTeams: pd.DataFrame,
                                dfGroupStage: pd.DataFrame) -> dict:
    """
    Returns a dict mapping groupID → DataFrame of standings for that group,
    for the given European group-stage competition (8 = EL or 9 = UCL).

    Each DataFrame has columns:
      ['Position', 'Team', 'Played', 'Wins', 'Draws', 'Losses',
       'GoalsFor', 'GoalsAgainst', 'GoalDiff', 'Points']

    Args:
      competitionID: 8 or 9
      dfFixtures:    DataFrame with group-stage matches, including:
                      ['competitionID','homeTeam','awayTeam','homeGoals','awayGoals','played']
      dfTeams:       DataFrame with ['teamID','teamName', …]
      dfGroupStage:  DataFrame with ['competitionID','teamID','groupID']

    Returns:
      A dict { groupID: group_table_df, … } for groupID in [1..8].
    """

    # 1) Filter to played matches of this competition
    mask = (
        (dfFixtures['competitionID'] == competitionID) &
        (dfFixtures['played'] == True)
    )
    played = dfFixtures.loc[mask].copy()
    if played.empty:
        print(f"No played fixtures found for competition {competitionID}.")
        return {}

    # 2) Merge in groupID for home and away teams
    #    We assume dfGroupStage has exactly one row per (competitionID, teamID).
    gs = dfGroupStage[dfGroupStage['competitionID'] == competitionID][['teamID','groupID']]

    played = played.merge(gs.rename(columns={'teamID':'homeTeam', 'groupID':'homeGroup'}),
                          on='homeTeam', how='left')
    played = played.merge(gs.rename(columns={'teamID':'awayTeam', 'groupID':'awayGroup'}),
                          on='awayTeam', how='left')

    # 3) Build a “per‐team‐per‐match” record
    records = []
    for _, row in played.iterrows():
        h_id = int(row['homeTeam'])
        a_id = int(row['awayTeam'])
        hg   = int(row['homeGoals'])
        ag   = int(row['awayGoals'])
        hg_id = row['homeGroup']
        ag_id = row['awayGroup']
        # (They should be equal: hg_id == ag_id, otherwise data is inconsistent.)

        # Home team stats
        if hg > ag:
            h_w, h_d, h_l, h_pts = 1, 0, 0, 3
            a_w, a_d, a_l, a_pts = 0, 0, 1, 0
        elif hg < ag:
            h_w, h_d, h_l, h_pts = 0, 0, 1, 0
            a_w, a_d, a_l, a_pts = 1, 0, 0, 3
        else:
            h_w, h_d, h_l, h_pts = 0, 1, 0, 1
            a_w, a_d, a_l, a_pts = 0, 1, 0, 1

        records.append({
            'groupID':      hg_id,
            'teamID':       h_id,
            'Played':       1,
            'Wins':         h_w,
            'Draws':        h_d,
            'Losses':       h_l,
            'GoalsFor':     hg,
            'GoalsAgainst': ag,
            'Points':       h_pts
        })
        # Away team stats
        records.append({
            'groupID':      ag_id,
            'teamID':       a_id,
            'Played':       1,
            'Wins':         a_w,
            'Draws':        a_d,
            'Losses':       a_l,
            'GoalsFor':     ag,
            'GoalsAgainst': hg,
            'Points':       a_pts
        })

    df_stats = pd.DataFrame(records)

    # 4) Aggregate by groupID + teamID
    agg = df_stats.groupby(['groupID','teamID'], as_index=False).sum()
    #    Compute goal difference
    agg['GoalDiff'] = agg['GoalsFor'] - agg['GoalsAgainst']

    # 5) Merge in team names
    agg = agg.merge(dfTeams[['teamID','teamName']], on='teamID', how='left')

    # 6) For each group, create a sorted table
    group_tables = {}
    for gid in sorted(agg['groupID'].unique()):
        gdf = agg[agg['groupID'] == gid].copy()
        # Sort by Points desc, then GoalDiff desc, then GoalsFor desc
        gdf = gdf.sort_values(
            by=['Points','GoalDiff','GoalsFor'],
            ascending=[False, False, False]
        ).reset_index(drop=True)

        # Assign position 1–4
        gdf.insert(0, 'Position', range(1, len(gdf)+1))

        # Reorder columns for readability
        gdf = gdf[['Position','teamName','Played','Wins','Draws','Losses',
                   'GoalsFor','GoalsAgainst','GoalDiff','Points']]
        gdf.rename(columns={'teamName':'Team'}, inplace=True)

        group_tables[gid] = gdf

    return group_tables

import pandas as pd

import pandas as pd

def print_euro_group_tables(comp_id: int,
                            dfTeams: pd.DataFrame,
                            dfFixtures: pd.DataFrame,
                            dfGroupStage: pd.DataFrame):
    """
    Prints all 8 group standings for the given European competition (8=EL or 9=UCL).
    - If no matches have been played in a group, that group prints all zeros.
    - If some matches have been played, you'll see real stats (Played/W/D/L/GF/GA/GD/Pts).

    Args:
      comp_id       : 8 for Europa League, 9 for Champions League
      dfTeams       : DataFrame with ['teamID','teamName', …]
      dfFixtures    : DataFrame with all group fixtures, including 'played', 'homeGoals', 'awayGoals'
      dfGroupStage  : DataFrame with ['competitionID','teamID','groupID'] (32 rows for comp_id)

    Usage:
      # Right after drawing groups (so dfGroupStage has comp_id rows):
      print_euro_group_tables(9, dfTeams, dfFixtures, dfGroupStage)
      
      # After some matchdays have been simulated:
      print_euro_group_tables(9, dfTeams, dfFixtures, dfGroupStage)
    """

    # 1) Build mapping: groupID → [teamID, …] for this competition
    gs = dfGroupStage[dfGroupStage['competitionID'] == comp_id]
    if len(gs) != 32:
        raise ValueError(
            f"dfGroupStage must contain exactly 32 rows for comp {comp_id}, "
            f"found {len(gs)}"
        )

    euro_groups = gs.groupby('groupID')['teamID'].apply(list).to_dict()
    missing = [gid for gid in range(1, 9) if gid not in euro_groups]
    if missing:
        raise ValueError(f"Missing groupIDs {missing} in dfGroupStage for comp {comp_id}.")

    # 2) Generate actual group tables (this will return a dict {gid: DataFrame} for groups
    #    where at least one match has been played; empty dict if none)
    actual_tables = generate_euro_group_tables(
        competitionID=comp_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )

    # 3) For each group (1..8), either print the actual table or a zero‐stats template
    for gid in range(1, 9):
        comp_name = dfCompetitions.loc[
            dfCompetitions['competitionID'] == comp_id, 'competitionName'
        ].values[0]
        print(f"\n--- {comp_name} Group {gid} Standings ---")

        if gid in actual_tables:
            tbl = actual_tables[gid].copy()
            # Ensure there’s a Position column in front
            if 'Position' not in tbl.columns:
                tbl.insert(0, 'Position', range(1, len(tbl) + 1))
            print(tbl.to_string(index=False))
            continue

        # No matches played yet in this group: build zero‐stats
        rows = []
        for tid in euro_groups[gid]:
            team_name = dfTeams.loc[dfTeams['teamID'] == tid, 'teamName'].values[0]
            rows.append({
                'Team':         team_name,
                'Played':       0,
                'Wins':         0,
                'Draws':        0,
                'Losses':       0,
                'GoalsFor':     0,
                'GoalsAgainst': 0,
                'GoalDiff':     0,
                'Points':       0
            })
        zero_df = pd.DataFrame(rows)
        zero_df.insert(0, 'Position', range(1, 5))
        print(zero_df.to_string(index=False))

import random

import random

def end_cl_groups(row, dfTeams, dfFixtures, dfGroupStage):
    """
    After UCL group stage completes:
      1) Reset all dfTeams['inCL'] to False.
      2) Re-flag the 16 teams (8 group winners + 8 runners-up).
      3) Draw two-legged Round of 16:
         - first half of row['dayCounter'] for leg1 days,
         - second half for leg2 days,
         cycling if fewer days than matches,
         and populate existing blanks (one fixture slot per match per leg).
    """
    comp_id = 9

    # 1) Clear previous CL flags
    dfTeams['inCL'] = False

    # 2) Find winners & runners-up
    tables = generate_euro_group_tables(
        competitionID=comp_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    winners = []
    runners  = []
    for gid, tbl in tables.items():
        # map names back to IDs
        win_name, run_name = tbl.iloc[0]['Team'], tbl.iloc[1]['Team']
        win_id = dfTeams.loc[dfTeams.teamName == win_name, 'teamID'].iat[0]
        run_id = dfTeams.loc[dfTeams.teamName == run_name, 'teamID'].iat[0]
        winners.append((gid, win_id))
        runners.append((gid, run_id))

    # flag them
    dfTeams.loc[dfTeams.teamID.isin([tid for _,tid in winners] + [tid for _,tid in runners]), 'inCL'] = True

    # 3) Pair winners vs runners from different groups
    rng = list(range(len(winners)))  # should be 8
    for _ in range(1000):
        random.shuffle(runners)
        if all(winners[i][0] != runners[i][0] for i in rng):
            break
    else:
        raise RuntimeError("Cannot pair winners with runners without rematches")

    match_pairs = [(winners[i][1], runners[i][1]) for i in rng]
    n_matches = len(match_pairs)

    # 4) Parse dayCounters and split into two pools
    days = [int(x.strip()) for x in str(row['dayCounter']).split(',') if x.strip().isdigit()]
    if not days:
        raise ValueError("No valid dayCounters provided for End CL Groups")
    half = len(days) // 2 or 1
    leg1_pool = days[:half]
    leg2_pool = days[half:half*2] if len(days) > half else days

    # build full schedules, cycling
    leg1_days = [leg1_pool[i % len(leg1_pool)] for i in range(n_matches)]
    leg2_days = [leg2_pool[i % len(leg2_pool)] for i in range(n_matches)]

    # 5) Fill placeholders for leg1 then leg2
    # leg1
    for (home_tid, away_tid), dc in zip(match_pairs, leg1_days):
        mask = (
            (dfFixtures.competitionID == comp_id) &
            (dfFixtures.dayCounter    == dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank fixture for leg1 match on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = home_tid
        dfFixtures.at[idxs[0], 'awayTeam'] = away_tid

    # leg2 (reverse)
    for (home_tid, away_tid), dc in zip(match_pairs, leg2_days):
        mask = (
            (dfFixtures.competitionID == comp_id) &
            (dfFixtures.dayCounter    == dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank fixture for leg2 match on day {dc}")
        # reverse home/away
        dfFixtures.at[idxs[0], 'homeTeam'] = away_tid
        dfFixtures.at[idxs[0], 'awayTeam'] = home_tid

    # 6) Summary
    print(f"\n🏆 UCL Round of 16 (two-legged) drawn:")
    for i, ((h, a), d1, d2) in enumerate(zip(match_pairs, leg1_days, leg2_days), 1):
        h_name = dfTeams.loc[dfTeams.teamID==h, 'teamName'].iat[0]
        a_name = dfTeams.loc[dfTeams.teamID==a, 'teamName'].iat[0]
        print(f"  Match {i:02d}: Leg1 (day {d1}) {h_name} vs {a_name}; "
              f"Leg2 (day {d2}) {a_name} vs {h_name}")

    # commit back
    globals()['dfFixtures'] = dfFixtures

import random

def end_el_groups(row, dfTeams, dfFixtures, dfGroupStage):
    """
    After EL group stage completes:
      1) Reset dfTeams['inEL'] to False.
      2) Re-flag 24 teams: 8 EL group winners, 8 EL runners-up, and 8 CL third-place finishers.
      3) Draw and populate two-legged “Knockout play-offs” between each EL runner-up
         and one CL third-place, avoiding same-nationality clashes.
    """
    el_id = 8
    cl_id = 9
    # 1) clear inEL
    dfTeams['inEL'] = False

    # 2a) EL group winners & runners-up
    el_tables = generate_euro_group_tables(
        competitionID=el_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    winners = []
    runners  = []
    for gid, tbl in el_tables.items():
        win_name = tbl.iloc[0]['Team']
        run_name = tbl.iloc[1]['Team']
        win_id = dfTeams.loc[dfTeams.teamName==win_name,'teamID'].iat[0]
        run_id = dfTeams.loc[dfTeams.teamName==run_name,'teamID'].iat[0]
        winners.append(win_id)
        runners.append(run_id)

    # 2b) CL third-place finishers
    cl_tables = generate_euro_group_tables(
        competitionID=cl_id,
        dfFixtures=dfFixtures,
        dfTeams=dfTeams,
        dfGroupStage=dfGroupStage
    )
    thirds = []
    for gid, tbl in cl_tables.items():
        third_name = tbl.iloc[2]['Team']
        third_id   = dfTeams.loc[dfTeams.teamName==third_name,'teamID'].iat[0]
        thirds.append(third_id)

    # re-flag all 24 inEL
    dfTeams.loc[dfTeams.teamID.isin(winners + runners + thirds), 'inEL'] = True

    # 3) Pair each EL runner-up with a CL third-place, no same-nationality
    def same_nation(e, c):
        return dfTeams.loc[dfTeams.teamID==e, 'nationality'].iat[0] == \
               dfTeams.loc[dfTeams.teamID==c, 'nationality'].iat[0]

    paired = False
    for _ in range(1000):
        random.shuffle(thirds)
        if all(not same_nation(runners[i], thirds[i]) for i in range(8)):
            paired = True
            break
    if not paired:
        raise RuntimeError("Cannot pair without same-nation clash")

    match_pairs = list(zip(runners, thirds))  # 8 pairs

    # 4) Parse dayCounters
    days = [int(d) for d in str(row['dayCounter']).split(',') if d.strip().isdigit()]
    if not days:
        raise ValueError("No dayCounters provided for EL playoffs")
    half = len(days)//2 or 1
    leg1_pool = days[:half]
    leg2_pool = days[half:half*2] if len(days)>half else days

    # cycle through pools
    leg1_days = [leg1_pool[i % len(leg1_pool)] for i in range(8)]
    leg2_days = [leg2_pool[i % len(leg2_pool)] for i in range(8)]

    # 5) Fill placeholders for leg1 and leg2
    # leg1: runner-up home
    for (run_id, third_id), dc in zip(match_pairs, leg1_days):
        mask = (
            (dfFixtures.competitionID==el_id) &
            (dfFixtures.dayCounter   ==dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank EL playoff fixture for leg1 on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = run_id
        dfFixtures.at[idxs[0], 'awayTeam'] = third_id

    # leg2: third-place home
    for (run_id, third_id), dc in zip(match_pairs, leg2_days):
        mask = (
            (dfFixtures.competitionID==el_id) &
            (dfFixtures.dayCounter   ==dc) &
            dfFixtures.homeTeam.isnull() &
            dfFixtures.awayTeam.isnull()
        )
        idxs = dfFixtures.loc[mask].index
        if idxs.empty:
            raise ValueError(f"No blank EL playoff fixture for leg2 on day {dc}")
        dfFixtures.at[idxs[0], 'homeTeam'] = third_id
        dfFixtures.at[idxs[0], 'awayTeam'] = run_id

    # 6) Print summary
    comp_name = dfCompetitions.loc[dfCompetitions.competitionID==el_id,'competitionName'].iat[0]
    print(f"\n🏆 {comp_name} Knockout Play-offs (two-legged):")
    for i, ((r, c), d1, d2) in enumerate(zip(match_pairs, leg1_days, leg2_days), 1):
        r_name = dfTeams.loc[dfTeams.teamID==r,'teamName'].iat[0]
        c_name = dfTeams.loc[dfTeams.teamID==c,'teamName'].iat[0]
        print(f"  Match {i:02d}: Leg1 (day {d1}) {r_name} vs {c_name}; "
              f"Leg2 (day {d2}) {c_name} vs {r_name}")

    globals()['dfFixtures'] = dfFixtures

# %% [markdown]
# ### The Flow

# %%
# Load verbose flow plan
dfSeasonFlow = pd.read_csv('Input/theFlow.csv')

# Initialise flow state only once
try:
    flow_state
except NameError:
    flow_state = {'step': 0}  # this advances by 1 each time the cell is run

# %%
# 🔄 Reset simulation flow to the start
flow_state = {'step': 0}
print("✅ Flow state reset. You can now re-run the simulation from the beginning.")
# Out:
# ✅ Flow state reset. You can now re-run the simulation from the beginning.

# %% [markdown]
# ### The Flow Helper Functions

# %%
def play_league_day(day):
    """
    Wrapper around play_league_round. If dfGroupStage is not defined yet,
    we simply pass None and skip European table updates inside play_league_round.
    """
    global dfFixtures, dfGroupStage  # dfGroupStage may or may not exist

    try:
        # If dfGroupStage exists, pass it in
        dfFixtures = play_league_round(
            day=day,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfCompetitions=dfCompetitions,
            dfGroupStage=dfGroupStage
        )
    except NameError:
        # dfGroupStage doesn’t exist yet—pass None instead
        dfFixtures = play_league_round(
            day=day,
            dfFixtures=dfFixtures,
            dfTeams=dfTeams,
            dfCompetitions=dfCompetitions,
            dfGroupStage=None
        )

def update_tables():
    global league_tables
    league_tables = generate_league_tables(dfFixtures, dfTeams)

def print_tables():
    print_all_league_tables(league_tables, dfCompetitions)
    
def create_new_fixture_list():
    global dfFixtures
    dfFixtures = create_fixture_list(season_state['current_year'])
    print(f"✅ Fixture list created for {season_state['current_year']}")

def create_team_attributes():
    global dfTeams
    dfTeams = generate_team_attributes()
    print(f"✅ Team attributes created for {season_state['current_year']}")

def update_cup_status(dayCounter, competitionID, dfFixtures, dfTeams):
    """
    For each day in 'dayCounter' (which may be an int or a comma-separated string of ints),
    find all played fixtures for that competition on those days, determine the losers
    (taking into account ET and penalties), and set their corresponding 'inX' flag to False.
    
    Mapping of competitionID → dfTeams flag:
      6  → 'inLC'
      7  → 'inFA'
      8  → 'inEL'
      9  → 'inCL'
      10 → 'inCS'
    """
    # 1) Parse dayCounter into a list of ints
    if isinstance(dayCounter, str):
        day_list = [int(d.strip()) for d in dayCounter.split(',') if d.strip().isdigit()]
    else:
        # assume it's already an int (or something convertible)
        day_list = [int(dayCounter)]
    
    # 2) Map competitionID to the dfTeams boolean column
    comp_flag_map = {
        6:  'inLC',
        7:  'inFA',
        8:  'inEL',
        9:  'inCL',
        10: 'inCS'
    }
    if competitionID not in comp_flag_map:
        print(f"[Warning] No flag mapping for competitionID {competitionID}")
        return
    
    flag_col = comp_flag_map[competitionID]

    # 3) Iterate over each specified day
    for day in day_list:
        # Look up competition name (optional; for nicer printing)
        comp_row = dfCompetitions.loc[
            dfCompetitions['competitionID'] == competitionID,
            'competitionName'
        ]
        comp_name = comp_row.values[0] if not comp_row.empty else f"ID {competitionID}"

        # Filter for fixtures matching this day & competition, and that have been played
        mask = (
            (dfFixtures['dayCounter']   == day) &
            (dfFixtures['competitionID'] == competitionID) &
            (dfFixtures['played']        == True)
        )
        played_matches = dfFixtures.loc[mask].copy()
        if played_matches.empty:
            print(f"No played fixtures found on day {day} for '{comp_name}'")
            continue

        # 4) For each match, determine loser and update dfTeams
        for idx, match in played_matches.iterrows():
            home_id    = int(match['homeTeam'])
            away_id    = int(match['awayTeam'])
            home_goals = int(match['homeGoals'])
            away_goals = int(match['awayGoals'])

            # Determine loser (accounting for ET/penalties if needed)
            if home_goals > away_goals:
                loser_id = away_id
            elif away_goals > home_goals:
                loser_id = home_id
            else:
                # tied after ET, so look at penalty columns
                home_pens = match.get('homePens')
                away_pens = match.get('awayPens')
                if home_pens is None or away_pens is None:
                    print(f"[Error] Tie on day {day}, comp '{comp_name}', but no penalty data.")
                    continue
                loser_id = home_id if home_pens < away_pens else away_id

            # Set that team’s 'inX' flag to False
            dfTeams.loc[dfTeams['teamID'] == loser_id, flag_col] = False

            # Print which team was knocked out
            loser_name = dfTeams.loc[
                dfTeams['teamID'] == loser_id, 'teamName'
            ].values[0]
            print(
                f"Day {day} | {comp_name} | Knocked out: {loser_name} → {flag_col} = False"
            )

def add_lc_teams_r2(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 2,
    except those already in Europa League or Champions League.
    Sets dfTeams['inLC'] = True for any teamID ≤ 20 where
    both inEL and inCL are False.
    """
    mask = (dfTeams['teamID'] <= 20) & (~dfTeams['inEL']) & (~dfTeams['inCL'])
    dfTeams.loc[mask, 'inLC'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to LC Round 2: {', '.join(added)}")

def add_lc_teams_r3(dfTeams):
    """
    Include all teams with teamID ≤ 20 into League Cup Round 3
    if they are in Europa League (inEL) or Champions League (inCL).
    Sets dfTeams['inLC'] = True for any team meeting those criteria.
    """
    mask = (dfTeams['teamID'] <= 20) & (dfTeams['inEL'] | dfTeams['inCL'])
    dfTeams.loc[mask, 'inLC'] = True
    added = dfTeams.loc[mask, 'teamName'].tolist()
    print(f"Added to LC Round 3: {', '.join(added)}")
    
# Map flow text to actual logic
flow_dispatch = {
    'Create New Fixture List': lambda row: create_new_fixture_list(),
    'Create Team Attributes': lambda row: create_team_attributes(),
    'Play League Matches': lambda row: play_league_day(int(row['dayCounter'])),
    'Print Tables': lambda row: print_tables(),
    'Play Cup Round': lambda row: play_cup_round(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams),
    'Update Cup Status': lambda row: update_cup_status(row['dayCounter'], int(row['competitionID']), dfFixtures, dfTeams),
    'Add LC Round2 Teams': lambda row: add_lc_teams_r2(dfTeams),
    'Add LC Round3 Teams': lambda row: add_lc_teams_r3(dfTeams),
    'Draw European Group Stage': lambda row: draw_euro_group_stage(row, dfTeams, dfFixtures, dfCompetitions),
    'Draw Cup' : lambda row: draw_cup(row, dfTeams, dfFixtures, dfCompetitions),
    'Initialize Cup Status' : lambda row: initialize_cup_status(dfTeams),
    'End CL Groups' : lambda row: end_cl_groups(row, dfTeams, dfFixtures, dfGroupStage),
    'End EL Groups' : lambda row: end_el_groups(row, dfTeams, dfFixtures, dfGroupStage)
}

# %%
# 📅 Initialize multi-season simulation state
try:
    season_state
except NameError:
    season_state = {
        'step': 0,
        'current_year': 2024,
        'fixtures_archive': {},
        'tables_archive': {}
    }
    print("✅ Season state initialized")
# Out:
# ✅ Season state initialized

# %%
# Step through the flow one step at a time
if flow_state['step'] < len(dfSeasonFlow):
    row = dfSeasonFlow.iloc[flow_state['step']]
    step_desc = row['functionToCall']
    print(f"\n=== STEP {flow_state['step']+1}: {step_desc} ===")

    # Run corresponding logic
    if step_desc in flow_dispatch:
        flow_dispatch[step_desc](row)
    else:
        print(f"[Skipped] No function mapped for: {step_desc}")

    flow_state['step'] += 1
else:
    print("=== All flow steps completed ===")

# %%
# Step through the flow in one hit to XX
def run_flow_to(target_step):
    """
    Advance the flow from its current position up to (but not including) target_step.
    target_step is 1-based: to run steps 1–80, call run_flow_to(80).
    """
    global flow_state, dfSeasonFlow, flow_dispatch

    # Convert target_step to zero-based index
    end_index = target_step

    while flow_state['step'] < len(dfSeasonFlow) and flow_state['step'] < end_index:
        row = dfSeasonFlow.iloc[flow_state['step']]
        step_desc = row['functionToCall']
        print(f"\n=== STEP {flow_state['step']+1}: {step_desc} ===")

        if step_desc in flow_dispatch:
            flow_dispatch[step_desc](row)
        else:
            print(f"[Skipped] No function mapped for: {step_desc}")

        flow_state['step'] += 1

    if flow_state['step'] >= end_index:
        print(f"\n=== Reached step {target_step}. Stopped. Current pointer: {flow_state['step']} ===")
    else:
        print("\n=== All flow steps completed before reaching the target ===")

run_flow_to(139)
# Out:
# === STEP 1: Create New Fixture List ===
# ✅ Fixture list created for 2024
#
# === STEP 2: Create Team Attributes ===
# ✅ Team attributes created for 2024
#
# === STEP 3: Initialize Cup Status ===
# ✅ Initialized cup status:
#   inCS: 2 teams
#   inCL: 32 teams
#   inEL: 32 teams
#   inFA: 80 teams
#   inLC: 72 teams
#
# === STEP 4: Draw Cup ===
#
# 🏆 Community Shield draw (1 matches) across: 2024-08-04
#   Match 01 (day 3): Manchester City vs Arsenal
#
# === STEP 5: Draw Cup ===
#
# 🏆 League Cup draw (36 matches) across: 2024-08-13, 2024-08-14
#   Match 01 (day 4): Salford City vs Birmingham
#   Match 02 (day 4): Watford vs Blackburn
#   Match 03 (day 4): Bradford vs Sunderland
#   Match 04 (day 4): Stockport County vs Sutton Utd
#   Match 05 (day 4): Tranmere vs Coventry
#   Match 06 (day 4): Hull City vs Southampton
#   Match 07 (day 4): AFC Wimbledon vs Fleetwood Town
#   Match 08 (day 4): Barrow vs Reading
#   Match 09 (day 4): Walsall vs Northampton
#   Match 10 (day 4): Swindon Town vs Bristol City
#   Match 11 (day 4): Leyton Orient vs Norwich
#   Match 12 (day 4): Wycombe vs Oxford United
#   Match 13 (day 4): Wigan vs Huddersfield
#   Match 14 (day 4): QPR vs Port Vale
#   Match 15 (day 4): Wrexham vs Shrewsbury
#   Match 16 (day 4): Leicester vs Lincoln
#   Match 17 (day 4): Millwall vs Barnsley
#   Match 18 (day 4): Derby vs Plymouth
#   Match 19 (day 4): West Brom vs Grimsby
#   Match 20 (day 4): Exeter City vs Newport County
#   Match 21 (day 4): Blackpool vs Bolton
#   Match 22 (day 4): Cambridge United vs Ipswich
#   Match 23 (day 4): Middlesbrough vs Doncaster
#   Match 24 (day 4): Carlisle vs Gillingham
#   Match 25 (day 4): Morecambe vs Sheffield Wednesday
#   Match 26 (day 4): Milton Keynes Dons vs Preston
#   Match 27 (day 4): Bristol Rovers vs Rotherham
#   Match 28 (day 4): Colchester vs Forest Green
#   Match 29 (day 4): Stevenage vs Leeds
#   Match 30 (day 5): Stoke City vs Charlton
#   Match 31 (day 5): Notts County vs Cardiff
#   Match 32 (day 5): Cheltenham vs Accrington ST
#   Match 33 (day 5): Burton Albion vs Portsmouth
#   Match 34 (day 5): Crewe vs Swansea
#   Match 35 (day 5): Crawley Town vs Harrogate Town
#   Match 36 (day 5): Mansfield Town vs Peterborough
#
# === STEP 6: Play League Matches ===
#
# Matches played on 2024-08-02:
# Championship
# Sheffield Wednesday 0 - 0 Southampton
#
# === STEP 7: Play League Matches ===
#
# Matches played on 2024-08-03:
# Championship
# Watford 0 - 0 QPR
# Bristol City 3 - 0 Preston
# Blackburn 0 - 0 West Brom
# Middlesbrough 2 - 1 Millwall
# Norwich 1 - 0 Hull City
# Stoke City 3 - 2 Rotherham
# Swansea 1 - 1 Birmingham
# Plymouth 3 - 0 Huddersfield
# League One
# Carlisle 1 - 2 Fleetwood Town
# Wycombe 2 - 1 Exeter City
# Cambridge United 0 - 0 Oxford United
# Reading 1 - 1 Peterborough
# Derby 0 - 1 Wigan
# Barnsley 3 - 0 Port Vale
# Charlton 5 - 0 Leyton Orient
# Northampton 1 - 0 Stevenage
# Shrewsbury 2 - 2 Cheltenham
# Portsmouth 1 - 0 Bristol Rovers
# Blackpool 3 - 1 Burton Albion
# Bolton 1 - 1 Lincoln
# League Two
# Accrington ST 1 - 1 Newport County
# Crawley Town 1 - 2 Bradford
# Crewe 1 - 1 Mansfield Town
# Grimsby 1 - 1 AFC Wimbledon
# Morecambe 3 - 0 Walsall
# Forest Green 1 - 1 Salford City
# Tranmere 0 - 0 Barrow
# Doncaster 0 - 0 Harrogate Town
# Sutton Utd 1 - 0 Notts County
# Stockport County 1 - 1 Gillingham
# Wrexham 0 - 0 Milton Keynes Dons
# National League
# Southend 0 - 0 Oldham
# Chesterfield 2 - 0 Dorking Wanderers
# Barnet 2 - 1 Hartlepool
# Aldershot Town 0 - 1 Oxford City
# Gateshead 1 - 2 Boreham Wood
# Solihull Moors 2 - 1 Eastleigh
# FC Halifax Town 1 - 0 Bromley
# Maidenhead 0 - 2 AFC Fylde
# Altrincham 1 - 1 Dagenham & Redbridge
# Wealdstone 2 - 0 York
# Rochdale 2 - 1 Ebbsfleet United
# Kidderminster Harriers 1 - 1 Woking
#
# === STEP 8: Play League Matches ===
#
# Matches played on 2024-08-04:
# Championship
# Leicester 1 - 0 Coventry
# Leeds 2 - 1 Cardiff
# Sunderland 2 - 0 Ipswich
#
# === STEP 9: Play Cup Round ===
# Day 3 | Community Shield | Manchester City 1–0 Arsenal → Winner: Manchester City
#
# === STEP 10: Play Cup Round ===
# Day 4 | League Cup | Salford City 1–2 Birmingham → Winner: Birmingham
# Day 4 | League Cup | Watford 0–1 Blackburn → Winner: Blackburn
# Day 4 | League Cup | Bradford 1–0 Sunderland → Winner: Bradford
# Day 4 | League Cup | Stockport County 2–0 Sutton Utd → Winner: Stockport County
# Day 4 | League Cup | Tranmere 1–4 Coventry → Winner: Coventry
# Day 4 | League Cup | Hull City 1–2 Southampton → Winner: Southampton
# Day 4 | League Cup | AFC Wimbledon 1–2 Fleetwood Town → Winner: Fleetwood Town
# Day 4 | League Cup | Barrow 0–2 Reading → Winner: Reading
# Day 4 | League Cup | Walsall 1–2 Northampton → Winner: Northampton
# Day 4 | League Cup | Swindon Town 2–3 Bristol City → Winner: Bristol City
# Day 4 | League Cup | Leyton Orient 2–1 Norwich → Winner: Leyton Orient
# Day 4 | League Cup | Wycombe 2–0 Oxford United → Winner: Wycombe
# Day 4 | League Cup | Wigan 1–2 Huddersfield → Winner: Huddersfield
# Day 4 | League Cup | QPR 3–0 Port Vale → Winner: QPR
# Day 4 | League Cup | Wrexham 1–1 Shrewsbury (a.e.t.) [p 6–7] → Winner: Shrewsbury
# Day 4 | League Cup | Leicester 2–1 Lincoln → Winner: Leicester
# Day 4 | League Cup | Millwall 0–0 Barnsley (a.e.t.) [p 5–2] → Winner: Millwall
# Day 4 | League Cup | Derby 0–2 Plymouth → Winner: Plymouth
# Day 4 | League Cup | West Brom 4–0 Grimsby → Winner: West Brom
# Day 4 | League Cup | Exeter City 2–1 Newport County → Winner: Exeter City
# Day 4 | League Cup | Blackpool 0–0 Bolton (a.e.t.) [p 1–0] → Winner: Blackpool
# Day 4 | League Cup | Cambridge United 1–5 Ipswich → Winner: Ipswich
# Day 4 | League Cup | Middlesbrough 4–0 Doncaster → Winner: Middlesbrough
# Day 4 | League Cup | Carlisle 2–1 Gillingham → Winner: Carlisle
# Day 4 | League Cup | Morecambe 0–2 Sheffield Wednesday → Winner: Sheffield Wednesday
# Day 4 | League Cup | Milton Keynes Dons 1–0 Preston → Winner: Milton Keynes Dons
# Day 4 | League Cup | Bristol Rovers 1–1 Rotherham (a.e.t.) [p 3–5] → Winner: Rotherham
# Day 4 | League Cup | Colchester 0–3 Forest Green → Winner: Forest Green
# Day 4 | League Cup | Stevenage 1–3 Leeds → Winner: Leeds
#
# === STEP 11: Play Cup Round ===
# Day 5 | League Cup | Stoke City 4–0 Charlton → Winner: Stoke City
# Day 5 | League Cup | Notts County 0–1 Cardiff → Winner: Cardiff
# Day 5 | League Cup | Cheltenham 5–0 Accrington ST → Winner: Cheltenham
# Day 5 | League Cup | Burton Albion 3–0 Portsmouth → Winner: Burton Albion
# Day 5 | League Cup | Crewe 0–0 Swansea (a.e.t.) [p 1–4] → Winner: Swansea
# Day 5 | League Cup | Crawley Town 1–2 Harrogate Town (a.e.t.) → Winner: Harrogate Town
# Day 5 | League Cup | Mansfield Town 1–3 Peterborough → Winner: Peterborough
#
# === STEP 12: Update Cup Status ===
# Day 4 | League Cup | Knocked out: Salford City → inLC = False
# Day 4 | League Cup | Knocked out: Watford → inLC = False
# Day 4 | League Cup | Knocked out: Sunderland → inLC = False
# Day 4 | League Cup | Knocked out: Sutton Utd → inLC = False
# Day 4 | League Cup | Knocked out: Tranmere → inLC = False
# Day 4 | League Cup | Knocked out: Hull City → inLC = False
# Day 4 | League Cup | Knocked out: AFC Wimbledon → inLC = False
# Day 4 | League Cup | Knocked out: Barrow → inLC = False
# Day 4 | League Cup | Knocked out: Walsall → inLC = False
# Day 4 | League Cup | Knocked out: Swindon Town → inLC = False
# Day 4 | League Cup | Knocked out: Norwich → inLC = False
# Day 4 | League Cup | Knocked out: Oxford United → inLC = False
# Day 4 | League Cup | Knocked out: Wigan → inLC = False
# Day 4 | League Cup | Knocked out: Port Vale → inLC = False
# Day 4 | League Cup | Knocked out: Wrexham → inLC = False
# Day 4 | League Cup | Knocked out: Lincoln → inLC = False
# Day 4 | League Cup | Knocked out: Barnsley → inLC = False
# Day 4 | League Cup | Knocked out: Derby → inLC = False
# Day 4 | League Cup | Knocked out: Grimsby → inLC = False
# Day 4 | League Cup | Knocked out: Newport County → inLC = False
# Day 4 | League Cup | Knocked out: Bolton → inLC = False
# Day 4 | League Cup | Knocked out: Cambridge United → inLC = False
# Day 4 | League Cup | Knocked out: Doncaster → inLC = False
# Day 4 | League Cup | Knocked out: Gillingham → inLC = False
# Day 4 | League Cup | Knocked out: Morecambe → inLC = False
# Day 4 | League Cup | Knocked out: Preston → inLC = False
# Day 4 | League Cup | Knocked out: Bristol Rovers → inLC = False
# Day 4 | League Cup | Knocked out: Colchester → inLC = False
# Day 4 | League Cup | Knocked out: Stevenage → inLC = False
# Day 5 | League Cup | Knocked out: Charlton → inLC = False
# Day 5 | League Cup | Knocked out: Notts County → inLC = False
# Day 5 | League Cup | Knocked out: Accrington ST → inLC = False
# Day 5 | League Cup | Knocked out: Portsmouth → inLC = False
# Day 5 | League Cup | Knocked out: Crewe → inLC = False
# Day 5 | League Cup | Knocked out: Crawley Town → inLC = False
# Day 5 | League Cup | Knocked out: Mansfield Town → inLC = False
#
# === STEP 13: Add LC Round2 Teams ===
# Added to LC Round 2: Bournemouth, Brentford, Burnley, Chelsea, Crystal Palace, Everton, Fulham, Luton, Nottingham Forest, Sheffield Utd, West Ham, Wolves
#
# === STEP 14: Draw Cup ===
#
# 🏆 League Cup draw (24 matches) across: 2024-08-27, 2024-08-28
#   Match 01 (day 20): Nottingham Forest vs Harrogate Town
#   Match 02 (day 20): Sheffield Utd vs Stoke City
#   Match 03 (day 20): Blackpool vs Burnley
#   Match 04 (day 20): West Brom vs Stockport County
#   Match 05 (day 20): Burton Albion vs Shrewsbury
#   Match 06 (day 20): Bradford vs Wycombe
#   Match 07 (day 20): Blackburn vs Middlesbrough
#   Match 08 (day 20): Northampton vs Cheltenham
#   Match 09 (day 20): QPR vs Brentford
#   Match 10 (day 20): Crystal Palace vs Cardiff
#   Match 11 (day 20): Luton vs Birmingham
#   Match 12 (day 20): Millwall vs Exeter City
#   Match 13 (day 20): Leyton Orient vs Chelsea
#   Match 14 (day 20): Huddersfield vs Rotherham
#   Match 15 (day 20): Leicester vs Sheffield Wednesday
#   Match 16 (day 20): Ipswich vs Bournemouth
#   Match 17 (day 20): Coventry vs Reading
#   Match 18 (day 20): Bristol City vs Everton
#   Match 19 (day 20): Forest Green vs Leeds
#   Match 20 (day 21): Fleetwood Town vs Carlisle
#   Match 21 (day 21): Milton Keynes Dons vs Swansea
#   Match 22 (day 21): Plymouth vs Southampton
#   Match 23 (day 21): West Ham vs Fulham
#   Match 24 (day 21): Wolves vs Peterborough
#
# === STEP 15: Play League Matches ===
#
# Matches played on 2024-08-09:
# Premier League
# Burnley 1 - 1 Manchester City
#
# === STEP 16: Play League Matches ===
#
# Matches played on 2024-08-10:
# Premier League
# Brighton 1 - 1 Luton
# Sheffield Utd 1 - 0 Crystal Palace
# Newcastle 0 - 0 Aston Villa
# Bournemouth 0 - 1 West Ham
# Everton 0 - 1 Fulham
# Arsenal 4 - 0 Nottingham Forest
# Championship
# Coventry 0 - 2 Middlesbrough
# Huddersfield 0 - 0 Leicester
# Watford 1 - 0 Plymouth
# Southampton 0 - 1 Norwich
# Cardiff 1 - 1 QPR
# Birmingham 1 - 3 Leeds
# Ipswich 3 - 0 Stoke City
# Millwall 0 - 0 Bristol City
# Preston 0 - 0 Sunderland
# West Brom 3 - 1 Swansea
# Hull City 2 - 0 Sheffield Wednesday
# Rotherham 0 - 1 Blackburn
# League One
# Wigan 1 - 0 Northampton
# Bristol Rovers 1 - 0 Barnsley
# Fleetwood Town 2 - 0 Cambridge United
# Oxford United 2 - 1 Carlisle
# Peterborough 2 - 1 Charlton
# Port Vale 0 - 0 Reading
# Exeter City 2 - 2 Blackpool
# Stevenage 1 - 2 Shrewsbury
# Cheltenham 1 - 0 Bolton
# Leyton Orient 1 - 1 Portsmouth
# Lincoln 3 - 0 Wycombe
# Burton Albion 2 - 2 Derby
# League Two
# AFC Wimbledon 2 - 0 Wrexham
# Mansfield Town 3 - 2 Morecambe
# Notts County 1 - 0 Grimsby
# Barrow 1 - 0 Sutton Utd
# Salford City 0 - 0 Crawley Town
# Harrogate Town 2 - 1 Forest Green
# Walsall 0 - 0 Stockport County
# Bradford 3 - 0 Colchester
# Gillingham 2 - 3 Accrington ST
# Milton Keynes Dons 1 - 1 Tranmere
# Swindon Town 4 - 0 Crewe
# Newport County 1 - 0 Doncaster
# National League
# Ebbsfleet United 0 - 2 Solihull Moors
# Oxford City 0 - 0 Rochdale
# Dorking Wanderers 2 - 0 Maidenhead
# Bromley 3 - 3 Barnet
# AFC Fylde 1 - 1 Chesterfield
# Oldham 4 - 0 Aldershot Town
# Hartlepool 3 - 2 Gateshead
# Dagenham & Redbridge 0 - 2 Southend
# Eastleigh 2 - 1 Wealdstone
# York 0 - 1 Kidderminster Harriers
# Boreham Wood 1 - 0 FC Halifax Town
# Woking 1 - 1 Altrincham
#
# === STEP 17: Play League Matches ===
#
# Matches played on 2024-08-11:
# Premier League
# Chelsea 3 - 0 Liverpool
# Brentford 3 - 2 Tottenham
#
# === STEP 18: Play League Matches ===
#
# Matches played on 2024-08-12:
# Premier League
# Manchester United 3 - 0 Wolves
#
# === STEP 19: Play League Matches ===
#
# Matches played on 2024-08-20:
# League One
# Barnsley 2 - 2 Peterborough
# Carlisle 1 - 3 Wigan
# Cambridge United 2 - 1 Stevenage
# Wycombe 2 - 0 Leyton Orient
# Blackpool 1 - 1 Port Vale
# Shrewsbury 1 - 2 Burton Albion
# Northampton 0 - 2 Lincoln
# Charlton 1 - 0 Bristol Rovers
# Reading 1 - 0 Cheltenham
# Portsmouth 3 - 0 Exeter City
# Derby 1 - 2 Oxford United
# Bolton 1 - 0 Fleetwood Town
# League Two
# Accrington ST 2 - 1 Barrow
# Sutton Utd 0 - 1 Gillingham
# Tranmere 2 - 2 Harrogate Town
# Forest Green 2 - 1 Swindon Town
# Morecambe 2 - 1 Notts County
# Grimsby 2 - 0 Salford City
# Crewe 0 - 3 Newport County
# Doncaster 0 - 0 Mansfield Town
# Crawley Town 1 - 0 Milton Keynes Dons
# Colchester 3 - 1 AFC Wimbledon
# Wrexham 1 - 1 Walsall
# Stockport County 2 - 4 Bradford
# National League
# Oldham 3 - 0 FC Halifax Town
# Hartlepool 1 - 0 Maidenhead
# Dagenham & Redbridge 4 - 0 Gateshead
# Eastleigh 0 - 1 Barnet
# Bromley 0 - 1 Wealdstone
# Woking 2 - 2 Rochdale
# AFC Fylde 0 - 0 Kidderminster Harriers
# Ebbsfleet United 2 - 1 Aldershot Town
# Oxford City 2 - 2 Chesterfield
# Dorking Wanderers 1 - 2 Southend
# York 1 - 3 Altrincham
#
# === STEP 20: Play League Matches ===
#
# Matches played on 2024-08-21:
# National League
# Boreham Wood 3 - 0 Solihull Moors
#
# === STEP 21: Play League Matches ===
#
# Matches played on 2024-08-16:
# Premier League
# Nottingham Forest 0 - 0 Sheffield Utd
# Championship
# Leeds 0 - 0 West Brom
#
# === STEP 22: Play League Matches ===
#
# Matches played on 2024-08-17:
# Premier League
# Fulham 2 - 1 Brentford
# Wolves 2 - 0 Brighton
# Liverpool 2 - 1 Bournemouth
# Tottenham 1 - 0 Manchester United
# Manchester City 1 - 2 Newcastle
# Championship
# Sunderland 2 - 2 Rotherham
# Swansea 1 - 2 Coventry
# Sheffield Wednesday 0 - 1 Preston
# QPR 2 - 0 Ipswich
# Stoke City 2 - 3 Watford
# Plymouth 0 - 2 Southampton
# Leicester 1 - 1 Cardiff
# Bristol City 2 - 1 Birmingham
# Blackburn 2 - 0 Hull City
# Middlesbrough 2 - 2 Huddersfield
# League One
# Derby 1 - 0 Fleetwood Town
# Reading 2 - 1 Stevenage
# Charlton 0 - 1 Port Vale
# Wycombe 1 - 0 Burton Albion
# Cambridge United 0 - 1 Bristol Rovers
# Carlisle 0 - 0 Exeter City
# Shrewsbury 1 - 0 Lincoln
# Northampton 0 - 1 Peterborough
# Bolton 0 - 2 Wigan
# Blackpool 2 - 0 Leyton Orient
# Barnsley 3 - 0 Oxford United
# Portsmouth 1 - 2 Cheltenham
# League Two
# Stockport County 0 - 1 Barrow
# Wrexham 1 - 1 Swindon Town
# Sutton Utd 0 - 2 AFC Wimbledon
# Tranmere 1 - 1 Salford City
# Forest Green 4 - 1 Newport County
# Morecambe 1 - 0 Bradford
# Crewe 0 - 1 Walsall
# Crawley Town 1 - 0 Gillingham
# Colchester 0 - 2 Milton Keynes Dons
# Accrington ST 0 - 3 Harrogate Town
# Doncaster 2 - 0 Notts County
# Grimsby 0 - 1 Mansfield Town
# National League
# Solihull Moors 1 - 0 Dorking Wanderers
# Maidenhead 0 - 2 Dagenham & Redbridge
# FC Halifax Town 3 - 1 Oxford City
# Kidderminster Harriers 0 - 1 Bromley
# Barnet 3 - 3 Woking
# Aldershot Town 1 - 0 York
# Gateshead 2 - 1 Ebbsfleet United
# Chesterfield 2 - 1 Oldham
# Rochdale 1 - 0 Eastleigh
# Southend 0 - 0 Hartlepool
# Wealdstone 1 - 0 AFC Fylde
# Altrincham 1 - 1 Boreham Wood
#
# === STEP 23: Play League Matches ===
#
# Matches played on 2024-08-18:
# Premier League
# Aston Villa 1 - 0 Everton
# West Ham 1 - 1 Chelsea
# Championship
# Norwich 1 - 3 Millwall
#
# === STEP 24: Play League Matches ===
#
# Matches played on 2024-08-19:
# Premier League
# Crystal Palace 0 - 1 Arsenal
#
# === STEP 25: Play League Matches ===
#
# Matches played on 2024-08-23:
# Premier League
# Chelsea 3 - 0 Luton
# Championship
# Hull City 0 - 0 Bristol City
# National League
# Solihull Moors 2 - 2 FC Halifax Town
# Southend 1 - 0 Eastleigh
# Rochdale 1 - 0 Bromley
#
# === STEP 26: Play League Matches ===
#
# Matches played on 2024-08-24:
# Premier League
# Arsenal 0 - 1 Fulham
# Everton 3 - 3 Wolves
# Manchester United 2 - 0 Nottingham Forest
# Bournemouth 1 - 0 Tottenham
# Brentford 0 - 2 Crystal Palace
# Brighton 3 - 0 West Ham
# Championship
# Coventry 0 - 0 Sunderland
# Rotherham 0 - 1 Leicester
# West Brom 0 - 2 Middlesbrough
# Preston 2 - 1 Swansea
# Millwall 2 - 0 Stoke City
# Ipswich 0 - 1 Leeds
# Birmingham 0 - 1 Plymouth
# Cardiff 2 - 0 Sheffield Wednesday
# Southampton 1 - 0 QPR
# Huddersfield 2 - 0 Norwich
# League One
# Oxford United 0 - 0 Charlton
# Leyton Orient 1 - 0 Cambridge United
# Lincoln 3 - 0 Blackpool
# Burton Albion 0 - 0 Bolton
# Bristol Rovers 0 - 1 Wycombe
# Fleetwood Town 1 - 0 Shrewsbury
# Peterborough 2 - 2 Derby
# Port Vale 2 - 0 Carlisle
# Exeter City 0 - 1 Reading
# Stevenage 1 - 0 Portsmouth
# Cheltenham 1 - 1 Northampton
# Wigan 1 - 0 Barnsley
# League Two
# AFC Wimbledon 1 - 1 Forest Green
# Walsall 0 - 0 Grimsby
# Bradford 2 - 1 Crewe
# Gillingham 1 - 0 Colchester
# Swindon Town 1 - 2 Crawley Town
# Newport County 3 - 0 Sutton Utd
# Mansfield Town 0 - 0 Stockport County
# Notts County 1 - 0 Tranmere
# Barrow 2 - 0 Wrexham
# Harrogate Town 0 - 2 Morecambe
# Salford City 1 - 1 Accrington ST
# Milton Keynes Dons 0 - 0 Doncaster
# National League
# Dagenham & Redbridge 1 - 1 Barnet
# Aldershot Town 1 - 0 Wealdstone
# Gateshead 0 - 2 Woking
# Boreham Wood 1 - 0 Oldham
# Maidenhead 1 - 1 Oxford City
# Ebbsfleet United 1 - 1 Kidderminster Harriers
# Altrincham 2 - 0 Chesterfield
# Dorking Wanderers 1 - 3 York
# Hartlepool 1 - 0 AFC Fylde
#
# === STEP 27: Play League Matches ===
#
# Matches played on 2024-08-25:
# Premier League
# Sheffield Utd 1 - 0 Manchester City
# Burnley 0 - 0 Aston Villa
# Newcastle 1 - 0 Liverpool
# Championship
# Watford 0 - 2 Blackburn
#
# === STEP 28: Play League Matches ===
#
# Matches played on 2024-08-26:
# National League
# AFC Fylde 1 - 0 Altrincham
# Kidderminster Harriers 1 - 0 Maidenhead
# Wealdstone 2 - 1 Dagenham & Redbridge
# FC Halifax Town 2 - 1 Gateshead
# Barnet 2 - 0 Ebbsfleet United
# Woking 3 - 1 Dorking Wanderers
# Bromley 1 - 2 Southend
# Chesterfield 1 - 0 Hartlepool
# York 0 - 1 Rochdale
# Eastleigh 3 - 0 Aldershot Town
# Oldham 0 - 0 Solihull Moors
# Oxford City 0 - 1 Boreham Wood
#
# === STEP 29: Draw European Group Stage ===
#
# Populated Champions League Group Stage (competitionID=9):
#   Group 1: Real Madrid, Borussia Dortmund, Paris Saint Germain, BSC Young Boys
#   Group 2: Benfica, AC Milan, Union Berlin, Manchester City
#   Group 3: Bayern Munich, Lazio, Ajax, Newcastle
#   Group 4: Arsenal, Sevilla, SC Braga, Antwerp
#   Group 5: Feyenoord, Barcelona, Celtic, Red Star Belgrade
#   Group 6: Lens, PSV Eindhoven, Real Sociedad, RB Leipzig
#   Group 7: FC Copenhagen, Inter, FC Porto, Atletico Madrid
#   Group 8: Manchester United, Red Bull Salzburg, Napoli, Galatasaray
#
# === STEP 30: Draw European Group Stage ===
#
# Populated Europa League Group Stage (competitionID=8):
#   Group 1: Brighton, Sparta Praha, Atalanta, AEK Athens FC
#   Group 2: Liverpool, Marseille, Shakhtar Donetsk, SC Freiburg
#   Group 3: Slavia Praha, Panathinaikos, Rennes, Lask Linz
#   Group 4: Sporting CP, Bayer Leverkusen, Villarreal, Aston Villa
#   Group 5: Servette FC, Toulouse, BK Hacken, TSC Backa Topola
#   Group 6: AS Roma, Aris Limassol, Real Betis, Qarabag
#   Group 7: Tottenham, Rangers, Sheriff Tiraspol, Sturm Graz
#   Group 8: Union St. Gilloise, Olympiacos, Molde, Maccabi Haifa
#
# === STEP 31: Play Cup Round ===
# Day 20 | League Cup | Nottingham Forest 4–0 Harrogate Town (a.e.t.) → Winner: Nottingham Forest
# Day 20 | League Cup | Sheffield Utd 2–0 Stoke City → Winner: Sheffield Utd
# Day 20 | League Cup | Blackpool 1–0 Burnley → Winner: Blackpool
# Day 20 | League Cup | West Brom 2–0 Stockport County → Winner: West Brom
# Day 20 | League Cup | Burton Albion 0–1 Shrewsbury → Winner: Shrewsbury
# Day 20 | League Cup | Bradford 0–2 Wycombe → Winner: Wycombe
# Day 20 | League Cup | Blackburn 0–2 Middlesbrough → Winner: Middlesbrough
# Day 20 | League Cup | Northampton 1–0 Cheltenham → Winner: Northampton
# Day 20 | League Cup | QPR 1–1 Brentford (a.e.t.) [p 5–3] → Winner: QPR
# Day 20 | League Cup | Crystal Palace 2–0 Cardiff → Winner: Crystal Palace
# Day 20 | League Cup | Luton 3–0 Birmingham → Winner: Luton
# Day 20 | League Cup | Millwall 0–0 Exeter City (a.e.t.) [p 4–3] → Winner: Millwall
# Day 20 | League Cup | Leyton Orient 0–2 Chelsea → Winner: Chelsea
# Day 20 | League Cup | Huddersfield 1–0 Rotherham (a.e.t.) → Winner: Huddersfield
# Day 20 | League Cup | Leicester 1–0 Sheffield Wednesday → Winner: Leicester
# Day 20 | League Cup | Ipswich 0–1 Bournemouth → Winner: Bournemouth
# Day 20 | League Cup | Coventry 2–0 Reading → Winner: Coventry
# Day 20 | League Cup | Bristol City 3–1 Everton → Winner: Bristol City
# Day 20 | League Cup | Forest Green 0–2 Leeds → Winner: Leeds
#
# === STEP 32: Play Cup Round ===
# Day 21 | League Cup | Fleetwood Town 4–0 Carlisle → Winner: Fleetwood Town
# Day 21 | League Cup | Milton Keynes Dons 1–2 Swansea → Winner: Swansea
# Day 21 | League Cup | Plymouth 0–2 Southampton → Winner: Southampton
# Day 21 | League Cup | West Ham 2–0 Fulham → Winner: West Ham
# Day 21 | League Cup | Wolves 1–0 Peterborough → Winner: Wolves
#
# === STEP 33: Update Cup Status ===
# Day 20 | League Cup | Knocked out: Harrogate Town → inLC = False
# Day 20 | League Cup | Knocked out: Stoke City → inLC = False
# Day 20 | League Cup | Knocked out: Burnley → inLC = False
# Day 20 | League Cup | Knocked out: Stockport County → inLC = False
# Day 20 | League Cup | Knocked out: Burton Albion → inLC = False
# Day 20 | League Cup | Knocked out: Bradford → inLC = False
# Day 20 | League Cup | Knocked out: Blackburn → inLC = False
# Day 20 | League Cup | Knocked out: Cheltenham → inLC = False
# Day 20 | League Cup | Knocked out: Brentford → inLC = False
# Day 20 | League Cup | Knocked out: Cardiff → inLC = False
# Day 20 | League Cup | Knocked out: Birmingham → inLC = False
# Day 20 | League Cup | Knocked out: Exeter City → inLC = False
# Day 20 | League Cup | Knocked out: Leyton Orient → inLC = False
# Day 20 | League Cup | Knocked out: Rotherham → inLC = False
# Day 20 | League Cup | Knocked out: Sheffield Wednesday → inLC = False
# Day 20 | League Cup | Knocked out: Ipswich → inLC = False
# Day 20 | League Cup | Knocked out: Reading → inLC = False
# Day 20 | League Cup | Knocked out: Everton → inLC = False
# Day 20 | League Cup | Knocked out: Forest Green → inLC = False
# Day 21 | League Cup | Knocked out: Carlisle → inLC = False
# Day 21 | League Cup | Knocked out: Milton Keynes Dons → inLC = False
# Day 21 | League Cup | Knocked out: Plymouth → inLC = False
# Day 21 | League Cup | Knocked out: Fulham → inLC = False
# Day 21 | League Cup | Knocked out: Peterborough → inLC = False
#
# === STEP 34: Add LC Round3 Teams ===
# Added to LC Round 3: Arsenal, Aston Villa, Brighton, Liverpool, Manchester City, Manchester United, Newcastle, Tottenham
#
# === STEP 35: Draw Cup ===
#
# 🏆 League Cup draw (16 matches) across: 2024-09-24, 2024-09-25
#   Match 01 (day 38): Sheffield Utd vs Blackpool
#   Match 02 (day 38): Tottenham vs Wolves
#   Match 03 (day 38): West Brom vs Huddersfield
#   Match 04 (day 38): Nottingham Forest vs Luton
#   Match 05 (day 38): Brighton vs Shrewsbury
#   Match 06 (day 38): Chelsea vs Southampton
#   Match 07 (day 38): Swansea vs Fleetwood Town
#   Match 08 (day 39): Middlesbrough vs Wycombe
#   Match 09 (day 39): Bournemouth vs Arsenal
#   Match 10 (day 39): Manchester United vs Leicester
#   Match 11 (day 39): West Ham vs Liverpool
#   Match 12 (day 39): Manchester City vs Newcastle
#   Match 13 (day 39): Bristol City vs Northampton
#   Match 14 (day 39): Leeds vs Coventry
#   Match 15 (day 39): Aston Villa vs QPR
#   Match 16 (day 39): Crystal Palace vs Millwall
#
# === STEP 36: Play League Matches ===
#
# Matches played on 2024-09-06:
# Premier League
# Luton 0 - 1 West Ham
#
# === STEP 37: Play League Matches ===
#
# Matches played on 2024-09-07:
# Premier League
# Brighton 1 - 1 Newcastle
# Brentford 1 - 1 Bournemouth
# Manchester City 4 - 0 Fulham
# Chelsea 3 - 1 Nottingham Forest
# Burnley 0 - 1 Tottenham
# Sheffield Utd 1 - 1 Everton
# Championship
# Coventry 2 - 0 Watford
# Birmingham 2 - 1 Millwall
# Swansea 0 - 0 Bristol City
# Sunderland 0 - 1 Southampton
# Plymouth 1 - 1 Blackburn
# Leicester 1 - 1 Hull City
# Ipswich 1 - 2 Cardiff
# West Brom 1 - 0 Huddersfield
# Leeds 1 - 0 Sheffield Wednesday
# Middlesbrough 2 - 0 QPR
# Rotherham 1 - 1 Norwich
# Stoke City 1 - 0 Preston
# League One
# Burton Albion 1 - 1 Exeter City
# Leyton Orient 0 - 0 Stevenage
# Bristol Rovers 2 - 2 Lincoln
# Charlton 1 - 2 Fleetwood Town
# Northampton 2 - 2 Wycombe
# Oxford United 0 - 1 Port Vale
# Bolton 1 - 0 Derby
# Blackpool 0 - 1 Wigan
# Carlisle 1 - 1 Shrewsbury
# Cheltenham 2 - 0 Barnsley
# Portsmouth 0 - 0 Peterborough
# League Two
# Stockport County 2 - 0 Crawley Town
# Harrogate Town 1 - 0 Barrow
# Tranmere 1 - 2 Wrexham
# Walsall 3 - 0 Colchester
# Doncaster 1 - 1 Swindon Town
# Grimsby 1 - 0 Gillingham
# Newport County 2 - 1 AFC Wimbledon
# Mansfield Town 0 - 1 Bradford
# Morecambe 2 - 1 Salford City
# Notts County 0 - 1 Accrington ST
# Sutton Utd 2 - 1 Forest Green
# Crewe 1 - 4 Milton Keynes Dons
# National League
# Rochdale 3 - 1 FC Halifax Town
# Hartlepool 1 - 0 Wealdstone
# Aldershot Town 0 - 2 Chesterfield
# Dagenham & Redbridge 0 - 1 AFC Fylde
# Boreham Wood 2 - 1 Barnet
# Solihull Moors 0 - 0 Oxford City
# Maidenhead 1 - 2 Woking
# Ebbsfleet United 0 - 0 York
# Altrincham 0 - 2 Bromley
# Dorking Wanderers 1 - 0 Eastleigh
# Gateshead 0 - 2 Oldham
# Southend 4 - 0 Kidderminster Harriers
#
# === STEP 38: Play League Matches ===
#
# Matches played on 2024-09-01:
# Premier League
# Liverpool 1 - 1 Aston Villa
# Crystal Palace 2 - 0 Wolves
# Arsenal 4 - 1 Manchester United
#
# === STEP 39: Play League Matches ===
#
# Matches played on 2024-09-02:
# League One
# Cambridge United 0 - 1 Reading
#
# === STEP 40: Play League Matches ===
#
# Matches played on 2024-09-14:
# League One
# Exeter City 3 - 0 Leyton Orient
# Stevenage 3 - 1 Carlisle
# League Two
# Salford City 4 - 1 Walsall
# Wrexham 0 - 2 Doncaster
# Forest Green 1 - 1 Crewe
# Accrington ST 3 - 1 Mansfield Town
# Colchester 0 - 3 Tranmere
# Swindon Town 2 - 0 Sutton Utd
# Gillingham 3 - 2 Harrogate Town
# Bradford 0 - 0 Grimsby
# Crawley Town 0 - 0 Newport County
# AFC Wimbledon 3 - 2 Stockport County
# Milton Keynes Dons 0 - 1 Notts County
# National League
# Woking 2 - 0 Solihull Moors
# FC Halifax Town 2 - 2 Southend
# Chesterfield 4 - 0 Dagenham & Redbridge
# Oldham 2 - 0 Dorking Wanderers
# Barnet 1 - 0 Altrincham
# Eastleigh 3 - 1 Gateshead
# York 1 - 4 Boreham Wood
# Bromley 1 - 0 Maidenhead
# AFC Fylde 1 - 0 Aldershot Town
# Oxford City 1 - 4 Hartlepool
# Wealdstone 3 - 0 Ebbsfleet United
# Kidderminster Harriers 0 - 1 Rochdale
#
# === STEP 41: Play League Matches ===
#
# Matches played on 2024-09-20:
# Championship
# Southampton 0 - 0 Leicester
# Hull City 0 - 1 Coventry
# League Two
# Salford City 4 - 1 Notts County
#
# === STEP 42: Play League Matches ===
#
# Matches played on 2024-09-21:
# Premier League
# Wolves 1 - 2 Liverpool
# Manchester United 2 - 0 Brighton
# Fulham 1 - 1 Luton
# Tottenham 2 - 0 Sheffield Utd
# West Ham 1 - 4 Manchester City
# Aston Villa 1 - 0 Crystal Palace
# Newcastle 2 - 0 Brentford
# Championship
# Norwich 0 - 1 Stoke City
# Huddersfield 1 - 0 Rotherham
# Watford 2 - 0 Birmingham
# Bristol City 2 - 1 West Brom
# Preston 1 - 1 Plymouth
# Blackburn 0 - 1 Middlesbrough
# QPR 2 - 2 Sunderland
# Sheffield Wednesday 0 - 0 Ipswich
# Cardiff 0 - 2 Swansea
# League One
# Reading 0 - 0 Bolton
# Wigan 1 - 1 Cambridge United
# Derby 2 - 1 Portsmouth
# Barnsley 1 - 1 Burton Albion
# Fleetwood Town 1 - 2 Oxford United
# Peterborough 1 - 0 Leyton Orient
# Port Vale 0 - 0 Northampton
# Shrewsbury 2 - 2 Bristol Rovers
# Wycombe 3 - 0 Blackpool
# Stevenage 1 - 0 Charlton
# Lincoln 2 - 0 Carlisle
# Exeter City 0 - 2 Cheltenham
# League Two
# Bradford 2 - 0 Harrogate Town
# AFC Wimbledon 2 - 2 Crewe
# Gillingham 1 - 2 Morecambe
# Milton Keynes Dons 1 - 2 Stockport County
# Swindon Town 1 - 0 Walsall
# Accrington ST 2 - 0 Sutton Utd
# Forest Green 3 - 0 Doncaster
# Newport County 1 - 0 Barrow
# Crawley Town 1 - 2 Tranmere
# Colchester 0 - 2 Mansfield Town
# Wrexham 1 - 0 Grimsby
# National League
# Maidenhead 0 - 1 Boreham Wood
# Bromley 1 - 1 Oldham
# Kidderminster Harriers 0 - 0 Solihull Moors
# Aldershot Town 0 - 1 Gateshead
# Hartlepool 1 - 1 Woking
# Rochdale 3 - 0 Barnet
# York 0 - 0 Southend
# Oxford City 0 - 2 Dagenham & Redbridge
# Wealdstone 0 - 0 Altrincham
# FC Halifax Town 3 - 0 Dorking Wanderers
# AFC Fylde 3 - 0 Eastleigh
# Ebbsfleet United 1 - 1 Chesterfield
#
# === STEP 43: Play League Matches ===
#
# Matches played on 2024-09-15:
# Premier League
# Bournemouth 1 - 3 Chelsea
# Everton 2 - 0 Arsenal
# Championship
# Millwall 0 - 1 Leeds
#
# === STEP 44: Play League Matches ===
#
# Matches played on 2024-09-16:
# Premier League
# Nottingham Forest 1 - 0 Burnley
#
# === STEP 45: Play League Matches ===
#
# Matches played on 2024-09-17:
# Championship
# QPR 2 - 0 Swansea
# Sheffield Wednesday 0 - 1 Middlesbrough
# Bristol City 2 - 0 Plymouth
# Preston 2 - 0 Birmingham
# Cardiff 3 - 0 Coventry
# Southampton 1 - 0 Ipswich
# League One
# Port Vale 0 - 0 Burton Albion
# Barnsley 3 - 0 Portsmouth
# Peterborough 1 - 0 Cheltenham
# National League
# Southend 1 - 0 Maidenhead
# Chesterfield 2 - 0 FC Halifax Town
# Oldham 1 - 0 York
# Barnet 2 - 0 Aldershot Town
# Dagenham & Redbridge 1 - 3 Bromley
# Eastleigh 2 - 0 Oxford City
# Gateshead 4 - 1 Kidderminster Harriers
# Boreham Wood 1 - 2 Rochdale
# Altrincham 0 - 2 Hartlepool
# Dorking Wanderers 1 - 2 Wealdstone
# Woking 1 - 0 Ebbsfleet United
# Solihull Moors 2 - 1 AFC Fylde
# Champions League
# Real Madrid 2 - 0 BSC Young Boys
# Borussia Dortmund 2 - 0 Paris Saint Germain
# Benfica 1 - 1 Manchester City
# AC Milan 1 - 0 Union Berlin
# Bayern Munich 1 - 0 Newcastle
# Lazio 1 - 0 Ajax
# Arsenal 2 - 0 Antwerp
# Sevilla 3 - 2 SC Braga
#
# === STEP 46: Play League Matches ===
#
# Matches played on 2024-09-18:
# Championship
# Hull City 1 - 1 Leeds
# Norwich 2 - 1 Leicester
# Blackburn 0 - 1 Sunderland
# Huddersfield 3 - 0 Stoke City
# Watford 1 - 2 West Brom
# Millwall 4 - 1 Rotherham
# Champions League
# Feyenoord 3 - 1 Red Star Belgrade
# Barcelona 1 - 0 Celtic
# Lens 0 - 1 RB Leipzig
# PSV Eindhoven 1 - 2 Real Sociedad
# FC Copenhagen 1 - 0 Atletico Madrid
# Inter 2 - 2 FC Porto
# Manchester United 3 - 1 Galatasaray
# Red Bull Salzburg 1 - 3 Napoli
#
# === STEP 47: Play League Matches ===
#
# Matches played on 2024-09-19:
# Europa League
# Brighton 2 - 0 AEK Athens FC
# Sparta Praha 0 - 1 Atalanta
# Liverpool 3 - 1 SC Freiburg
# Marseille 1 - 0 Shakhtar Donetsk
# Slavia Praha 2 - 0 Lask Linz
# Panathinaikos 2 - 2 Rennes
# Sporting CP 0 - 2 Aston Villa
# Bayer Leverkusen 1 - 0 Villarreal
# Servette FC 3 - 0 TSC Backa Topola
# Toulouse 3 - 1 BK Hacken
# AS Roma 2 - 0 Qarabag
# Aris Limassol 0 - 3 Real Betis
# Tottenham 2 - 0 Sturm Graz
# Rangers 3 - 1 Sheriff Tiraspol
# Union St. Gilloise 2 - 1 Maccabi Haifa
# Olympiacos 0 - 1 Molde
#
# === STEP 48: Play League Matches ===
#
# Matches played on 2024-09-27:
# Championship
# Birmingham 0 - 2 QPR
#
# === STEP 49: Play League Matches ===
#
# Matches played on 2024-09-28:
# Premier League
# Manchester City 0 - 0 Nottingham Forest
# Crystal Palace 0 - 1 Fulham
# Luton 0 - 0 Wolves
# Brentford 1 - 2 Everton
# Burnley 0 - 0 Manchester United
# Championship
# Leicester 2 - 0 Bristol City
# West Brom 1 - 0 Millwall
# Leeds 1 - 2 Watford
# Middlesbrough 3 - 1 Southampton
# Rotherham 1 - 1 Preston
# Swansea 1 - 0 Sheffield Wednesday
# Plymouth 0 - 1 Norwich
# Ipswich 0 - 2 Blackburn
# League One
# Bolton 0 - 2 Peterborough
# Cambridge United 2 - 1 Port Vale
# Leyton Orient 1 - 1 Shrewsbury
# Burton Albion 2 - 1 Fleetwood Town
# Carlisle 0 - 1 Derby
# Bristol Rovers 0 - 2 Wigan
# Charlton 1 - 3 Wycombe
# Northampton 0 - 2 Barnsley
# Oxford United 0 - 0 Exeter City
# Portsmouth 2 - 1 Lincoln
# Blackpool 0 - 1 Reading
# Cheltenham 2 - 0 Stevenage
# League Two
# Morecambe 2 - 2 Swindon Town
# Mansfield Town 0 - 1 Barrow
# Newport County 1 - 2 Bradford
# Grimsby 2 - 1 Crawley Town
# Crewe 1 - 0 Colchester
# Doncaster 1 - 1 Gillingham
# Walsall 3 - 0 AFC Wimbledon
# Stockport County 0 - 1 Wrexham
# Harrogate Town 2 - 0 Salford City
# Sutton Utd 0 - 1 Milton Keynes Dons
# Tranmere 2 - 3 Accrington ST
# Notts County 1 - 0 Forest Green
# National League
# Altrincham 2 - 0 Ebbsfleet United
# Dorking Wanderers 0 - 5 Rochdale
# Solihull Moors 3 - 2 Bromley
# Boreham Wood 3 - 0 Aldershot Town
# Eastleigh 1 - 0 Kidderminster Harriers
# Woking 3 - 1 York
# Southend 3 - 1 AFC Fylde
# Chesterfield 2 - 0 Wealdstone
# Barnet 3 - 1 FC Halifax Town
# Dagenham & Redbridge 2 - 1 Hartlepool
# Gateshead 2 - 0 Maidenhead
# Oldham 1 - 0 Oxford City
#
# === STEP 50: Play League Matches ===
#
# Matches played on 2024-09-22:
# Premier League
# Liverpool 2 - 0 West Ham
# Arsenal 3 - 1 Tottenham
# Brighton 1 - 1 Bournemouth
# Sheffield Utd 0 - 3 Newcastle
# Chelsea 0 - 1 Aston Villa
# Championship
# Sunderland 1 - 1 Cardiff
# Stoke City 1 - 0 Hull City
#
# === STEP 51: Play League Matches ===
#
# Matches played on 2024-09-23:
# Championship
# Coventry 1 - 0 Huddersfield
#
# === STEP 52: Play League Matches ===
#
# Matches played on 2024-09-24:
# National League
# Hartlepool 1 - 0 Solihull Moors
# Aldershot Town 0 - 0 Southend
# York 0 - 2 Barnet
# Bromley 3 - 3 Eastleigh
# Wealdstone 1 - 1 Woking
# Maidenhead 2 - 2 Altrincham
# AFC Fylde 0 - 4 Boreham Wood
# Ebbsfleet United 1 - 1 Dorking Wanderers
# FC Halifax Town 3 - 2 Dagenham & Redbridge
# Oxford City 2 - 1 Gateshead
# Kidderminster Harriers 0 - 1 Oldham
# Rochdale 2 - 0 Chesterfield
#
# === STEP 53: Play Cup Round ===
# Day 38 | League Cup | Sheffield Utd 4–2 Blackpool (a.e.t.) → Winner: Sheffield Utd
# Day 38 | League Cup | Tottenham 2–1 Wolves → Winner: Tottenham
# Day 38 | League Cup | West Brom 3–0 Huddersfield → Winner: West Brom
# Day 38 | League Cup | Nottingham Forest 2–0 Luton → Winner: Nottingham Forest
# Day 38 | League Cup | Brighton 3–1 Shrewsbury → Winner: Brighton
# Day 38 | League Cup | Chelsea 2–0 Southampton → Winner: Chelsea
# Day 38 | League Cup | Swansea 4–1 Fleetwood Town → Winner: Swansea
#
# === STEP 54: Play Cup Round ===
# Day 39 | League Cup | Middlesbrough 0–0 Wycombe (a.e.t.) [p 3–4] → Winner: Wycombe
# Day 39 | League Cup | Bournemouth 2–1 Arsenal → Winner: Bournemouth
# Day 39 | League Cup | Manchester United 2–0 Leicester → Winner: Manchester United
# Day 39 | League Cup | West Ham 1–0 Liverpool → Winner: West Ham
# Day 39 | League Cup | Manchester City 3–0 Newcastle → Winner: Manchester City
# Day 39 | League Cup | Bristol City 2–0 Northampton → Winner: Bristol City
# Day 39 | League Cup | Leeds 2–0 Coventry → Winner: Leeds
# Day 39 | League Cup | Aston Villa 4–0 QPR → Winner: Aston Villa
# Day 39 | League Cup | Crystal Palace 1–1 Millwall (a.e.t.) [p 2–3] → Winner: Millwall
#
# === STEP 55: Update Cup Status ===
# Day 38 | League Cup | Knocked out: Blackpool → inLC = False
# Day 38 | League Cup | Knocked out: Wolves → inLC = False
# Day 38 | League Cup | Knocked out: Huddersfield → inLC = False
# Day 38 | League Cup | Knocked out: Luton → inLC = False
# Day 38 | League Cup | Knocked out: Shrewsbury → inLC = False
# Day 38 | League Cup | Knocked out: Southampton → inLC = False
# Day 38 | League Cup | Knocked out: Fleetwood Town → inLC = False
# Day 39 | League Cup | Knocked out: Middlesbrough → inLC = False
# Day 39 | League Cup | Knocked out: Arsenal → inLC = False
# Day 39 | League Cup | Knocked out: Leicester → inLC = False
# Day 39 | League Cup | Knocked out: Liverpool → inLC = False
# Day 39 | League Cup | Knocked out: Newcastle → inLC = False
# Day 39 | League Cup | Knocked out: Northampton → inLC = False
# Day 39 | League Cup | Knocked out: Coventry → inLC = False
# Day 39 | League Cup | Knocked out: QPR → inLC = False
# Day 39 | League Cup | Knocked out: Crystal Palace → inLC = False
#
# === STEP 56: Draw Cup ===
#
# 🏆 League Cup draw (8 matches) across: 2024-10-29, 2024-11-06
#   Match 01 (day 63): West Brom vs Nottingham Forest
#   Match 02 (day 63): Millwall vs Tottenham
#   Match 03 (day 64): West Ham vs Chelsea
#   Match 04 (day 64): Manchester City vs Swansea
#   Match 05 (day 64): Bournemouth vs Leeds
#   Match 06 (day 64): Wycombe vs Bristol City
#   Match 07 (day 64): Sheffield Utd vs Brighton
#   Match 08 (day 64): Aston Villa vs Manchester United
#
# === STEP 57: Play League Matches ===
#
# Matches played on 2024-09-27:
# Championship
# Sheffield Wednesday 1 - 1 Sunderland
#
# === STEP 58: Play League Matches ===
#
# Matches played on 2024-09-28:
# Premier League
# Aston Villa 1 - 0 Brighton
# Manchester United 1 - 0 Crystal Palace
# Newcastle 2 - 0 Burnley
# Wolves 0 - 1 Manchester City
# Everton 1 - 0 Luton
# West Ham 1 - 1 Sheffield Utd
# Bournemouth 2 - 5 Arsenal
# Tottenham 0 - 1 Liverpool
# Championship
# Norwich 1 - 1 Birmingham
# QPR 0 - 2 Coventry
# Hull City 3 - 0 Plymouth
# Watford 0 - 0 Middlesbrough
# Huddersfield 1 - 0 Ipswich
# Southampton 0 - 0 Leeds
# Millwall 3 - 2 Swansea
# Preston 1 - 1 West Brom
# Cardiff 3 - 0 Rotherham
# Bristol City 4 - 0 Stoke City
# League One
# Reading 3 - 1 Burton Albion
# Port Vale 2 - 3 Bolton
# Derby 3 - 1 Cambridge United
# Barnsley 1 - 0 Blackpool
# Fleetwood Town 1 - 0 Leyton Orient
# Peterborough 2 - 1 Bristol Rovers
# Shrewsbury 1 - 0 Charlton
# Wycombe 2 - 0 Carlisle
# Exeter City 0 - 2 Northampton
# Stevenage 4 - 0 Oxford United
# Lincoln 1 - 0 Cheltenham
# Wigan 2 - 1 Portsmouth
# League Two
# Gillingham 2 - 1 Mansfield Town
# Salford City 0 - 2 Newport County
# Colchester 4 - 1 Notts County
# Accrington ST 0 - 0 Stockport County
# Swindon Town 2 - 0 Grimsby
# Milton Keynes Dons 1 - 1 Harrogate Town
# AFC Wimbledon 2 - 0 Tranmere
# Crawley Town 2 - 1 Sutton Utd
# Forest Green 0 - 0 Morecambe
# Barrow 1 - 0 Doncaster
# Wrexham 0 - 1 Crewe
# Bradford 3 - 0 Walsall
# National League
# Hartlepool 1 - 0 Dorking Wanderers
# Rochdale 3 - 1 Southend
# Aldershot Town 1 - 2 Dagenham & Redbridge
# York 2 - 1 Solihull Moors
# Oxford City 1 - 1 Altrincham
# Wealdstone 1 - 2 Oldham
# Kidderminster Harriers 0 - 1 Barnet
# FC Halifax Town 3 - 2 Eastleigh
# Ebbsfleet United 0 - 2 Boreham Wood
# Bromley 2 - 3 Gateshead
# AFC Fylde 1 - 0 Woking
# Maidenhead 0 - 2 Chesterfield
#
# === STEP 59: Play League Matches ===
#
# Matches played on 2024-10-06:
# Premier League
# Nottingham Forest 0 - 0 Brentford
# Championship
# Blackburn 0 - 0 Leicester
#
# === STEP 60: Play League Matches ===
#
# Matches played on 2024-10-07:
# Premier League
# Fulham 1 - 1 Chelsea
# Luton 0 - 1 Burnley
#
# === STEP 61: Play League Matches ===
#
# Matches played on 2024-10-01:
# Championship
# Stoke City 0 - 2 Southampton
# West Brom 4 - 0 Sheffield Wednesday
# Plymouth 1 - 0 Millwall
# Middlesbrough 1 - 0 Cardiff
# Ipswich 0 - 1 Hull City
# Birmingham 2 - 1 Huddersfield
# League One
# Northampton 1 - 3 Reading
# Blackpool 2 - 0 Derby
# Cambridge United 2 - 0 Barnsley
# Carlisle 0 - 0 Peterborough
# Cheltenham 0 - 1 Fleetwood Town
# Charlton 1 - 0 Exeter City
# Portsmouth 1 - 1 Wycombe
# Oxford United 2 - 1 Shrewsbury
# Bristol Rovers 3 - 0 Port Vale
# Bolton 3 - 0 Stevenage
# Burton Albion 2 - 0 Wigan
# League Two
# Grimsby 1 - 2 Barrow
# Harrogate Town 1 - 2 AFC Wimbledon
# Sutton Utd 2 - 4 Salford City
# Tranmere 0 - 3 Bradford
# Morecambe 0 - 0 Accrington ST
# Mansfield Town 3 - 0 Wrexham
# Newport County 2 - 1 Colchester
# Crewe 1 - 1 Gillingham
# Doncaster 0 - 0 Crawley Town
# Walsall 0 - 2 Milton Keynes Dons
# Stockport County 1 - 2 Forest Green
# Notts County 1 - 1 Swindon Town
# National League
# Chesterfield 1 - 0 Bromley
# Southend 2 - 0 Oxford City
# Oldham 2 - 0 Maidenhead
# Barnet 1 - 0 AFC Fylde
# Dagenham & Redbridge 3 - 0 York
# Eastleigh 1 - 0 Ebbsfleet United
# Gateshead 0 - 2 Wealdstone
# Solihull Moors 0 - 2 Rochdale
# Woking 5 - 0 FC Halifax Town
# Altrincham 3 - 0 Aldershot Town
# Dorking Wanderers 1 - 0 Kidderminster Harriers
# Champions League
# Real Madrid 1 - 0 Paris Saint Germain
# BSC Young Boys 1 - 3 Borussia Dortmund
# Benfica 1 - 0 Union Berlin
# Manchester City 1 - 1 AC Milan
# Bayern Munich 3 - 1 Ajax
# Newcastle 0 - 0 Lazio
# Arsenal 1 - 0 SC Braga
# Antwerp 0 - 2 Sevilla
#
# === STEP 62: Play League Matches ===
#
# Matches played on 2024-10-02:
# Championship
# Rotherham 0 - 2 Bristol City
# Coventry 0 - 0 Blackburn
# Sunderland 1 - 1 Watford
# Swansea 2 - 1 Norwich
# Leeds 0 - 0 QPR
# Leicester 1 - 2 Preston
# National League
# Boreham Wood 4 - 0 Hartlepool
# Champions League
# Feyenoord 1 - 0 Celtic
# Red Star Belgrade 0 - 0 Barcelona
# Lens 1 - 3 Real Sociedad
# RB Leipzig 2 - 1 PSV Eindhoven
# FC Copenhagen 0 - 0 FC Porto
# Atletico Madrid 1 - 1 Inter
# Manchester United 2 - 1 Napoli
# Galatasaray 2 - 0 Red Bull Salzburg
#
# === STEP 63: Play League Matches ===
#
# Matches played on 2024-10-03:
# Europa League
# Brighton 1 - 2 Atalanta
# AEK Athens FC 2 - 2 Sparta Praha
# Liverpool 2 - 0 Shakhtar Donetsk
# SC Freiburg 0 - 1 Marseille
# Slavia Praha 1 - 0 Rennes
# Lask Linz 2 - 0 Panathinaikos
# Sporting CP 0 - 1 Villarreal
# Aston Villa 1 - 0 Bayer Leverkusen
# Servette FC 0 - 1 BK Hacken
# TSC Backa Topola 0 - 2 Toulouse
# AS Roma 1 - 1 Real Betis
# Qarabag 2 - 0 Aris Limassol
# Tottenham 1 - 0 Sheriff Tiraspol
# Sturm Graz 0 - 3 Rangers
# Union St. Gilloise 0 - 1 Molde
# Maccabi Haifa 1 - 0 Olympiacos
#
# === STEP 64: Play League Matches ===
#
# Matches played on 2024-10-04:
# Championship
# Birmingham 0 - 2 West Brom
#
# === STEP 65: Play League Matches ===
#
# Matches played on 2024-10-05:
# Premier League
# Manchester United 2 - 1 Brentford
# Fulham 2 - 0 Sheffield Utd
# Burnley 0 - 0 Chelsea
# Everton 1 - 0 Bournemouth
# Crystal Palace 1 - 0 Nottingham Forest
# Luton 0 - 1 Tottenham
# Championship
# Plymouth 1 - 1 Swansea
# Sunderland 0 - 3 Middlesbrough
# Southampton 2 - 1 Rotherham
# Cardiff 2 - 1 Watford
# Leicester 3 - 0 Stoke City
# Ipswich 0 - 0 Preston
# Millwall 2 - 0 Hull City
# Leeds 4 - 0 Bristol City
# QPR 1 - 2 Blackburn
# Sheffield Wednesday 1 - 0 Huddersfield
# Coventry 0 - 1 Norwich
# League One
# Oxford United 0 - 2 Bristol Rovers
# Bolton 1 - 0 Carlisle
# Charlton 0 - 1 Blackpool
# Fleetwood Town 1 - 0 Wycombe
# Peterborough 1 - 1 Lincoln
# Shrewsbury 1 - 0 Northampton
# Portsmouth 2 - 0 Port Vale
# Exeter City 3 - 1 Barnsley
# Cheltenham 3 - 2 Derby
# Stevenage 1 - 3 Wigan
# Leyton Orient 1 - 1 Reading
# League Two
# Stockport County 2 - 0 Doncaster
# Barrow 3 - 2 Notts County
# Tranmere 2 - 2 Grimsby
# Mansfield Town 4 - 0 AFC Wimbledon
# Newport County 3 - 0 Harrogate Town
# Crawley Town 3 - 1 Wrexham
# Colchester 0 - 1 Morecambe
# Accrington ST 3 - 1 Forest Green
# Gillingham 2 - 0 Milton Keynes Dons
# Bradford 2 - 0 Swindon Town
# Salford City 1 - 2 Crewe
# Sutton Utd 1 - 2 Walsall
# National League
# Hartlepool 2 - 0 Eastleigh
# Dorking Wanderers 2 - 1 Barnet
# Kidderminster Harriers 0 - 1 Wealdstone
# Oxford City 0 - 2 AFC Fylde
# Ebbsfleet United 0 - 2 FC Halifax Town
# Maidenhead 0 - 4 Rochdale
# Woking 0 - 3 Southend
# Solihull Moors 1 - 0 Aldershot Town
# Boreham Wood 1 - 3 Chesterfield
# York 1 - 1 Bromley
# Gateshead 0 - 2 Altrincham
# Oldham 2 - 0 Dagenham & Redbridge
#
# === STEP 66: Play League Matches ===
#
# Matches played on 2024-10-13:
# Premier League
# Arsenal 1 - 2 Manchester City
# Brighton 3 - 0 Liverpool
# West Ham 1 - 2 Newcastle
# Wolves 0 - 4 Aston Villa
#
# === STEP 67: Play League Matches ===
#
# Matches played on 2024-10-14:
# League One
# Burton Albion 3 - 2 Cambridge United
#
# === STEP 68: Play League Matches ===
#
# Matches played on 2024-10-12:
# League One
# Lincoln 4 - 0 Burton Albion
# Carlisle 0 - 2 Leyton Orient
# Cambridge United 1 - 0 Shrewsbury
# Blackpool 1 - 0 Stevenage
# League Two
# Crewe 2 - 1 Tranmere
# Grimsby 1 - 1 Accrington ST
# Doncaster 0 - 0 Sutton Utd
# Swindon Town 0 - 4 Newport County
# Walsall 0 - 2 Gillingham
# Forest Green 4 - 0 Colchester
# AFC Wimbledon 1 - 2 Bradford
# Notts County 1 - 1 Mansfield Town
# Milton Keynes Dons 4 - 1 Barrow
# Wrexham 2 - 2 Salford City
# Harrogate Town 0 - 2 Stockport County
#
# === STEP 69: Draw Cup ===
#
# 🏆 FA Cup draw (40 matches) across: 2024-11-01, 2024-11-02, 2024-11-03
#   Match 01 (day 65): Cheltenham vs Lincoln
#   Match 02 (day 65): Barnsley vs Mansfield Town
#   Match 03 (day 65): Derby vs Gateshead
#   Match 04 (day 66): Wrexham vs Ebbsfleet United
#   Match 05 (day 66): York vs Accrington ST
#   Match 06 (day 66): Milton Keynes Dons vs Barnet
#   Match 07 (day 66): Grimsby vs Bradford
#   Match 08 (day 66): Bromley vs Morecambe
#   Match 09 (day 66): Cambridge United vs Dagenham & Redbridge
#   Match 10 (day 66): Kidderminster Harriers vs Maidstone Utd
#   Match 11 (day 66): AFC Wimbledon vs Carlisle
#   Match 12 (day 66): Exeter City vs Reading
#   Match 13 (day 66): Yeovil Town vs Newport County
#   Match 14 (day 66): FC Halifax Town vs Salford City
#   Match 15 (day 66): Leyton Orient vs Cray Valley PM
#   Match 16 (day 66): Walsall vs Gillingham
#   Match 17 (day 66): Charlton vs Sheppey United
#   Match 18 (day 66): Wealdstone vs Shrewsbury
#   Match 19 (day 66): Crawley Town vs Swindon Town
#   Match 20 (day 66): Slough Town vs Chesham United
#   Match 21 (day 66): Chester vs Peterborough
#   Match 22 (day 66): Oldham vs Harrogate Town
#   Match 23 (day 66): Southend vs Burton Albion
#   Match 24 (day 66): Blackpool vs Doncaster
#   Match 25 (day 66): Notts County vs Worthing
#   Match 26 (day 66): Stevenage vs Bristol Rovers
#   Match 27 (day 66): Stockport County vs Sutton Utd
#   Match 28 (day 66): Curzon Ashton vs Scarborough Athletic
#   Match 29 (day 66): Solihull Moors vs Colchester
#   Match 30 (day 66): Barrow vs Bracknell Town
#   Match 31 (day 66): Horsham vs Marine
#   Match 32 (day 66): AFC Fylde vs Forest Green
#   Match 33 (day 66): Portsmouth vs Oxford City
#   Match 34 (day 66): Chesterfield vs Tranmere
#   Match 35 (day 66): Hereford vs Wigan
#   Match 36 (day 67): Crewe vs Fleetwood Town
#   Match 37 (day 67): Port Vale vs Dorking Wanderers
#   Match 38 (day 67): Oxford United vs Alfreton Town
#   Match 39 (day 67): Wycombe vs Northampton
#   Match 40 (day 67): Bolton vs Whitby Town
#
# === STEP 70: Play League Matches ===
#
# Matches played on 2024-10-18:
# League Two
# Newport County 4 - 0 Walsall
# Tranmere 0 - 1 Doncaster
#
# === STEP 71: Play League Matches ===
#
# Matches played on 2024-10-19:
# Premier League
# Sheffield Utd 1 - 0 Manchester United
# Chelsea 0 - 2 Arsenal
# Nottingham Forest 1 - 1 Luton
# Bournemouth 1 - 0 Wolves
# Newcastle 3 - 0 Crystal Palace
# Liverpool 0 - 0 Everton
# Manchester City 2 - 2 Brighton
# Brentford 2 - 0 Burnley
# Championship
# Swansea 0 - 1 Leicester
# Norwich 2 - 2 Leeds
# Middlesbrough 2 - 0 Birmingham
# Blackburn 0 - 1 Cardiff
# Hull City 2 - 2 Southampton
# West Brom 4 - 0 Plymouth
# Bristol City 0 - 5 Coventry
# Watford 0 - 0 Sheffield Wednesday
# Huddersfield 0 - 0 QPR
# Preston 0 - 2 Millwall
# Stoke City 0 - 1 Sunderland
# League One
# Bolton 2 - 0 Northampton
# Leyton Orient 1 - 3 Barnsley
# Cheltenham 0 - 0 Cambridge United
# Stevenage 0 - 0 Port Vale
# Exeter City 0 - 3 Wigan
# Charlton 1 - 1 Reading
# Shrewsbury 3 - 2 Derby
# Peterborough 1 - 0 Wycombe
# Oxford United 0 - 1 Blackpool
# Fleetwood Town 1 - 0 Lincoln
# Burton Albion 0 - 1 Bristol Rovers
# Portsmouth 2 - 0 Carlisle
# League Two
# Barrow 0 - 0 AFC Wimbledon
# Crawley Town 1 - 1 Crewe
# Colchester 0 - 4 Harrogate Town
# Accrington ST 1 - 1 Milton Keynes Dons
# Sutton Utd 0 - 5 Morecambe
# Salford City 3 - 0 Swindon Town
# Bradford 3 - 0 Wrexham
# Stockport County 1 - 1 Grimsby
# Gillingham 0 - 1 Notts County
# National League
# Southend 1 - 0 Solihull Moors
# Barnet 5 - 0 Maidenhead
# Aldershot Town 1 - 3 Hartlepool
# Dagenham & Redbridge 2 - 0 Woking
# Eastleigh 1 - 0 York
# Bromley 1 - 1 Oxford City
# AFC Fylde 0 - 0 Ebbsfleet United
# FC Halifax Town 4 - 0 Kidderminster Harriers
# Wealdstone 1 - 1 Boreham Wood
# Rochdale 5 - 1 Oldham
#
# === STEP 72: Play League Matches ===
#
# Matches played on 2024-10-27:
# Premier League
# Aston Villa 3 - 0 West Ham
#
# === STEP 73: Play League Matches ===
#
# Matches played on 2024-10-28:
# Premier League
# Tottenham 2 - 1 Fulham
#
# === STEP 74: Play League Matches ===
#
# Matches played on 2024-10-22:
# Championship
# West Brom 0 - 0 QPR
# Huddersfield 0 - 1 Cardiff
# Swansea 3 - 3 Watford
# Norwich 1 - 1 Middlesbrough
# Millwall 0 - 2 Blackburn
# Leicester 0 - 2 Sunderland
# League One
# Wigan 1 - 1 Oxford United
# Derby 1 - 1 Exeter City
# Barnsley 1 - 0 Shrewsbury
# Cambridge United 0 - 2 Portsmouth
# Northampton 0 - 2 Leyton Orient
# Blackpool 1 - 1 Cheltenham
# Wycombe 1 - 0 Bolton
# Carlisle 0 - 4 Burton Albion
# Bristol Rovers 1 - 0 Stevenage
# Lincoln 3 - 0 Charlton
# Reading 3 - 0 Fleetwood Town
# Port Vale 1 - 1 Peterborough
# League Two
# AFC Wimbledon 0 - 1 Accrington ST
# Milton Keynes Dons 1 - 1 Bradford
# Swindon Town 1 - 1 Gillingham
# Doncaster 1 - 1 Salford City
# Crewe 2 - 2 Stockport County
# Grimsby 1 - 0 Colchester
# Morecambe 2 - 0 Tranmere
# Notts County 0 - 0 Newport County
# Forest Green 3 - 0 Barrow
# Wrexham 0 - 0 Sutton Utd
# Harrogate Town 1 - 3 Mansfield Town
# Walsall 1 - 2 Crawley Town
# National League
# Wealdstone 5 - 0 Oxford City
# Altrincham 2 - 0 Kidderminster Harriers
# FC Halifax Town 0 - 0 Hartlepool
# AFC Fylde 2 - 2 Oldham
# Bromley 0 - 0 Dorking Wanderers
# Eastleigh 1 - 0 Woking
# Dagenham & Redbridge 0 - 1 Boreham Wood
# Aldershot Town 0 - 1 Maidenhead
# Barnet 1 - 1 Solihull Moors
# Chesterfield 2 - 0 York
# Southend 3 - 0 Ebbsfleet United
# Rochdale 2 - 1 Gateshead
# Champions League
# Real Madrid 1 - 2 Borussia Dortmund
# Paris Saint Germain 1 - 0 BSC Young Boys
# Benfica 1 - 1 AC Milan
# Union Berlin 1 - 1 Manchester City
# Bayern Munich 2 - 1 Lazio
# Ajax 1 - 0 Newcastle
# Arsenal 1 - 0 Sevilla
# SC Braga 1 - 0 Antwerp
#
# === STEP 75: Play League Matches ===
#
# Matches played on 2024-10-23:
# Championship
# Stoke City 0 - 2 Leeds
# Plymouth 1 - 0 Sheffield Wednesday
# ...
# Championship
# Rotherham 1 - 2 Leeds
#
# === STEP 106: Play League Matches ===
#
# Matches played on 2024-11-23:
# Premier League
# Brentford 1 - 0 Arsenal
# Luton 0 - 1 Crystal Palace
# Nottingham Forest 1 - 1 Brighton
# Sheffield Utd 1 - 0 Bournemouth
# Burnley 1 - 2 West Ham
# Newcastle 2 - 0 Chelsea
# Manchester City 1 - 0 Liverpool
# Championship
# Swansea 1 - 0 Hull City
# Plymouth 1 - 1 Sunderland
# West Brom 2 - 1 Ipswich
# Huddersfield 0 - 2 Southampton
# Leicester 2 - 0 Watford
# Birmingham 2 - 0 Sheffield Wednesday
# Bristol City 1 - 1 Middlesbrough
# Millwall 1 - 1 Coventry
# Preston 0 - 1 Cardiff
# Norwich 1 - 1 QPR
# Stoke City 2 - 3 Blackburn
# League One
# Fleetwood Town 2 - 1 Stevenage
# Shrewsbury 0 - 0 Port Vale
# Portsmouth 1 - 2 Blackpool
# Leyton Orient 0 - 1 Wigan
# Lincoln 1 - 0 Barnsley
# Bolton 3 - 0 Exeter City
# Wycombe 2 - 0 Reading
# Northampton 0 - 1 Cambridge United
# Cheltenham 1 - 1 Oxford United
# Derby 1 - 1 Bristol Rovers
# Carlisle 1 - 1 Charlton
# Peterborough 0 - 1 Burton Albion
# League Two
# Wrexham 1 - 4 Morecambe
# Salford City 0 - 0 Milton Keynes Dons
# Newport County 0 - 1 Stockport County
# Grimsby 2 - 1 Sutton Utd
# Crewe 0 - 1 Doncaster
# Crawley Town 1 - 2 Harrogate Town
# Colchester 1 - 4 Barrow
# Swindon Town 0 - 2 Mansfield Town
# Bradford 2 - 0 Accrington ST
# Walsall 0 - 2 Forest Green
# AFC Wimbledon 2 - 1 Notts County
# Tranmere 2 - 2 Gillingham
# National League
# Chesterfield 1 - 0 Eastleigh
# AFC Fylde 4 - 0 Dorking Wanderers
# Wealdstone 1 - 2 Barnet
# Boreham Wood 2 - 0 Woking
# Maidenhead 0 - 1 York
# Gateshead 0 - 1 Southend
# Dagenham & Redbridge 0 - 1 Rochdale
# Altrincham 0 - 2 Solihull Moors
# Hartlepool 0 - 1 Bromley
# Oldham 0 - 0 Ebbsfleet United
# Aldershot Town 1 - 2 FC Halifax Town
# Oxford City 2 - 0 Kidderminster Harriers
#
# === STEP 107: Play League Matches ===
#
# Matches played on 2024-11-24:
# Premier League
# Everton 1 - 1 Manchester United
# Tottenham 1 - 2 Aston Villa
#
# === STEP 108: Play League Matches ===
#
# Matches played on 2024-11-25:
# Premier League
# Fulham 2 - 0 Wolves
#
# === STEP 109: Play League Matches ===
#
# Matches played on 2024-11-26:
# Championship
# Cardiff 3 - 1 West Brom
# Hull City 2 - 2 Rotherham
# Middlesbrough 2 - 0 Preston
# Watford 2 - 1 Norwich
# QPR 2 - 1 Stoke City
# Coventry 4 - 0 Plymouth
# League One
# Port Vale 0 - 1 Derby
# Cambridge United 1 - 0 Lincoln
# Oxford United 0 - 2 Bolton
# Reading 2 - 0 Carlisle
# Charlton 0 - 2 Cheltenham
# Bristol Rovers 1 - 1 Leyton Orient
# Burton Albion 2 - 1 Portsmouth
# Barnsley 2 - 0 Wycombe
# Wigan 1 - 0 Fleetwood Town
# Blackpool 4 - 0 Northampton
# Exeter City 0 - 2 Shrewsbury
# Stevenage 0 - 1 Peterborough
# League Two
# Harrogate Town 3 - 0 Wrexham
# Stockport County 0 - 1 Salford City
# Gillingham 1 - 2 AFC Wimbledon
# Doncaster 2 - 0 Colchester
# Milton Keynes Dons 1 - 0 Grimsby
# Accrington ST 1 - 0 Swindon Town
# Mansfield Town 3 - 0 Tranmere
# Morecambe 0 - 0 Newport County
# Notts County 1 - 0 Crawley Town
# Forest Green 0 - 0 Bradford
# Barrow 2 - 0 Walsall
# Sutton Utd 2 - 1 Crewe
# Champions League
# Paris Saint Germain 0 - 2 Real Madrid
# Borussia Dortmund 2 - 0 BSC Young Boys
# Union Berlin 2 - 2 Benfica
# AC Milan 2 - 2 Manchester City
# Ajax 0 - 2 Bayern Munich
# Lazio 1 - 0 Newcastle
# SC Braga 0 - 0 Arsenal
# Sevilla 0 - 0 Antwerp
#
# === STEP 110: Play League Matches ===
#
# Matches played on 2024-11-27:
# Championship
# Sheffield Wednesday 1 - 0 Leicester
# Sunderland 0 - 0 Huddersfield
# Leeds 2 - 1 Swansea
# Ipswich 1 - 2 Millwall
# Southampton 2 - 2 Bristol City
# Blackburn 1 - 1 Birmingham
# Champions League
# Celtic 1 - 1 Feyenoord
# Barcelona 3 - 0 Red Star Belgrade
# Real Sociedad 2 - 0 Lens
# PSV Eindhoven 1 - 1 RB Leipzig
# FC Porto 1 - 0 FC Copenhagen
# Inter 1 - 1 Atletico Madrid
# Napoli 0 - 2 Manchester United
# Red Bull Salzburg 2 - 0 Galatasaray
#
# === STEP 111: Play League Matches ===
#
# Matches played on 2024-11-28:
# Europa League
# Atalanta 0 - 1 Brighton
# Sparta Praha 2 - 1 AEK Athens FC
# Shakhtar Donetsk 0 - 1 Liverpool
# Marseille 4 - 0 SC Freiburg
# Rennes 2 - 4 Slavia Praha
# Panathinaikos 0 - 0 Lask Linz
# Villarreal 4 - 1 Sporting CP
# Bayer Leverkusen 3 - 1 Aston Villa
# BK Hacken 0 - 1 Servette FC
# Toulouse 0 - 0 TSC Backa Topola
# Real Betis 1 - 2 AS Roma
# Aris Limassol 1 - 1 Qarabag
# Sheriff Tiraspol 1 - 0 Tottenham
# Rangers 2 - 0 Sturm Graz
# Molde 0 - 0 Union St. Gilloise
# Olympiacos 4 - 3 Maccabi Haifa
#
# === STEP 112: Play League Matches ===
#
# Matches played on 2024-12-06:
# Championship
# Preston 3 - 2 QPR
#
# === STEP 113: Play Cup Round ===
# Day 85 | FA Cup | AFC Fylde 0–1 Tranmere → Winner: Tranmere
# Day 85 | FA Cup | Carlisle 2–1 Portsmouth (a.e.t.) → Winner: Carlisle
#
# === STEP 114: Play League Matches ===
#
# Matches played on 2024-12-07:
# Premier League
# Brentford 0 - 1 Luton
# Burnley 3 - 1 Sheffield Utd
# Arsenal 1 - 0 Wolves
# Newcastle 2 - 3 Manchester United
# Nottingham Forest 2 - 0 Everton
# Championship
# Plymouth 1 - 1 Stoke City
# Swansea 3 - 0 Huddersfield
# Sheffield Wednesday 0 - 1 Blackburn
# Hull City 1 - 2 Watford
# Leeds 2 - 1 Middlesbrough
# Millwall 1 - 1 Sunderland
# Ipswich 1 - 0 Coventry
# Birmingham 0 - 0 Rotherham
# Southampton 3 - 0 Cardiff
# West Brom 0 - 1 Leicester
# League One
# Northampton 0 - 1 Portsmouth
# National League
# Kidderminster Harriers 0 - 1 Ebbsfleet United
# Oxford City 1 - 1 Maidenhead
# Bromley 0 - 2 Rochdale
#
# === STEP 115: Play Cup Round ===
# Day 86 | FA Cup | Gillingham 0–3 Milton Keynes Dons → Winner: Milton Keynes Dons
# Day 86 | FA Cup | Chesham United 1–2 Blackpool (a.e.t.) → Winner: Blackpool
# Day 86 | FA Cup | Wycombe 2–1 Charlton (a.e.t.) → Winner: Wycombe
# Day 86 | FA Cup | Morecambe 0–1 Barnsley → Winner: Barnsley
# Day 86 | FA Cup | Newport County 0–1 Port Vale → Winner: Port Vale
# Day 86 | FA Cup | Derby 4–0 Leyton Orient → Winner: Derby
# Day 86 | FA Cup | Cambridge United 2–0 Marine (a.e.t.) → Winner: Cambridge United
# Day 86 | FA Cup | Wigan 3–0 Peterborough → Winner: Wigan
# Day 86 | FA Cup | Notts County 3–3 Reading (a.e.t.) [p 3–4] → Winner: Reading
# Day 86 | FA Cup | Scarborough Athletic 0–2 Bolton → Winner: Bolton
#
# === STEP 116: Play League Matches ===
#
# Matches played on 2024-12-01:
# Premier League
# Chelsea 2 - 0 Brighton
# Liverpool 1 - 0 Fulham
# Bournemouth 1 - 1 Aston Villa
# Manchester City 2 - 0 Tottenham
# West Ham 1 - 2 Crystal Palace
# Championship
# Bristol City 2 - 1 Norwich
#
# === STEP 117: Play Cup Round ===
# Day 87 | FA Cup | Oxford United 3–0 Barrow → Winner: Oxford United
# Day 87 | FA Cup | Wrexham 1–1 Wealdstone (a.e.t.) [p 3–4] → Winner: Wealdstone
# Day 87 | FA Cup | Cheltenham 2–0 Accrington ST → Winner: Cheltenham
# Day 87 | FA Cup | Solihull Moors 0–1 Stockport County → Winner: Stockport County
#
# === STEP 118: Play Cup Round ===
# Day 88 | FA Cup | Bradford 0–3 Burton Albion → Winner: Burton Albion
#
# === STEP 119: Play League Matches ===
#
# Matches played on 2024-12-03:
# Premier League
# Wolves 2 - 0 Burnley
# Luton 2 - 2 Arsenal
#
# === STEP 120: Play Cup Round ===
# Day 89 | FA Cup | Oldham 0–1 Maidstone Utd (a.e.t.) → Winner: Maidstone Utd
#
# === STEP 121: Play League Matches ===
#
# Matches played on 2024-12-04:
# Premier League
# Manchester United 2 - 0 Chelsea
# Aston Villa 3 - 1 Manchester City
# Sheffield Utd 0 - 2 Liverpool
# Crystal Palace 0 - 1 Bournemouth
# Brighton 1 - 1 Brentford
# Fulham 2 - 0 Nottingham Forest
# Europa League
# BSC Young Boys 2 - 0 Real Betis
#
# === STEP 122: Play League Matches ===
#
# Matches played on 2024-12-05:
# Premier League
# Tottenham 1 - 1 West Ham
# Everton 1 - 1 Newcastle
#
# === STEP 123: Play League Matches ===
#
# Matches played on 2024-12-13:
# Championship
# Coventry 1 - 0 Birmingham
#
# === STEP 124: Play League Matches ===
#
# Matches played on 2024-12-14:
# Premier League
# Wolves 2 - 1 Nottingham Forest
# Crystal Palace 0 - 2 Liverpool
# Manchester United 2 - 0 Bournemouth
# Aston Villa 1 - 1 Arsenal
# Sheffield Utd 1 - 2 Brentford
# Brighton 2 - 0 Burnley
# Championship
# Sunderland 1 - 1 West Brom
# Huddersfield 0 - 1 Bristol City
# Watford 2 - 0 Southampton
# Cardiff 0 - 0 Millwall
# Leicester 1 - 0 Plymouth
# Middlesbrough 1 - 0 Ipswich
# Norwich 1 - 0 Preston
# QPR 0 - 0 Hull City
# Rotherham 2 - 3 Swansea
# Stoke City 1 - 0 Sheffield Wednesday
# Blackburn 1 - 2 Leeds
# League One
# Peterborough 2 - 0 Oxford United
# Burton Albion 2 - 1 Stevenage
# Wigan 0 - 0 Lincoln
# Reading 1 - 1 Barnsley
# Northampton 1 - 1 Fleetwood Town
# Leyton Orient 1 - 1 Derby
# Exeter City 1 - 0 Port Vale
# Wycombe 3 - 0 Shrewsbury
# Blackpool 3 - 0 Carlisle
# Bristol Rovers 2 - 0 Cheltenham
# Charlton 1 - 1 Cambridge United
# League Two
# Tranmere 1 - 0 Newport County
# Notts County 2 - 0 Walsall
# Morecambe 2 - 0 Stockport County
# Grimsby 3 - 3 Crewe
# Colchester 0 - 0 Crawley Town
# Accrington ST 1 - 0 Doncaster
# AFC Wimbledon 2 - 0 Swindon Town
#
# === STEP 125: Play League Matches ===
#
# Matches played on 2024-12-08:
# Premier League
# Everton 0 - 1 Chelsea
# Fulham 2 - 0 West Ham
# Luton 1 - 4 Manchester City
# Tottenham 0 - 2 Newcastle
#
# === STEP 126: Play League Matches ===
#
# Matches played on 2024-12-09:
# League One
# Portsmouth 0 - 2 Bolton
#
# === STEP 127: Play League Matches ===
#
# Matches played on 2024-12-10:
# Championship
# Huddersfield 1 - 0 Preston
# Watford 0 - 0 Ipswich
# Rotherham 0 - 1 West Brom
# Stoke City 0 - 1 Swansea
# Sunderland 1 - 1 Leeds
# Blackburn 5 - 1 Bristol City
# League One
# Reading 2 - 0 Oxford United
# Champions League
# Borussia Dortmund 2 - 1 Real Madrid
# BSC Young Boys 0 - 1 Paris Saint Germain
# AC Milan 0 - 1 Benfica
# Manchester City 1 - 0 Union Berlin
# Lazio 0 - 1 Bayern Munich
# Newcastle 4 - 1 Ajax
# Sevilla 0 - 1 Arsenal
# Antwerp 0 - 1 SC Braga
#
# === STEP 128: Play Cup Round ===
# Day 96 | FA Cup | Bristol Rovers 3–0 Swindon Town → Winner: Bristol Rovers
# Day 96 | FA Cup | Fleetwood Town 2–0 Salford City → Winner: Fleetwood Town
#
# === STEP 129: Update Cup Status ===
# Day 85 | FA Cup | Knocked out: AFC Fylde → inFA = False
# Day 85 | FA Cup | Knocked out: Portsmouth → inFA = False
# Day 86 | FA Cup | Knocked out: Gillingham → inFA = False
# Day 86 | FA Cup | Knocked out: Chesham United → inFA = False
# Day 86 | FA Cup | Knocked out: Charlton → inFA = False
# Day 86 | FA Cup | Knocked out: Morecambe → inFA = False
# Day 86 | FA Cup | Knocked out: Newport County → inFA = False
# Day 86 | FA Cup | Knocked out: Leyton Orient → inFA = False
# Day 86 | FA Cup | Knocked out: Marine → inFA = False
# Day 86 | FA Cup | Knocked out: Peterborough → inFA = False
# Day 86 | FA Cup | Knocked out: Notts County → inFA = False
# Day 86 | FA Cup | Knocked out: Scarborough Athletic → inFA = False
# Day 87 | FA Cup | Knocked out: Barrow → inFA = False
# Day 87 | FA Cup | Knocked out: Wrexham → inFA = False
# Day 87 | FA Cup | Knocked out: Accrington ST → inFA = False
# Day 87 | FA Cup | Knocked out: Solihull Moors → inFA = False
# Day 88 | FA Cup | Knocked out: Bradford → inFA = False
# Day 89 | FA Cup | Knocked out: Oldham → inFA = False
# Day 96 | FA Cup | Knocked out: Swindon Town → inFA = False
# Day 96 | FA Cup | Knocked out: Salford City → inFA = False
#
# === STEP 130: Play League Matches ===
#
# Matches played on 2024-12-11:
# Championship
# Middlesbrough 1 - 0 Hull City
# Cardiff 0 - 1 Birmingham
# Leicester 0 - 2 Millwall
# Norwich 2 - 1 Sheffield Wednesday
# QPR 1 - 0 Plymouth
# Coventry 2 - 1 Southampton
# Champions League
# Barcelona 2 - 0 Feyenoord
# Red Star Belgrade 1 - 1 Celtic
# PSV Eindhoven 2 - 0 Lens
# RB Leipzig 0 - 1 Real Sociedad
# Inter 1 - 1 FC Copenhagen
# Atletico Madrid 4 - 0 FC Porto
# Red Bull Salzburg 1 - 1 Manchester United
# Galatasaray 1 - 1 Napoli
#
# === STEP 131: Play League Matches ===
#
# Matches played on 2024-12-12:
# Europa League
# Sparta Praha 1 - 2 Brighton
# AEK Athens FC 2 - 1 Atalanta
# Marseille 1 - 0 Liverpool
# SC Freiburg 1 - 0 Shakhtar Donetsk
# Panathinaikos 0 - 0 Slavia Praha
# Lask Linz 2 - 2 Rennes
# Bayer Leverkusen 1 - 0 Sporting CP
# Aston Villa 2 - 1 Villarreal
# Toulouse 1 - 0 Servette FC
# TSC Backa Topola 3 - 1 BK Hacken
# Aris Limassol 2 - 1 AS Roma
# Qarabag 1 - 0 Real Betis
# Rangers 2 - 0 Tottenham
# Sturm Graz 2 - 0 Sheriff Tiraspol
# Olympiacos 0 - 1 Union St. Gilloise
# Maccabi Haifa 2 - 0 Molde
#
# === STEP 132: Play League Matches ===
#
# Matches played on 2024-12-20:
# Premier League
# Nottingham Forest 0 - 2 Tottenham
#
# === STEP 133: Play League Matches ===
#
# Matches played on 2024-12-21:
# Premier League
# Burnley 0 - 0 Everton
# Manchester City 1 - 0 Crystal Palace
# Newcastle 2 - 0 Fulham
# Chelsea 2 - 0 Sheffield Utd
# Championship
# Ipswich 2 - 1 Norwich
# Bristol City 1 - 1 Sunderland
# Southampton 1 - 1 Blackburn
# Millwall 2 - 0 Huddersfield
# Preston 2 - 2 Watford
# Leeds 3 - 0 Coventry
# Hull City 1 - 0 Cardiff
# Plymouth 0 - 1 Rotherham
# Sheffield Wednesday 0 - 1 QPR
# Swansea 2 - 2 Middlesbrough
# League One
# Lincoln 2 - 1 Reading
# Cheltenham 3 - 0 Leyton Orient
# Carlisle 1 - 1 Northampton
# Stevenage 1 - 0 Exeter City
# Shrewsbury 0 - 1 Portsmouth
# Port Vale 0 - 2 Wigan
# Oxford United 2 - 1 Burton Albion
# Fleetwood Town 2 - 2 Peterborough
# Barnsley 2 - 0 Charlton
# Derby 0 - 2 Wycombe
# Bolton 0 - 2 Bristol Rovers
# Cambridge United 0 - 3 Blackpool
# League Two
# Walsall 2 - 3 Tranmere
# Gillingham 0 - 2 Bradford
# Milton Keynes Dons 1 - 1 Forest Green
# Swindon Town 1 - 0 Barrow
# Doncaster 1 - 2 Morecambe
# Crawley Town 1 - 1 Mansfield Town
# Crewe 1 - 3 Accrington ST
# Newport County 0 - 1 Grimsby
# Stockport County 2 - 0 Sutton Utd
# Wrexham 2 - 0 Colchester
# Salford City 2 - 0 AFC Wimbledon
# Harrogate Town 3 - 1 Notts County
# National League
# Gateshead 0 - 0 FC Halifax Town
# Rochdale 2 - 0 York
# Solihull Moors 2 - 2 Oldham
# Maidenhead 0 - 1 Kidderminster Harriers
# Ebbsfleet United 1 - 3 Barnet
# Altrincham 1 - 1 AFC Fylde
# Dorking Wanderers 2 - 2 Woking
# Boreham Wood 5 - 0 Oxford City
# Dagenham & Redbridge 1 - 1 Wealdstone
# Hartlepool 1 - 3 Chesterfield
# Southend 2 - 0 Bromley
# Aldershot Town 1 - 2 Eastleigh
#
# === STEP 134: Play League Matches ===
#
# Matches played on 2024-12-15:
# Premier League
# Liverpool 2 - 1 Manchester United
# Brentford 1 - 2 Aston Villa
# West Ham 1 - 1 Wolves
# Arsenal 2 - 1 Brighton
# Championship
# West Brom 0 - 0 Stoke City
#
# === STEP 135: Play League Matches ===
#
# Matches played on 2024-12-16:
# Championship
# Birmingham 1 - 2 Leicester
#
# === STEP 136: End CL Groups ===
#
# 🏆 UCL Round of 16 (two-legged) drawn:
#   Match 01: Leg1 (day 152) Borussia Dortmund vs Lazio; Leg2 (day 172) Lazio vs Borussia Dortmund
#   Match 02: Leg1 (day 153) Manchester City vs SC Braga; Leg2 (day 173) SC Braga vs Manchester City
#   Match 03: Leg1 (day 159) Bayern Munich vs Red Bull Salzburg; Leg2 (day 179) Red Bull Salzburg vs Bayern Munich
#   Match 04: Leg1 (day 160) Arsenal vs Feyenoord; Leg2 (day 180) Feyenoord vs Arsenal
#   Match 05: Leg1 (day 152) Barcelona vs FC Copenhagen; Leg2 (day 172) FC Copenhagen vs Barcelona
#   Match 06: Leg1 (day 153) Real Sociedad vs Real Madrid; Leg2 (day 173) Real Madrid vs Real Sociedad
#   Match 07: Leg1 (day 159) Atletico Madrid vs RB Leipzig; Leg2 (day 179) RB Leipzig vs Atletico Madrid
#   Match 08: Leg1 (day 160) Manchester United vs Benfica; Leg2 (day 180) Benfica vs Manchester United
#
# === STEP 137: End EL Groups ===
#
# 🏆 Europa League Knockout Play-offs (two-legged):
#   Match 01: Leg1 (day 154) Brighton vs Inter; Leg2 (day 161) Inter vs Brighton
#   Match 02: Leg1 (day 154) Marseille vs Napoli; Leg2 (day 161) Napoli vs Marseille
#   Match 03: Leg1 (day 154) Rennes vs PSV Eindhoven; Leg2 (day 161) PSV Eindhoven vs Rennes
#   Match 04: Leg1 (day 154) Aston Villa vs AC Milan; Leg2 (day 161) AC Milan vs Aston Villa
#   Match 05: Leg1 (day 154) Servette FC vs Ajax; Leg2 (day 161) Ajax vs Servette FC
#   Match 06: Leg1 (day 154) Qarabag vs Sevilla; Leg2 (day 161) Sevilla vs Qarabag
#   Match 07: Leg1 (day 154) Tottenham vs Paris Saint Germain; Leg2 (day 161) Paris Saint Germain vs Tottenham
#   Match 08: Leg1 (day 154) Maccabi Haifa vs Celtic; Leg2 (day 161) Celtic vs Maccabi Haifa
#
# === STEP 138: Play Cup Round ===
# Day 103 | League Cup | West Brom 0–1 Manchester United → Winner: Manchester United
# Day 103 | League Cup | Bristol City 0–1 Brighton → Winner: Brighton
# Day 103 | League Cup | Millwall 0–1 Manchester City → Winner: Manchester City
# Day 104 | League Cup | Chelsea 0–1 Bournemouth → Winner: Bournemouth
#
# === STEP 139: Update Cup Status ===
# Day 103 | League Cup | Knocked out: West Brom → inLC = False
# Day 103 | League Cup | Knocked out: Bristol City → inLC = False
# Day 103 | League Cup | Knocked out: Millwall → inLC = False
# Day 104 | League Cup | Knocked out: Chelsea → inLC = False
#
# === Reached step 139. Stopped. Current pointer: 139 ===

# %% [markdown]
# ### Still in Cup

# %%
eligible_teams = dfTeams[dfTeams['inLC'] == True].copy()
print(len(eligible_teams))
pd.set_option('display.max_rows', None)
eligible_teams
# Out:
# 4
#     teamID           teamName  lastPos nationality   inFA  inLC   inCS   inEL  \
# 2        3        Bournemouth       15         ENG  False  True  False  False
# 4        5           Brighton        6         ENG  False  True  False   True
# 12      13    Manchester City        1         ENG  False  True   True  False
# 13      14  Manchester United        3         ENG  False  True  False  False
#
#      inCL  faCupWin  lcCupWin  elCupWin  clCupWin  defense  midfield  attack
# 2   False     False     False     False     False     7.75      7.60    6.91
# 4   False     False     False     False     False     7.82      7.81    7.43
# 12   True     False     False     False     False     7.97      8.84    8.35
# 13   True     False     False     False     False     8.61      8.52    8.91

# %% [markdown]
# ### Print League Tables

# %%
print_all_league_tables(league_tables, dfCompetitions)

# %%
print_euro_group_tables(8, dfTeams, dfFixtures, dfGroupStage)

# %%
clgames = dfFixtures[dfFixtures['competitionID'] == 7].copy()

# %%
pd.set_option('display.max_rows', None)
print(len(clgames))
clgames
